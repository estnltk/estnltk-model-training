# %% [markdown]
# ## Entity separation

# %% [markdown]
# This notebook takes the CSV file from the previous step and separates the data into three
# CSV-s: one for singletons (entities with just one word), one for the first words
# (all but the last word of multiword entities) and one for the last words (last
# word of multiword entities)

# %%
import pandas as pd
ner_counts = pd.read_csv('ner_counts_5000_lemmas.csv')

# %%
ner_counts[:10]
# Out:
#    Unnamed: 0                entity label  entity_count
# 0           0  ('Aive', 'Lauriste')   PER             2
# 1           1           ('Eminem',)   PER            19
# 2           2    ('Mathers', 'III')   PER             1
# 3           3     ('Slim', 'Shady')   PER             1
# 4           4           ('People',)   ORG             1
# 5           5           ('Hailie',)   PER             2
# 6           6             ('Mile',)   LOC             1
# 7           7    ('Jimmy', 'Smith')   PER             1
# 8           8          ('Detroit',)   LOC            14
# 9           9            ('Jimmy',)   PER             7

# %% [markdown]
# Separate the entites to three

# %%
singletons_map = {}
last_word_map = {}
first_words_map = {}

import ast 

for row in ner_counts.itertuples():
    entity = ast.literal_eval(row.entity)
    if len(entity) == 1:
        curr_map = singletons_map.get(entity,{})
        curr_count = curr_map.get(row.label,0) 
        curr_map[row.label] = row.entity_count + curr_count
        singletons_map[entity] = curr_map
    else:
        last_word = entity[-1]
        curr_map = last_word_map.get(last_word,{})
        curr_count = curr_map.get(row.label,0) 
        curr_map[row.label] = curr_count + row.entity_count
        last_word_map[last_word] = curr_map
        
        first_words = entity[:-1]
        curr_map = first_words_map.get(first_words,{})
        curr_count = curr_map.get(row.label,0) 
        curr_map[row.label] = row.entity_count + curr_count
        first_words_map[first_words] = curr_map

# %%
singletons_map
# Out:
# {('Eminem',): {'PER': 19},
#  ('People',): {'ORG': 1, 'PER': 2},
#  ('Hailie',): {'PER': 2},
#  ('Mile',): {'LOC': 1},
#  ('Detroit',): {'LOC': 14, 'ORG': 4},
#  ('Jimmy',): {'PER': 7},
#  ('Ameerika',): {'LOC': 294},
#  ('Jimmyl',): {'PER': 1},
#  ('Grazer',): {'PER': 1},
#  ('Hanson',): {'PER': 13, 'ORG': 1},
#  ('Hollywood',): {'LOC': 39},
#  ('STING',): {'ORG': 1, 'PER': 1},
#  ('Sting',): {'PER': 32},
#  ('Trudie',): {'PER': 16},
#  ('Lock',): {'PER': 1},
#  ('Ritchiele',): {'PER': 1},
#  ('Coco',): {'PER': 1},
#  ('Giacomo',): {'PER': 1},
#  ('Mickey',): {'PER': 1},
#  ('Jake',): {'PER': 1},
#  ('Worcestershire',): {'LOC': 1},
#  ('Stingi-Tomelty',): {'LOC': 1},
#  ('Styleri-Tomelty',): {'LOC': 1},
#  ('Paul',): {'PER': 7},
#  ('Stella',): {'PER': 1},
#  ('Stingi',): {'PER': 3},
#  ('Versace',): {'PER': 1},
#  ('Universal',): {'ORG': 2, 'PER': 1},
#  ('Evelin',): {'PER': 30},
#  ('Alternature',): {'PER': 3},
#  ('Pajusaar',): {'PER': 3},
#  ('Euroopa',): {'LOC': 920},
#  ('EBS',): {'ORG': 4, 'LOC': 1},
#  ('Universa',): {'ORG': 1},
#  ('Eesti',): {'LOC': 6355},
#  ('Maarja',): {'LOC': 20, 'PER': 12, 'ORG': 1},
#  ('Oslo',): {'LOC': 6},
#  ('Norra',): {'LOC': 139},
#  ('Priit',): {'PER': 5},
#  ('Glen',): {'PER': 1},
#  ('Timmo',): {'PER': 1},
#  ('Padar',): {'LOC': 8, 'PER': 35},
#  ('Hiina',): {'LOC': 208},
#  ('Kallas',): {'PER': 47},
#  ('Jaan',): {'PER': 77, 'LOC': 1},
#  ('Kadri',): {'PER': 10},
#  ('Joosep',): {'PER': 17},
#  ('Jaanus',): {'PER': 47},
#  ('Siira',): {'LOC': 1},
#  ('kadri',): {'PER': 1},
#  ('Tallinn',): {'LOC': 1947, 'ORG': 20},
#  ('Tartu',): {'LOC': 892, 'PER': 1},
#  ('Lucifer',): {'PER': 1},
#  ('Gerundija',): {'ORG': 1},
#  ('Kaspar',): {'PER': 6},
#  ('Igor',): {'PER': 51},
#  ('Kasparile',): {'PER': 1},
#  ('Rootsi',): {'LOC': 448},
#  ('Maret',): {'PER': 7},
#  ('Collins',): {'PER': 18},
#  ('Percy',): {'PER': 1},
#  ('Gibson',): {'PER': 2},
#  ('USA',): {'LOC': 959},
#  ('London',): {'LOC': 88, 'PER': 2},
#  ('Collinsile',): {'PER': 2},
#  ('Gibsonile',): {'PER': 1},
#  ('Maie',): {'PER': 2},
#  ('Valdur',): {'PER': 2},
#  ('Haavel',): {'PER': 1},
#  ('Ukraina',): {'LOC': 160},
#  ('Petrovka',): {'LOC': 1},
#  ('Krimm',): {'LOC': 25},
#  ('Kiiev',): {'LOC': 14},
#  ('Harkov',): {'LOC': 1},
#  ('Poltava',): {'LOC': 1},
#  ('Lvov',): {'LOC': 4},
#  ('Odessa',): {'LOC': 1},
#  ('Läti',): {'LOC': 453},
#  ('Leedu',): {'LOC': 329},
#  ('Pervomaisk',): {'LOC': 1},
#  ('Beregovoje',): {'LOC': 1},
#  ('Abhaasia',): {'LOC': 19},
#  ('Põhja-Ameerika',): {'LOC': 23},
#  ('Siber',): {'LOC': 31},
#  ('Estonkas',): {'ORG': 1},
#  ('Estonka',): {'ORG': 1},
#  ('riigikogu',): {'ORG': 1291},
#  ('maksuamet',): {'ORG': 73},
#  ('maarjamaa',): {'LOC': 14},
#  ('Estonia',): {'ORG': 90, 'LOC': 4},
#  ('Veritas',): {'PER': 1},
#  ('Titanic',): {'PER': 4, 'LOC': 1},
#  ('Brit',): {'LOC': 75, 'PER': 2, 'ORG': 1},
#  ('Derbyshire',): {'ORG': 2, 'LOC': 1},
#  ('Meri',): {'PER': 48},
#  ('Fairplay',): {'ORG': 1},
#  ('Inglismaa',): {'LOC': 170},
#  ('Soome',): {'LOC': 730},
#  ('Läänemeri',): {'LOC': 68},
#  ('saksa',): {'LOC': 51},
#  ('Atlandi',): {'ORG': 7, 'PER': 2, 'LOC': 1},
#  ('Solas',): {'ORG': 1},
#  ('Leedo',): {'PER': 31},
#  ('Regula',): {'PER': 1},
#  ('Ofelia',): {'PER': 3, 'LOC': 1, 'ORG': 1},
#  ('Hiiumaa',): {'LOC': 78},
#  ('Saaremaa',): {'LOC': 131, 'ORG': 1},
#  ('Vormsi',): {'LOC': 9, 'PER': 2, 'ORG': 1},
#  ('RAS',): {'ORG': 2},
#  ('Nautex',): {'PER': 1},
#  ('paluma',): {'PER': 14},
#  ('Peeter',): {'PER': 21},
#  ('Leedog',): {'ORG': 1},
#  ('Nautexi',): {'PER': 1},
#  ('Kuivastu-Virtsu',): {'LOC': 4},
#  ('Riigikogu',): {'ORG': 297},
#  ('Stockholm',): {'LOC': 63},
#  ('EMSA',): {'ORG': 3},
#  ('Lember',): {'PER': 5},
#  ('Leedol',): {'PER': 1},
#  ('Läänemaa',): {'LOC': 94},
#  ('järvesoo',): {'PER': 1},
#  ('Maapank',): {'ORG': 34},
#  ('Eenmaa',): {'LOC': 6, 'PER': 19},
#  ('Harjumaa',): {'LOC': 67},
#  ('Tartumaa',): {'LOC': 31},
#  ('Estis',): {'PER': 1},
#  ('Rakvere',): {'LOC': 102},
#  ('Ärikas',): {'PER': 1},
#  ('Eestimaa',): {'LOC': 75},
#  ('Lurich',): {'ORG': 2},
#  ('palusalu',): {'PER': 22, 'LOC': 2},
#  ('Venemaa',): {'LOC': 1110},
#  ('Kristjan',): {'PER': 16},
#  ('Berliin',): {'LOC': 74},
#  ('Führer',): {'PER': 1},
#  ('KGB',): {'ORG': 34},
#  ('Hololei',): {'PER': 10},
#  ('NLKP',): {'ORG': 8},
#  ('Koigi',): {'LOC': 2},
#  ('Rooma',): {'LOC': 53, 'PER': 3},
#  ('nõukogu',): {'LOC': 32, 'ORG': 2, 'PER': 1},
#  ('Koik',): {'PER': 1},
#  ('Julia',): {'PER': 10},
#  ('Seewald',): {'PER': 1, 'ORG': 1, 'LOC': 1},
#  ('Annika',): {'ORG': 1, 'PER': 5},
#  ('Ain',): {'PER': 8},
#  ('Alar',): {'PER': 6},
#  ('Karin',): {'PER': 4},
#  ('Katrin',): {'PER': 33},
#  ('Kätlin',): {'PER': 1},
#  ('Kristel',): {'PER': 13},
#  ('Humanita',): {'LOC': 1},
#  ('Terje',): {'PER': 4},
#  ('THEATRUM',): {'ORG': 2},
#  ('VAT-teater',): {'ORG': 1},
#  ('M. Karusoo',): {'PER': 1},
#  ('jõhv',): {'LOC': 19},
#  ('Laekvere',): {'LOC': 1},
#  ('Türi',): {'LOC': 27},
#  ('Rapla',): {'LOC': 36},
#  ('Vändra',): {'LOC': 8},
#  ('Haapsalu',): {'LOC': 205},
#  ('Ahja',): {'LOC': 2},
#  ('Ruusa',): {'LOC': 2},
#  ('Kehtna',): {'LOC': 6},
#  ('Kohtla-Järve',): {'LOC': 48},
#  ('Suure-Jaan',): {'LOC': 2, 'ORG': 1},
#  ('Kiviõli',): {'LOC': 13},
#  ('Maardu',): {'LOC': 17, 'PER': 1},
#  ('Haljala',): {'LOC': 2},
#  ('Paide',): {'LOC': 16, 'PER': 1, 'ORG': 1},
#  ('Järvakandi',): {'LOC': 3},
#  ('Viimsi',): {'LOC': 16},
#  ('Lihula',): {'LOC': 30},
#  ('Koeru',): {'LOC': 2},
#  ('Endla',): {'PER': 14, 'LOC': 5, 'ORG': 2},
#  ('Vanalinnastuudio',): {'PER': 1},
#  ('M. Kivastik',): {'LOC': 1},
#  ('Tõnu',): {'PER': 10},
#  ('Ugala',): {'LOC': 4, 'PER': 2},
#  ('Sisul',): {'PER': 1},
#  ('Vanemuine',): {'ORG': 45, 'LOC': 1, 'PER': 1},
#  ('Kruusvall',): {'LOC': 1},
#  ('Kivirähu',): {'ORG': 1},
#  ('Karusoo',): {'PER': 1},
#  ('Kall',): {'PER': 1},
#  ('Kivastik',): {'ORG': 1},
#  ('Unt',): {'PER': 5},
#  ('Ibsen',): {'PER': 5, 'LOC': 1},
#  ('Gogoli',): {'PER': 1},
#  ('Moliere',): {'PER': 1},
#  ('Shakespeare',): {'ORG': 1, 'PER': 1, 'LOC': 4},
#  ('Pushkin',): {'PER': 2},
#  ('Shaw',): {'PER': 1},
#  ('Brecht',): {'PER': 1},
#  ('Miller',): {'PER': 8, 'ORG': 2},
#  ('Giraudoux',): {'PER': 1},
#  ('T. Stoppart',): {'PER': 1},
#  ('Priestley',): {'PER': 1},
#  ('P',): {'ORG': 4, 'LOC': 3, 'PER': 13},
#  ('Shaffer',): {'PER': 1},
#  ('Kanada',): {'LOC': 81},
#  ('Austria',): {'LOC': 96, 'PER': 1},
#  ('Island',): {'LOC': 31},
#  ('Greenpeace',): {'ORG': 2},
#  ('Hamburg',): {'LOC': 20},
#  ('Antwerpen',): {'LOC': 1},
#  ('Liverpool',): {'LOC': 3, 'ORG': 9},
#  ('Rhein',): {'LOC': 1},
#  ('Jaapan',): {'LOC': 159},
#  ('Ennustusi',): {'PER': 1},
#  ('Shotimaa',): {'LOC': 7},
#  ('Taani',): {'LOC': 171},
#  ('Viljandi',): {'LOC': 136, 'ORG': 10, 'PER': 1},
#  ('Koidula',): {'PER': 3, 'LOC': 4},
#  ('Kreutzwald',): {'ORG': 4, 'PER': 2, 'LOC': 1},
#  ('Jakobson',): {'PER': 15, 'ORG': 1},
#  ('Abruka',): {'LOC': 10},
#  ('Vahane',): {'LOC': 1},
#  ('Vilsandi',): {'LOC': 13, 'ORG': 1},
#  ('Prangli',): {'LOC': 3},
#  ('Piirissaar',): {'LOC': 3, 'PER': 1},
#  ('Ruhnu',): {'ORG': 1, 'LOC': 21},
#  ('Roomassaar',): {'PER': 1, 'LOC': 6},
#  ('Kuramaa',): {'LOC': 5},
#  ('Sõrve',): {'LOC': 1},
#  ('Vesk',): {'PER': 7, 'LOC': 1},
#  ('Johannes',): {'PER': 10},
#  ('Kihnu',): {'LOC': 18, 'PER': 1},
#  ('Korsi',): {'PER': 1},
#  ('Mõisaküla',): {'LOC': 9},
#  ('Kuke',): {'PER': 18},
#  ('Jüri',): {'PER': 52, 'LOC': 1},
#  ('Albert',): {'PER': 13},
#  ('NKVD',): {'ORG': 5},
#  ('Merdik',): {'ORG': 1},
#  ('Ilison',): {'PER': 2},
#  ('Saks',): {'LOC': 113, 'PER': 5},
#  ('Meeta',): {'ORG': 4, 'PER': 1},
#  ('Abja',): {'LOC': 2},
#  ('Ants',): {'PER': 19},
#  ('TRÜ',): {'ORG': 4},
#  ('Jõers',): {'PER': 1},
#  ('Belomor',): {'LOC': 1},
#  ('Narva',): {'LOC': 159, 'ORG': 1},
#  ('Jõersile',): {'PER': 1},
#  ('Padise',): {'LOC': 6},
#  ('Kukk',): {'PER': 15, 'LOC': 2},
#  ('Prantsusmaa',): {'LOC': 329},
#  ('prantsuse',): {'LOC': 90},
#  ('TÜ',): {'ORG': 42},
#  ('Kesk-Aasia',): {'LOC': 4},
#  ('Past',): {'PER': 5},
#  ('Moskvitsh',): {'LOC': 2, 'ORG': 1},
#  ('Tamm',): {'PER': 24, 'LOC': 3, 'ORG': 1},
#  ('allsalu',): {'PER': 1},
#  ('Moskva',): {'LOC': 371},
#  ('Talur',): {'PER': 1},
#  ('ISR',): {'ORG': 4},
#  ('Harvard',): {'LOC': 4, 'PER': 3},
#  ('ETV',): {'ORG': 308},
#  ('Kagu-Aasia',): {'LOC': 11},
#  ('Türgi',): {'LOC': 92},
#  ('Y2K',): {'ORG': 1},
#  ('NATO',): {'ORG': 313},
#  ('Kosovo',): {'LOC': 76},
#  ('Jugoslaavia',): {'LOC': 83},
#  ('Serbia',): {'LOC': 30},
#  ('Belgrad',): {'LOC': 17},
#  ('Tshetsheenia',): {'LOC': 43},
#  ('kreml',): {'ORG': 6},
#  ('Kreml',): {'ORG': 33, 'LOC': 1},
#  ('riigiduuma',): {'ORG': 4},
#  ('Putin',): {'PER': 99},
#  ('Lääs',): {'LOC': 10},
#  ('Kaukaasia',): {'LOC': 9},
#  ('Lääne',): {'LOC': 88},
#  ('USA-Suurbritannia',): {'LOC': 1},
#  ('Iraak',): {'LOC': 262},
#  ('Clinton',): {'PER': 72},
#  ('Luub',): {'LOC': 1},
#  ('Luik',): {'PER': 28},
#  ('euroliit',): {'ORG': 13},
#  ('Spring',): {'PER': 1},
#  ('Jack',): {'PER': 2},
#  ('Külvet',): {'PER': 4},
#  ('Kalev',): {'ORG': 32, 'PER': 87, 'LOC': 2},
#  ('Lk',): {'ORG': 1},
#  ('Baldwin',): {'PER': 2},
#  ('Aafrika',): {'LOC': 46},
#  ('Arno',): {'PER': 14},
#  ('Slavoonia',): {'ORG': 1},
#  ('Stalin',): {'PER': 22},
#  ('Lubaduste',): {'PER': 1},
#  ('Külveti',): {'PER': 1},
#  ('ESTO',): {'ORG': 4},
#  ('Vene',): {'LOC': 362, 'PER': 2},
#  ('Baltikum',): {'LOC': 30},
#  ('Balti-Vene',): {'LOC': 1},
#  ('vene',): {'LOC': 109},
#  ('EL',): {'ORG': 253, 'LOC': 26, 'PER': 2},
#  ('Tatarstan',): {'LOC': 1},
#  ('Bashkortostan',): {'LOC': 1},
#  ('Javlinski',): {'PER': 1},
#  ('Jeltsin',): {'PER': 68},
#  ('lääs',): {'LOC': 4},
#  ('Gumiljov',): {'PER': 1, 'LOC': 1},
#  ('Krasnojarsk',): {'LOC': 5},
#  ('Poola',): {'LOC': 274},
#  ('Varssavi',): {'LOC': 24},
#  ('Brezhnev',): {'PER': 5},
#  ('FSB',): {'ORG': 11},
#  ('Rumeenia',): {'LOC': 52},
#  ('Petrovitsh',): {'LOC': 1},
#  ('Petrovna',): {'LOC': 1},
#  ('Uzhin',): {'PER': 1},
#  ('Koshkina',): {'LOC': 1},
#  ('Baltimaa',): {'LOC': 54},
#  ('Prishtina',): {'LOC': 1},
#  ('Andrei',): {'PER': 47},
#  ('Piontkovski',): {'PER': 1},
#  ('Jevgeni',): {'PER': 7},
#  ('Eesti-Vene',): {'LOC': 22},
#  ('Kristin',): {'PER': 3},
#  ('Kristi',): {'PER': 46, 'LOC': 1},
#  ('Pärnamägi',): {'LOC': 1},
#  ('Pirita',): {'LOC': 72, 'PER': 20},
#  ('Daum',): {'PER': 2},
#  ('Nielsen',): {'PER': 11},
#  ('Võrumaa',): {'LOC': 46},
#  ('Skandinaavia',): {'LOC': 26},
#  ('kosk',): {'LOC': 3},
#  ('Saksamaa',): {'LOC': 463},
#  ('Schubert',): {'PER': 2},
#  ('Ida-Virumaa',): {'LOC': 61},
#  ('RAM',): {'ORG': 3},
#  ('Tõnissoo',): {'PER': 1},
#  ('Raplamaa',): {'LOC': 22},
#  ('Villand',): {'PER': 1},
#  ('Pärnamäe',): {'PER': 3},
#  ('Rahumägi',): {'LOC': 3},
#  ('Liiva',): {'LOC': 2, 'PER': 2},
#  ('pärnamägi',): {'LOC': 4},
#  ('Väino',): {'PER': 6},
#  ('Kisler',): {'PER': 1},
#  ('Down',): {'ORG': 2, 'PER': 1},
#  ('PE',): {'ORG': 5, 'LOC': 6},
#  ('CMP',): {'ORG': 3},
#  ('CFG',): {'ORG': 5, 'LOC': 1},
#  ('E',): {'ORG': 7, 'PER': 1},
#  ('PE1-PEn',): {'ORG': 1},
#  ('ARB',): {'ORG': 1},
#  ('MDT',): {'ORG': 1},
#  ('Andmeskalaarne',): {'PER': 2},
#  ('MMM',): {'ORG': 1},
#  ('protsessor',): {'PER': 1},
#  ('talitlus',): {'ORG': 1},
#  ('PÜ',): {'ORG': 10},
#  ('PÜ1-PÜ4',): {'ORG': 1},
#  ('CPU',): {'ORG': 2},
#  ('GB',): {'ORG': 1},
#  ('SMEM',): {'ORG': 1},
#  ('Icmem',): {'ORG': 1},
#  ('CMEM',): {'ORG': 1},
#  ('RMEM',): {'ORG': 2},
#  ('PÜ2',): {'ORG': 3},
#  ('PÜ1',): {'ORG': 2},
#  ('ANSI',): {'ORG': 1},
#  ('SCI',): {'ORG': 1},
#  ('IRAM',): {'ORG': 1},
#  ('Võru',): {'LOC': 78},
#  ('Valga',): {'LOC': 183, 'ORG': 1},
#  ('Toronto',): {'LOC': 11, 'ORG': 10, 'PER': 1},
#  ('RT',): {'ORG': 7, 'PER': 167},
#  ('Riia',): {'LOC': 132, 'ORG': 3},
#  ('Latvia',): {'LOC': 2},
#  ('Levišauskaite',): {'ORG': 1},
#  ('Kaupelyte',): {'PER': 1},
#  ('Leie',): {'ORG': 1},
#  ('HLÜ',): {'ORG': 20},
#  ('BIG',): {'ORG': 1},
#  ('Silberg',): {'PER': 1},
#  ('Pärnu',): {'LOC': 362, 'PER': 2, 'ORG': 5},
#  ('Põlva',): {'LOC': 33},
#  ('OKO',): {'ORG': 1},
#  ('Kedzierski',): {'PER': 1},
#  ('Sõrg',): {'PER': 9},
#  ('Einola',): {'PER': 1},
#  ('põllumajandusministeerium',): {'ORG': 33},
#  ('Salomo',): {'PER': 1},
#  ('EMOR',): {'ORG': 17},
#  ('Dubroff',): {'PER': 1},
#  ('Addams',): {'PER': 1},
#  ('Blank',): {'ORG': 1},
#  ('I. Hannula',): {'PER': 1},
#  ('taliolümpia',): {'ORG': 1},
#  ('Helsingi',): {'LOC': 161, 'PER': 1},
#  ('Peetrus',): {'PER': 1},
#  ('Nada',): {'PER': 5},
#  ('CompuMedia',): {'LOC': 1},
#  ('Dallas',): {'ORG': 18, 'PER': 6},
#  ('Mars',): {'LOC': 12},
#  ('NetWebis',): {'ORG': 1},
#  ('NADA',): {'ORG': 1},
#  ('Quebec',): {'LOC': 1},
#  ('ÜRO',): {'ORG': 119},
#  ('Now',): {'ORG': 1},
#  ('Finnair',): {'PER': 6, 'LOC': 5, 'ORG': 1},
#  ('Kitzmantel',): {'PER': 1},
#  ('siseministeerium',): {'ORG': 49},
#  ('Pikaro',): {'PER': 36},
#  ('kaitseministeerium',): {'ORG': 45},
#  ('Price',): {'PER': 1},
#  ('Shell',): {'ORG': 12},
#  ('Najibullah',): {'PER': 1},
#  ('Afganistan',): {'LOC': 83},
#  ('Guldara',): {'LOC': 1},
#  ('Kabul',): {'LOC': 11},
#  ('Pakistan',): {'LOC': 49},
#  ('Iraan',): {'LOC': 71},
#  ('Ühendemiraat',): {'LOC': 1},
#  ('Taliban',): {'ORG': 16},
#  ('Ladeni',): {'PER': 1},
#  ('Araabia',): {'LOC': 15},
#  ('India',): {'LOC': 56, 'ORG': 9, 'PER': 3},
#  ('Kandahar',): {'LOC': 6},
#  ('Najib',): {'PER': 1},
#  ('Stinger',): {'PER': 1},
#  ('Beck',): {'PER': 5},
#  ('Dunlap',): {'LOC': 5},
#  ('Christopher',): {'PER': 3},
#  ('Becki',): {'PER': 1},
#  ('Nõukogu',): {'LOC': 59},
#  ('Århus',): {'LOC': 3},
#  ('Natura',): {'ORG': 2},
#  ('Põhja-Euroobas',): {'LOC': 7},
#  ('Emajõgi',): {'LOC': 30},
#  ('Põhjamaa',): {'LOC': 56},
#  ('Tähtvere',): {'LOC': 9},
#  ('Kopenhaagen',): {'LOC': 33},
#  ('Joensuu',): {'LOC': 2},
#  ('Ó',): {'ORG': 1},
#  ('Th',): {'ORG': 1},
#  ('Bartholin',): {'PER': 1},
#  ('Eggertsson',): {'PER': 2},
#  ('Novgorod',): {'LOC': 9},
#  ('P. Zetterberg',): {'PER': 1},
#  ('Lund',): {'LOC': 1},
#  ('Lõuna-Soome',): {'LOC': 5},
#  ('B',): {'LOC': 6, 'ORG': 13},
#  ('Zetterberg',): {'PER': 1},
#  ('Vagal',): {'PER': 1},
#  ('Sloveenia',): {'LOC': 47},
#  ('MDP',): {'ORG': 2},
#  ('Lääne-Virumaa',): {'LOC': 28},
#  ('Viitna',): {'LOC': 4},
#  ('Tallinna-Peterbur',): {'LOC': 1},
#  ('Reivart',): {'PER': 2},
#  ('Taivo',): {'PER': 2},
#  ('Eha',): {'PER': 1},
#  ('Kaire',): {'PER': 2},
#  ('Aare',): {'PER': 9},
#  ('Linask',): {'PER': 3},
#  ('Zhiguli',): {'LOC': 1, 'PER': 1},
#  ('Kalda',): {'PER': 3},
#  ('linask',): {'PER': 1},
#  ('Audil',): {'PER': 1},
#  ('Jaak-Kristjan',): {'PER': 1},
#  ('Põlvamaa',): {'LOC': 33},
#  ('Sulev',): {'PER': 8},
#  ('Andres',): {'PER': 34},
#  ('Järvamaa',): {'LOC': 43},
#  ('Pärnu-Rakvere',): {'LOC': 2},
#  ('Võru-Valga',): {'LOC': 2},
#  ('Heinola',): {'PER': 1},
#  ('BNS',): {'ORG': 199},
#  ('Robert',): {'PER': 9},
#  ('Jekaterina',): {'PER': 1},
#  ('Keila',): {'LOC': 39, 'PER': 1, 'ORG': 1},
#  ('Rein',): {'PER': 9, 'ORG': 5, 'LOC': 1},
#  ('Saare',): {'LOC': 9, 'PER': 12, 'ORG': 2},
#  ('Anna',): {'PER': 5},
#  ('Oleg',): {'PER': 10},
#  ('Radiolinja',): {'ORG': 4},
#  ('EMT',): {'ORG': 19},
#  ('Bns',): {'ORG': 21},
#  ('Balaton',): {'LOC': 2},
#  ('Bulgaaria',): {'LOC': 33},
#  ('Ida-Rumeenia',): {'LOC': 1},
#  ('Jaak',): {'PER': 14},
#  ('Sisask',): {'PER': 2},
#  ('Harry',): {'PER': 12},
#  ('Ungari',): {'LOC': 98},
#  ('Merkuur',): {'LOC': 2},
#  ('Maa',): {'PER': 2, 'LOC': 11},
#  ('Lõuna-Aafrika',): {'LOC': 15},
#  ('Austraalia',): {'LOC': 145},
#  ('Antarktika',): {'LOC': 13},
#  ('Põhja-Aafrika',): {'LOC': 1},
#  ('Kesk-Siber',): {'ORG': 1},
#  ('Kirde-Eest',): {'LOC': 4},
#  ('Wolf',): {'PER': 1},
#  ('Jupiter',): {'ORG': 1, 'LOC': 2},
#  ('Marss',): {'LOC': 1},
#  ('Newton',): {'PER': 3},
#  ('Einstein',): {'PER': 8},
#  ('Holland',): {'LOC': 100, 'ORG': 2, 'PER': 1},
#  ('Pluuto',): {'PER': 1},
#  ('Päike',): {'LOC': 1},
#  ('Kuu',): {'LOC': 7},
#  ('Meeus',): {'PER': 1},
#  ('Sõnumileht',): {'ORG': 39},
#  ('Sõnumilehe',): {'ORG': 1, 'PER': 2},
#  ('sõnumileht',): {'ORG': 29},
#  ('Postimees',): {'ORG': 176},
#  ('Hõbemägi',): {'PER': 8, 'LOC': 1},
#  ('õhtuleht',): {'ORG': 16},
#  ('Mõõdukas',): {'ORG': 62},
#  ('Lääne-Viru',): {'LOC': 9},
#  ('Historia',): {'PER': 2},
#  ('Kadriorg',): {'ORG': 66, 'LOC': 5},
#  ('B7',): {'ORG': 2},
#  ('Ahvenamaa',): {'LOC': 2},
#  ('Gotland',): {'LOC': 5},
#  ('Öland',): {'LOC': 6},
#  ('Bornholm',): {'LOC': 3},
#  ('EELK',): {'ORG': 12},
#  ('XXV',): {'ORG': 1},
#  ('raepress',): {'ORG': 16},
#  ('Nõmme',): {'LOC': 50, 'ORG': 3, 'PER': 4},
#  ('Keres',): {'PER': 2},
#  ('Kagu',): {'LOC': 1},
#  ('Telo',): {'ORG': 1},
#  ('Kägu',): {'LOC': 6},
#  ('Kalberg',): {'PER': 2},
#  ('kaitseliit',): {'ORG': 70},
#  ('Luzern',): {'LOC': 2},
#  ('Ottey',): {'PER': 4},
#  ('Kostov',): {'PER': 1},
#  ('Gruusia',): {'LOC': 60},
#  ('Gor',): {'LOC': 4},
#  ('Reuters',): {'ORG': 116},
#  ('Diana',): {'PER': 66},
#  ('Dome',): {'LOC': 1},
#  ('Mini',): {'PER': 1},
#  ('Interfax',): {'ORG': 18, 'PER': 1},
#  ('Morozov',): {'PER': 1},
#  ('Viru-Jaagup',): {'LOC': 2},
#  ('Oviir',): {'PER': 24},
#  ('WEU',): {'ORG': 3},
#  ('Luxembourg',): {'LOC': 10},
#  ('Solana',): {'PER': 2},
#  ('Cutileiro',): {'PER': 1},
#  ('Helilooja',): {'PER': 1},
#  ('Köln',): {'LOC': 8},
#  ('Veneetsia',): {'LOC': 11},
#  ('Lõuna-Saksale',): {'LOC': 1},
#  ('Dowland',): {'PER': 1},
#  ('Mederi',): {'ORG': 1},
#  ('Goebel',): {'PER': 1},
#  ('telemann',): {'PER': 1},
#  ('Ida-Euroobas',): {'LOC': 37},
#  ('Balt',): {'LOC': 23},
#  ('Vike-Freiberga',): {'PER': 4},
#  ('rahvaerakond',): {'ORG': 3},
#  ('seim',): {'ORG': 1},
#  ('Hispaania',): {'LOC': 206, 'PER': 1},
#  ('Rünne',): {'PER': 5},
#  ('Tammert',): {'PER': 18},
#  ('Nool',): {'PER': 53, 'ORG': 1},
#  ('Urmet',): {'PER': 1},
#  ('Siilats',): {'PER': 2},
#  ('Jane',): {'PER': 5},
#  ('päts',): {'PER': 3},
#  ('Laidoner',): {'PER': 2, 'ORG': 1},
#  ('Rei',): {'PER': 5},
#  ('Suurbritannia',): {'LOC': 155},
#  ('NSVL',): {'LOC': 4, 'ORG': 6},
#  ('Päts',): {'PER': 6, 'ORG': 2, 'LOC': 1},
#  ('Vitali',): {'PER': 7},
#  ('Epl',): {'PER': 111},
#  ('Lääne-Euroobas',): {'LOC': 29},
#  ('Draganov',): {'PER': 2},
#  ('Primakov',): {'PER': 8},
#  ('Segodnja',): {'ORG': 4, 'PER': 1},
#  ('Itaalia',): {'LOC': 289},
#  ('Foggia',): {'LOC': 1},
#  ('Makedoonia',): {'LOC': 19},
#  ('VMRO',): {'ORG': 1},
#  ('Egypt-Air',): {'LOC': 1},
#  ('Tai',): {'LOC': 48},
#  ('Reformierakond',): {'ORG': 231},
#  ('Sukles',): {'PER': 11},
#  ('Keskerakond',): {'ORG': 267},
#  ('Isamaaliit',): {'ORG': 163},
#  ('Ilves',): {'PER': 35, 'LOC': 4},
#  ('Margus',): {'PER': 11},
#  ('Svetlana',): {'PER': 6},
#  ('Sukleski',): {'PER': 1},
#  ('Lipstok',): {'PER': 7},
#  ('Kanepi',): {'PER': 14, 'LOC': 1},
#  ('reformierakond',): {'ORG': 20},
#  ('keskerakond',): {'ORG': 23},
#  ('isamaaliit',): {'ORG': 16},
#  ('Tischler',): {'PER': 5},
#  ('Paldiski',): {'LOC': 65},
#  ('Ene',): {'PER': 7},
#  ('Galina',): {'PER': 3},
#  ('Kuressaare',): {'LOC': 69},
#  ('Tamkivi',): {'PER': 2},
#  ('Mõõduka',): {'ORG': 45},
#  ('Naissaar',): {'LOC': 14},
#  ('Omavalitsusliit',): {'ORG': 1},
#  ('Botaanikaaias',): {'PER': 1},
#  ('Kloostrimets',): {'LOC': 3},
#  ('Küüdipoiste',): {'PER': 3},
#  ('karusoo',): {'PER': 5},
#  ('saar',): {'LOC': 6, 'PER': 7},
#  ('võru',): {'LOC': 13},
#  ('viru',): {'LOC': 1},
#  ('Tapa',): {'LOC': 6, 'PER': 1},
#  ('Barjabin',): {'PER': 1},
#  ('EMEX',): {'ORG': 7},
#  ('Lasnamäe',): {'LOC': 99},
#  ('Järv',): {'PER': 8, 'LOC': 7},
#  ('ühispank',): {'ORG': 24},
#  ('Toivo',): {'PER': 15},
#  ('Lippmaa',): {'PER': 2},
#  ('EM',): {'ORG': 59, 'LOC': 1},
#  ('Business',): {'PER': 1},
#  ('Klementi',): {'LOC': 3, 'ORG': 1, 'PER': 1},
#  ('Microsoft',): {'ORG': 21, 'PER': 6, 'LOC': 1},
#  ('udu',): {'PER': 2},
#  ('Udu',): {'PER': 2},
#  ('Kergejõustiku',): {'PER': 2},
#  ('LAV',): {'LOC': 3, 'ORG': 6},
#  ('Jones',): {'PER': 22},
#  ('Greene',): {'PER': 1},
#  ('Fredericks',): {'PER': 1},
#  ('Namiibia',): {'LOC': 3},
#  ('Barbados',): {'LOC': 2},
#  ('Keenia',): {'LOC': 10},
#  ('Alzheeria',): {'ORG': 1, 'LOC': 4},
#  ('Maroko',): {'LOC': 23},
#  ('Jamaika',): {'ORG': 2, 'LOC': 2},
#  ('Oda',): {'PER': 2},
#  ('Kreeka',): {'LOC': 85},
#  ('Tshehhimaa',): {'LOC': 10},
#  ('Mosambiik',): {'LOC': 2},
#  ('Nigeeria',): {'LOC': 16},
#  ('Kasahstan',): {'LOC': 27},
#  ('Lewinsky',): {'PER': 26},
#  ('CNN',): {'ORG': 14},
#  ('Rahvusraamatukogu',): {'ORG': 13},
#  ('INNOPAC',): {'ORG': 1},
#  ('EPL',): {'ORG': 43},
#  ('Gluhhov',): {'PER': 3},
#  ('Vene-Eest',): {'LOC': 1},
#  ('Transilvaania',): {'LOC': 1},
#  ('Kerttu',): {'PER': 5},
#  ('Õhtulehele',): {'PER': 3},
#  ('ESS',): {'ORG': 14, 'LOC': 2},
#  ('Hansapank',): {'ORG': 203},
#  ('Guvatrak',): {'ORG': 1},
#  ('Hardo',): {'PER': 1},
#  ('Pajula',): {'PER': 2},
#  ('Argentiina',): {'LOC': 15},
#  ('Hongkong',): {'LOC': 44},
#  ('Brasiilia',): {'LOC': 62},
#  ('Ühendriik',): {'PER': 1, 'LOC': 68},
#  ('Rolls-Royce',): {'ORG': 1},
#  ('Chrysler',): {'LOC': 1, 'ORG': 1, 'PER': 3},
#  ('Daimler-Benz',): {'LOC': 2},
#  ('Volkswagen',): {'PER': 1},
#  ('Volvo',): {'LOC': 3, 'ORG': 5},
#  ('Mercedes',): {'PER': 3},
#  ('ÕL',): {'ORG': 6},
#  ('NBA',): {'ORG': 48, 'LOC': 1},
#  ('San',): {'LOC': 9},
#  ('Milwaukee',): {'LOC': 7, 'ORG': 2},
#  ('Lakers',): {'PER': 9, 'ORG': 6},
#  ('Cleveland',): {'ORG': 5},
#  ('Rider',): {'ORG': 1},
#  ('Orlando',): {'ORG': 6},
#  ('Coleman',): {'PER': 1},
#  ('Philadelphia',): {'ORG': 5, 'LOC': 18},
#  ('Iverson',): {'PER': 7},
#  ('Minnesota',): {'LOC': 5},
#  ('Brandon',): {'ORG': 1},
#  ('Payton',): {'PER': 5, 'ORG': 4},
#  ('Houston',): {'ORG': 11, 'PER': 6, 'LOC': 4},
#  ('Washington',): {'ORG': 16, 'LOC': 55, 'PER': 23},
#  ('Cato',): {'ORG': 1},
#  ('Duncan',): {'ORG': 1, 'PER': 5},
#  ('Cassell',): {'ORG': 2},
#  ('Phoenix',): {'ORG': 14, 'PER': 1},
#  ('Robinson',): {'ORG': 2, 'PER': 9},
#  ('Finley',): {'LOC': 1},
#  ('Portland',): {'LOC': 8, 'ORG': 2},
#  ('Wallace',): {'ORG': 1, 'PER': 1},
#  ('Vancouver',): {'ORG': 8, 'LOC': 4},
#  ('Denver',): {'ORG': 5, 'LOC': 1},
#  ('Rahim',): {'ORG': 2},
#  ('Lafrentz',): {'ORG': 1},
#  ('Sacramento',): {'ORG': 5, 'LOC': 8, 'PER': 1},
#  ('Webber',): {'PER': 7},
#  ('Indiana',): {'LOC': 19, 'PER': 1, 'ORG': 1},
#  ('Sprewell',): {'ORG': 1, 'PER': 2},
#  ('Ewing',): {'PER': 3},
#  ('ONeal',): {'ORG': 1},
#  ('Rice',): {'PER': 5},
#  ('Bryant',): {'PER': 4},
#  ('Boston',): {'ORG': 7},
#  ('Taylor',): {'ORG': 2, 'PER': 14},
#  ('Walker',): {'ORG': 1},
#  ('Charlotte',): {'ORG': 1, 'LOC': 1},
#  ('Carter',): {'PER': 4},
#  ('Chicago',): {'ORG': 5, 'LOC': 15},
#  ('Seattle',): {'LOC': 7, 'ORG': 1},
#  ('Miami',): {'ORG': 3, 'LOC': 17},
#  ('Robonson',): {'ORG': 1},
#  ('McDyess',): {'ORG': 1, 'PER': 1},
#  ('Estonija',): {'ORG': 5},
#  ('Vasetshkin',): {'PER': 2},
#  ('Zavtra',): {'ORG': 1},
#  ('Bairash',): {'PER': 1},
#  ('Kolumnist',): {'PER': 4},
#  ('A. H. Tammsaare',): {'PER': 1, 'LOC': 1},
#  ('EW',): {'ORG': 3},
#  ('Tammsaare',): {'PER': 49},
#  ('Luts',): {'LOC': 5, 'PER': 1},
#  ('K. Päts',): {'PER': 1},
#  ('Henrik',): {'PER': 3},
#  ('Hoeneke',): {'ORG': 1},
#  ('Russow',): {'ORG': 1},
#  ('Loksa',): {'LOC': 3},
#  ('Jashtshenko',): {'PER': 5},
#  ('Haitov',): {'PER': 4},
#  ('Bondartshuk',): {'PER': 2},
#  ('Suvorov',): {'PER': 1},
#  ('rahva-erakond',): {'ORG': 1},
#  ('Mõõdukatel',): {'ORG': 2},
#  ('Nature',): {'ORG': 2},
#  ('A',): {'LOC': 6, 'ORG': 18, 'PER': 28},
#  ('G',): {'ORG': 5, 'LOC': 1},
#  ('DNA',): {'ORG': 7},
#  ('C',): {'ORG': 10, 'LOC': 5},
#  ('Nasva',): {'LOC': 2},
#  ('Verg',): {'ORG': 2, 'LOC': 2},
#  ('Lepikson',): {'PER': 18},
#  ('Haanja',): {'LOC': 16},
#  ('kapo',): {'ORG': 35},
#  ('Cortes',): {'PER': 1},
#  ('EÜRP',): {'ORG': 3},
#  ('Rebane',): {'PER': 12, 'LOC': 2},
#  ('SS',): {'ORG': 2},
#  ('Jõgeva',): {'LOC': 23, 'PER': 1},
#  ('Elmar',): {'PER': 6},
#  ('vooremaa',): {'LOC': 1},
#  ('Äripäev',): {'ORG': 42},
#  ('akropol-A',): {'ORG': 1},
#  ('Tootsi',): {'PER': 11, 'LOC': 1},
#  ('Toots',): {'PER': 8},
#  ('Muuga',): {'LOC': 15, 'ORG': 14},
#  ('Paljassaar',): {'LOC': 1},
#  ('Vanasadam',): {'LOC': 1},
#  ('Kemerovo',): {'LOC': 5},
#  ('Venemaa-Valgevene',): {'LOC': 1},
#  ('Eutelsat',): {'LOC': 1},
#  ('OSCE',): {'ORG': 22},
#  ('Stoel',): {'ORG': 1, 'PER': 1},
#  ('Schengen',): {'LOC': 30},
#  ('DIS',): {'ORG': 1},
#  ('Jonskopink',): {'LOC': 1},
#  ('Bendreu',): {'LOC': 1},
#  ('Strasbourg',): {'LOC': 15},
#  ('ENPA',): {'ORG': 9},
#  ('Strasboug',): {'LOC': 1},
#  ('telgmaa',): {'PER': 1},
#  ('Starman',): {'ORG': 7, 'PER': 2},
#  ('Velman',): {'PER': 3},
#  ('Põhja-Tallinn',): {'LOC': 14},
#  ('Haabersti',): {'LOC': 23, 'ORG': 1},
#  ('Harku',): {'LOC': 14},
#  ('Kakumägi',): {'LOC': 6},
#  ('Karis',): {'PER': 4},
#  ('Rotterdam',): {'LOC': 3},
#  ('AEK',): {'ORG': 8},
#  ('Shklover',): {'PER': 1},
#  ('Gdansk',): {'LOC': 2, 'PER': 1},
#  ('Seeman',): {'PER': 2},
#  ('Baltika',): {'LOC': 2, 'ORG': 4},
#  ('IAAF',): {'ORG': 14},
#  ('Brüssel',): {'LOC': 108, 'PER': 1},
#  ('Etioopia',): {'LOC': 3},
#  ('Uus-Guinea',): {'LOC': 1},
#  ('paapua',): {'LOC': 1},
#  ('Pankrotitoimkond',): {'PER': 1},
#  ('Eipre',): {'PER': 7},
#  ('Urm',): {'PER': 6},
#  ('Eiprele',): {'PER': 2},
#  ('Eipret',): {'PER': 1},
#  ('Hara',): {'ORG': 1},
#  ('Sassian',): {'PER': 2},
#  ('kultuuriministeerium',): {'ORG': 23},
#  ('Mahtra',): {'LOC': 11},
#  ('Kärdla',): {'LOC': 5},
#  ('Kiv',): {'PER': 4, 'ORG': 2},
#  ('Kivi',): {'PER': 14, 'LOC': 1},
#  ('Tallinna-Narva',): {'LOC': 12},
#  ('Aleksander',): {'ORG': 9, 'PER': 10},
#  ('Tamara',): {'PER': 1},
#  ('Meelis',): {'PER': 20},
#  ('Ervin',): {'PER': 1},
#  ('Andro',): {'PER': 1},
#  ('Mathias',): {'PER': 1},
#  ('Viin',): {'LOC': 12},
#  ('Lauda',): {'PER': 4},
#  ('Boeing',): {'ORG': 12},
#  ('Lõuna-Ameerika',): {'LOC': 20},
#  ('Tampõld',): {'PER': 5},
#  ('Leiger',): {'PER': 4},
#  ('Shveits',): {'LOC': 26},
#  ('Albaania',): {'LOC': 28},
#  ('Milosevic',): {'PER': 23},
#  ('briti',): {'LOC': 28},
#  ('Guthrie',): {'PER': 2},
#  ('Pristina',): {'LOC': 3, 'PER': 1},
#  ('BMF',): {'ORG': 1},
#  ('Põhja-Eest',): {'LOC': 10},
#  ('Lõuna-Eest',): {'LOC': 50},
#  ('ER',): {'ORG': 16},
#  ('ETA',): {'ORG': 107},
#  ('Rummo',): {'PER': 12, 'LOC': 1},
#  ('Ferrari',): {'ORG': 53, 'PER': 1},
#  ('Schumacher',): {'PER': 22},
#  ('Pariis',): {'LOC': 116},
#  ('Mugello',): {'LOC': 2},
#  ('Nyyd-Ensemble',): {'PER': 1},
#  ('Von',): {'PER': 5},
#  ('Nyyd-Ensemblei',): {'LOC': 1},
#  ('Krall',): {'PER': 2},
#  ('Rodgers-Hammerstein',): {'ORG': 1},
#  ('Pinocchio',): {'PER': 2},
#  ('Estonia-Endla',): {'PER': 1},
#  ('Irma',): {'PER': 1},
#  ('Offenbachi',): {'PER': 1},
#  ('Neeme',): {'PER': 3, 'ORG': 4},
#  ('Spurs',): {'PER': 6},
#  ('Knicks',): {'PER': 4},
#  ('Heat',): {'PER': 1, 'ORG': 1},
#  ('Johnson',): {'PER': 7},
#  ('Spursile',): {'PER': 1},
#  ('Pat',): {'PER': 4},
#  ('Larry',): {'PER': 11},
#  ('Pacers',): {'ORG': 1},
#  ('Knicksi',): {'LOC': 1, 'PER': 1},
#  ('Blazers',): {'PER': 1},
#  ('Elliott',): {'PER': 3},
#  ('Halliste',): {'LOC': 4, 'PER': 2},
#  ('kultuurkapital',): {'ORG': 4},
#  ('Vähi',): {'PER': 25},
#  ('raidveri',): {'PER': 1},
#  ('kalm',): {'LOC': 1, 'PER': 2},
#  ('Terras',): {'PER': 2},
#  ('Nõmme-Hiiu',): {'LOC': 2},
#  ('Ramsau',): {'LOC': 7},
#  ('Mustamägi',): {'LOC': 36},
#  ('Stratum',): {'ORG': 1},
#  ('nõmm',): {'LOC': 9},
#  ('Võrno',): {'PER': 11},
#  ('keskkonnaministeerium',): {'ORG': 10},
#  ('Järvan',): {'PER': 4},
#  ('Makarov',): {'PER': 19},
#  ('Erastamisagentuur',): {'ORG': 12},
#  ('Naglis',): {'PER': 1},
#  ('Shkele',): {'PER': 4},
#  ('Grinblats',): {'PER': 1},
#  ('Kiviter',): {'ORG': 4},
#  ('Vitsur',): {'PER': 7},
#  ('Siimann',): {'PER': 21},
#  ('Nixon',): {'PER': 1},
#  ('Pele',): {'PER': 3},
#  ('Assuan',): {'LOC': 2},
#  ('Niilus',): {'LOC': 1},
#  ('Egiptus',): {'LOC': 14},
#  ('W. Gomulka',): {'PER': 1},
#  ('E. Itkonen',): {'PER': 1},
#  ('Valdek',): {'LOC': 2},
#  ('F. Klementi',): {'PER': 1},
#  ('teos',): {'PER': 2},
#  ('Portlant',): {'LOC': 2},
#  ('Läänerannik',): {'PER': 1},
#  ('Salme',): {'PER': 3, 'LOC': 1},
#  ('Pill',): {'LOC': 1},
#  ('TV1',): {'ORG': 15},
#  ('Toomet',): {'PER': 4, 'ORG': 1},
#  ('Talbott',): {'PER': 3},
#  ('Rubin',): {'PER': 2},
#  ('Lipponen',): {'PER': 14},
#  ('koondpartei',): {'ORG': 2},
#  ('vasakliit',): {'ORG': 1},
#  ('Keskpartei',): {'ORG': 2},
#  ('Niinistöga',): {'LOC': 1, 'PER': 1},
#  ('Aho',): {'PER': 5},
#  ('SDP',): {'ORG': 2},
#  ('Niinistö',): {'PER': 4},
#  ('WWW-Värk',): {'PER': 1},
#  ('Mölder',): {'PER': 8, 'LOC': 1},
#  ('meediamaa',): {'ORG': 1},
#  ('rk',): {'ORG': 1},
#  ('maanteeamet',): {'ORG': 15},
#  ('Vilnius',): {'LOC': 54},
#  ('Nestor',): {'PER': 24},
#  ('Tominga',): {'PER': 2},
#  ('nestor',): {'PER': 1},
#  ('Vilippunen',): {'PER': 2},
#  ('Andry',): {'PER': 1},
#  ('Raimo',): {'PER': 8},
#  ('Leevik',): {'PER': 1},
#  ('Aris',): {'PER': 1},
#  ('PAOK',): {'ORG': 2},
#  ('Morozevitsh',): {'PER': 1},
#  ('Barejev',): {'LOC': 1},
#  ('Sydney',): {'LOC': 22, 'PER': 3, 'ORG': 1},
#  ('Otepää',): {'LOC': 67},
#  ('Atomic',): {'ORG': 1},
#  ('Fischer',): {'PER': 2},
#  ('Madshus',): {'ORG': 1},
#  ('Visu',): {'PER': 1},
#  ('ESL',): {'ORG': 1},
#  ('Rovaniemi',): {'LOC': 4},
#  ('Vuokatt',): {'ORG': 1},
#  ('Alaver',): {'PER': 27},
#  ('Rüütel',): {'PER': 84},
#  ('Kaarel',): {'PER': 15, 'LOC': 3},
#  ('Põhja-Korea',): {'LOC': 14},
#  ('Mehhiko',): {'LOC': 35},
#  ('Sadova',): {'PER': 2},
#  ('Lamela',): {'ORG': 1},
#  ('Torino',): {'LOC': 11},
#  ('Huffins',): {'PER': 2},
#  ('Götzise',): {'ORG': 1},
#  ('sise-MM',): {'ORG': 3},
#  ('McLaren',): {'ORG': 28, 'LOC': 1},
#  ('Nabokov',): {'PER': 16},
#  ('Valentin',): {'PER': 11},
#  ('Sobolev',): {'PER': 3},
#  ('Kafka',): {'PER': 2, 'ORG': 1},
#  ('Eiche',): {'PER': 2},
#  ('Timmer',): {'PER': 1},
#  ('Näkineius',): {'PER': 1},
#  ('Natasha',): {'PER': 11},
#  ('Möldrile',): {'PER': 1},
#  ('Bertman',): {'PER': 3},
#  ('Lipunov',): {'PER': 1},
#  ('Arkadi',): {'PER': 1},
#  ('Grosstha',): {'PER': 1},
#  ('Grossthal',): {'PER': 8},
#  ('Reisner',): {'PER': 2},
#  ('Elva',): {'LOC': 15, 'ORG': 3},
#  ('Grossthali',): {'PER': 1},
#  ('mäekala',): {'ORG': 1},
#  ('Hansa',): {'ORG': 6},
#  ('Gaspli',): {'LOC': 1},
#  ('Raoul',): {'PER': 4, 'LOC': 1},
#  ('Shveit',): {'LOC': 1},
#  ('riigikontroll',): {'ORG': 62},
#  ('Vaher',): {'PER': 12},
#  ('krediidipank',): {'ORG': 4},
#  ('Voitka',): {'PER': 12, 'LOC': 1},
#  ('Raivo',): {'PER': 9},
#  ('Ülo',): {'PER': 15},
#  ('Viru',): {'LOC': 51, 'PER': 5, 'ORG': 1},
#  ('Mere',): {'PER': 1, 'LOC': 4, 'ORG': 6},
#  ('Aivar',): {'PER': 8},
#  ('N. Liit',): {'ORG': 6, 'LOC': 10, 'PER': 3},
#  ('Taran',): {'ORG': 1},
#  ('transpordiamet',): {'ORG': 7},
#  ('Songisepp',): {'PER': 7},
#  ('Reuters-bns',): {'ORG': 1},
#  ('Põhja-Inglismaa',): {'LOC': 3},
#  ('Naissaart',): {'PER': 1},
#  ('DEG',): {'ORG': 3},
#  ('Bergmann',): {'PER': 13},
#  ('Euro-Aafrika',): {'LOC': 2},
#  ('Zimbabwe',): {'LOC': 3},
#  ('Belgia',): {'LOC': 108},
#  ('Slovakkia',): {'LOC': 34},
#  ('Horvaatia',): {'LOC': 27},
#  ('Mäkinen',): {'PER': 30},
#  ('Mitsubishi',): {'PER': 1},
#  ('Mannisenmäki',): {'PER': 1},
#  ('Tommi',): {'PER': 3},
#  ('Mägi',): {'PER': 35, 'LOC': 2, 'ORG': 1},
#  ('Meerits',): {'PER': 4},
#  ('Iisrael',): {'LOC': 176},
#  ('Maarjamägi',): {'LOC': 3},
#  ('Kink',): {'PER': 1, 'LOC': 1},
#  ...}

# %%
first_words_map
# Out:
# {('Aive',): {'PER': 6},
#  ('Mathers',): {'PER': 1},
#  ('Slim',): {'PER': 1},
#  ('Jimmy',): {'PER': 7},
#  ('Kim',): {'PER': 16},
#  ('Brittany',): {'PER': 1},
#  ('Brian',): {'PER': 9},
#  ('Curtis',): {'PER': 1},
#  ('LA',): {'ORG': 13},
#  ('Wonder',): {'PER': 1},
#  ('New',): {'LOC': 25, 'ORG': 91, 'PER': 3},
#  ('Trudie',): {'PER': 2},
#  ('vihmamets',): {'ORG': 1},
#  ('Xingu',): {'PER': 1},
#  ('Guy',): {'PER': 4},
#  ('Stock', '&', 'Two', 'Smoking'): {'ORG': 1},
#  ('Bristoli', 'Old', 'Vic'): {'ORG': 1},
#  ('West',): {'PER': 4, 'ORG': 7},
#  ('Frances',): {'PER': 4},
#  ('Linda',): {'PER': 12, 'ORG': 4},
#  ('Sven',): {'PER': 47},
#  ('Evelin',): {'PER': 19},
#  ('Priit',): {'PER': 169},
#  ('Over', 'The', 'Water'): {'ORG': 1},
#  ('Glen',): {'PER': 4},
#  ('Koit',): {'PER': 85, 'ORG': 2},
#  ('Kati',): {'PER': 12},
#  ('Kaire-Külli',): {'PER': 1},
#  ('AS',): {'ORG': 189},
#  ('Jaan',): {'PER': 271, 'ORG': 2},
#  ('Rahu',): {'PER': 1},
#  ('Aino',): {'PER': 20},
#  ('Tartu', 'Maarja'): {'ORG': 2},
#  ('Rocca', 'al'): {'LOC': 18},
#  ('Toomas',): {'PER': 314},
#  ('Ivi',): {'PER': 19},
#  ('Maret',): {'PER': 45},
#  ('Jaanus',): {'PER': 180},
#  ('Valdo',): {'PER': 11, 'ORG': 1},
#  ('Igor',): {'PER': 62},
#  ('Heli',): {'PER': 24},
#  ('Olaf',): {'PER': 8},
#  ('Joan',): {'PER': 6},
#  ('Percy',): {'PER': 1},
#  ('Robin',): {'PER': 5},
#  ('Love',): {'ORG': 1, 'PER': 1},
#  ('Henrik',): {'ORG': 1, 'PER': 21},
#  ('Madis',): {'ORG': 10, 'PER': 57},
#  ('Kaupo',): {'PER': 12, 'ORG': 1},
#  ('Tõnis',): {'PER': 79},
#  ('Valeri',): {'PER': 25},
#  ('Krasnodarka',): {'LOC': 2},
#  ('Eesti',): {'LOC': 477, 'ORG': 1195},
#  ('N',): {'ORG': 13, 'LOC': 2},
#  ('Estonka',): {'LOC': 1},
#  ('Salme',): {'LOC': 1, 'ORG': 2, 'PER': 5},
#  ('Ukraina', 'Eesti'): {'ORG': 2},
#  ('Paul',): {'PER': 72},
#  ('Viktor',): {'PER': 55},
#  ('Eero',): {'PER': 19, 'ORG': 2},
#  ('Tallinn',): {'ORG': 766, 'LOC': 91},
#  ('AS', 'mulk'): {'ORG': 1},
#  ('Andi',): {'PER': 3, 'ORG': 1},
#  ('Okinawa',): {'LOC': 1},
#  ('Lloyd',): {'PER': 2},
#  ('John',): {'PER': 78},
#  ('Bureau',): {'PER': 5},
#  ('Meyer',): {'PER': 1},
#  ('Diana',): {'PER': 8},
#  ('Åke',): {'PER': 1},
#  ('Nordström', '&'): {'ORG': 1},
#  ('Deep',): {'PER': 8},
#  ('Bureau', 'Veritas'): {'ORG': 1},
#  ('eluohutu',): {'ORG': 1},
#  ('Derbyshire',): {'ORG': 1},
#  ('Mai',): {'PER': 20},
#  ('Saaremaa',): {'ORG': 43, 'LOC': 3},
#  ('Vjatsheslav',): {'PER': 6},
#  ('Margo',): {'PER': 21},
#  ('saar',): {'ORG': 5, 'LOC': 2},
#  ('Ruth',): {'PER': 17, 'LOC': 1},
#  ('Heltermaa-Rohuküla', 'ja'): {'LOC': 1},
#  ('RAS', 'saar'): {'ORG': 1},
#  ('Eiki',): {'PER': 24},
#  ('Eesti', 'meremees', 'sõltumatu'): {'ORG': 1},
#  ('Jüri',): {'PER': 334},
#  ('Vello',): {'PER': 76},
#  ('Raivo',): {'PER': 91, 'ORG': 1},
#  ('riik',): {'ORG': 24},
#  ('Malle',): {'PER': 38},
#  ('Ülo',): {'PER': 66, 'ORG': 1},
#  ('Vaapo',): {'PER': 1},
#  ('Ameerika',): {'LOC': 99, 'ORG': 4},
#  ('Kristjan',): {'PER': 46},
#  ('Vend',): {'PER': 5},
#  ('Kurt',): {'PER': 6},
#  ('Paavo',): {'PER': 18},
#  ('Gunnar',): {'PER': 35},
#  ('Lembit',): {'PER': 58},
#  ('Indrek',): {'PER': 170},
#  ('Nõukogu', 'Eesti'): {'ORG': 1},
#  ('Ivo',): {'PER': 47},
#  ('Imant',): {'PER': 1},
#  ('Reino',): {'PER': 2},
#  ('Milosh',): {'PER': 1},
#  ('Jõgi',): {'ORG': 1},
#  ('Tsai',): {'PER': 1},
#  ('Eric',): {'PER': 14},
#  ('Juliette',): {'PER': 4},
#  ('Anthony',): {'PER': 8},
#  ('Leonardo',): {'PER': 2},
#  ('Baz',): {'PER': 1},
#  ('Raoul',): {'PER': 5},
#  ('Terje',): {'PER': 32},
#  ('Saku',): {'ORG': 32, 'PER': 2, 'LOC': 2},
#  ('Tartu',): {'ORG': 436, 'LOC': 51},
#  ('Rakvere',): {'ORG': 44, 'LOC': 3},
#  ('Vene',): {'ORG': 18, 'LOC': 28},
#  ('Linnateater', 'ja'): {'ORG': 1},
#  ('Von',): {'PER': 6},
#  ('Andres',): {'PER': 332},
#  ('Mati',): {'PER': 112},
#  ('Allen',): {'PER': 5},
#  ('Ave',): {'PER': 17},
#  ('Euroopa',): {'ORG': 820, 'LOC': 123},
#  ('Ingvar',): {'PER': 8},
#  ('Arvo',): {'PER': 115},
#  ('Ruhnu',): {'LOC': 6, 'ORG': 1},
#  ('Rainer',): {'PER': 20},
#  ('Enn',): {'PER': 100},
#  ('Saare',): {'ORG': 18, 'LOC': 4},
#  ('Ilmar',): {'PER': 45},
#  ('Helga',): {'PER': 3},
#  ('Mõisaküla',): {'ORG': 4},
#  ('Alma',): {'PER': 4},
#  ('Albert',): {'PER': 13},
#  ('Rein',): {'PER': 147, 'ORG': 8, 'LOC': 4},
#  ('Marie',): {'PER': 6},
#  ('Kuke',): {'PER': 1},
#  ('Juha',): {'PER': 10},
#  ('Ants',): {'PER': 100},
#  ('Mari-Liis',): {'PER': 2},
#  ('Arnold',): {'PER': 67},
#  ('Anti',): {'PER': 59},
#  ('Mart',): {'PER': 256},
#  ('“', 'Postimees'): {'ORG': 75},
#  ('International', 'Star'): {'ORG': 1},
#  ('Tõnu',): {'PER': 142},
#  ('Harvard',): {'ORG': 3},
#  ('Aarne',): {'PER': 17},
#  ('Agentuuri',): {'ORG': 1},
#  ('ÜRO',): {'ORG': 15},
#  ('Kreml',): {'ORG': 2},
#  ('Jevgeni',): {'PER': 49},
#  ('Sergei',): {'PER': 85},
#  ('Vladimir',): {'PER': 113, 'ORG': 1},
#  ('Saddam',): {'PER': 30},
#  ('Teet',): {'PER': 30},
#  ('Mr',): {'PER': 12, 'ORG': 1},
#  ('James',): {'PER': 32, 'ORG': 1},
#  ('Saul',): {'PER': 4},
#  ('Parnass',): {'PER': 1},
#  ('Emma',): {'PER': 7},
#  ('Deelos',): {'LOC': 1},
#  ('Ain',): {'PER': 93},
#  ('Ayn',): {'PER': 1},
#  ('Arno',): {'PER': 22},
#  ('Lemuel',): {'PER': 1},
#  ('Svevo',): {'PER': 1},
#  ('Malcolm',): {'PER': 4},
#  ('Peeter',): {'PER': 259},
#  ('Balt',): {'LOC': 63, 'ORG': 2},
#  ('McDonald', '’'): {'PER': 8},
#  ('v.a',): {'PER': 1},
#  ('U',): {'ORG': 4},
#  ('Posol', 'Sovetskovo'): {'PER': 1},
#  ('Primakov',): {'LOC': 1},
#  ('vene',): {'LOC': 2, 'ORG': 8},
#  ('USA',): {'LOC': 37, 'ORG': 27},
#  ('Nikolai',): {'PER': 39},
#  ('Andrei', 'Rjabov'): {'PER': 1},
#  ('Kozhokin',): {'ORG': 1},
#  ('Roald',): {'PER': 6},
#  ('Dmitri',): {'PER': 43, 'ORG': 1},
#  ('vestma',): {'PER': 1},
#  ('Meelis',): {'PER': 86},
#  ('Sven-Erik',): {'PER': 2},
#  ('Olev',): {'PER': 105},
#  ('meremees',): {'ORG': 1},
#  ('super',): {'PER': 1},
#  ('Heigo',): {'PER': 7},
#  ('Florida',): {'LOC': 3, 'ORG': 1},
#  ('Mihkel',): {'PER': 66},
#  ('Väino',): {'PER': 39, 'ORG': 1},
#  ('Margus',): {'PER': 172, 'ORG': 1},
#  ('Peep',): {'PER': 34},
#  ('TTÜ', 'arvutitehnika'): {'ORG': 1},
#  ('Multiskalaarne', 'protsessor'): {'ORG': 2},
#  ('Processing',): {'ORG': 1},
#  ('Control', 'Flow'): {'ORG': 1},
#  ('PE',): {'ORG': 1},
#  ('Address', 'Resolution'): {'ORG': 1},
#  ('protsessor',): {'ORG': 1},
#  ('Massive', 'Memory'): {'ORG': 1},
#  ('Scalable', 'Coherent'): {'ORG': 1},
#  ('Nõukogu',): {'ORG': 5, 'LOC': 47},
#  ('Karl',): {'PER': 51},
#  ('Kanada', 'rahvusvaheline'): {'ORG': 1},
#  ('Hansa',): {'ORG': 32},
#  ('Põlvamaa',): {'ORG': 5},
#  ('Uno',): {'PER': 39},
#  ('Jõgeva',): {'LOC': 4, 'ORG': 16},
#  ('Eesti', 'hoiu-laenuühistu'): {'ORG': 1},
#  ('HLÜ',): {'ORG': 1},
#  ('Viiratsi',): {'ORG': 1, 'LOC': 3},
#  ('Kehtna',): {'ORG': 4, 'LOC': 2},
#  ('Central', 'Credit'): {'ORG': 1},
#  ('Toronto', 'Eesti'): {'ORG': 1},
#  ('Dr',): {'PER': 7, 'ORG': 2},
#  ('/',): {'ORG': 4, 'PER': 9},
#  ('pill',): {'ORG': 1},
#  ('Passport',): {'PER': 2},
#  ('Pjotr',): {'PER': 15},
#  ('Oleg',): {'PER': 40},
#  ('Steven',): {'PER': 13},
#  ('The',): {'PER': 28, 'ORG': 27},
#  ('Space',): {'PER': 2},
#  ('Jack',): {'PER': 16},
#  ('Uuringute',): {'PER': 1},
#  ('BioMechanics', 'Ltd'): {'ORG': 1},
#  ('BioMechanics',): {'PER': 3},
#  ('Juhan', 'Parts'): {'PER': 1},
#  ('Kaido',): {'PER': 49},
#  ('kanal',): {'ORG': 9},
#  ('Siim',): {'PER': 80},
#  ('Haidary',): {'ORG': 1},
#  ('Mazar',): {'ORG': 1},
#  ('s.t',): {'PER': 1},
#  ('Saud',): {'LOC': 8},
#  ('Saudi',): {'LOC': 16},
#  ('bin',): {'PER': 10},
#  ('India',): {'LOC': 6, 'ORG': 2},
#  ('Inglismaa',): {'ORG': 4, 'PER': 1},
#  ('Araabia',): {'LOC': 10, 'ORG': 1},
#  ('Saudi', 'Araabia'): {'LOC': 1},
#  ('NSV',): {'ORG': 27, 'LOC': 14},
#  ('Aleksander',): {'ORG': 13, 'PER': 49},
#  ('Ibn',): {'PER': 1},
#  ('Maie',): {'PER': 24},
#  ('Ulrich',): {'PER': 3},
#  ('Van',): {'PER': 26, 'ORG': 1},
#  ('Michael',): {'PER': 87},
#  ('Eesti', 'looduskaitse'): {'ORG': 4},
#  ('Res',): {'ORG': 66},
#  ('Alar',): {'PER': 55},
#  ('Voldemar',): {'PER': 19},
#  ('Tartu', 'Jaan'): {'ORG': 3},
#  ('Udo',): {'PER': 9},
#  ('Kaur',): {'PER': 10},
#  ('Thomas',): {'PER': 19},
#  ('Pentti',): {'PER': 2},
#  ('Eggertsson',): {'ORG': 1},
#  ('Hamburg',): {'ORG': 3},
#  ('Roman',): {'PER': 42},
#  ('Niels', 'Bond', 'Taani'): {'ORG': 1},
#  ('Wilhelm',): {'PER': 2, 'ORG': 1},
#  ('Emil',): {'PER': 8},
#  ('Joseph',): {'PER': 8},
#  ('Robert',): {'PER': 103},
#  ('Maria',): {'PER': 35, 'ORG': 1},
#  ('Akadeemia',): {'ORG': 1},
#  ('Oliver',): {'PER': 33},
#  ('Aare',): {'PER': 57},
#  ('Rakvere', 'haigla', 'kerge'): {'ORG': 1},
#  ('Lääne-Viru',): {'ORG': 13, 'LOC': 1},
#  ('STT', '-'): {'ORG': 1},
#  ('Raad',): {'LOC': 8, 'ORG': 1},
#  ('Mustamägi',): {'ORG': 49, 'LOC': 3},
#  ('Keila',): {'ORG': 7, 'LOC': 6},
#  ('Maardu',): {'ORG': 7},
#  ('Baltic', 'News'): {'ORG': 63},
#  ('Radiolinja',): {'ORG': 2},
#  ('Q',): {'ORG': 4},
#  ('Läti',): {'ORG': 44, 'LOC': 5},
#  ('Turu',): {'ORG': 4},
#  ('Harry',): {'PER': 48},
#  ('Jaak',): {'PER': 147},
#  ('Macsit',): {'LOC': 1},
#  ('Lõuna', 'ja'): {'LOC': 1},
#  ('Jean',): {'PER': 15},
#  ('Urmet',): {'PER': 6},
#  ('Alo',): {'PER': 22},
#  ('Hannes',): {'PER': 45},
#  ('uus',): {'ORG': 12},
#  ('riigikogu', 'ja'): {'ORG': 5},
#  ('Rene',): {'PER': 28, 'ORG': 1},
#  ('Endel',): {'PER': 53},
#  ('Rügen', ','): {'LOC': 1},
#  ('Interreg',): {'PER': 1},
#  ('Eesti', 'Evangeelne', 'luterlik'): {'ORG': 3},
#  ('Viljandi',): {'ORG': 43, 'LOC': 8},
#  ('Deloitte', '&', 'Touche', 'Eesti', 'AS'): {'ORG': 1},
#  ('Põhja-Tallinn',): {'LOC': 7, 'ORG': 1},
#  ('AS', 'KPMG'): {'ORG': 1},
#  ('Anto',): {'PER': 7},
#  ('nõmm',): {'ORG': 1},
#  ('Jätkuv',): {'ORG': 1},
#  ('Matti',): {'PER': 11},
#  ('Aleksei',): {'PER': 49},
#  ('Taivo',): {'PER': 18},
#  ('korp',): {'ORG': 1},
#  ('Merlene',): {'PER': 3},
#  ('Reuters', '/', 'AP', '/'): {'ORG': 1},
#  ('Bulgaaria',): {'ORG': 1, 'LOC': 1},
#  ('Ivan',): {'PER': 25},
#  ('Sri',): {'LOC': 5},
#  ('Chandrika',): {'PER': 1},
#  ('Gruusia',): {'LOC': 1, 'ORG': 1},
#  ('Jossif',): {'PER': 3},
#  ('Sülejman',): {'PER': 1},
#  ('Hanno',): {'PER': 11},
#  ('seadma',): {'PER': 7, 'ORG': 1},
#  ('Cliff',): {'PER': 3},
#  ('Elton',): {'PER': 16},
#  ('Tony',): {'PER': 28},
#  ('Margaret',): {'PER': 11},
#  ('Winston',): {'PER': 2},
#  ('Roy',): {'PER': 5},
#  ('Aliinen',): {'PER': 2},
#  ('Lääne', 'Virumaa'): {'ORG': 1},
#  ('Eestimaa', 'rahvarind'): {'ORG': 1},
#  ('Pro',): {'PER': 1, 'ORG': 6},
#  ('Kaleva', 'Uno'): {'ORG': 1},
#  ('AFP', '/', 'Reuters', '/', 'BNS', '/'): {'ORG': 1},
#  ('Lääne-Euroobas',): {'ORG': 1, 'LOC': 1},
#  ('Jose',): {'PER': 5},
#  ('Rauno',): {'PER': 62},
#  ('Musica',): {'PER': 2},
#  ('Reinhard',): {'PER': 5},
#  ('Die',): {'PER': 3, 'ORG': 5},
#  ('Katrin',): {'PER': 65},
#  ('Kaja',): {'PER': 16},
#  ('Vaira',): {'PER': 8},
#  ('Kesk', 'ja'): {'LOC': 14},
#  ('Guntis',): {'PER': 2},
#  ('Anatolijs',): {'PER': 1},
#  ('Raimonds',): {'PER': 2},
#  ('isamaa', 'ja'): {'ORG': 2},
#  ('Läti', 'Rahvuslik', 'Sõltumatus'): {'ORG': 2},
#  ('Andris', 'Shkele'): {'ORG': 1},
#  ('Ville',): {'PER': 21},
#  ('Andrus',): {'PER': 136},
#  ('Erki',): {'PER': 83},
#  ('Eha',): {'PER': 21},
#  ('Kärt',): {'PER': 35},
#  ('Jane',): {'PER': 25},
#  ('Tomas',): {'PER': 8},
#  ('Peeter', 'Kallas'): {'PER': 1},
#  ('Küllo',): {'PER': 18},
#  ('Konstantin',): {'PER': 24},
#  ('Magnus',): {'PER': 8},
#  ('NSV', 'Liit'): {'ORG': 1},
#  ('Johan',): {'PER': 15},
#  ('August',): {'PER': 12},
#  ('Narva',): {'ORG': 47, 'LOC': 21},
#  ('Tanel',): {'PER': 55},
#  ('Venemaa', 'riiklik', 'tollikomitee', 'juhiValeri'): {'ORG': 1},
#  ('kommersant',): {'ORG': 1},
#  ('Karjääritolliametnik',): {'PER': 1},
#  ('Reuters', '/', 'ap', '/'): {'ORG': 1},
#  ('sotsiaaldemokraatlik',): {'ORG': 6},
#  ('Tito',): {'PER': 1},
#  ('Boris',): {'PER': 14},
#  ('Anneli',): {'PER': 38, 'ORG': 1},
#  ('Urmas',): {'PER': 175},
#  ('Isamaa', 'ja'): {'ORG': 2},
#  ('Märt',): {'PER': 67},
#  ('Lääne',): {'ORG': 46, 'LOC': 4},
#  ('Lehte',): {'PER': 11},
#  ('Harju',): {'ORG': 47, 'LOC': 6},
#  ('Haapsalu',): {'ORG': 25, 'LOC': 10},
#  ('Heiki',): {'PER': 56},
#  ('Lääne-Eest',): {'ORG': 5, 'LOC': 3},
#  ('Veiko',): {'PER': 45},
#  ('Ervin-Johan',): {'PER': 1},
#  ('Maarahvas',): {'ORG': 6},
#  ('Arder',): {'PER': 4},
#  ('Tiit',): {'PER': 336},
#  ('Juhan',): {'PER': 65},
#  ('kristlik',): {'ORG': 2},
#  ('Edgar',): {'PER': 88},
#  ('Tisler',): {'PER': 1},
#  ('Raimu',): {'PER': 4},
#  ('mina',): {'ORG': 10, 'PER': 3},
#  ('Reet',): {'PER': 64},
#  ('Harjumaa', 'omavalitsus'): {'ORG': 2},
#  ('Eesti', 'Linn'): {'ORG': 1},
#  ('Viimsi',): {'LOC': 13, 'ORG': 4, 'PER': 1},
#  ('Meelis', 'Kapstas'): {'PER': 1},
#  ('Merle',): {'PER': 29},
#  ('Pille',): {'PER': 26, 'ORG': 1},
#  ('Taavi',): {'PER': 30, 'ORG': 2},
#  ('Garmen',): {'PER': 1},
#  ('Kleer',): {'PER': 2},
#  ('Helle',): {'PER': 14},
#  ('Kadi',): {'PER': 13},
#  ('Sirje',): {'PER': 44},
#  ('Kadriorg',): {'ORG': 11, 'LOC': 1},
#  ('Meri',): {'ORG': 1, 'PER': 11},
#  ('Optiva',): {'ORG': 10},
#  ('Lindakivi',): {'PER': 1},
#  ('Volli', 'Kalam'): {'ORG': 2},
#  ('BNS', '/'): {'ORG': 5},
#  ('Kiil',): {'LOC': 3},
#  ('OÜ',): {'ORG': 40},
#  ('Software',): {'PER': 1},
#  ('Ahti',): {'PER': 10, 'ORG': 1},
#  ('pank',): {'ORG': 5},
#  ('Riia', 'balti'): {'LOC': 1},
#  ('Microsoft',): {'LOC': 1, 'ORG': 4, 'PER': 2},
#  ('Bizness', '&'): {'ORG': 3},
#  ('balti',): {'LOC': 43, 'ORG': 13},
#  ('Silmet',): {'ORG': 2},
#  ('Reuters', '/'): {'ORG': 30},
#  ('Hestrie',): {'PER': 2},
#  ('Maksim',): {'PER': 16},
#  ('Jeff',): {'PER': 4},
#  ('Bernard',): {'PER': 6},
#  ('Wilson',): {'PER': 2},
#  ('Marion',): {'PER': 8},
#  ('Inger',): {'PER': 5, 'ORG': 2},
#  ('Maurice',): {'PER': 5},
#  ('Frank',): {'PER': 22},
#  ('Oba',): {'PER': 2},
#  ('Noah',): {'PER': 2},
#  ('Noureddine',): {'PER': 1},
#  ('Laban',): {'PER': 1},
#  ('Benjamin',): {'PER': 4},
#  ('Salah',): {'PER': 2},
#  ('Brahim',): {'PER': 1},
#  ('Daniel',): {'PER': 27},
#  ('Younes',): {'PER': 1},
#  ('Kareem',): {'PER': 1},
#  ('Konstantinos',): {'PER': 1},
#  ('Raymond',): {'PER': 3},
#  ('Steve',): {'PER': 15},
#  ('Jan',): {'PER': 28},
#  ('Ludmila',): {'PER': 2},
#  ('Svetlana',): {'PER': 16},
#  ('Glory',): {'PER': 1},
#  ('Olga',): {'PER': 30},
#  ('Melissa',): {'PER': 6},
#  ('Ljudmila',): {'PER': 4},
#  ('Inga',): {'PER': 8},
#  ('Monica',): {'PER': 15},
#  ('Aivar',): {'PER': 159},
#  ('viru',): {'LOC': 1},
#  ('Kaivo',): {'PER': 13},
#  ('Bill',): {'PER': 54},
#  ('Piret',): {'PER': 76},
#  ('Triin',): {'PER': 34},
#  ('Eesti', 'akadeemiline'): {'ORG': 4},
#  ('Riigikogu',): {'ORG': 7},
#  ('Harri',): {'PER': 39},
#  ('Kerttu',): {'PER': 62},
#  ('Rain',): {'PER': 33, 'ORG': 2, 'LOC': 1},
#  ('Helen',): {'PER': 35},
#  ('Riina',): {'PER': 48},
#  ('Tiina',): {'PER': 79},
#  ('Price',): {'PER': 4},
#  ('General',): {'ORG': 3, 'PER': 1},
#  ('Chrysleri',): {'LOC': 1},
#  ('Volvo',): {'PER': 1},
#  ('Antonio',): {'PER': 19},
#  ('Los', 'Angeles'): {'ORG': 12, 'LOC': 3},
#  ('Kobe',): {'PER': 4},
#  ('Jaren',): {'PER': 2},
#  ('San',): {'ORG': 26, 'LOC': 11, 'PER': 2},
#  ('Golden',): {'ORG': 8, 'PER': 1},
#  ('Pierce',): {'ORG': 1, 'PER': 4},
#  ('Vene', 'rahvuslik'): {'ORG': 2},
#  ('vene', 'Rahvuslik'): {'ORG': 1},
#  ('Aleksandr',): {'PER': 62},
#  ('Vene', 'Rahvuslik'): {'ORG': 4},
#  ('Andrei',): {'PER': 77},
#  ('Nashe',): {'ORG': 1},
#  ('Tarmo-Jaan',): {'PER': 2},
#  ('Ulvi',): {'PER': 3},
#  ('Ulvi', 'Postkaart'): {'ORG': 1},
#  ('Epp',): {'PER': 17, 'ORG': 2},
#  ('Lennart',): {'PER': 88},
#  ('Hermen', 'Rode'): {'PER': 1},
#  ('Ann',): {'PER': 11},
#  ('Teadus',): {'ORG': 7},
#  ('Friedebert',): {'PER': 3},
#  ('Johannes',): {'PER': 58},
#  ('Eduard',): {'PER': 35},
#  ('Gustave', 'Le'): {'ORG': 1},
#  ('Oswald',): {'PER': 1},
#  ('Vitali',): {'PER': 13},
#  ('Juri',): {'PER': 40},
#  ('Siiri',): {'PER': 61},
#  ('A', ','): {'ORG': 1},
#  ('California',): {'ORG': 2, 'LOC': 2},
#  ('Genoomi',): {'ORG': 1},
#  ('USA', 'inimene', 'Genoomi'): {'ORG': 1},
#  ('Ess',): {'ORG': 7, 'LOC': 1},
#  ('Võrumaa',): {'ORG': 8, 'LOC': 1},
#  ('Luchino',): {'ORG': 1},
#  ('Eestimaa', 'ühendatu'): {'ORG': 4},
#  ('Alfons',): {'PER': 1},
#  ('Securitas', 'Eesti'): {'ORG': 1},
#  ('Riho',): {'PER': 48},
#  ('Astrid',): {'PER': 8},
#  ('Moskva',): {'ORG': 24, 'LOC': 8},
#  ('kommunistlik',): {'ORG': 5},
#  ('Kamtshatka',): {'LOC': 3},
#  ('Gennadi',): {'PER': 22},
#  ('Boriss',): {'PER': 41},
#  ('Aman',): {'PER': 2},
#  ('Venemaa', 'kommunistlik'): {'ORG': 1},
#  ('Venemaa-Valgevene-Ukraina',): {'LOC': 1},
#  ('Gamesat', 'Saatekeskus'): {'ORG': 1},
#  ('Benelux',): {'LOC': 1},
#  ('Max', 'van', 'der'): {'PER': 4},
#  ('De',): {'ORG': 5, 'PER': 6},
#  ('Raul',): {'PER': 59},
#  ('Roberto',): {'PER': 8},
#  ('Kicher', 'Raman'): {'PER': 1},
#  ('Atal', 'Behari'): {'PER': 2},
#  ('Lok',): {'PER': 1},
#  ('Ganti', 'Mohanachandra'): {'ORG': 1},
#  ('Krishnant',): {'PER': 1},
#  ('TT',): {'ORG': 2},
#  ('Ermo',): {'PER': 3},
#  ('Liia',): {'PER': 15, 'ORG': 1},
#  ('Euroopa', 'Nõukogu', 'parlamentaarne'): {'ORG': 1},
#  ('Tunne',): {'PER': 15},
#  ('Kristiina',): {'PER': 38},
#  ('Pirita',): {'LOC': 11, 'ORG': 10},
#  ('Ülle',): {'PER': 43},
#  ('Pirita', 'vaba', 'aeg'): {'ORG': 3},
#  ('Erasmus',): {'ORG': 1},
#  ('London', 'rahvuslik'): {'ORG': 1},
#  ('BNS', '/', 'Reuters', '/'): {'ORG': 1},
#  ('Ateena', 'AEK'): {'ORG': 2},
#  ('Martin',): {'PER': 109, 'ORG': 1},
#  ('Viktoria',): {'PER': 8},
#  ('Valdis',): {'ORG': 1, 'PER': 1},
#  ('grand',): {'PER': 4},
#  ('Aljona',): {'PER': 2},
#  ('Stanislav',): {'PER': 13, 'ORG': 2},
#  ('Tarvo',): {'PER': 11},
#  ('Eduardo',): {'PER': 1},
#  ('Paulo',): {'PER': 3},
#  ('Richard',): {'PER': 51},
#  ('Lydia',): {'PER': 1, 'ORG': 1},
#  ('Ayelech',): {'PER': 1},
#  ('Jackline',): {'PER': 1},
#  ('Portland', 'Trail'): {'ORG': 3},
#  ('Phoenix',): {'ORG': 3, 'PER': 1},
#  ('Tom',): {'PER': 29},
#  ('Port', 'Moresby', 'PNG', 'Banking'): {'ORG': 1},
#  ('Port',): {'PER': 3},
#  ('Alar', 'Urm', 'Terje'): {'PER': 1},
#  ('AS', 'Hara'): {'ORG': 3},
#  ('Loksa',): {'LOC': 2},
#  ('Põhisüüdistus',): {'PER': 1},
#  ('Edith',): {'PER': 2},
#  ('Kai',): {'PER': 34},
#  ('Signe',): {'PER': 29},
#  ('Illuka',): {'LOC': 2},
#  ('Agusalu',): {'LOC': 1},
#  ('Purjus',): {'PER': 1},
#  ('Vikerkaar',): {'ORG': 1},
#  ('Toyota',): {'PER': 11},
#  ('Niki',): {'PER': 3},
#  ('laut',): {'ORG': 1},
#  ('Lauda',): {'PER': 1},
#  ('Risto',): {'PER': 40},
#  ('Hiiu',): {'ORG': 18},
#  ('Käina',): {'ORG': 1},
#  ('Anne',): {'PER': 65, 'LOC': 3, 'ORG': 2},
#  ('Aurelia',): {'PER': 1},
#  ('Ida-Viru',): {'ORG': 15, 'LOC': 2},
#  ('Reuters', '/', 'BNS', '/'): {'ORG': 3},
#  ('Pristina',): {'LOC': 1},
#  ('Kosovo',): {'ORG': 3},
#  ('valge',): {'ORG': 40, 'LOC': 2},
#  ('Slobodan',): {'PER': 10},
#  ('Charles',): {'PER': 16},
#  ('David',): {'PER': 70, 'ORG': 2},
#  ('Soome',): {'ORG': 31, 'LOC': 25, 'PER': 1},
#  ('Liisa',): {'PER': 9},
#  ('BMF', 'Gallup'): {'ORG': 2},
#  ('Nädalalehe', 'Eesti'): {'ORG': 1},
#  ('Paul-Eerik',): {'PER': 8},
#  ('LETA',): {'ORG': 1},
#  ('Mika',): {'PER': 22},
#  ('Heili',): {'PER': 8},
#  ('Krahl',): {'ORG': 4},
#  ('Ardo-Ran',): {'PER': 1},
#  ('Krall',): {'PER': 1},
#  ('Olav',): {'PER': 21},
#  ('Sepo',): {'PER': 7},
#  ('Ilusa',): {'PER': 1},
#  ('Finn',): {'PER': 7},
#  ('Estonia', 'esietenduv'): {'ORG': 1},
#  ('Don',): {'PER': 15},
#  ('kaks',): {'ORG': 1},
#  ('New', 'York'): {'ORG': 37},
#  ('Minnesota',): {'ORG': 2, 'LOC': 2},
#  ('Tim',): {'PER': 21},
#  ('Patrick',): {'PER': 15},
#  ('Allan',): {'PER': 29},
#  ('Atlanta',): {'ORG': 4},
#  ('Indiana',): {'ORG': 12},
#  ('Larry',): {'PER': 7},
#  ('PJ',): {'ORG': 1},
#  ('Latrell',): {'PER': 1},
#  ('Marcus',): {'PER': 17},
#  ('Reggie',): {'PER': 6},
#  ('Mario',): {'PER': 15},
#  ('Avery',): {'PER': 1},
#  ('Gregg',): {'PER': 3},
#  ('Jeff', 'Van'): {'PER': 2},
#  ('Argo',): {'PER': 24},
#  ('Anu',): {'PER': 56, 'ORG': 1},
#  ('Halliste',): {'ORG': 3, 'LOC': 2},
#  ('Ene',): {'PER': 41},
#  ('Neeme',): {'PER': 18, 'LOC': 5, 'ORG': 3},
#  ('Leonhard',): {'PER': 27},
#  ('Mare',): {'PER': 41, 'ORG': 1},
#  ('Eve',): {'PER': 40},
#  ('Omar',): {'PER': 3},
#  ('Aron',): {'PER': 3},
#  ('Red',): {'PER': 3},
#  ('Lauri',): {'PER': 75, 'ORG': 1},
#  ('Dago',): {'PER': 1},
#  ('Erika',): {'PER': 22},
#  ('Reedik',): {'PER': 1},
#  ('Veljo',): {'PER': 9},
#  ('Tiiu',): {'PER': 51},
#  ('Janis',): {'PER': 11},
#  ('Andris',): {'PER': 7},
#  ('mari',): {'PER': 8, 'ORG': 1, 'LOC': 1},
#  ('Anneli', 'Ammas'): {'PER': 1},
#  ('Heido',): {'PER': 5},
#  ('Eesti', 'korteriühistu'): {'ORG': 4},
#  ('Hillar',): {'PER': 21},
#  ('Bertrand',): {'PER': 2},
#  ('Brasiilia',): {'ORG': 3, 'LOC': 1},
#  ('Mexico',): {'LOC': 1, 'ORG': 1},
#  ('Gamal', 'Abdel'): {'PER': 2},
#  ('Anvar',): {'PER': 2},
#  ('Hiina',): {'LOC': 10, 'ORG': 5},
#  ('Vanemuine',): {'ORG': 21},
#  ('Kaarel',): {'PER': 27, 'ORG': 3},
#  ('Thorton', 'Heathi', 'st'): {'ORG': 1},
#  ('Andrew', '’'): {'PER': 1},
#  ('Rakvere', 'lihakombinaat'): {'ORG': 4},
#  ('Age',): {'PER': 5},
#  ('Liina',): {'PER': 44},
#  ('Ullo',): {'PER': 3, 'ORG': 2},
#  ('Lehti',): {'PER': 2},
#  ('Heino',): {'PER': 68, 'ORG': 1},
#  ('Ott',): {'PER': 14, 'ORG': 1},
#  ('Lill',): {'ORG': 1},
#  ('Helju',): {'PER': 18},
#  ('Virve',): {'PER': 3},
#  ('Mait',): {'PER': 42},
#  ('ilma',): {'ORG': 1},
#  ('Maido',): {'PER': 2},
#  ('Vallo',): {'PER': 22},
#  ('Merike',): {'PER': 19},
#  ('Strobe',): {'PER': 5},
#  ('Martti',): {'PER': 15},
#  ('Rootsi',): {'ORG': 9, 'LOC': 11},
#  ('Esko',): {'PER': 3},
#  ('Tarja',): {'PER': 6},
#  ('Kalev',): {'ORG': 14, 'PER': 109},
#  ('kuldne',): {'ORG': 2},
#  ('Jolanta',): {'PER': 1},
#  ('Virgilijus',): {'PER': 6},
#  ('Villu',): {'PER': 69},
#  ('Artur',): {'PER': 19},
#  ('Andry',): {'PER': 2},
#  ('Raimo',): {'PER': 35},
#  ('EPL', '/', 'AFP', '/', 'BNS', '/'): {'ORG': 1},
#  ('Saloniki',): {'ORG': 1},
#  ('Didier',): {'PER': 9, 'ORG': 1},
#  ('Massimo',): {'PER': 3},
#  ('Laurent',): {'PER': 9},
#  ('Garr',): {'PER': 2},
#  ('AS', 'Merko'): {'ORG': 3},
#  ('AS', 'ELL'): {'ORG': 1},
#  ('AS', 'Silmet'): {'ORG': 1},
#  ('OÜ', 'Elmo'): {'ORG': 1},
#  ('A', '&', 'Tova'): {'ORG': 1},
#  ('AS', 'Extreme'): {'ORG': 1},
#  ('Denis',): {'PER': 2, 'ORG': 1},
#  ('Kaspar',): {'PER': 6},
#  ('Tagne',): {'PER': 2},
#  ('Salt', 'Lake'): {'ORG': 13, 'LOC': 2},
#  ('Kaia',): {'PER': 28},
#  ('Margit',): {'PER': 24},
#  ('Sandra',): {'ORG': 2, 'PER': 4},
#  ('Laos',): {'PER': 1},
#  ('Natalja',): {'PER': 23},
#  ('Yago',): {'PER': 1},
#  ('Tibor',): {'PER': 1},
#  ('Chris',): {'PER': 21, 'ORG': 1},
#  ('Stephen',): {'PER': 9},
#  ('Dan',): {'PER': 10},
#  ('DeDee',): {'PER': 1},
#  ('Seilala',): {'PER': 1},
#  ('Kris',): {'PER': 5},
#  ('Aretha',): {'PER': 2},
#  ('Dawn',): {'PER': 1},
#  ('Tamika',): {'PER': 1},
#  ('Windy',): {'PER': 1},
#  ('Elizabeth',): {'PER': 11},
#  ('Alan',): {'PER': 11},
#  ('Bra',): {'ORG': 5, 'PER': 3},
#  ('Abdi',): {'PER': 1},
#  ('LaMark',): {'PER': 1},
#  ('Desmond',): {'PER': 2},
#  ('Prantsusmaa',): {'ORG': 2, 'LOC': 1},
#  ('Eddie',): {'PER': 8},
#  ('Hendrik',): {'PER': 22},
#  ('Elina', 'Reinoldi', 'Evelin'): {'PER': 1},
#  ('Andres', 'Puustusmaa'): {'PER': 1},
#  ('Ago',): {'PER': 11},
#  ('Tõnis', 'Mägi'): {'ORG': 1},
#  ('Anneli', 'Remme'): {'ORG': 1},
#  ('Kuldne',): {'ORG': 4},
#  ('Arkadi',): {'PER': 3},
#  ('BBC',): {'ORG': 23},
#  ('Mihhail',): {'PER': 72},
#  ('Mitsubishi',): {'PER': 1},
#  ('Fontes',): {'ORG': 3},
#  ('Slava',): {'PER': 1},
#  ('Väidetav',): {'PER': 1},
#  ('Väekargaja',): {'PER': 1},
#  ('Puka',): {'LOC': 2},
#  ('Keele',): {'ORG': 2},
#  ('Kate',): {'PER': 12},
#  ('Journal', 'of'): {'ORG': 1},
#  ('Community',): {'PER': 1},
#  ('Naissaar',): {'ORG': 1, 'LOC': 1},
#  ('Harjumaa',): {'LOC': 1, 'ORG': 2},
#  ('era',): {'ORG': 15},
#  ('EVEA',): {'ORG': 11},
#  ('EPL', '/', 'BNS', '/'): {'ORG': 3},
#  ('Davis',): {'ORG': 3},
#  ('Kreeka',): {'ORG': 3, 'LOC': 3},
#  ('Lionel',): {'PER': 7},
#  ('Greg',): {'PER': 7},
#  ('Dominik',): {'PER': 4},
#  ('Goran',): {'PER': 3},
#  ('Tommi',): {'PER': 14},
#  ('Herzliya',): {'ORG': 1},
#  ('Marko',): {'PER': 93},
#  ('Timo',): {'PER': 12},
#  ('Gerd',): {'PER': 15},
#  ('Tarmo',): {'PER': 134},
#  ('Raido',): {'PER': 8},
#  ('Kristo',): {'PER': 8},
#  ('Ragnar',): {'PER': 8},
#  ('Pärnu',): {'LOC': 23, 'ORG': 102, 'PER': 1},
#  ('Taebla',): {'LOC': 1, 'ORG': 2},
#  ('kirimägi',): {'LOC': 1},
#  ('Volkswagen',): {'PER': 6, 'ORG': 3},
#  ('Eri',): {'PER': 4},
#  ('Memoriam', 'Benjamin'): {'PER': 1},
#  ('Susan',): {'PER': 3},
#  ('Yoel',): {'PER': 1},
#  ('Reuters', '/', 'dpa', '/', 'bns', '/'): {'ORG': 1},
#  ('Serbia',): {'ORG': 2, 'LOC': 1},
#  ('Dragan',): {'PER': 1},
#  ('Guntars',): {'PER': 2},
#  ('Vsevolo',): {'PER': 2},
#  ('Galina',): {'PER': 23, 'ORG': 1},
#  ('Severnaja',): {'ORG': 1},
#  ('Russell',): {'PER': 12},
#  ('Geoffrey',): {'PER': 3},
#  ('Surm',): {'PER': 1},
#  ('liberaalne',): {'ORG': 2},
#  ('Nigeeria',): {'ORG': 2},
#  ('Ane',): {'PER': 1},
#  ('Viive',): {'PER': 32},
#  ('Baltic',): {'ORG': 7, 'PER': 13},
#  ('vili',): {'PER': 9},
#  ('Reval', 'Hotel'): {'ORG': 2},
#  ('Ülemkomissar',): {'PER': 1},
#  ('MM',): {'ORG': 4},
#  ('Peterburi',): {'ORG': 5},
#  ('Alajoenkosk',): {'ORG': 2},
#  ('Pensa',): {'ORG': 1},
#  ('Tampere',): {'ORG': 4, 'PER': 1},
#  ('Olle',): {'PER': 4},
#  ('Georgi',): {'PER': 15, 'ORG': 1},
#  ('Ihk',): {'ORG': 1},
#  ('tjumeni',): {'ORG': 1},
#  ('Helsingi',): {'ORG': 16, 'LOC': 1},
#  ('Nizhn', 'Novgorod'): {'ORG': 1},
#  ('Pelle',): {'PER': 2},
#  ('Tartu', 'Ülikool'): {'ORG': 32},
#  ('Harald',): {'PER': 16},
#  ('Valve',): {'PER': 16},
#  ('Arne',): {'PER': 15},
#  ('FIS', 'Marathon'): {'ORG': 1},
#  ('Erik', 'Niiles'): {'PER': 1},
#  ('Romi',): {'PER': 9},
#  ('Georg',): {'PER': 113, 'ORG': 1},
#  ('Go',): {'ORG': 2},
#  ('Code',): {'PER': 6},
#  ('Ricky',): {'PER': 2},
#  ('Vida',): {'PER': 1},
#  ('Basement',): {'ORG': 1, 'PER': 1},
#  ('Flat',): {'PER': 2},
#  ('That', 'Youve'): {'ORG': 1},
#  ('Eesti', 'Kadi'): {'ORG': 1},
#  ('House', 'Of'): {'ORG': 1},
#  ('Electra',): {'PER': 1},
#  ('Mega',): {'ORG': 2},
#  ('Natalia',): {'PER': 3, 'ORG': 1},
#  ('ING', 'Bank'): {'ORG': 1},
#  ('Ove',): {'PER': 4},
#  ('AS', 'Hiiu'): {'ORG': 1},
#  ('Elukindlustusselts',): {'ORG': 1},
#  ('E-Liini',): {'ORG': 1},
#  ('Anders',): {'PER': 3},
#  ('Võru',): {'ORG': 20, 'LOC': 7},
#  ('aktuaalne',): {'PER': 1, 'ORG': 2},
#  ('Reisile',): {'PER': 1},
#  ('Tähe',): {'ORG': 4, 'PER': 5},
#  ('Haabersti', 'vaba', 'aeg'): {'ORG': 2},
#  ('Tallinn', 'Nõmme'): {'ORG': 2},
#  ('Nurme',): {'ORG': 1},
#  ('Joschka',): {'PER': 4},
#  ('Ateena',): {'ORG': 15},
#  ('Salonik',): {'ORG': 2},
#  ('Steamboat',): {'PER': 2},
#  ('Samppa',): {'PER': 4},
#  ('Bjarte', 'Engen'): {'PER': 3},
#  ('Ladislav',): {'PER': 2},
#  ('Jari',): {'PER': 11},
#  ('Einar',): {'PER': 20},
#  ('Fred', 'Børre'): {'PER': 1},
#  ('Ronny',): {'PER': 4},
#  ('Jaakko',): {'PER': 3},
#  ('Toronto',): {'ORG': 8},
#  ('New', 'Jersey'): {'ORG': 3},
#  ('Louis',): {'PER': 10},
#  ('Mike',): {'PER': 25},
#  ('NY',): {'ORG': 7},
#  ('Tampa',): {'ORG': 5},
#  ('st',): {'ORG': 16, 'PER': 1},
#  ('Jiang',): {'PER': 1},
#  ('Wang',): {'PER': 1},
#  ('Lee',): {'PER': 9},
#  ('Royal', 'Philips', 'Electronics'): {'ORG': 1},
#  ('Saks', 'Dresdner'): {'ORG': 1},
#  ('Ühendriik', 'First'): {'ORG': 1},
#  ('B. B.Bredo',): {'PER': 2},
#  ('Taani', 'DFDS', 'Thor'): {'ORG': 1},
#  ('DFDS', 'Thor'): {'ORG': 1},
#  ('Peder', 'Gellert'): {'PER': 1},
#  ('Klaipeda-Stockholm', 'ja'): {'LOC': 1},
#  ('Kristin',): {'PER': 3},
#  ('Al',): {'ORG': 11, 'PER': 16},
#  ('Pauline', 'La', 'Fon'): {'ORG': 1},
#  ('Gore',): {'PER': 3},
#  ('Mary',): {'PER': 4},
#  ('Tennessee',): {'LOC': 2},
#  ('puine',): {'ORG': 1},
#  ('Al', 'Gorei'): {'ORG': 1},
#  ('sama',): {'ORG': 3},
#  ('Natura', 'Law'): {'ORG': 1},
#  ('Philips',): {'PER': 3},
#  ('Web', 'White', '&'): {'PER': 1},
#  ('America',): {'ORG': 1},
#  ('Peedu',): {'PER': 2},
#  ('ETK',): {'ORG': 2},
#  ('Raimond',): {'PER': 12},
#  ('Goitõ',): {'LOC': 1},
#  ('Tina',): {'PER': 2},
#  ('tina',): {'PER': 2},
#  ('Jõgeva', 'Sordiaretus'): {'ORG': 2},
#  ('Haide',): {'PER': 2},
#  ('AS', 'osa', 'ja'): {'ORG': 1},
#  ('Heinrich',): {'PER': 14},
#  ('Polaris',): {'ORG': 13},
#  ('Maire',): {'PER': 13},
#  ('Urmo',): {'PER': 15},
#  ('AS', 'Saks'): {'ORG': 2},
#  ('AS', 'aasta', 'auto'): {'ORG': 1},
#  ('aasta',): {'ORG': 1},
#  ('Ilja',): {'PER': 5},
#  ('Tuumaallveelaev',): {'PER': 1},
#  ('Barentsi',): {'LOC': 6},
#  ('Fallout',): {'PER': 2},
#  ('teras',): {'ORG': 1},
#  ('Merko',): {'ORG': 9, 'PER': 2},
#  ('Reval',): {'ORG': 15, 'PER': 15},
#  ('Rasage',): {'PER': 1},
#  ('Coupe',): {'PER': 1},
#  ('Keep',): {'ORG': 1},
#  ('L', '’'): {'ORG': 5},
#  ('Diesel', 'Zero', 'Plus'): {'ORG': 1},
#  ('Jaanek',): {'PER': 2},
#  ('Erko',): {'PER': 4},
#  ('Sigvard',): {'PER': 2},
#  ('Caspar',): {'ORG': 1, 'PER': 1},
#  ('Aadria',): {'LOC': 2},
#  ('Oscar',): {'PER': 7},
#  ('Abraham',): {'PER': 2},
#  ('Miami',): {'ORG': 8},
#  ('Alonzo',): {'PER': 2},
#  ('Los',): {'ORG': 40},
#  ('Shaquille', 'O'): {'PER': 1},
#  ('Nashville',): {'ORG': 2},
#  ('Edmonton',): {'ORG': 2},
#  ('Arturs',): {'PER': 2},
#  ('Laur',): {'PER': 12},
#  ('Ralph',): {'PER': 5},
#  ('Befrienders',): {'ORG': 2},
#  ('Cha',): {'PER': 2, 'ORG': 1},
#  ('Gustav', 'Adolf'): {'ORG': 6},
#  ('MEGA', 'Tallinn', 'tuletõrje', 'ja'): {'ORG': 1},
#  ('Tallinn', 'täiskasvanu'): {'ORG': 2},
#  ('Kersti',): {'PER': 27},
#  ('ÕL', '/'): {'ORG': 1},
#  ('Carmen',): {'PER': 20},
#  ('Naomi',): {'PER': 2},
#  ('Claudia',): {'PER': 5},
#  ('Gise',): {'ORG': 2, 'PER': 1},
#  ('Cindy',): {'PER': 3},
#  ('Christy',): {'PER': 1},
#  ('Cindy', 'Crawford'): {'PER': 1},
#  ('Vogue',): {'PER': 1},
#  ('Kansas', 'City'): {'ORG': 1},
#  ('Indeks',): {'PER': 2, 'ORG': 1},
#  ('Baötic', 'News'): {'ORG': 1},
#  ('Kenjiro',): {'PER': 1},
#  ('Jutta', 'Kleinschmidt-Tina'): {'PER': 1},
#  ('Jean-Louis', 'Schlesser-Henri'): {'PER': 1},
#  ('Bruno', 'Saby-Yves'): {'PER': 1},
#  ('Kenjiro', 'Shinozuka-Dominique'): {'PER': 1},
#  ('Jean-Pierre', 'Fontenay-Gilles'): {'PER': 1},
#  ('Hiroshi', 'Masuoka-Andreas'): {'PER': 1},
#  ('Peterhansel-Jean-Paul',): {'PER': 1},
#  ('De', 'La', 'Vergne-Jacky'): {'ORG': 1},
#  ('Heinz',): {'PER': 3},
#  ('Kari',): {'PER': 3, 'ORG': 1},
#  ('Clava',): {'ORG': 1},
#  ('Eesti', 'Jalgrattur'): {'ORG': 2},
#  ('FILA',): {'ORG': 1},
#  ('Kentuk',): {'LOC': 1},
#  ('Harold',): {'PER': 5},
#  ('riigikogu', 'Eesti-Ameerika', 'Ühendriik'): {'ORG': 1},
#  ('Georgia',): {'LOC': 1},
#  ('Collin',): {'PER': 1},
#  ('One',): {'PER': 1},
#  ('Göteborg',): {'ORG': 3},
#  ('Groznõi',): {'ORG': 2},
#  ('Aslanbek',): {'PER': 1},
#  ('Sunža',): {'LOC': 2},
#  ('Aslan',): {'PER': 11},
#  ('VW',): {'ORG': 3},
#  ('Jeep',): {'PER': 1},
#  ('Heimtali-Uus',): {'PER': 1},
#  ('Kaassõitja',): {'PER': 1},
#  ('piir',): {'LOC': 1},
#  ('keskkriminaalpolitsei', 'Lõuna'): {'ORG': 1},
#  ('Tallinn', 'linnavolikogu'): {'ORG': 1},
#  ('Evelyn',): {'PER': 7},
#  ('tühi',): {'ORG': 1},
#  ('miljon',): {'ORG': 1},
#  ('Hotell',): {'PER': 1},
#  ('Viru',): {'ORG': 31},
#  ('Qioge',): {'PER': 2},
#  ('Huangzhong',): {'LOC': 1},
#  ('Vilma',): {'PER': 3},
#  ('Toomas', 'Hendrik'): {'PER': 32},
#  ('Günter',): {'PER': 5},
#  ('Viivi',): {'PER': 12},
#  ('Väike',): {'LOC': 1},
#  ('Rooma',): {'LOC': 6, 'PER': 2, 'ORG': 4},
#  ('luule',): {'PER': 5},
#  ('Merry',): {'PER': 2},
#  ('Santa',): {'PER': 7, 'ORG': 2},
#  ('Kaspia',): {'LOC': 2},
#  ('Gerhard',): {'PER': 24},
#  ('Pekka',): {'PER': 3},
#  ('Asekantsler',): {'PER': 2},
#  ('Estonia',): {'ORG': 22},
#  ('Tauno',): {'PER': 8},
#  ('Astor',): {'PER': 1},
#  ...}

# %%
# making first words mapping keys strings to allow convenient dataframe creation
first_words_map = {str(k):v for k,v in first_words_map.items()}

# %%
last_word_map
# Out:
# {'Lauriste': {'PER': 2},
#  'III': {'PER': 10, 'ORG': 3},
#  'Shady': {'PER': 1},
#  'Smith': {'PER': 14},
#  'Basinger': {'PER': 3},
#  'Murphy': {'PER': 1},
#  'Grazer': {'PER': 1},
#  'Hanson': {'PER': 24},
#  'Confidential': {'ORG': 2},
#  'Boys': {'PER': 4},
#  'York': {'LOC': 21, 'ORG': 84, 'PER': 1},
#  'Styler': {'PER': 2},
#  'Fond': {'ORG': 11, 'PER': 2, 'LOC': 1},
#  'Films': {'PER': 2},
#  'Ritchie': {'PER': 1},
#  'Barrels': {'ORG': 1},
#  'teatrikool': {'ORG': 2},
#  'ise': {'PER': 4},
#  'Tomelty': {'PER': 1},
#  'McCartneyst': {'PER': 1},
#  'Haljand': {'PER': 3},
#  'Samuel': {'PER': 2},
#  'Jeruusalemm': {'PER': 1},
#  'Pajusaar': {'PER': 1},
#  'Blue': {'ORG': 2, 'PER': 1},
#  'Pilvre': {'PER': 5},
#  'Toome': {'PER': 18},
#  'Murutar': {'PER': 5},
#  'Kuldbek': {'PER': 1},
#  'Sangar': {'ORG': 1},
#  'Kallas': {'PER': 106},
#  'kool': {'ORG': 53, 'PER': 1},
#  'Mare': {'LOC': 19},
#  'Paul': {'PER': 6},
#  'Eenmaa': {'PER': 21},
#  'maripuu': {'PER': 5},
#  'Rahumägi': {'PER': 5},
#  'Randpere': {'PER': 1},
#  'Gräzin': {'PER': 6},
#  'Maripuu': {'PER': 14},
#  'Aurum': {'PER': 1},
#  'Kuulman': {'PER': 1},
#  'randpere': {'ORG': 1},
#  'kibe': {'PER': 1},
#  'Collins': {'PER': 6},
#  'Gibson': {'PER': 4},
#  'Hurlstone': {'PER': 1},
#  'Letters': {'ORG': 1},
#  'NORMANN': {'ORG': 1},
#  'MILLINGu': {'ORG': 1},
#  'Karelson': {'PER': 2},
#  'Haavel': {'PER': 3},
#  'Kalabugin': {'PER': 1},
#  'küla': {'LOC': 125},
#  'riik': {'LOC': 386, 'PER': 4},
#  'liit': {'ORG': 148, 'LOC': 91},
#  'selts': {'ORG': 35},
#  'Lettens': {'PER': 3},
#  'Selts': {'ORG': 11, 'PER': 1},
#  'Kõrvel': {'PER': 1},
#  'Johannes': {'PER': 3, 'ORG': 2},
#  'halduskohus': {'ORG': 23},
#  'meier': {'ORG': 1},
#  'Meister': {'PER': 3, 'ORG': 1},
#  'saar': {'LOC': 100, 'ORG': 6},
#  'list': {'PER': 2},
#  'Prescott': {'PER': 2},
#  'Veritas': {'PER': 4},
#  'Werft': {'PER': 1},
#  'II': {'PER': 48, 'ORG': 8},
#  'Sjöblom': {'PER': 1},
#  'Thulin': {'ORG': 1},
#  'Veritase': {'PER': 1},
#  'Sea': {'PER': 6},
#  'Estline': {'ORG': 1},
#  'meri': {'ORG': 1, 'LOC': 57},
#  'puhul': {'ORG': 2},
#  'Vöörmann': {'PER': 3},
#  'laevakompanii': {'ORG': 22},
#  'Leedo': {'PER': 7},
#  'Nautex': {'ORG': 2},
#  'Purru': {'PER': 2},
#  'Liin': {'ORG': 4, 'PER': 1},
#  'Martin': {'PER': 17},
#  'Sviby-Rohuküla': {'LOC': 1},
#  'Leedol': {'PER': 2},
#  'Nestor': {'PER': 25},
#  'ametiühing': {'ORG': 1},
#  'Lember': {'PER': 9},
#  'Salusoo': {'PER': 1},
#  'Varele': {'PER': 2},
#  'tööinspektsioon': {'ORG': 2},
#  'tervisekaitsekeskus': {'ORG': 1},
#  'lamp': {'PER': 5, 'ORG': 1},
#  'Salupere': {'PER': 1},
#  'Järvesoole': {'PER': 2},
#  'järvesoo': {'PER': 2},
#  'vabariik': {'LOC': 260, 'ORG': 1},
#  'koit': {'PER': 1},
#  'Vaher': {'PER': 18},
#  'linn': {'LOC': 208, 'ORG': 3},
#  'Trossmann': {'PER': 1},
#  'Popov': {'PER': 2},
#  'Hornfischer': {'PER': 1},
#  'Kivine': {'PER': 6},
#  'Hololei': {'PER': 7},
#  'Koik': {'PER': 3},
#  'Jürjo': {'PER': 2},
#  '”': {'ORG': 100},
#  'Belokon': {'PER': 2},
#  'Iliste': {'PER': 2},
#  'Rebane': {'PER': 50},
#  'Sepp': {'PER': 30},
#  'Forman': {'PER': 1},
#  'Ming-liang': {'PER': 1},
#  'Heumann': {'PER': 1},
#  'Binoche': {'PER': 2},
#  'Minghella': {'PER': 2},
#  'DiCaprio': {'PER': 2},
#  'Luhrmann': {'PER': 1},
#  'Ruiz': {'PER': 1},
#  'psühhiaatriahaigla': {'ORG': 1},
#  'Kross': {'PER': 21, 'ORG': 1},
#  'gümnaasium': {'ORG': 81},
#  'Tonts': {'PER': 3},
#  'humanitaarinstituut': {'ORG': 3},
#  'Peterson': {'PER': 18},
#  'lasteteater': {'ORG': 1},
#  'teater': {'ORG': 72},
#  'Draamateater': {'ORG': 18, 'LOC': 4},
#  'Ugala': {'ORG': 1, 'PER': 1},
#  'Krahl': {'PER': 4},
#  'Dvinjaninov': {'PER': 7},
#  'Unt': {'PER': 24},
#  'Tooming': {'PER': 17},
#  'Kaasik': {'PER': 17},
#  'Minajeva': {'PER': 1},
#  'Ühendriik': {'LOC': 75, 'ORG': 1},
#  'Liit': {'ORG': 33, 'LOC': 59},
#  'Luhaäär': {'PER': 2},
#  'Vesk': {'PER': 14},
#  'Kolts': {'PER': 3},
#  'Sild': {'PER': 13},
#  'kalur': {'ORG': 8},
#  'Palli': {'PER': 1},
#  'Kukk': {'PER': 36},
#  'kukk': {'PER': 1},
#  'Sams': {'PER': 1},
#  'keskkool': {'ORG': 39},
#  'Ilison': {'PER': 2},
#  'Kukke': {'PER': 2},
#  'Taagepera': {'PER': 5},
#  'Kuke': {'PER': 16, 'ORG': 1},
#  'Curiest': {'PER': 1},
#  'Mõisaküla': {'PER': 1, 'LOC': 1},
#  'Jõers': {'PER': 2},
#  'Jõersile': {'PER': 1},
#  'Ülikool': {'ORG': 199, 'PER': 1},
#  'Tamm': {'PER': 48, 'ORG': 1},
#  'Past': {'PER': 3},
#  'Ehrlich': {'PER': 1, 'ORG': 1},
#  'Silk': {'PER': 1},
#  'Alumaa': {'PER': 1},
#  'suurkool': {'ORG': 1},
#  'tamm': {'PER': 1},
#  'Allsalu': {'PER': 1},
#  'Koop': {'PER': 2},
#  'Talur': {'PER': 1},
#  'Niklus': {'PER': 4},
#  'Register': {'ORG': 2},
#  'Viigilt': {'PER': 1},
#  'Rannamäe': {'PER': 53},
#  'Luik': {'PER': 35},
#  'Reuters': {'ORG': 7, 'PER': 2},
#  'Julgeolekunõukogu': {'ORG': 7},
#  'valik': {'ORG': 4},
#  'Primakov': {'PER': 8},
#  'Stepashin': {'PER': 2},
#  'Putin': {'PER': 38},
#  'Hussein': {'PER': 33, 'ORG': 1},
#  'Luige': {'PER': 8},
#  'Raudam': {'PER': 4},
#  'Külvet': {'PER': 2},
#  'Shakespeare': {'PER': 2, 'ORG': 1},
#  'Baldwin': {'PER': 2},
#  'Bellow': {'PER': 1},
#  'Mirnõi': {'PER': 1},
#  'Bovaryst': {'PER': 1},
#  'Rand': {'PER': 40},
#  'rand': {'PER': 1, 'ORG': 4},
#  'Randiks': {'PER': 1},
#  'Tölner': {'PER': 1},
#  'Gulliver': {'PER': 1},
#  'Zenot': {'PER': 1},
#  'Lowryt': {'PER': 1},
#  'Kaldre': {'PER': 1},
#  'Föderatsioon': {'LOC': 26, 'ORG': 3, 'PER': 1},
#  'siga': {'PER': 2},
#  'Berezovski': {'PER': 4},
#  'Petrovitsha': {'ORG': 1},
#  'Sojuza': {'PER': 1},
#  'poolpolitseiriik': {'LOC': 1},
#  'Alaska': {'LOC': 1},
#  'Petrov': {'PER': 4},
#  'Carnegie': {'PER': 4},
#  'valitsus': {'ORG': 295},
#  'Piskoppel': {'PER': 1},
#  'Jakushkin': {'PER': 1},
#  'Reest': {'PER': 1},
#  'Piller': {'PER': 3},
#  'matusebüroo': {'ORG': 6},
#  'krematoorium': {'ORG': 3},
#  'Daum': {'PER': 2},
#  'Nielsen': {'PER': 5, 'ORG': 1},
#  'Kisler': {'PER': 1},
#  'haigla': {'ORG': 112},
#  'Attack': {'PER': 2},
#  'Cadillac': {'ORG': 1},
#  'Rohtla': {'PER': 3},
#  'Krematoorium': {'ORG': 1},
#  'Tõnissoo': {'PER': 3},
#  'osariik': {'LOC': 35},
#  'Villand': {'PER': 1},
#  'Piilpärk': {'PER': 1},
#  'Jõgi': {'PER': 9},
#  'Loognal': {'PER': 1},
#  'Lääne': {'PER': 10, 'LOC': 1},
#  'Kala': {'PER': 5},
#  'Toomsalu': {'PER': 103},
#  'instituut': {'ORG': 39},
#  'arhitektuur': {'ORG': 3},
#  'Element': {'ORG': 1},
#  'Graph': {'ORG': 1},
#  'mikroarhitektuur': {'ORG': 1},
#  'ringstruktuur': {'ORG': 1},
#  'Buffer': {'ORG': 1},
#  'Machine': {'ORG': 1, 'PER': 3},
#  'Interface': {'ORG': 1},
#  'Sõrg': {'PER': 3},
#  'Vabariik': {'LOC': 49, 'PER': 1},
#  'Liidu': {'ORG': 503, 'LOC': 43},
#  'Tõnisson': {'PER': 29},
#  'Inno': {'PER': 1},
#  'Statistika': {'ORG': 1},
#  'areng': {'ORG': 2},
#  'LTB': {'ORG': 1},
#  'Panga': {'ORG': 99, 'PER': 4},
#  'HLÜ': {'ORG': 7},
#  'Silberg': {'PER': 1},
#  'maakond': {'LOC': 63},
#  'Blank': {'PER': 3},
#  'Mereste': {'PER': 6},
#  'Union': {'ORG': 4, 'PER': 1},
#  'ühispank': {'ORG': 12},
#  'Salomo': {'PER': 1},
#  'pank': {'ORG': 96},
#  'Pank': {'ORG': 20, 'PER': 1},
#  'Virtuaal-Helsingi': {'ORG': 1},
#  'võlu': {'ORG': 1},
#  'Ltd': {'PER': 8, 'ORG': 2},
#  'Tšaikovski': {'PER': 2},
#  'Kagan': {'PER': 1},
#  'Playberg': {'PER': 1},
#  'Beatles': {'PER': 1},
#  'Girls': {'PER': 5},
#  'Michaelson': {'PER': 1},
#  'Faile': {'PER': 1},
#  'fail': {'ORG': 3},
#  'Ernits': {'PER': 7},
#  'Luubile': {'PER': 2},
#  'Kama': {'PER': 3},
#  'parlament': {'ORG': 47},
#  '2': {'ORG': 13, 'PER': 1},
#  'Lacto': {'ORG': 1},
#  'Sharif': {'ORG': 1},
#  'Massudi': {'PER': 1},
#  'Araabia': {'LOC': 26},
#  'Laden': {'PER': 35},
#  'ookean': {'LOC': 67, 'PER': 1, 'ORG': 4},
#  'India': {'ORG': 3},
#  'ühendemiraat': {'LOC': 6},
#  'Talibanile': {'LOC': 1},
#  'Suur': {'ORG': 1, 'PER': 9},
#  'poolsaar': {'LOC': 32, 'ORG': 1},
#  'Saud': {'PER': 1},
#  'Kiisel': {'PER': 1},
#  'Beck': {'PER': 1},
#  'Liere': {'PER': 2},
#  'Becki': {'PER': 2},
#  'Christopher': {'PER': 2},
#  'keskkonnastrateegia': {'ORG': 1},
#  'Publica': {'ORG': 68},
#  'Läänelaid': {'PER': 2},
#  'Vaga': {'PER': 4},
#  'kirik': {'ORG': 31, 'PER': 2},
#  'tiirmaa': {'PER': 1},
#  'Vagalt': {'PER': 1},
#  'Alttuba': {'PER': 1},
#  'Bartholin': {'PER': 1},
#  'Zetterberg': {'PER': 1},
#  'Lund': {'ORG': 1},
#  'ülikool': {'ORG': 240},
#  'Lev': {'PER': 2},
#  'rahvusmuuseum': {'ORG': 1},
#  'Greisinger': {'PER': 1},
#  'Kraepelin': {'PER': 1},
#  'W. Eaton': {'PER': 1},
#  'J. Weil': {'PER': 1},
#  'Teiverlaur': {'PER': 1},
#  'nord': {'ORG': 1},
#  'Päevaleht': {'ORG': 151},
#  'Reivart': {'PER': 8},
#  'ajuvapustus': {'ORG': 1},
#  'politseiprefektuur': {'ORG': 46},
#  'Linask': {'PER': 2},
#  'Kalda': {'PER': 8},
#  'prefektuur': {'ORG': 17},
#  'Ringo': {'PER': 1},
#  'AP': {'ORG': 1, 'PER': 1},
#  'vald': {'LOC': 199},
#  'politsei': {'ORG': 126},
#  'Service': {'ORG': 79, 'PER': 1},
#  'Mobiiltelefon': {'ORG': 5},
#  'Eesti': {'ORG': 10, 'LOC': 3},
#  'GSM': {'ORG': 4},
#  'Vilaka': {'ORG': 1},
#  'KALV': {'PER': 1},
#  'tehnikaülikool': {'ORG': 38},
#  'Tähetorn': {'ORG': 1},
#  'Lehto': {'PER': 1},
#  'Jaanis': {'PER': 1},
#  'Kesk-Venemaa': {'LOC': 1},
#  'Meeus': {'PER': 1},
#  'Kook': {'PER': 5},
#  'Heinsalu': {'PER': 2},
#  'Rumm': {'PER': 9},
#  'riigikogu': {'ORG': 2},
#  'Leito': {'PER': 2},
#  'Hõbemägi': {'PER': 11},
#  'Tammist': {'PER': 4},
#  'Sakk': {'PER': 2},
#  'Pulver': {'PER': 5, 'ORG': 2},
#  'Uuskam': {'PER': 1},
#  'Soo': {'PER': 4},
#  'Nõmmik': {'PER': 2},
#  'Hiiumaa': {'LOC': 4},
#  'maavalitsus': {'ORG': 42},
#  'Lasnamäe': {'ORG': 1},
#  'linnaosa': {'LOC': 42},
#  'Estonia': {'ORG': 6, 'PER': 12},
#  'pedagoogikaülikool': {'ORG': 14},
#  'Raukas': {'PER': 8},
#  'geoloogia': {'ORG': 1},
#  'Aster': {'ORG': 3},
#  'Kristiine': {'ORG': 3, 'PER': 2},
#  'linnakohus': {'ORG': 67},
#  'Kaubamaja': {'ORG': 10},
#  'Korb': {'PER': 1},
#  'kuusk': {'PER': 2},
#  'Kalbergile': {'PER': 1},
#  'Securitas': {'ORG': 2},
#  'kaitseliit': {'ORG': 7},
#  'Põldoja': {'PER': 7},
#  'Ottey': {'PER': 3},
#  'Interfax': {'ORG': 3},
#  'Kostov': {'PER': 1},
#  'Lanka': {'LOC': 5},
#  'Kumaratungat': {'PER': 1},
#  'Stalin': {'PER': 1, 'ORG': 1},
#  'Demirel': {'PER': 1},
#  'Pajula': {'PER': 37},
#  'Isok': {'PER': 1},
#  'Bond': {'PER': 2},
#  'Connery': {'PER': 5},
#  'McCartney': {'PER': 3},
#  'Richard': {'PER': 2, 'ORG': 1},
#  'John': {'PER': 18},
#  'Blair': {'PER': 23},
#  'Thatcher': {'PER': 6},
#  'Churchill': {'PER': 3},
#  'Strong': {'PER': 1},
#  'siseministeerium': {'ORG': 13},
#  'Morozov': {'PER': 3},
#  'Vaasma': {'PER': 2},
#  'Malmberg': {'PER': 2},
#  'Viru-Jaagup': {'ORG': 1},
#  'Oviir': {'ORG': 1, 'PER': 41},
#  'I': {'ORG': 22, 'PER': 24},
#  'taremaa': {'ORG': 1},
#  'EPL': {'ORG': 19, 'PER': 1},
#  'Cutileiro': {'PER': 1},
#  'Remme': {'PER': 1},
#  'Antiqua': {'PER': 2},
#  'Goebel': {'PER': 2},
#  'Battaglia': {'PER': 1},
#  'Saks': {'PER': 23, 'ORG': 1, 'LOC': 1},
#  'Oras': {'PER': 4},
#  'Pajuste': {'PER': 2},
#  'Vike-Freiberga': {'PER': 8},
#  'Ida-Euroopa': {'LOC': 2},
#  'Ulmanis': {'PER': 2},
#  'Gorbunovs': {'PER': 1},
#  'Pauls': {'PER': 3},
#  'vabadus': {'ORG': 2},
#  'liikumine': {'ORG': 6},
#  'tee': {'ORG': 8, 'PER': 2},
#  'rahvaerakond': {'ORG': 3},
#  'Arike': {'PER': 18},
#  'allikas': {'PER': 15},
#  'Nool': {'PER': 54},
#  'Kaseorg': {'PER': 16},
#  'Rünne': {'PER': 5},
#  'Tammert': {'PER': 16},
#  'Siilats': {'PER': 7},
#  'Salumäe': {'PER': 24},
#  'Uusorg': {'PER': 4},
#  'Kergejõustikuliit': {'ORG': 2},
#  'Uudmäe': {'PER': 1},
#  'nool': {'PER': 5},
#  'Dvorak': {'PER': 4},
#  'Arjakas': {'PER': 16},
#  'entsüklopeediakirjastus': {'ORG': 3},
#  'Päts': {'PER': 10, 'ORG': 1},
#  'Ilmjärv': {'PER': 2},
#  'Laidoner': {'PER': 5},
#  'Rei': {'PER': 4},
#  'Piirsalu': {'PER': 11},
#  'kriminaalpolitsei': {'ORG': 21},
#  'Jaggo': {'PER': 1},
#  'Murre': {'PER': 2},
#  'Draganov': {'ORG': 1, 'PER': 1},
#  'Daily': {'ORG': 2},
#  'bns': {'ORG': 13},
#  'Petkovsk': {'PER': 1},
#  'Trajkovsk': {'PER': 1},
#  'Ammas': {'PER': 32},
#  'Sukles': {'PER': 10},
#  'Liberaal': {'ORG': 1},
#  'Maiste': {'PER': 4},
#  'elu': {'ORG': 29},
#  'Ilves': {'PER': 56, 'ORG': 1},
#  'Lipstok': {'PER': 14},
#  'elekter': {'ORG': 14},
#  'Kanepi': {'PER': 11},
#  'linnavolikogu': {'ORG': 60},
#  'Uluots': {'PER': 2},
#  'Kranich': {'PER': 18},
#  'Tischler': {'PER': 6},
#  'Pinn': {'PER': 1},
#  'Sedman': {'PER': 1},
#  'Erakond': {'ORG': 22},
#  'Väli': {'PER': 12},
#  'Beeren': {'PER': 1},
#  'Paju': {'PER': 13},
#  'Padama': {'PER': 1},
#  'savisaar': {'PER': 5},
#  'Mets': {'PER': 10, 'ORG': 1},
#  'Margus': {'PER': 2},
#  'omavalitsus': {'ORG': 16, 'LOC': 1},
#  'Tamkivi': {'PER': 3},
#  'Saare': {'PER': 15, 'ORG': 1, 'LOC': 1},
#  'Aardam': {'PER': 1},
#  'maa': {'ORG': 18, 'LOC': 1},
#  'Tuisk': {'PER': 7},
#  'meelisepl.ee': {'PER': 1},
#  'karusoo': {'PER': 3},
#  'Jänes': {'PER': 4},
#  'Puustusmaa': {'PER': 3},
#  'Teplenkov': {'PER': 3},
#  'Tabor': {'PER': 1},
#  'Palmiste': {'PER': 4, 'ORG': 1},
#  'Avdjushko': {'PER': 4},
#  'Maibaum': {'PER': 2},
#  'Pihlaku': {'PER': 2},
#  'Rooma': {'PER': 2, 'ORG': 1},
#  'Barjabin': {'PER': 1},
#  'park': {'ORG': 14, 'PER': 1},
#  'Järve': {'PER': 9},
#  'Koorti': {'PER': 1},
#  'majandusministeerium': {'ORG': 7},
#  'maakohus': {'ORG': 58},
#  'Rekesontile': {'ORG': 1},
#  'Alliance': {'PER': 1, 'ORG': 1},
#  'Leppik': {'PER': 15},
#  'Telefon': {'ORG': 54},
#  'kaardikeskus': {'ORG': 5},
#  'Aun': {'PER': 3},
#  'balti': {'LOC': 5, 'ORG': 1},
#  'Baltija': {'ORG': 4, 'PER': 2},
#  'Grupp': {'ORG': 15, 'PER': 12},
#  'Grupi': {'ORG': 1, 'PER': 3},
#  'Udu': {'PER': 1},
#  'udu': {'PER': 1},
#  'Storbeck-Cloete': {'PER': 2},
#  'Tarassov': {'PER': 5},
#  'Markov': {'PER': 3},
#  'Hartwig': {'PER': 2},
#  'Galfione': {'PER': 3},
#  'Barmasai': {'PER': 3},
#  'Kipketer': {'PER': 2},
#  'Jones': {'PER': 21, 'ORG': 13},
#  'Miller': {'PER': 21},
#  'Greene': {'PER': 4},
#  'Fredericks': {'PER': 3},
#  'Thompson': {'PER': 8},
#  'Ngeny': {'PER': 2},
#  'Lagat': {'PER': 1},
#  'Morceli': {'PER': 1},
#  'Rotich': {'PER': 1},
#  'Limo': {'PER': 2},
#  'Hissou': {'PER': 1},
#  'Lahlabi': {'PER': 1},
#  'Komen': {'PER': 1},
#  'Beckford': {'PER': 2},
#  'Moudrik': {'PER': 1},
#  'Streete-Thompson': {'PER': 1},
#  'Gatsioudis': {'PER': 2},
#  'Hecht': {'PER': 1},
#  'Makarov': {'PER': 9},
#  'Backley': {'PER': 1},
#  'Henry': {'PER': 3},
#  'Zhelezny': {'PER': 1},
#  'Mutola': {'PER': 3},
#  'Formanova': {'PER': 2},
#  'Masterkova': {'PER': 3},
#  'Alozie': {'PER': 1},
#  'Shishigina': {'PER': 2},
#  'Morrison': {'PER': 3},
#  'Engqvist': {'PER': 1},
#  'Babakova': {'PER': 1},
#  'Dinescu-Iagar': {'PER': 1},
#  'Oinus': {'PER': 1},
#  'Wiklar': {'ORG': 1},
#  'Valge': {'PER': 3, 'ORG': 1},
#  'Kuusmaa': {'PER': 23},
#  'võru': {'LOC': 1},
#  'Kopli': {'PER': 19, 'ORG': 2},
#  'Clinton': {'PER': 48, 'ORG': 1},
#  'Lewinsky': {'PER': 8},
#  'Peensoo': {'PER': 35},
#  'Reial': {'PER': 1},
#  'Soon': {'PER': 3},
#  'Raamatukogu': {'ORG': 2},
#  'nutt': {'PER': 4},
#  'Liige': {'ORG': 1},
#  'Tiidole': {'PER': 1},
#  'Gluhhov': {'PER': 1},
#  'Simon': {'PER': 3},
#  'Mõis': {'PER': 58, 'ORG': 6},
#  'Laar': {'PER': 87, 'ORG': 1},
#  'Tamjärv': {'PER': 4},
#  'Lao': {'PER': 3},
#  'Lõhmus': {'PER': 31, 'ORG': 2},
#  'Laupa': {'PER': 2},
#  'Neivelt': {'PER': 14},
#  'Suhhotskaja': {'PER': 2},
#  'Karjahärm': {'PER': 2},
#  'Kilgase': {'PER': 2},
#  'WaterhouseCoopers': {'PER': 1},
#  'Motors': {'ORG': 6},
#  'Escort': {'PER': 1},
#  'Spurs': {'PER': 3},
#  'Lakers': {'ORG': 10, 'PER': 1},
#  'Bryant': {'PER': 3, 'ORG': 1},
#  'Jackson': {'PER': 15},
#  'Jersey': {'ORG': 13},
#  'Horn': {'ORG': 1, 'PER': 6},
#  'Antonio': {'ORG': 8, 'LOC': 1, 'PER': 1},
#  'State': {'ORG': 6},
#  'Clippers': {'ORG': 7},
#  'Clipper': {'ORG': 1},
#  '24': {'ORG': 3, 'PER': 2},
#  'Exel': {'PER': 5},
#  'ühtsus': {'ORG': 2},
#  'Vasetshkini': {'PER': 1},
#  'Ühtsus': {'ORG': 6},
#  'Barkashov': {'PER': 1},
#  'kaitsepolitsei': {'ORG': 2},
#  'ringkonnakohus': {'ORG': 38},
#  'Bairashi': {'PER': 1},
#  'Otetshestvo': {'ORG': 1},
#  'Tõeleid': {'PER': 2},
#  'Post': {'ORG': 49, 'PER': 9},
#  'Kuusk': {'PER': 13},
#  'OÜ': {'ORG': 39, 'PER': 6},
#  'Talts': {'PER': 16},
#  'Alatalu': {'PER': 18},
#  'Meri': {'PER': 104},
#  'Niguliste': {'PER': 1},
#  'Tenno': {'PER': 12},
#  'Hvostov': {'PER': 2},
#  'Akadeemia': {'ORG': 14, 'PER': 1},
#  'Tuglas': {'PER': 3},
#  'Semper': {'PER': 5, 'ORG': 1},
#  'Vilde': {'PER': 5, 'ORG': 1},
#  'Gailit': {'PER': 1},
#  'Johanseni': {'PER': 1},
#  'Solovjov': {'PER': 2},
#  'Bon': {'ORG': 1},
#  'Spengler': {'PER': 1},
#  'Ristikivi': {'PER': 4},
#  'Jerofejev': {'PER': 1},
#  'Pelevin': {'PER': 1},
#  'Valter': {'PER': 3},
#  'Kivirähk': {'PER': 16},
#  'Jashtshenko': {'PER': 1},
#  'Haitov': {'PER': 1},
#  'Nõukogu': {'ORG': 24},
#  'Grinshpun': {'PER': 1},
#  'Bondartshuk': {'PER': 1},
#  'Kannik': {'PER': 5},
#  'linnriik': {'LOC': 2},
#  'Kändler': {'PER': 12},
#  'T': {'ORG': 2},
#  'Harvard': {'LOC': 1},
#  'Scient': {'ORG': 3},
#  'Instituud': {'ORG': 10, 'PER': 1},
#  'Kalev': {'ORG': 37, 'PER': 6},
#  'Pirnpuu': {'PER': 1},
#  'Lepikson': {'PER': 24},
#  'Laarile': {'PER': 3},
#  'teataja': {'ORG': 85},
#  'Holmi': {'PER': 1},
#  'Kirs': {'PER': 15},
#  'Cortes': {'ORG': 1},
#  'Rahvapartei': {'ORG': 30},
#  'sadam': {'ORG': 28},
#  'akropol-A': {'ORG': 2},
#  'Sadam': {'ORG': 29, 'PER': 4},
#  'Proos': {'PER': 5},
#  'AS': {'ORG': 106, 'PER': 5},
#  'Lutter': {'PER': 4},
#  'Toots': {'PER': 11},
#  'Rasmann': {'PER': 2},
#  'Kannel': {'PER': 2},
#  'partei': {'ORG': 40},
#  'Zjuganov': {'PER': 4},
#  'Jeltsin': {'PER': 26},
#  'Selesnjov': {'PER': 1},
#  'Kulik': {'PER': 1},
#  'Masljukov': {'PER': 1},
#  'Seleznjov': {'PER': 8},
#  'oblast': {'LOC': 22},
#  'Tulejev': {'PER': 2},
#  'Stoel': {'PER': 3},
#  'Volkskrant': {'ORG': 2},
#  'Mälk': {'PER': 6},
#  'Narayanan': {'PER': 1},
#  'Vajpaye': {'PER': 1},
#  'Sabha': {'PER': 1},
#  'Balayog': {'ORG': 1},
#  'Kant': {'PER': 3},
#  'Bendreus': {'PER': 1},
#  '.': {'ORG': 79, 'PER': 2, 'LOC': 5},
#  'Perolainen': {'PER': 1},
#  'Hänni': {'PER': 11, 'ORG': 1},
#  'assamblee': {'ORG': 15, 'LOC': 1},
#  'Kelam': {'PER': 26},
#  'Ojuland': {'PER': 14},
#  'Telgmaa': {'PER': 1},
#  'raepress': {'ORG': 2},
#  'kaabeltelevisioon': {'ORG': 1},
#  'Velmani': {'PER': 1},
#  'Heidov': {'PER': 2},
#  'Rajasalu': {'PER': 2},
#  'Dormidontov': {'PER': 1},
#  'keskus': {'ORG': 72},
#  'Citrina': {'ORG': 1},
#  'Karisel': {'PER': 1},
#  'Karis': {'PER': 2},
#  'meditsiiniinstituut': {'ORG': 1},
#  'Dafn': {'ORG': 1},
#  'Müürsepp': {'PER': 29},
#  'Shklover': {'PER': 1},
#  'Mintals': {'ORG': 1},
#  'Prix': {'PER': 3, 'ORG': 1},
#  'Savtshenko': {'PER': 1},
#  'malemaja': {'ORG': 1},
#  'Seeman': {'PER': 8},
#  'Liiva': {'PER': 14, 'ORG': 3},
#  'Külaots': {'PER': 3},
#  'Henriques': {'PER': 1},
#  'Guerra': {'PER': 1},
#  'Cheromei': {'PER': 1},
#  'Worku': {'PER': 1},
#  'Maranga': {'PER': 1},
#  'Blazers': {'ORG': 3},
#  'Suns': {'ORG': 2},
#  'Gugliottat': {'PER': 1},
#  'Australian': {'ORG': 1},
#  'Corporation': {'ORG': 8, 'PER': 1},
#  'Moresby': {'PER': 1},
#  'Eipre': {'PER': 4},
#  'Eiprele': {'PER': 1},
#  'Sassian': {'PER': 1},
#  'Kalamees': {'PER': 27, 'ORG': 1},
#  'Kiv': {'PER': 9},
#  'televisioon': {'ORG': 61},
#  'raadio': {'ORG': 41},
#  'Herkel': {'PER': 10},
#  'Kivi': {'PER': 32},
#  'Meelis': {'PER': 1},
#  'aianduskooperatiiv': {'ORG': 1},
#  'Sõle': {'ORG': 2, 'PER': 1},
#  'Hiace': {'PER': 3},
#  'Lauda': {'PER': 3},
#  'Air': {'ORG': 44, 'PER': 3},
#  'Tampõld': {'PER': 3},
#  'Leiger': {'PER': 2},
#  'leigerist': {'PER': 1},
#  'vallavalitsus': {'ORG': 25},
#  'Mishinal': {'PER': 1},
#  'Koitver': {'PER': 1},
#  'kohus': {'ORG': 22},
#  'kesklinn': {'LOC': 2},
#  'Ülem-Drenica': {'ORG': 1},
#  'maja': {'ORG': 51},
#  'Milosevic': {'PER': 10},
#  'Guthrie': {'PER': 1},
#  'Wilby': {'PER': 1},
#  'Jaakonsaari': {'PER': 2},
#  'Lipponen': {'PER': 7},
#  'Media': {'ORG': 3, 'PER': 2},
#  'Ekspress': {'ORG': 49},
#  'päevaleht': {'ORG': 21},
#  'ekspress': {'ORG': 7},
#  'Raadio': {'ORG': 48},
#  'Rummo': {'PER': 8},
#  'Saarna': {'PER': 4},
#  'Televisioon': {'ORG': 28},
#  'Schumacher': {'PER': 18},
#  'Salo': {'PER': 5},
#  'Vaus': {'PER': 5},
#  'Bertmani': {'PER': 1},
#  'Varres': {'PER': 1},
#  'Krall': {'PER': 3},
#  'Linnahall': {'PER': 1},
#  'Ehala': {'PER': 6},
#  'Seemann': {'PER': 1},
#  'Helena': {'PER': 4},
#  'Poulsen': {'PER': 5},
#  'Dvinjaninovile': {'PER': 1},
#  'Mozart': {'ORG': 1},
#  'Giovanni': {'PER': 1},
#  'torn': {'ORG': 2},
#  'Knicks': {'ORG': 2},
#  'Timberwolves': {'ORG': 1},
#  'Duncan': {'PER': 1},
#  'Robinson': {'PER': 2},
#  'Ewing': {'PER': 2},
#  'Houston': {'PER': 5, 'ORG': 2},
#  'Hawksile': {'ORG': 1},
#  'Pacers': {'ORG': 4},
#  'Johnson': {'PER': 13, 'ORG': 1},
#  'Stateis': {'ORG': 1},
#  'Carlesimo': {'ORG': 1},
#  'Sprewell': {'PER': 1},
#  'Gundy': {'PER': 4},
#  'Cambyle': {'PER': 2},
#  'Oakley': {'PER': 1},
#  'Elie': {'PER': 1},
#  'Kerr': {'PER': 1},
#  'Popovich': {'PER': 1},
#  'Gundyt': {'PER': 1},
#  'Kasela': {'PER': 3},
#  'Raualt': {'PER': 1},
#  'Vähi': {'PER': 41},
#  'põhikool': {'ORG': 49},
#  'Saalfeldt': {'PER': 1},
#  'Tomberg': {'PER': 10},
#  'Raidveri': {'PER': 1},
#  'Lapini': {'PER': 1},
#  'Vinogradov': {'PER': 4},
#  'Meeli': {'PER': 1},
#  'Ole': {'PER': 1},
#  'Toltsi': {'PER': 1},
#  'Vindi': {'PER': 1},
#  'Kase': {'PER': 9},
#  'Tali': {'PER': 27},
#  'Jaesk': {'PER': 1},
#  'Kalmus': {'PER': 4},
#  'Bullsi': {'PER': 1},
#  'Terras': {'PER': 2},
#  'Vunk': {'PER': 3},
#  'Einrel': {'PER': 1},
#  'Vilu': {'PER': 7},
#  'Jõgeva': {'PER': 8},
#  'transpordiamet': {'ORG': 13},
#  'Antov': {'PER': 1},
#  'keskkonnaamet': {'ORG': 5},
#  'Viirand': {'PER': 1},
#  'Ulas': {'PER': 1},
#  'Salumägi': {'PER': 4},
#  'Võrno': {'PER': 9},
#  'Rannik': {'PER': 2},
#  'Pirn': {'PER': 4},
#  'Järva': {'PER': 4},
#  'merelaevandus': {'ORG': 11},
#  'Naglis': {'PER': 1},
#  'Shkele': {'PER': 2},
#  'Grinblats': {'PER': 1},
#  'annely@epl.ee': {'PER': 1},
#  'Siimann': {'PER': 30, 'ORG': 1},
#  'Vitsur': {'PER': 4},
#  'Sõerd': {'PER': 5},
#  'linnavalitsus': {'ORG': 123},
#  'Vridolin': {'PER': 1},
#  'Jaadla': {'PER': 6},
#  'Lii': {'ORG': 2},
#  'Palamets': {'PER': 2},
#  'Russell': {'PER': 5},
#  'IX': {'ORG': 1},
#  'City': {'LOC': 17, 'ORG': 24, 'PER': 2},
#  'Nasser': {'PER': 2},
#  'sada': {'PER': 1},
#  'rahvavabariik': {'LOC': 9, 'ORG': 2},
#  'NSV': {'LOC': 7, 'ORG': 3},
#  '100': {'ORG': 1},
#  'Ird': {'PER': 2},
#  'Panso': {'PER': 3},
#  'Kõpp': {'PER': 2},
#  'lihakombinaat': {'ORG': 13},
#  'grupp': {'ORG': 27, 'PER': 4},
#  'raa': {'PER': 1},
#  'teos': {'PER': 2},
#  'raekoda': {'ORG': 3},
#  'Toom': {'PER': 9, 'ORG': 3},
#  'Toomi': {'PER': 1},
#  'Merilo-Teos': {'PER': 1},
#  'Merilo': {'PER': 2},
#  'Orav': {'PER': 10},
#  'Aassalu': {'PER': 1},
#  'Valgemäe': {'PER': 2},
#  'Arraste': {'ORG': 1, 'PER': 2},
#  'Mikkel': {'PER': 6},
#  'Kurbel': {'PER': 1},
#  'Tõnnus': {'PER': 1},
#  'Agu': {'PER': 4},
#  'Madi': {'PER': 1},
#  'Adamson': {'ORG': 1, 'PER': 11},
#  'Luht': {'PER': 4},
#  'Saar': {'PER': 40, 'LOC': 1},
#  'tv': {'ORG': 15, 'PER': 4},
#  'Toomet': {'PER': 10},
#  'Lepa': {'PER': 14},
#  'Villard': {'PER': 1},
#  'Rubin': {'PER': 7, 'ORG': 1},
#  'Talbott': {'PER': 4},
#  'Ahtisaarile': {'PER': 1},
#  'Niinistö': {'PER': 2},
#  'Aho': {'PER': 3},
#  'Halonen': {'PER': 6},
#  'Hemilä': {'ORG': 1},
#  'Eelrand': {'PER': 10},
#  'Mölder': {'PER': 18},
#  'börs': {'ORG': 23},
#  'S': {'PER': 4, 'ORG': 5},
#  'Metsamaa': {'PER': 17},
#  'Öövel': {'PER': 5},
#  'Konceviciene': {'PER': 1},
#  'Noreika': {'PER': 1},
#  'Tominga': {'PER': 3},
#  'Kilgas': {'PER': 6},
#  'Kangur': {'PER': 13},
#  'Oja': {'PER': 14, 'ORG': 1},
#  'Sisask': {'PER': 6},
#  'Berendson': {'PER': 22},
#  'Karpov': {'PER': 5},
#  'aas': {'PER': 8},
#  'Tshulitski': {'PER': 3},
#  'Leeviku': {'PER': 1},
#  'Vilippunen': {'PER': 1},
#  'Leevik': {'PER': 1},
#  'Aris': {'ORG': 1},
#  'Auriol': {'PER': 7},
#  'Burns': {'PER': 11},
#  'Kankkunen': {'PER': 7},
#  'Cipollini': {'PER': 1},
#  'Quaranta': {'PER': 1},
#  'Strazzeri': {'PER': 1},
#  'Jalabert': {'PER': 6},
#  'Morozevitsh': {'PER': 1},
#  'Barejevile': {'PER': 1},
#  'Kasparov': {'PER': 5},
#  'Adams': {'PER': 41},
#  'Shirov': {'PER': 5},
#  'Suusaliit': {'ORG': 2},
#  'Õlletehas': {'ORG': 12},
#  'Ehitus': {'ORG': 18, 'PER': 1},
#  'kinnisvara': {'ORG': 17},
#  'lootus': {'ORG': 1},
#  'Avallone': {'ORG': 1},
#  'sport': {'ORG': 9},
#  'Viisnurk': {'ORG': 1},
#  'Ustinsk': {'PER': 1},
#  'Rehemaa': {'PER': 3},
#  'Tärn': {'PER': 1},
#  'Kokk': {'PER': 14},
#  'Kümmel': {'PER': 5},
#  'Remmelg': {'PER': 2},
#  'otsus': {'PER': 1},
#  'Tähe': {'PER': 2},
#  'Saarepuu': {'PER': 7},
#  'Vuokatt': {'ORG': 1, 'PER': 1},
#  'suusaliit': {'ORG': 9},
#  'Alaver': {'PER': 13},
#  'kanep': {'PER': 3},
#  'Rüütel': {'PER': 71},
#  'Kvelsteini': {'ORG': 1},
#  'kai': {'PER': 1},
#  'Niinemägi': {'PER': 3},
#  'Arak': {'PER': 3},
#  'Lukas': {'PER': 26},
#  'Järvala': {'PER': 1},
#  'Sadova': {'PER': 4},
#  'Lamelale': {'PER': 1},
#  'Voronin': {'PER': 1},
#  'Gecsek': {'PER': 1},
#  'Huffins': {'PER': 1},
#  'Moore': {'PER': 14},
#  'OBrien': {'PER': 1},
#  'Nathan': {'PER': 2},
#  'Sua': {'PER': 1},
#  'Kuehl': {'PER': 1},
#  'Hill': {'PER': 10},
#  'Ellerbe': {'PER': 1},
#  'Powell': {'PER': 5},
#  'Dean': {'PER': 3},
#  'Culpepper': {'PER': 1},
#  'Hauser': {'ORG': 1, 'PER': 1},
#  'Abdirahman': {'PER': 1},
#  'Carter': {'PER': 3},
#  'Hunt': {'PER': 7},
#  'Ware': {'PER': 1},
#  'GP': {'ORG': 15, 'LOC': 1, 'PER': 1},
#  'Irvine': {'PER': 3},
#  'Häkkinen': {'PER': 14},
#  'Coulthard': {'PER': 6},
#  'Laasik': {'PER': 16},
#  'Timmer': {'PER': 8},
#  'Janson': {'PER': 4},
#  'Eelmaa': {'ORG': 5, 'PER': 2},
#  'Berg': {'PER': 5},
#  'Roo': {'PER': 3},
#  'Kukumägi': {'PER': 1},
#  'Ümängitu': {'ORG': 1},
#  'muusikakriitik': {'ORG': 1},
#  'Bertman': {'PER': 4},
#  'poiss': {'ORG': 1},
#  'Lipunov': {'PER': 2},
#  'Anisimov': {'PER': 1},
#  'Grossthali': {'PER': 1},
#  'Reisneri': {'PER': 1},
#  'mäekala': {'PER': 1},
#  'Galanti': {'PER': 1},
#  'erakool': {'ORG': 5},
#  'Kesa': {'PER': 1},
#  'Gasplit': {'PER': 1},
#  'Grossthal': {'PER': 1},
#  'Colorado': {'LOC': 1},
#  'Meira': {'ORG': 1},
#  'Heinla': {'PER': 6},
#  'Voitka': {'PER': 7},
#  'Mere': {'PER': 2},
#  'Songisepa': {'PER': 4},
#  'Kivikas': {'PER': 2},
#  'Dunn': {'PER': 1},
#  'Epidemiology': {'ORG': 1},
#  'Health': {'PER': 1},
#  'Tallinn': {'ORG': 28},
#  'Simson': {'PER': 43, 'ORG': 1},
#  'Bergmann': {'PER': 11, 'ORG': 1},
#  'Cup': {'ORG': 10, 'PER': 12},
#  'Albaania': {'ORG': 1},
#  'Kafelnikov': {'PER': 4},
#  'Roux': {'PER': 1},
#  'Rusedski': {'PER': 2},
#  'Hrbaty': {'PER': 1},
#  'Ivanishevic': {'PER': 1},
#  'Woodruff': {'PER': 1},
#  'Mäkinen': {'PER': 12},
#  'postiamet': {'ORG': 1},
#  'Mannisenmäki': {'PER': 1},
#  'Mägi': {'PER': 44, 'ORG': 1},
#  'Lauk': {'PER': 4},
#  'Meerits': {'PER': 6},
#  'Maccab': {'ORG': 1},
#  'kuusik': {'PER': 2},
#  'Afanasjev': {'PER': 2},
#  'Savotshkin': {'PER': 1},
#  'Käärik': {'PER': 5},
#  'Kink': {'PER': 8},
#  'Raudnagel': {'PER': 1},
#  'Kasemets': {'PER': 1},
#  'Aus': {'PER': 14, 'ORG': 1},
#  'nüüd': {'PER': 1},
#  'Antonov': {'PER': 1},
#  'Girishin': {'PER': 1},
#  'Dupikov': {'PER': 1},
#  'Konsa': {'PER': 2},
#  ...}

# %% [markdown]
# creating three dataframes, filling missing values with 0

# %%
single_csv = pd.DataFrame.from_dict(singletons_map,orient='index')
single_csv = single_csv.fillna(0)
single_csv
# Out:
#                             PER  ORG   LOC
# Eminem                     19.0  0.0   0.0
# People                      2.0  1.0   0.0
# Hailie                      2.0  0.0   0.0
# Jimmy                       7.0  0.0   0.0
# Jimmyl                      1.0  0.0   0.0
# ...                         ...  ...   ...
# RSbeta@xxxxx.ee             0.0  0.0   6.0
# MinNike-vs-mimmi-vs-Liisk   0.0  0.0   2.0
# LoLL@xxxxx.ee               0.0  0.0   1.0
# Syru                        0.0  0.0   1.0
# XeRoXmas                    0.0  0.0  11.0
#
# [12657 rows x 3 columns]

# %%
last_df = pd.DataFrame.from_dict(last_word_map,orient='index')
last_df = last_df.fillna(0)
last_df
# Out:
#                     PER  ORG  LOC
# Lauriste            2.0  0.0  0.0
# III                10.0  3.0  0.0
# Shady               1.0  0.0  0.0
# Smith              14.0  0.0  0.0
# Basinger            3.0  0.0  0.0
# ...                 ...  ...  ...
# eiiiii              0.0  0.0  1.0
# Syru                0.0  0.0  1.0
# nu                  0.0  0.0  1.0
# HannuLa             0.0  0.0  1.0
# alizee-MaNNuKe-jt   0.0  0.0  2.0
#
# [14637 rows x 3 columns]

# %%
first_df = pd.DataFrame.from_dict(first_words_map,orient='index')
first_df
# Out:
#                         PER  ORG  LOC
# ('Aive',)               6.0  NaN  NaN
# ('Mathers',)            1.0  NaN  NaN
# ('Slim',)               1.0  NaN  NaN
# ('Jimmy',)              7.0  NaN  NaN
# ('Kim',)               16.0  NaN  NaN
# ...                     ...  ...  ...
# ('Eoikjiiiiiiiiiio',)   NaN  NaN  1.0
# ('Pioneereml',)         NaN  NaN  1.0
# ('hihii',)              NaN  NaN  1.0
# ('Freddy-Uni', ',')     NaN  NaN  1.0
# ('Tieeereeeeeee',)      NaN  NaN  1.0
#
# [9307 rows x 3 columns]

# %% [markdown]
# Saving results to CSV files

# %%
last_df.to_csv('data/last_counts_lemma_5000.csv')

# %%
single_csv.to_csv('data/single_counts_lemma_5000.csv')

# %%
first_df.to_csv('data/first_counts_lemma_5000.csv')
