# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Loading the corpus

# %%
from estnltk import Text
from estnltk.storage.postgres import PostgresStorage, create_schema


storage = PostgresStorage(host='postgres.keeleressursid.ee',
                          port=5432,
                          dbname='estonian-text-corpora',
                          user='rasmusm',
                          password='',
                          schema='estonian_text_corpora',
                          role='estonian_text_corpora_read',
                          temporary=False)
# Out:
# INFO:storage.py:58: connecting to host: 'postgres.keeleressursid.ee', port: 5432, dbname: 'estonian-text-corpora', user: 'rasmusm'
# INFO:storage.py:108: schema: 'estonian_text_corpora', temporary: False, role: 'estonian_text_corpora_read'

# %%
storage
# Out:
# <b>PostgresStorage</b><br/>
# user=rasmusm password=xxx dbname=estonian-text-corpora host=postgres.keeleressursid.ee port=5432 schema=estonian_text_corpora<br/>temporary=False<br/>
# collection count: 5
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>rows</th>
#       <th>total_size</th>
#       <th>comment</th>
#     </tr>
#     <tr>
#       <th>collection</th>
#       <th>version</th>
#       <th>relations</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="16" valign="top">koondkorpus_base_subset_of_5000_v2</th>
#       <th rowspan="16" valign="top">2.0</th>
#       <th></th>
#       <td>0</td>
#       <td>12 MB</td>
#       <td>Collection of 5000 randomly picked Koondkorpus texts (v2)</td>
#     </tr>
#     <tr>
#       <th>original_sentences_flat__la</th>
#       <td>0</td>
#       <td>5544 kB</td>
#       <td>created by soras on Fri Jun 12 11:28:06 2020</td>
#     </tr>
#     <tr>
#       <th>original_words__layer</th>
#       <td>0</td>
#       <td>19 MB</td>
#       <td>created by soras on Fri Jun 12 09:15:46 2020</td>
#     </tr>
#     <tr>
#       <th>original_words_morph_analys</th>
#       <td>0</td>
#       <td>96 MB</td>
#       <td>Morphological analysis from v1.6.2/3, probably based on commit 349a7c2 (2018-11-22)</td>
#     </tr>
#     <tr>
#       <th>structure</th>
#       <td>2</td>
#       <td>32 kB</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>v166_compound_tokens__layer</th>
#       <td>0</td>
#       <td>5472 kB</td>
#       <td>created by soras on Thu Jun  4 12:29:42 2020</td>
#     </tr>
#     <tr>
#       <th>v166_morph_analysis__layer</th>
#       <td>0</td>
#       <td>97 MB</td>
#       <td>created by soras on Tue Jun  9 14:13:07 2020</td>
#     </tr>
#     <tr>
#       <th>v166_sentences__layer</th>
#       <td>0</td>
#       <td>21 MB</td>
#       <td>created by soras on Tue Jun  9 06:01:41 2020</td>
#     </tr>
#     <tr>
#       <th>v166_tokens__layer</th>
#       <td>0</td>
#       <td>20 MB</td>
#       <td>created by soras on Thu Jun  4 07:40:39 2020</td>
#     </tr>
#     <tr>
#       <th>v166_words__layer</th>
#       <td>0</td>
#       <td>20 MB</td>
#       <td>created by soras on Fri Jun  5 05:49:26 2020</td>
#     </tr>
#     <tr>
#       <th>v168_stanza_ensemble_syntax</th>
#       <td>0</td>
#       <td>95 MB</td>
#       <td>created by soras on Wed Aug  4 08:53:37 2021</td>
#     </tr>
#     <tr>
#       <th>v168_stanza_pos_based_synta</th>
#       <td>0</td>
#       <td>77 MB</td>
#       <td>created by soras on Wed Aug 11 17:26:41 2021</td>
#     </tr>
#     <tr>
#       <th>v168_stanza_syntax__layer</th>
#       <td>0</td>
#       <td>95 MB</td>
#       <td>created by soras on Fri Jul  2 16:07:05 2021</td>
#     </tr>
#     <tr>
#       <th>v169_clauses__layer</th>
#       <td>5000</td>
#       <td>22 MB</td>
#       <td>created by soras on Mon Sep 12 11:26:29 2022</td>
#     </tr>
#     <tr>
#       <th>v169_named_entities__layer</th>
#       <td>0</td>
#       <td>5624 kB</td>
#       <td>created by soras on Tue May 17 11:01:56 2022</td>
#     </tr>
#     <tr>
#       <th>v172_geo_terms__layer</th>
#       <td>5000</td>
#       <td>1896 kB</td>
#       <td>created by soras on Mon Jan  2 12:25:16 2023</td>
#     </tr>
#     <tr>
#       <th rowspan="16" valign="top">koondkorpus_base_v2</th>
#       <th rowspan="16" valign="top">2.0</th>
#       <th></th>
#       <td>0</td>
#       <td>1618 MB</td>
#       <td>Collection of Koondkorpus texts (v2)</td>
#     </tr>
#     <tr>
#       <th>original_sentences_flat__layer</th>
#       <td>0</td>
#       <td>740 MB</td>
#       <td>created by soras on Mon Jun 15 06:44:30 2020</td>
#     </tr>
#     <tr>
#       <th>original_words__layer</th>
#       <td>0</td>
#       <td>2553 MB</td>
#       <td>created by soras on Fri Jun 12 12:25:44 2020</td>
#     </tr>
#     <tr>
#       <th>original_words_morph_analysis__layer</th>
#       <td>0</td>
#       <td>13 GB</td>
#       <td>Morphological analysis from v1.6.2/3, probably based on commit 349a7c2 (2018-11-22)</td>
#     </tr>
#     <tr>
#       <th>structure</th>
#       <td>2</td>
#       <td>32 kB</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>v166_compound_tokens__layer</th>
#       <td>0</td>
#       <td>698 MB</td>
#       <td>created by soras on Thu Jun  4 12:36:01 2020</td>
#     </tr>
#     <tr>
#       <th>v166_morph_analysis__layer</th>
#       <td>0</td>
#       <td>13 GB</td>
#       <td>created by soras on Tue Jun  9 14:32:08 2020</td>
#     </tr>
#     <tr>
#       <th>v166_sentences__layer</th>
#       <td>0</td>
#       <td>2860 MB</td>
#       <td>created by soras on Tue Jun  9 06:07:08 2020</td>
#     </tr>
#     <tr>
#       <th>v166_tokens__layer</th>
#       <td>0</td>
#       <td>2587 MB</td>
#       <td>created by soras on Thu Jun  4 07:42:49 2020</td>
#     </tr>
#     <tr>
#       <th>v166_words__layer</th>
#       <td>0</td>
#       <td>2622 MB</td>
#       <td>created by soras on Fri Jun  5 05:53:18 2020</td>
#     </tr>
#     <tr>
#       <th>v168_stanza_ensemble_syntax__layer</th>
#       <td>0</td>
#       <td>12 GB</td>
#       <td>created by soras on Thu Aug  5 17:31:45 2021</td>
#     </tr>
#     <tr>
#       <th>v168_stanza_pos_based_syntax__layer</th>
#       <td>0</td>
#       <td>10 GB</td>
#       <td>created by soras on Thu Aug 12 18:03:09 2021</td>
#     </tr>
#     <tr>
#       <th>v168_stanza_syntax__layer</th>
#       <td>0</td>
#       <td>12 GB</td>
#       <td>created by soras on Wed Jul 28 10:45:04 2021</td>
#     </tr>
#     <tr>
#       <th>v169_clauses__layer</th>
#       <td>703506</td>
#       <td>2884 MB</td>
#       <td>created by soras on Mon Sep 12 11:46:59 2022</td>
#     </tr>
#     <tr>
#       <th>v169_named_entities__layer</th>
#       <td>0</td>
#       <td>752 MB</td>
#       <td>created by soras on Tue May 17 14:29:05 2022</td>
#     </tr>
#     <tr>
#       <th>v172_geo_terms__layer</th>
#       <td>705356</td>
#       <td>247 MB</td>
#       <td>created by soras on Mon Jan  2 12:30:20 2023</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">koondkorpus_sentences</th>
#       <th rowspan="4" valign="top">3.0</th>
#       <th></th>
#       <td>21377855</td>
#       <td>82 GB</td>
#       <td>koondkorpus_base_v2 texts split into sentences</td>
#     </tr>
#     <tr>
#       <th>structure</th>
#       <td>8</td>
#       <td>32 kB</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>v171_named_entities__layer</th>
#       <td>18950492</td>
#       <td>7452 MB</td>
#       <td>created by soras on Mon Dec  5 11:27:53 2022</td>
#     </tr>
#     <tr>
#       <th>v172_geo_terms__layer</th>
#       <td>21237460</td>
#       <td>6187 MB</td>
#       <td>created by soras on Wed Jan  4 11:12:06 2023</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">koondkorpus_sentences_test_5000_sg_thread</th>
#       <th rowspan="4" valign="top">3.0</th>
#       <th></th>
#       <td>159829</td>
#       <td>652 MB</td>
#       <td>5000 texts split into sentences (based on v2)</td>
#     </tr>
#     <tr>
#       <th>structure</th>
#       <td>8</td>
#       <td>32 kB</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>v171_named_entities_</th>
#       <td>146503</td>
#       <td>62 MB</td>
#       <td>created by soras on Fri Dec  2 16:19:38 2022</td>
#     </tr>
#     <tr>
#       <th>v172_geo_terms__laye</th>
#       <td>159745</td>
#       <td>46 MB</td>
#       <td>created by soras on Mon Jan  2 12:39:29 2023</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">koondkorpus_words_v16_1</th>
#       <th rowspan="2" valign="top">0.0</th>
#       <th></th>
#       <td>0</td>
#       <td>2718 MB</td>
#       <td>example sentence for every word in koondkorpus_base__v16_1_words__layer</td>
#     </tr>
#     <tr>
#       <th>structure</th>
#       <td>0</td>
#       <td>32 kB</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
#  There are collections listed in the __collections table without tables in the database: ['koondkorpus_syntax_subset']

# %%
collection = storage['koondkorpus_sentences']

# %%
collection.selected_layers = ['v171_named_entities','v172_geo_terms']

# %%
from estnltk.vabamorf.morf import synthesize

cases = [
    ('n', 'nimetav'),
    ('g', 'omastav'),
    ('p', 'osastav'),
    ('ill', 'sisseütlev'),
    ('in', 'seesütlev'),
    ('el', 'seestütlev'),
    ('all', 'alaleütlev'),
    ('ad', 'alalütlev'),
    ('abl', 'alaltütlev'),
    ('tr', 'saav'),
    ('ter', 'rajav'),
    ('es', 'olev'),
    ('ab', 'ilmaütlev'),
    ('kom', 'kaasaütlev')]

all_forms = []
for case, name in cases:
    all_forms.append(', '.join(synthesize('kanal', 'sg ' + case, 'S')))
    all_forms.append(', '.join(synthesize('kanal', 'pl ' + case, 'S')))

# %%
terms = []
with open('geo_terms.txt','r',encoding='UTF-8') as f:
    term = f.readline()
    while term is not '':
        terms.append(term.strip())
        term = f.readline()

# %% [markdown]
# ### Local copy of Span Sampler

# %%
    def attribute_locations_creation(self):
        self.conn.commit()
        self.cur.execute("""SELECT EXISTS (
           SELECT FROM information_schema.tables 
           WHERE  table_schema = 'public'
           AND    table_name   = 'attribute_locations'
           );""")
        res = self.cur.fetchall()
        if not res[0][0]:
            self.cur.execute("CREATE TABLE attribute_locations (layer_id integer, attribute_value varchar, indices integer[], count integer);")
            self.conn.commit()
            for term in terms:
                q = LayerQuery('v172_geo_terms', lemma=term)
                for key, txt in tqdm(collection.select(query=q,layers=['v172_geo_terms'])):
                    indices = [i for i, nertag in enumerate(txt['v172_geo_terms']['lemma']) if nertag[0] ==term]
                    self.cur.execute("INSERT INTO attribute_locations (layer_id, attribute_value,indices,count) VALUES (%s, %s, %s, %s)",(key, term, indices,len(indices)))

        self.conn.commit()

# %%
from random import sample, choices
from estnltk.storage.postgres import LayerQuery, IndexQuery
from tqdm import tqdm

class SpanSampler:
    
    def __init__(self, storage, collection, layer, attribute):
        self.storage = storage
        self.conn = storage.conn
        self.cur = self.conn.cursor()
        self.collection = collection
        self.layer = layer
        self.attribute = attribute
    
    def __call__(self, count, attribute, return_index=False, with_replacement=True): 
        # Returns iterator of type Text, Span or int, Text, span
        # count determines the number of samples
        # with replacement means that same span can be sampled several times
        self.conn.commit()
        self.create_sampling_matrix(attribute)
        indices = self.find_sampled_indices(count,with_replacement)
        result_list = []
        only_txt_index = [idx[1] for idx in indices]
        texts = list(collection.select( query=IndexQuery(only_txt_index),layers=[self.layer],return_index=True ))
        for text in texts:
            idx = [index for index in indices if text[0] == index[1]][0]
            if return_index:
                result_list.append((idx[0],text[1],text[1][self.layer][idx[2]]))
            else:
                result_list.append((text[1],text[1][self.layer][idx[2]]))
        self.clear_sampling_matrix()
        return result_list
    

        
    def create_sampling_matrix(self,attribute_val):
        self.cur.execute("CREATE TABLE sampling_matrix (id serial, layer integer, layer_index integer);")
        self.cur.execute("INSERT INTO sampling_matrix (layer,layer_index) (SELECT layer_id as layer, unnest(indices) as layer_index FROM attribute_locations WHERE attribute_value IN " + str(attribute_val) + ");")
        self.conn.commit()
    
    def find_sampled_indices(self,count,with_replacement):
        self.cur.execute("SELECT COUNT(*) FROM sampling_matrix;")
        span_count = self.cur.fetchall()[0][0]
        self.conn.commit()
        if with_replacement:
            sampled = choices(range(span_count),k=count)
        else:
            sampled = sample(range(span_count),count)
        self.cur.execute("SELECT * FROM sampling_matrix WHERE id IN " + str(tuple(sampled)) + ';')
        return self.cur.fetchall()
    
    def clear_sampling_matrix(self):
        self.conn.commit()
        self.cur.execute("DROP TABLE sampling_matrix;")
        self.conn.commit()

# %%
# Second storage to keep the temporary lists used for sampling
localstorage = PostgresStorage(host='localhost',
                          port=5432,
                          dbname='ner_test',
                          user='postgres',
                          password='dbpass',
                          pgpass_file='~/.pgpass',
                          schema='my_schema',
                          role=None,
                          temporary=False)
# Out:
# INFO:storage.py:58: connecting to host: 'localhost', port: 5432, dbname: 'ner_test', user: 'postgres'
# INFO:storage.py:108: schema: 'my_schema', temporary: False, role: 'postgres'

# %%
mycur = localstorage.conn.cursor()

# %%
sampler = SpanSampler(storage=localstorage,collection=collection, layer='v172_geo_terms',attribute='lemma')

# %%
#localstorage.conn.commit()

# %%
#sampler.clear_sampling_matrix()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-59-bf092aec357a> in <module>
# ----> 1 sampler.clear_sampling_matrix()
#
# <ipython-input-57-f3558ac821cf> in clear_sampling_matrix(self)
#      52     def clear_sampling_matrix(self):
#      53         self.conn.commit()
# ---> 54         self.cur.execute("DROP TABLE sampling_matrix;")
#      55         self.conn.commit()
#      56
#
# UndefinedTable: table "sampling_matrix" does not exist

# %%
samples = sampler(count=1000,attribute=tuple(filtered_terms))

# %%
samples
# Out:
# [(Text(text='Võib kujutleda ärimeeste rõõmu , kui nad põhjakõrbenud hotelliprojektist kasuliku hinnaga lahti said .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='“ Riinal ja Juhanil ( Riina on Kaljo Kiisa tütar ja Juhan Viiding väimees - toim ) jäi suu lahti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Saajate ja maksjate “ eurosuhe ” 1,5 : 1 pole sugugi mägede taga .'),
#   Span('mägede', [{'lemma': 'mägi'}])),
#  (Text(text='Munad munetakse seisva vee pinnale kraavides , tiikides , lompides , mudaaukudes .'),
#   Span('tiikides', [{'lemma': 'tiik'}])),
#  (Text(text='Aga kui kõik minutaolised lahti lasta , kust siis uued võtta ? ”'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Mees nägi kaldast umbes 1,5 km kaugusel palju päid ja tumedat pampu , mida ta pidas ümberläinud paadiks ( tegelikult oli see rahuvalvajate nööriga kokkuseotud varustus ) .'),
#   Span('kaldast', [{'lemma': 'kallas'}])),
#  (Text(text='Oma olemuselt on meri , kus vesi vahetub kitsaste Taani väinade kaudu iga 30-40 aasta järel , rohkem nagu suur järv .'),
#   Span('väinade', [{'lemma': 'väin'}])),
#  (Text(text='Ometi ei osanud daam , kes tööalaselt linna juhtidega pidevalt lävib ( Kink on Eesti juhtiva hüdrogeoloogina aastaid jälginud Pakri poolsaare vete puhtust ) , kuidagi arvata , et tema huvidest nii mööda vaadatakse .'),
#   Span('poolsaare', [{'lemma': 'poolsaar'}])),
#  (Text(text='Tulevikus peavad tänased noored sõltumata soost ja elupaigast esmatähtsaks head töökohta .'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='Sageli esinevad kõrbed mäestike taga allatuult .'),
#   Span('kõrbed', [{'lemma': 'kõrb'}])),
#  (Text(text='Tegelikult on arhitektuuriajaloolaste käsutuses mitmesuguseid kaudseid võimalusi hoone vanuse määramiseks ka kirjalike allikate puudumisel .'),
#   Span('allikate', [{'lemma': 'allikas'}])),
#  (Text(text='On tekkinud mõte koostada “ Yleissuomalainen sananlaskurekisteri ” , mis võimaldaks viidata soome materjali üheainsa koondnumbri tagant ( analoogiliselt EV-ga , mitte kõiki allikaid ühekaupa loetledes ) .'),
#   Span('allikaid', [{'lemma': 'allikas'}])),
#  (Text(text='Häired , mis ilmnevad esmaselt varases lapseeas ( ja alati enne puberteediiga ) ja millele on iseloomulik püsiv ja intensiivne piin olemasoleva soo pärast , koos sooviga ( või nõudega ) olla vastassugupoolest .'),
#   Span('soo', [{'lemma': 'soo'}])),
#  (Text(text='a ) Ookean - kontinent laamade kokkupressimisel sukeldub ( subdueerub ) ookeani suurema tihedusega kivimitest ja õhem maakoor kergema ja paksema kontinentaalse litosfääri ääre alla .'),
#   Span('kontinent', [{'lemma': 'kontinent'}])),
#  (Text(text='Keskaegkonna lõpul kriidi ajastul alanud ning uusaegkonnas jätkunud Alpi kurrutus on loonud Alpid , Apenniinid , Karpaadid , Krimmi ja Kaukaasia mäed , Atlase mäed ja enamiku Väike-Aasiast kuni Malaka poolsaareni kulgevatest mäestikest .'),
#   Span('mäed', [{'lemma': 'mägi'}])),
#  (Text(text='Koos paiknenud kontinendid võisid mõnekümne miljoni aasta jooksul ka ükshaaval pooluse alt läbi triivida ning seal jäätuda .'),
#   Span('kontinendid', [{'lemma': 'kontinent'}])),
#  (Text(text='Samal ajal laskusid Põhjamere bassein ( Neogeenis olid Briti saared mandri osaks ) , Baikal , Kaspia .'),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='" Varem näisid nad väga kurnatutena , aga nüüd olid nende näod peaaegu naerul , kui tagauks tehti lahti ja neil lubati istuda ükskõik , millisele kohale välja arvatud kõige tagumised , " ütles ametnik .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Sotsiaalselt heakskiidetud võimuhierarhia perekonnas on seotud nii soo kui vanusega : naine valitseb laste , mees naise üle .'),
#   Span('soo', [{'lemma': 'soo'}])),
#  (Text(text='Maarjamäe lossi all , kaldast ligikaudu 900 meetri kaugusel , nähti mere põhjas tohutut lasu suuri kivimürakaid ja palke , mis kohati omavahel tappidega kokku liidetud .'),
#   Span('kaldast', [{'lemma': 'kallas'}])),
#  (Text(text='Liha kuivatame või suitsutame , sest sool on kallis .'),
#   Span('sool', [{'lemma': 'soo'}])),
#  (Text(text='Nojaa , stabilisatsioonifond täpses mõistes ei ole stabilisatsioonifond , see vajab lahti seletamist ning vaidlus käib .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Masinate seadistamiseks ja kontrollimiseks oli niigi vähe aega , kuid lisasegadust tekitas tuul , mis tõstis meie meeskonna telgi maast lahti . "'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Juhataja asetäitja sõnul istus mõni narkomaan mitu tundi WC-s ega teinud ust ka koputamise peale lahti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Maailma esimese triivjaama rajajaid ; tema nime kannab Banksi maal ( saar Kanada Arktika saarestiku lääneosas ) voolav jõgi ( Masik River ) .'),
#   Span('saarestiku', [{'lemma': 'saarestik'}])),
#  (Text(text='Edasi suundusid kurjategijad kirikusse , kus peetakse jumalateenistusi , lõhkusid lukustatud korjanduskarbi , rebisid lahti altarit katnud riide ning vigastasid oreli tagaseina .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Tunamullu alustatud mäge üritas Nõmme suusaklubi käivitada juba eelmisel aastal , paraku nullis heitlik ilm ootamatute suladega siis aga kõik mäetegijate ponnistused .'),
#   Span('mäge', [{'lemma': 'mägi'}])),
#  (Text(text='Naine telefoniga : " Ja Kukus räägiti ja see , kes esindas politseid Kanal 2 saates , oli absoluutne kurva kuju rüütel , Lahil oli raudne loogika küll , hea , et politseid puhastatakse , saab kogu nõukogudeaegsest saastast lahti . "'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text="Kuid Ferrarile lähedalseisvad isikud on kinnitanud , et juba kevadel algas Eddie'st lahti saamise protsess ."),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Piirivalvurid tõid kaldale kummuliläinud paadi külge klammerdunud uppunud Tõnise ( 61 ) .'),
#   Span('kaldale', [{'lemma': 'kallas'}])),
#  (Text(text='žnformeeritud allikate andmeil olid žMF-i esindajad soovitanud kaotada kõik seni massiteabevahenditele kehtinud maksusoodustused .'),
#   Span('allikate', [{'lemma': 'allikas'}])),
#  (Text(text='Nokk kinni , saba lahti .'), Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Hiljem , kui sulas kogu jääkate , osutusid kunagised järved mägedeks .'),
#   Span('mägedeks', [{'lemma': 'mägi'}])),
#  (Text(text='Sõjanõukogu allikad teatavad , et valitsuse juht on juba ametisse määratud .'),
#   Span('allikad', [{'lemma': 'allikas'}])),
#  (Text(text='Neljane Sass võtab helesinise liniku , voldib selle lahti ja asetab lauale .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Nooremal eesti soost kuulajaskonnal oli ilmseid raskusi vene keeles esinenud Zukermanist aru saamisega .'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='" Pirita sel aastal ei taotlenudki , neil oli eelmisel aastal probleeme ranna korrashoiuga , " ütles ühenduse " Hoia Eesti merd " vastutav sekretär Kaja Pirnpuu .'),
#   Span('ranna', [{'lemma': 'rand'}])),
#  (Text(text='Lääne kultuuris on ka religioosne tekst uue teksti allikas .'),
#   Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Bernard Buigues plaanib seda eksponeerida Hatanga koobastes , kuhu lisaks mammutile hakatakse tooma teisi väljasurnud loomade jäänuseid .'),
#   Span('koobastes', [{'lemma': 'koobas'}])),
#  (Text(text='Radoon tekib uraani lagunemisel pinnases ja kaljudes , millest võetud kividest monumendid ehitatakse .'),
#   Span('kaljudes', [{'lemma': 'kalju'}])),
#  (Text(text='" Ehkki me pole nii kõrgest soost nagu karu ega nii suured nagu põder , on meilgi metsas oma koht !'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='Ametlik uurimiskomisjon peab laeva hukkumise põhjuseks tormilaineid , mis tagusid lahti parvlaeva vööriluugi .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Selgus , et nad olid suusarullid lahti kruvinud , ja võimalik , et nende sõiduomadusi parandanud , " selgitas peakohtunik Tiit Pekk .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kalastajad , kes olid oma soome kelkudega läinud 1,5 -2 kilomeetri kaugusele rannast , olid veendunud , et saavad ka ise maale tagasi .'),
#   Span('rannast', [{'lemma': 'rand'}])),
#  (Text(text='Rootsist Rohuküla-Heltermaa liinile sõitma ostetud parvlaev Scania lõpetab Saaremaa Laevakompanii mandri ja saarte vahel kurseerivate aluste väljavahetamise .'),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='25 miljonit krooni maksnud ja liisinguga ostetud parvlaev on oma mugavusastmelt võrreldav praegu Hiiumaa ja mandri vahel seilava Ofeliaga .'),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='Sajad inimesed on kogunenud rannale õnnetuskoha lähistel .'),
#   Span('rannale', [{'lemma': 'rand'}])),
#  (Text(text='Ja , mis põhiline , ta naerab kõigi tema viletsate naljade peale , " märkis allikas .'),
#   Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Vaikse ookeani äärest Kaukaasiani ja kaugemale on Moskva uus juhtkond võtmas kasutusele aina agressiivsemat välispoliitikat , mis on rajatud pigem vastasseisule Läänega kui partnerlusele .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Vaikse ookeani äärsete riikide juhid otsustasid Ühendriikide presidendi Bill Clintoni survel nõuda uut ülemaailmset vabakaubanduskõneluste vooru järgmisel aastal .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Nüüdseks vahistatud polkovnik ise eitab vägistamist , edastas Interfax uurimisele lähedal seisvatele allikatele tuginedes .'),
#   Span('allikatele', [{'lemma': 'allikas'}])),
#  (Text(text='Sellistest kõrgustest on unistatud juba klike ajast saati , mil läti korporandid Suur Munamäge labidatega madalamaks käisid kaevamas , kuna Läti kõrgeim mägi juhtus paar meetrit nadim olema .'),
#   Span('mägi', [{'lemma': 'mägi'}])),
#  (Text(text='" Ühendriikide majandus on olnud tugevuse allikaks iseendale ja globaalsele majandusele , " sõnas reedel rahandusminister Lawrence Summers .'),
#   Span('allikaks', [{'lemma': 'allikas'}])),
#  (Text(text='Li Pengi ja tema abikaasat olid tervitama tulnud poolsada Leedus elavat hiinlast , samas seisis kümmekond leedu soost meeleavaldajad , kelle plakatid nõudsid Tiibetile iseseisvust .'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='allikas : EPL'), Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Keskkonnainspektsiooni pressiesindaja Tõnu Paakspuu sõnul TV 3 seiklussaadet " Robinsonid " tootnud Strix Television in the Baltics\'it siiski ei karistata , sest nad jõudsid Hiiumaa laidude kaitsealaga vastastikusele kokkuleppele .'),
#   Span('laidude', [{'lemma': 'laid'}])),
#  (Text(text='Tõsi , seda küll kõigest 1693. aastani , mil Taiwan ühendati mandri-Hiinaga ja kuulutati ametlikult Hiina impeeriumi üheks provintsiks .'),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='Neljandat suve tegutsev Emajõe Suveteater rajas Emajõe kaldale Tartu Ujula tänava lõppu St.'),
#   Span('kaldale', [{'lemma': 'kallas'}])),
#  (Text(text='Kuuba rezhiimi kas siis leebumist või ka allaandmist näitab analüütikute hinnangul asjaolu , et sel nädalal lasi Kuuba valitsus taas enne tähtaega vangist lahti ühe kuulsa dissidendi , 56-aastase advokaadi Rene Gomez Manzano .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Samas tõdes Ojava , et reostus paistis olevat Tallinna lahel ja selle ümbruses triivinud juba mitu päeva , mistõttu on selle tekitajat väga raske tabada .'),
#   Span('lahel', [{'lemma': 'laht'}])),
#  (Text(text='Novaja Gazeta hinnangul on hoopis Tadzhikistan muutunud vähemalt sama kontrollimatuks kuritegevuse ja narkootikumide allikaks kui Afganistan .'),
#   Span('allikaks', [{'lemma': 'allikas'}])),
#  (Text(text='Viiendaks : vaadata Copacabana või Ipanema rannal tüdrukuid .'),
#   Span('rannal', [{'lemma': 'rand'}])),
#  (Text(text='Maitse poolest igati sobilik valik neile , kes ei armasta suu lahti vastu tuult joosta , kuid vürtsikast toidust ometi lugu peavad .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Esimesel juhul lasen lahti , " lausub Kuusk karmilt .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Siis jõuavad kätte Brasiilia ja Kariibi mere saared , läbi Panama kanali sõidetakse Vaiksele ookeanile , kus on palju peatuskohti .'),
#   Span('ookeanile', [{'lemma': 'ookean'}])),
#  (Text(text='" Kui see turvaauk lahti jätta , on võimalik see , mida varem peeti järjekindlalt võimatuks , " ütles Baltic Computer Systemsi tootejuht Risto Agu .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Mõnede allikate sõnul pole siiski välistatud ka konkureerivate kandidaatide ülesseadmine .'),
#   Span('allikate', [{'lemma': 'allikas'}])),
#  (Text(text='Austraalia huvi sõnastas aga üks saareametnik : " Omada keset India ookeani sellist lennukikandjat - selle eest võib ju igal aastal mõnedkümned miljonid maksta .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Praegu ei ütle nad midagi , kuid 24 tunni jooksul võidakse järgmistest sammudest teada anda , " kinnitas Sportlive Interneti-leheküljele klubi allikas .'),
#   Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Mis oli aga ainuõige tegu - keeris kandis ta vaiksemasse vette ning poiss ujus kaldale .'),
#   Span('kaldale', [{'lemma': 'kallas'}])),
#  (Text(text='Pärast pandi signaaltuled , et oleks teada , kas vöör on lahti või kinni .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Pühapäeval kell 19.18 helistas Pärnu piirivalvuritele jahi Mileena kapten , kes teatas , et on sõitnud Lindi kandis madalikule ega suuda oma jõududega jahti taas liikuma saada .'),
#   Span('madalikule', [{'lemma': 'madalik'}])),
#  (Text(text='Kui 5 või 10 aasta pärast on jäme ots konservatiividel , kas siis läheb lahti uus nõiajaht liikmesriikide nende erakondade sürjutamiseks , mille võimulolijad on tembeldanud vasak-äärmuslikeks ?'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Piirivalveameti pressiesindaja Urmo Kohv ütles ETAle , et laev jõudis kell 14.45 Kolka poolsaare juures madalikule .'),
#   Span('poolsaare', [{'lemma': 'poolsaar'}])),
#  (Text(text='Sihtpunktini , Salmistu rannani , on jäänud veel palju kilomeetreid .'),
#   Span('rannani', [{'lemma': 'rand'}])),
#  (Text(text='Niisamuti hoiab pind teravikku mingi aeg kinni , enne kui selle lahti laseb .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Tallinna Kesklinna tuletõrjekomando sai Kadrioru tiigi juurde väljakutse kell 14.16.'),
#   Span('tiigi', [{'lemma': 'tiik'}])),
#  (Text(text='Aga ju on selline Kreeka komme , nii et me jõime viina nahka ega jaksanud enam mägede vallutamisele mõeldagi .'),
#   Span('mägede', [{'lemma': 'mägi'}])),
#  (Text(text='Keskkonnainspektsiooni Pärnu osakonna vaneminspektori Aavo Sempelsoni andmeil on Pärnu lahelt tabatud ka suurema kalakogusega röövpüüdjaid , kuid keskkonnale tekitatud kahju eest nõutav hüvitis kujunes rekordiliseks seetõttu , et keelualal püüdmise eest on seadusega ette nähtud tavalisest kolm korda suurem summa .'),
#   Span('lahelt', [{'lemma': 'laht'}])),
#  (Text(text='Õhutõrjedivisjoni sõduritel ajas kõhu lahti rotaviirus , mis võis väeossa sattuda pesemata käte või puuviljade kaudu .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Trapido sõnul ajab viirus kõhu lahti ja võib ka oksendama ajada .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Seltsi eestvedaja Olev Meremaa kurdab ajakirjandusele , et ametlikku randa , kus palja keha kultuslased isekeskis ja segamatult viibida võiksid , pole suudetud kätte võita , kuigi palvekirju võimudele on saadetud aastaid .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='Näiteks on autotootja General Motors teatanud , et nende OnStar-teenusega varustatud autod teavitavad häireteenistustele oma asukoha automaatselt , kui turvapadi on lahti läinud .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Mulle meeldib , et see pole klassikaline happy endiga muusikal , pigem jäävad kõik otsad lahti , " ütleb Toome .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Lähima 50 aasta jooksul kolmekordistub ka Aasiast ja Vaikse ookeani saartelt pärit ameeriklaste arv , ulatudes 38 miljoni ehk üheksa protsendini .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Eelarve kasvu allikatena on planeeritud maksutulude kasv 95 miljoni krooni võrra .'),
#   Span('allikatena', [{'lemma': 'allikas'}])),
#  (Text(text='USA ja Ladina-Ameerika suurte banaanitootjariikide nn. banaanisõda Euroopa Liidu vastu kestab juba mitu aastat , sest Euroopa Liit on andnud eelisseisundi banaanikaubanduses endistele Kariibi mere , Vaikse ookeani ja Aafrika kolooniatele .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Aruande allikad :'), Span('allikad', [{'lemma': 'allikas'}])),
#  (Text(text='Saab näha uusi inimesi ja sügavalt lahti bikiine .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Saarte ja mandri vahel ei ole lähiajal oodata ka monopoolses seisundis Saaremaa laevakompaniile konkurendi tulekut , sest Hansatee lükkas edasi plaani alustada reise Saaremaa ja mandri laevaliinil .'),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='" Juudi soost abikaasa - ei ole eriti suur kingitus , aga on kindel viis sattuda Iisraeli ! "'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='" Oi , kui tore , mul on selle otsuse üle nii hea meel , et lausa pisar tuleb silma , " ütles kaks ja pool aastat tagasi Pakri saare ja mandri vahelise veetõkke ületamisel hukkunud Baltpati luurerühma liikme Rocco Pussi ema Elli Tamm .'),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='Tallinna Pirita rannas avatakse esmaspäeval rannahooaeg , ülejäänud kolm Tallinna avalikku randa - Kakumäe , Harku ja Stroomi rand avatakse ametlikult 3. juunil .'),
#   Span('rand', [{'lemma': 'rand'}])),
#  (Text(text='Aktiivne tegevus läks lahti juba sel kevadel .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kaks puksiiri tõmbasid Eesti kaubalaeva Kapten Konga teisipäeval tugevamini madalikule kinni , et lained alust sealt lahti ei lükkaks ning viisid kaldale kaubaleva 11 meeskonnaliiget , ütles Läti merepäästeteenistuse ülem Andris Bernans .'),
#   Span('kaldale', [{'lemma': 'kallas'}])),
#  (Text(text='Laulud löödi kiiresti lahti , üks neist oli " Sepapoisid " peoperemeeste keeles .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Linnateater on end traditsioonilisest suvementaliteedist lahti rebinud ning toonud välja lavastuse , mis küllaltki sordiini all .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Eriti hull oli vehklemishallis , seal kisuti fotoaparaadil objektiivid ka lahti ja vaadati läbi . "'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Tallinna etenduse põhjal tundub küll , et Austraalia eestlastele külakostiks mõeldud-tehtud " Kolmandad mäed " oleks võinud kaugete võõrus-etendustega piirdudagi .'),
#   Span('mäed', [{'lemma': 'mägi'}])),
#  (Text(text='Läbi Iraani kulgevad uimastite salakaubaveo trassid Afganistanist ja Pakistanist Pärsia lahele , Euroopasse ja Kesk-Aasiasse ning seal toimub sageli kokkupõrkeid uimastikaupmeeste ja julgeoleku vahel .'),
#   Span('lahele', [{'lemma': 'laht'}])),
#  (Text(text='Abelsil on näiteks teos " Global Warming " , ( " Globaalne soojendamine " ) : helilooja istub kitarr käes Ameerika lõpututes kõrbetes ja mängib - sooloviiuli ja tshello pöörased käigud .'),
#   Span('kõrbetes', [{'lemma': 'kõrb'}])),
#  (Text(text='Õnnetus juhtus Apayo provintsis , kus lapsed olid kolmapäeval teel koolist koju , kui neid tabasid pinnaseerosioonist põhjustatud maalihked kahelt läheduses olevalt mäelt , ütlesid ametnikud .'),
#   Span('mäelt', [{'lemma': 'mägi'}])),
#  (Text(text='" Üks võistlus kestis pea-aegu nädala , mõne jaoks ei lõppenudki need kunagi - jäid soos kadunuks , " märgib Leisson .'),
#   Span('soos', [{'lemma': 'soo'}])),
#  (Text(text='Tallinnas Mustamäe tee 122 elumajas unustas korteri valdaja kolmapäeval lahti gaasipliidi kraani ja kui ta läks hiljem kööki suitsu tegema , toimus plahvatus .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Nad paterdavad koos aedikus ringi ja käivad koos väljas , väikese tiigi jääaugus sulistamas , " räägib Kaja Kübar .'),
#   Span('tiigi', [{'lemma': 'tiik'}])),
#  (Text(text='Õhupall sõidab ligikaudu sajakilomeetrise tunnikiirusega enam kui 9000 meetri kõrgusel kirde suunas ja peaks senist kurssi jätkates ületama Põhja-Hiina ranniku , Korea poolsaare ja Jaapani .'),
#   Span('poolsaare', [{'lemma': 'poolsaar'}])),
#  (Text(text='Lisaks staabis ringivaatamisele sõidab seltskond miinitraaleril Sulev Tallinna lahel ringi .'),
#   Span('lahel', [{'lemma': 'laht'}])),
#  (Text(text='Ausi sõnul oli tegemist velotuuri raskeima etapiga , ületada tuli kuus mäge .'),
#   Span('mäge', [{'lemma': 'mägi'}])),
#  (Text(text='Tartu linnavalitsus soovib viie miljoni kroonise alghinnaga maha müüa südalinnas Lille mäel asuva mitu aastat ilmastikuoludele räsida olnud poolelioleva haldushoone .'),
#   Span('mäel', [{'lemma': 'mägi'}])),
#  (Text(text='Üleval mäe otsas ootab aga šampanja puuviljadega .'),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='Maapangas loodud klassikalise püramiidskeemi , kus aastaid kaeti kahjumit kolmest näiliselt põhjatust allikast pealevoolava riigi rahajõega , purustas sügisene börsikrahh .'),
#   Span('allikast', [{'lemma': 'allikas'}])),
#  (Text(text='Elvas hukkus ööl vastu eilset teelt välja tiiki paiskunud sõiduautos kolm meest , nendega koos olnud naise päästsid kohaliku päästeameti töötajad .'),
#   Span('tiiki', [{'lemma': 'tiik'}])),
#  (Text(text='Ka ühe korraldaja Priit Vare sõnul võis Right Said Fredi kontserti lugeda selle suve tippürituseks rannas .'),
#   Span('rannas', [{'lemma': 'rand'}])),
#  (Text(text='Tenson peab Pärnu lahe vee suuremaks puuduseks seda , et bakteriaalsed näitajad pole ühtlased ja veeproov võib nädalaga oluliselt muutuda .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Tegemist oli viimase sileda etapiga , täna jõuab karavan mägedesse .'),
#   Span('mägedesse', [{'lemma': 'mägi'}])),
#  (Text(text='Tänavune maailmanäitus on pühendatud ÜRO rahvusvahelisele ookeanide aastale .'),
#   Span('ookeanide', [{'lemma': 'ookean'}])),
#  (Text(text='Kohtuasja algatamise tänamatu ülesanne lasub Hispaania valitsusel ja rahvusvahelisel meresõiduorganisatsioonil , mis on esmavastutavad randade koristamise ja jooksvate kulude kandmise eest .'),
#   Span('randade', [{'lemma': 'rand'}])),
#  (Text(text='Juhuslikult on vastaja ka samast soost ning omab mõningast kogemust , et sellised vaated eksisteerivad .'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='Viimane väljub mandrilt Saaremaa poole kell 21 ja Saaremaalt mandrile kell 22.'),
#   Span('mandrile', [{'lemma': 'manner'}])),
#  (Text(text='Alates 1979. aasta suvest , mil Ott Arder ja Juhan Viiding juhatasid mind esmakordselt puhkekompleksi kõrval asuvasse Meremõisa salapärasesse liivaranda , olen olnud kõigil suvedel tolle avaliku ranna külastaja .'),
#   Span('ranna', [{'lemma': 'rand'}])),
#  (Text(text='Ainult palun teid , öelge mulle , kuidas peaksin lahti saama oma praegusest abikaasast ? "'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Atlandi ookean on siiski avatud ookean ja seal on tankeriõnnetuse tagajärjed tunduvalt väiksemad kui Läänemerel , kus sellest tuleks ökokatastroof . "'),
#   Span('ookean', [{'lemma': 'ookean'}])),
#  (Text(text='Rajatava looduskaitseala piirid ulatuvad eraldi maatükkidena randa kavandatavast Kristiine vesilõbustuskeskusest kuni Raekülani ja Vana-Pärnus puhastusseadmetest kuni Pärnu jõeni .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='Hruštšov riietas aeglaselt lahti Stalinit , kes lesis tohutusuures voodis .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Katus on majal kehv ja niiskusega läks lagi natuke lahti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Vene Kaug-Idas Vitjazhi lahes paiknenud mereväebaasis õpetati kashelotte vaenlase sukeldujaid otsima , laevu ründama , pommid keha külge kinnitatud , ja teisi lahinguülesandeid täitma .'),
#   Span('lahes', [{'lemma': 'laht'}])),
#  (Text(text='Ajalehe Morgenavisen Jyllands-Posteni peatoimetaja saatis politseile kirja koos juudi soost Taani kodanike nimekirjaga , kuid politsei nõudis , et palestiinlaste hulgas uurimistööd teinud ajakirjanik avaldaks ka oma infoallikate nimed .'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='Nähakse ära , millise veidra ja ainulaadse mõhnastiku on jääajajärg Elva jõe ürgorgu jätnud , kuidas näeb välja mets , mida inimene juba mõisaajast peale ülemäära palju torkinud pole , imetletakse vesiroosi ilu Viti järvel ja kui järsud võivad mõhna-nõlvad mõnes kohas olla .'),
#   Span('mõhna', [{'lemma': 'mõhn'}])),
#  (Text(text='Festivali pressiesindaja Gea Kammeri sõnul on sool juba tünnilaudadest välja kippumas ning lõhngi ehe .'),
#   Span('sool', [{'lemma': 'soo'}])),
#  (Text(text='Süüdistuse kohaselt hakkas kohtuniku rendiautos istunud Torger naisele püstolit demonstreerima , sest relv oli tal päev varem kodus puhastades kogemata lahti läinud .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kokku jõudis eile mäe tippu 55 inimest , rohkem kui kunagi varem ühe päeva jooksul .'),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='Telliskivi tänava ülesõit on juba praegu autojuhtidele suure peavalu ja ohu allikas .'),
#   Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Kallas ei nõustunud erakonnakaaslase Ignar Fjukiga , kes soovitas valitsusel Eesti Energia juhtkond liiga väikeste järeleandmiste ees lahti lasta .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Eesti tuntuimasse infoturbeettevõtte Privadori serverist andmeid kopeerinud häkker ei murdnud lahti süsteemi loogikat vaid sisenes varastatud parooliga , teatas Privador .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kuigi eeliseks oli see , et naftatankerid ei koorma Bosporuse väina , näitasid arvestused , et Iraani või Venemaa kaudu on toru ehitada palju odavam .'),
#   Span('väina', [{'lemma': 'väin'}])),
#  (Text(text='Iisrael tõi väed Egiptusele kuuluvalt Siinai poolsaarelt välja ja riigid sõlmisid diplomaatilised suhted .'),
#   Span('poolsaarelt', [{'lemma': 'poolsaar'}])),
#  (Text(text='" Tehakse uuringud selle kohta , millised on elanikkonna salvestamisharjumused - kes , mida , kus ja millisest allikast salvestab .'),
#   Span('allikast', [{'lemma': 'allikas'}])),
#  (Text(text='Kandideerides kultuuripealinna tiitlile , peab Tallinn Priimäe sõnul mõtestama lahti linna müügilaused " Keskaegne pealinn " ning " Keskaeg kaasajas " .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kui lasta peast läbi huupi ette kargavad märksõnad ning mõisted , siis need võiks olla : palavus , mäed , lamba- ja kitsekarjad , miljon , lipuvärvid , igavus , sebimine , " Iggy Popi sugulased " , higi , katkised majad ja sõiduteed , mustlased ( keda oleks võinud rohkem näha olla ) , väga odav alkohol ( odavam kui leib ) jne.'),
#   Span('mäed', [{'lemma': 'mägi'}])),
#  (Text(text='Mitme allika hinnangul on varem Keskerakonda kuulunud Streimann senini väga heades suhetes teede- ja sideminister Liina Tõnissoniga , kellel on otsene mõju haldusalasse kuuluvate firmade juhtide ametisse nimetamisel .'),
#   Span('allika', [{'lemma': 'allikas'}])),
#  (Text(text="Piirivalvurid , Nordic Jet Line'i katamaraani meeskond ja veeteede ameti töötajad harjutavad kolmapäeval Tallinna lahel päästetegevust ."),
#   Span('lahel', [{'lemma': 'laht'}])),
#  (Text(text='" Vinge märulitõrjuri suu vajub selle peale lahti , laseb käe valla .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kopamehe sõnul moodustavad Triigi poolsaarel kasvavad puu ja põõsaliigid kolmandiku kogu Eesti puudest ja põõsastest .'),
#   Span('poolsaarel', [{'lemma': 'poolsaar'}])),
#  (Text(text='Uuringud näitavad , et kui tegemist on sektoriga , kus varem on töötanud peamiselt ühe soo esindajad , kuid kuhu ühel hetkel hakkab tööle tulema rohkem teise soo esindajaid , siis palgad langevad sektorites , kuhu tuleb tööle rohkem naisi ning suurenevad seal , kuhu otsustavad tööle asuda mehed .'),
#   Span('soo', [{'lemma': 'soo'}])),
#  (Text(text='Sõjaliste allikatele viidates teatas ajaleht , et Bush soostus armeekindral Tommy Franksi soovitusega , mille kohaselt ei suudaks väiksem kontingent vajaduse korral maad vallutada .'),
#   Span('allikatele', [{'lemma': 'allikas'}])),
#  (Text(text='USA kaitseministeerium kavatseb vabastada mõned terrorismis kahtlustatavad vangid , keda hoitakse Kuubal Guantanamo lahe laagris , kuna nad ei ole enam ohtlikud ning neil pole pakkuda ka enamat luureinfot .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Kolmapäeval päästsid piirivalvurid Peipsi järvelt neli kalurit , kes tugeva tuule toimel jäässe tekkinud pragude tõttu omal jõul kaldale ei pääsenud .'),
#   Span('kaldale', [{'lemma': 'kallas'}])),
#  (Text(text='Kell 13.41 vajasid Kalmaküla all abi kolm kohalikku kalurit , kes kaldast 200 meetri kaugusel tekkinud samuti 50-60 meetri laiuse lahvanduse tõttu maale ei pääsenud .'),
#   Span('kaldast', [{'lemma': 'kallas'}])),
#  (Text(text='Hambaarsti Eevi Aramaa sõnul on omanik püüdnud temast lahti saada , keerates jaanuari algul kinni tema kasutuses olevasse majaossa tuleva veetoru ning ühendades ta 1. veebruaril lahti vooluvõrgust .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kriitikud nimetavad seda riigi ainsaks vaimsuse allikaks .'),
#   Span('allikaks', [{'lemma': 'allikas'}])),
#  (Text(text='Pihkva oblasti elanikud Vladimir ( 30 ) ja Viktor ( 22 ) olid 23. novembril suundunud Storošinetsi rannikult jävele võrke välja võtma , kui paadil mootor ootamatult katki läks ja kaldast eemale triivinud jää haaras paadi kaasa .'),
#   Span('kaldast', [{'lemma': 'kallas'}])),
#  (Text(text='Viimsi vald muutis eelmise aasta jaanipäeva paiku kaheksa päevaga kurikuulsa nn Antenniväljaku detailplaneeringut , mille tõttu saab Viimsi poolsaare keskel asuvale krundile ehitada 80 elamuühiku asemel 320 elamuühikut .'),
#   Span('poolsaare', [{'lemma': 'poolsaar'}])),
#  (Text(text='Chittagongi sadamas anti tormihoiatus , kuid kõik kalurid ei jõudnud enne tormi tõusmist randa tagasi ja Bagladeshi võimud usuvad , et uppunud on vähemasti 100 kalurit .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='" Tollal mõtlesin : no mis siis , ma olen noor , see on president , ta on kena , see on nii lahe , vastutustundetu , aga lahe , " meenutas Lewinski maksulises kaabeltelekanalis HBO näidatud dokumentaalsaates " Monica mustas ja valges " .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Kallas kirjeldas Eesti ja Venemaa suhteid ning avaldas heameelt , et Eesti loodetav liitumine NATO-ga ei ole enam konflikti allikaks Venemaaga .'),
#   Span('allikaks', [{'lemma': 'allikas'}])),
#  (Text(text='allikas : Viru Hotell'), Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='" Oleme katnud muruga mitme renoveeritud maanteelõigu teeservi ja kraavide kaldaid Konuveres , Lohusuus ja mujal , " rääkis Vares .'),
#   Span('kaldaid', [{'lemma': 'kallas'}])),
#  (Text(text='Eile keskpäeval avasid YIT Ehituse ja Pärnu linnavalitsuse esindajad Pärnus Ranna puiestee ja Side tänava pikenduse , millega sai linn rannas juurde ligi 300 meetrit uut tänavat ja jalgrattateed ning busside parkla .'),
#   Span('rannas', [{'lemma': 'rand'}])),
#  (Text(text='Paari nädala eest Viljandi järve randa ja Sammulisse välja pandud infotahvlitel on selgelt kirjas , et kaatrid ei tohi sõita kiiremini kui 30 kilomeetrit tunnis .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='Inimesed tahavad ebatavalisi õllesid kogu mandrilt ja me loodame sellistele õlledele pubides suur menu . "'),
#   Span('mandrilt', [{'lemma': 'manner'}])),
#  (Text(text='Muuseumi direktor Mihkel Kallaste rääkis Pärnu Postimehele , et sea köht läks lahti juba üle-eelmisel neljapäeval ja ta viis looma enda koju , kus tolle elu esmaspäeval löppeski .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Hiinas hukkus terasetehases 32 inimest , kui sulaterase konteiner katki läks ja tehasetöölised kuuma metalliga üle kallas .'),
#   Span('kallas', [{'lemma': 'kallas'}])),
#  (Text(text='Olin lasknud tal korraks käest lahti , sest ei osanud kooli territooriumil karta kiirust ületavat autot .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Venemaa president Vladimir Putin peatas laupäeval ametlikult Venemaa osaluse tähtsas Külma sõja järgses tavarelvastusleppes , mille eesmärgiks oli piirata raskerelvade arvu Atlandi ookeani ja Uuralite vahelisel alal , põhjendades seda erakorraliste turvalisust puudutavate asjaoludega .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Siis märkad , et kõrb on täis varjatud elu , näed selliseid värvikombinatsioone , mis võtavad hingetuks ja avastad , et liiv ja tuul oskavad luua kahasse reljeefe , mida ka kõige osavam skulptor võib ainult kadestada .'),
#   Span('kõrb', [{'lemma': 'kõrb'}])),
#  (Text(text='Üheski dokumendis pole aga seletatud lahti mõistet " vaba aja veetmiseks ettenähtud ruum " .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Teine pomm plahvatas pisut hiljem Bosporuse väina kaldal Ceylan Intercontinental hotelli juures .'),
#   Span('väina', [{'lemma': 'väin'}])),
#  (Text(text='Kodanikesaalis on praegu veel lahti võtmata koht , mis 1970-ndate remondis lõuendiga kinni kaeti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kui talupojad mäe otsa ronisid , leidsid nad sealt , kus imeline nägemus oli seisnud , ühe vana männi alt Jumalaema Uinumist kujutava ikooni .'),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='Tänavu paisatakse Salmistu-Valkla rannas meredessandiga rannale 31 neljaliikmelist võistkonda , nende seas 14 välisvõistkonda 11 riigist .'),
#   Span('rannas', [{'lemma': 'rand'}])),
#  (Text(text='" Harku ja Pääsküla raba kaitseala moodustamine on oluline etapp Tallinna rahvuspargi rajamisel , " ütles Ratas .'),
#   Span('raba', [{'lemma': 'raba'}])),
#  (Text(text='Kavandatav köisraudtee viib inimesed järve vastaskaldale randa või suusakeskusesse .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='Kui riik andis lubaduse kogumispensioniga liitujatele , siis riik peab leidma ka selleks rahastamise allikad , aga mitte lükkama pensionireformi praeguste pensionäride kanda .'),
#   Span('allikad', [{'lemma': 'allikas'}])),
#  (Text(text='" Usun , et meist saavad suured sõbrad ja meri koos rannaga on meile heaks naabriks , " ütles ta .'),
#   Span('rannaga', [{'lemma': 'rand'}])),
#  (Text(text='Musumäele ( Viruvärava mägi ) valati skulptuuride tarbeks eelmisel nädalal kaks alust , 1,5 -2 meetri kõrguste kujude paigaldamine peaks esialgsete kavade kohaselt algama täna .'),
#   Span('mägi', [{'lemma': 'mägi'}])),
#  (Text(text='Röövitud inimesed olid pärit UKst , Filipiinidelt ja Kosovost , ütlesid allikad .'),
#   Span('allikad', [{'lemma': 'allikas'}])),
#  (Text(text='Üks meremees annab tööd kolmele inimesele kaldal . "'),
#   Span('kaldal', [{'lemma': 'kallas'}])),
#  (Text(text='Täna tabas USA laev 1. jaanuaril kaduma läinud Indoneesia lennuki musta kasti signaali , mis tuli ookeani põhjast .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Kui hästi läheb , saame ehk sel talvelgi jääteed pidi Hiiumaalt mandrile sõita , hea rahulik mõtteid mõlgutada .'),
#   Span('mandrile', [{'lemma': 'manner'}])),
#  (Text(text="Teine operaator asub mäe all , et snowtube'id mäest üles sõitmiseks tõstuki külge haakida ."),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='Harju mäe aluste tunnelite korrastamine ja turismiobjektina avamine on kirjas ka linnavõimu koalitsioonileppes .'),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='Nende suhtarvude muutmine ei ole aga mägede taga .'),
#   Span('mägede', [{'lemma': 'mägi'}])),
#  (Text(text='Ajakirjanike Kaitse Komitee kindel seisukoht on , et ajakirjanikke ei tohiks mitte kunagi sundida oma allikaid avalikustama .'),
#   Span('allikaid', [{'lemma': 'allikas'}])),
#  (Text(text='Seni on treeningmängud sujunud nagu sõit " ameerika mägedes " .'),
#   Span('mägedes', [{'lemma': 'mägi'}])),
#  (Text(text='Paldiski piirivalvurid märkasid eile kell 3.53 radarit jälgides , et juba kümne minuti jagu seisab Suur-Pakri saare põhjatipust kolme miili kaugusel läänes Krassi madalikul tundmatu laev , mis ei vasta kutsungile .'),
#   Span('madalikul', [{'lemma': 'madalik'}])),
#  (Text(text='Avar ja tuuline laht .'), Span('laht', [{'lemma': 'laht'}])),
#  (Text(text='Ainsana pealinna randadest on puhas ja ujumiskõlblik vesi Kakumäe rannas .'),
#   Span('rannas', [{'lemma': 'rand'}])),
#  (Text(text='Ja kui oma siirusest lahti rabelda ja vaadata kirjandusest mõtleja pilguga , siis sisaldab see raamat ühe metafooriteoreetiliselt põnevama luuleteksti eesti luules üldse .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Inimohvritega suuri õnnetusi juhtus sealseis vetes eelmisel sajandil kolm : peale Estonia uppus saare külje all 1947. aasta jõulu-õhtul Ameerika kaubalaev Park Victory kümne madrusega par-dal ning 1929. aastal jäid veelgi lähemal , 300 meetrit Utö rannast merre kolmemastilisel purjekal Drake olnud kuus madrust .'),
#   Span('rannast', [{'lemma': 'rand'}])),
#  (Text(text='Põhja-Tallinnas on tähtsaimaks Stroomi ranna väljaehitamine ja korrastamine - Stroomi rannast peab saama üle Eesti tunnustatud puhkekoht , ütles Järve .'),
#   Span('ranna', [{'lemma': 'rand'}])),
#  (Text(text='Igas eas loodushuvilisi peaksid köitma ka lood Põhja-Ameerika piisoni ellujäämise saladusest , samuti Põhjaranniku äärses Soome lahes talvituvatest lindudest , virmalistest ja kaugetest reisidest .'),
#   Span('lahes', [{'lemma': 'laht'}])),
#  (Text(text='" Arvan , et mulle kõige ohtlikum on Basso , kes näitas oma tugevust mägedes ja on hea ka eraldistardis .'),
#   Span('mägedes', [{'lemma': 'mägi'}])),
#  (Text(text='Leisi vallas on Pihla laid erakätes , aga Kihelkonna vallas , Vilsandi rahvuspargi ümber olevad väikelaiud kuuluvad riigile .'),
#   Span('laid', [{'lemma': 'laid'}])),
#  (Text(text='Lihulas avati eile reoveepuhasti , mis on Haapsalu-Matsalu lahe keskkonnaprojekti esimene osa .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Eesti rannikumeres on kokku 1521 saart , neist 96 on suuremad kui 10 hektarit , ülejäänud aga väikesed laiud ja saarekesed .'),
#   Span('laiud', [{'lemma': 'laid'}])),
#  (Text(text='PÄRNU , 14. märts ( EPLO ) - Liivi lahes ulbib rannast lahti murdunud jäämassiiv , mille tugevad edela- ja läänetuuled võivad puhuda rüsisse Pärnu lahte , kirjutas Pärnu Postimees .'),
#   Span('rannast', [{'lemma': 'rand'}])),
#  (Text(text='Äravoolu kaudu lastaks tiik tühjaks Toompuiesteel asuvasse kanalisatsiooni .'),
#   Span('tiik', [{'lemma': 'tiik'}])),
#  (Text(text='Sel kevadel kalasõja alana tuntuks saanud Liivi lahe osa on Saaremaa piirkonna piirivalvurite valvata .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Paralepa veetemperatuur pole ilmade soojenemisest alates alla 21,5 kraadi langenud ning rand on päevad läbi rahvast täis .'),
#   Span('rand', [{'lemma': 'rand'}])),
#  (Text(text='Teine allikas sõnsa , et mehed on usutavasti seotud terrorirühmitusega Ansar al-Islam , see on iraalaste rühmitus , millel on seoseid al-Qaidaga .'),
#   Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Mitu ööd-päeva hiilimist metsi , soid ja kraave mööda , ja lõpuks sünnipäevahommikul kodutrepil .'),
#   Span('soid', [{'lemma': 'soo'}])),
#  (Text(text='Tähelepanekud näitavad , et tihti sünnivad pojad samas koopas või urus , kus mullugi .'),
#   Span('koopas', [{'lemma': 'koobas'}])),
#  (Text(text='Hispaania välisministeeriumi pressiesindaja sõnul tehakse selline ettepanek strateegiliselt tähtsal poolsaarel võimu jagamiseks tänasel kohtumisel Briti välisministri Robin Cookiga .'),
#   Span('poolsaarel', [{'lemma': 'poolsaar'}])),
#  (Text(text='Järgmisel , 1886. aastal ehitati puust päevamärk , mis koos tuulikuga juhatas laevadele Väinamerre sõites möödapääsu Eeriku kivist , s.t väikesest laiust sellel asuva suure rändrahnuga .'),
#   Span('laiust', [{'lemma': 'laid'}])),
#  (Text(text='Tõivo Sarmeti poolt juhitud rühm oli mägedes kokku 15 päeva .'),
#   Span('mägedes', [{'lemma': 'mägi'}])),
#  (Text(text='Kuna auto oli nii turvaline , siis juhipoolset ust me lahti ei saanud .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kuid niisugune uus keskendumine Pärsia lahe piirkonnale on siiski laiema tähtsusega : hoolimata kõigist suurtest probleemidest Venemaa , NATO laienemise ja Hiinaga , asuvad kõige suuremad koheste poliitiliste ja diplomaatiliste raskuste piirkonnad Pärsia lahe ja Vahemere regioonis , Kesk-Aasias , Balkanil , Aafrikas - ehk " Lõunas " , nagu prantslased ütlevad .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Vaadata ja pildistada on aga võimalik 100-kilomeetrise läbimõõduga Popikai kraatrit , mis asub Leena suudmes Taimõri poolsaare taga .'),
#   Span('poolsaare', [{'lemma': 'poolsaar'}])),
#  (Text(text='Selles veendumiseks piisab vaid võrrelda kliimat Eesti saartel ja mandril .'),
#   Span('mandril', [{'lemma': 'manner'}])),
#  (Text(text='Hommikujooksu tegijaid võttis kuulsal Bondi rannal vastu põlevate eukalüptide kirbe lõhn .'),
#   Span('rannal', [{'lemma': 'rand'}])),
#  (Text(text='Pereürituse Eesti rekordid 97 korraldab Highland Marketing , kelle direktori David Couttsi sõnul on üritus lahe nädalalõpp nii võistlejatele kui vaatajatele .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Kaks aastat pärast seda alustas Hawaiil tööd USA Vaikse ookeani hoiatuskeskus .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Hea on küsida tagasisidet enda kui töötaja kohta ning tekkinud ebakõlad lahti arutada .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Äkki peaksime kala adopteerima ja India ookeanist Soome lahte ümber kolima ?'),
#   Span('ookeanist', [{'lemma': 'ookean'}])),
#  (Text(text='Vee sissevoolu saanuks täpsemalt analüüsida , kui tuukriuuringute käigus oleks uuritud veekindlate uste , autoteki tulekindlate uste ja lasti seisundit , samuti seda , kas ventilatsiooniavad olid kinni või lahti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Linnavolikogu linnavarakomisjon ja Kristiine linnaosa halduskogu taotlevad , et müüdavate kruntide seast jäetaks välja ja linnaosale kasutada kaks 4,5 hektari suuruse kogupinnaga krunti , millest ühel on tiik ja park ning teisel staadion , mida renditakse võimlemisliidule veel üheksa aastat .'),
#   Span('tiik', [{'lemma': 'tiik'}])),
#  (Text(text='Ta palus autojuhil haagise lahti teha , kuid ta keeldus .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='1682 - Prantsuse maadeuurija La Salle jõudis mööda Mississippi jõge Mehhiko laheni .'),
#   Span('laheni', [{'lemma': 'laht'}])),
#  (Text(text='Arengukava aitab need eesmärgid iga metskonna ja RMK struktuuriüksuse jaoks lahti mõtestada konkreetseteks tegevusteks , ?'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Siis oli suur hädakisa lahti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='14.30 - 15.00 Argo Kirjastus esitleb : kohtumine Navitrollaga , kes räägib oma viimaste aastate maalidest , mis on kogutud ja lahti seletatud vastilmunud " Navitrolla kolmandas raamatus " ja näitab animafilmi .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kakumäe randa plaanitakse järgmiseks suveks rannahoonet , palliplatse ja vabaõhulava .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='Kaks nädalat tagasi Pärnu kesklinna rannas toimunud raadiojaama Sky Plus rannapeo korraldajad tunnistasid , et ei saanud peojärgsete koristustöödega õigeks ajaks hakkama ega vaidle linna esitatud 10 000kroonise leppetrahvi üle .'),
#   Span('rannas', [{'lemma': 'rand'}])),
#  (Text(text='Eile varahommikul Paide tehisjärve äärde kalale läinud Krassil ei olnud alguses püügiõnne .'),
#   Span('tehisjärve', [{'lemma': 'tehisjärv'}])),
#  (Text(text='" Õngitsesin oma forellid kahest tiigist välja ja panin ühte tiiki kolme tiigi jagu kalu .'),
#   Span('tiigi', [{'lemma': 'tiik'}])),
#  (Text(text='Kulguril on kaks mustvalget stereokaamerat ja tema ninas on aparaat , mis määrab täpselt pinnase keemilise koostise .'),
#   Span('ninas', [{'lemma': 'ninas'}])),
#  (Text(text='Teise preemia ( 7000 krooni ) pälvis Jüri Tuuliku tekst " Ameerika mäed " ja kolmanda preemia ( 4000 krooni ) vääriliseks tunnistati Teet Kallase raadionäidend " Palatimäng " .'),
#   Span('mäed', [{'lemma': 'mägi'}])),
#  (Text(text='Maastikuring , mille pikkus on 12,1 kilomeetrit ja mis kulgeb Rakke Linnamäel ning Edru mägedes , nõuab sõitjalt head treenitust ja oskust ratast valitseda , kuid rada on siiski oluliselt kergem kui maratonidel .'),
#   Span('mägedes', [{'lemma': 'mägi'}])),
#  (Text(text='Kogu see nirvaana lõppes muidugi paari päeva või nädala pärast mandrile tagasi pöördudes , vene piirivalvurile nõukogude passi esitades ja pohmeluses vaeveldes .'),
#   Span('mandrile', [{'lemma': 'manner'}])),
#  (Text(text='Teede- ja sideministeeriumi asekantsleri kinnitusel on maailmapraktikas mitu erinevat võimalust , kuidas saarte ja mandri vahel praame käigus hoida .'),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='Lebed lõi selle lauale lahti ja rääkis oma kõmiseval bassihäälel : " Ma ei tunne Kozõrevi , kuid selle artikli suund on õige .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Näiteks loitsu alla pandud tsemendikott , mis kleepus varga õlgade külge ega tulnud enam lahti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Ruhnus viib kohaliku külapoe omanik Vitali meid kohe Limo randa karu jälgi vaatama .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='Võitjaks pärjatakse võistleja , kes kõige kiiremini üles või kõige kõrgemale jõuab , " rääkis üks mäkketõusuvõistluste korraldajatest Motoklubi HMG juhataja Erkki Salak ja lisas , et eelmisel aastal jõudsid mäe tippu vaid neli mootorratast ja üle-eelmisel kaks .'),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='Torustikes võib vesi tavapärasega võrreldes hakata liikuma vastupidises suunas , lükates nõnda lahti torude siseseintele kogunenud roostekihi .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Teadlased avastasid , et Soome lahe teatud osas ei liigu pinnaalused veekihid mitte Eesti või Soome ranna suunas , vaid suunaga lahest välja .'),
#   Span('ranna', [{'lemma': 'rand'}])),
#  (Text(text='Õrnemast soost töötajaid on ilmateenistustes kõige vähem Süürias'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='Paskvillide avaldamise komme , mis nõukogude ajast juurdunud , näeb ette võimalikult isiklikke rünnakuid ja võimalikult laiu üldistusi .'),
#   Span('laiu', [{'lemma': 'laid'}])),
#  (Text(text='" Sellel aastal tehakse seire täies mahus , et selgitada ranna avamise võimalusi 2007. aastal , " märkis Sõtnik .'),
#   Span('ranna', [{'lemma': 'rand'}])),
#  (Text(text='" Minu ema oli õpetaja ja koolijuhataja , minu poeg on Rõuge põhikooli direktor , " selgitas Raju seda , mis on teda selle ameti juurde toonud ja pole siiani lahti lasknud .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Novembri lõpus kavatsevad 60 eestlast ühel ajal jõuda ligi 6000-meetrise Kilimanjaro mäe tippu Aafrikas .'),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='üRO allikate teatel on PUK lisaks Sulaimaniya tagasivallutamisele võtnud taas enda kontrolli alla ka Chamchamali ning Darbandikhani linnad .'),
#   Span('allikate', [{'lemma': 'allikas'}])),
#  (Text(text='See on loomulik reaktsioon möödunud aastal ebamõistlikult kõrgeks tõusnud kinnisvarahindadele , peamiselt Tallinna ja siinsete mägede korterite hindadele , ütles Hansapanga eluaseme finantseerimise osakonna arendusjuht Kersti Arro .'),
#   Span('mägede', [{'lemma': 'mägi'}])),
#  (Text(text='Diktor annab lihtsa võtme filmi detailide mõistmiseks : lendamiseks tuleb lasta lahti asjadest , mis sind maa küljes kinni hoiavad .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='" Kulude kasvul on põhiliselt kaks allikat - püsikulud ( kütuse- ja personalikulu ) ning käitluskulud , mis aasta-aastalt tõusevad .'),
#   Span('allikat', [{'lemma': 'allikas'}])),
#  (Text(text='Kui olete tuletorni kürgetest trepiastmetest üles turninud , siis paistab ära ka Ristna neem .'),
#   Span('neem', [{'lemma': 'neem'}])),
#  (Text(text='" Kui piraaja näpust kinni haarab , siis seda enam lahti ei saa , " hoiatab Siigur .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Eesmärgi saavutamiseks on kohalikud turismiettevõtjad investeerinud uue golfikeskuse ehitamisse , vald korrastab Pühajärve randa ja suurenev turistide hulk innustab ettevõtjaid rajama ka uusi hotellikohti .'),
#   Span('randa', [{'lemma': 'rand'}])),
# ...
#  (Text(text='mis ma tahan öelda , et lahe 2D !'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='suud lahti'), Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='näitus on 2. aprillini lahti aga ma ise tõenäoliselt ei satu sinna .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='mida algav aasta toob sellest räägib horoskoop ah mis ta siis ikka toob vahel õlut väike toop vahel kõrvale ka leib rohkem rõõmsaid uudiseid polegi vist oodata maha jätab sind su neid lahti saad ka ametist ja veel maksuametist saabub ettekritseldus ablas kaljukitsendus mägismaine antiloop näkitseb su õunapuult takerdunud lõunatuult kuusirp põllult vilja joob vaat mis räägib horoskoop   CONTRA'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Diplomaatiliste allikate väitel on suur-saadik pantvangi võetud .'),
#   Span('allikate', [{'lemma': 'allikas'}])),
#  (Text(text='Tead seda anekdooti bänd mängib , solist mõtleb : oh , tibid vaatavad mind , ma rokin täiega ; kidramees mõtleb , vat panen ägeda soolo praegu , tibid vaatavad , jumala lahe ; ja taga mõtleb bassimees : tümm , tümm , tümm .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Kes neist võib koha kaotada , allikas ei teadnud .'),
#   Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Tervikuna lahe tapeet , kuigi kõva 20 minutit pikem kui vaja .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Jälle mägi .'), Span('mägi', [{'lemma': 'mägi'}])),
#  (Text(text='Silindrid tuleks lahti võtta ja üle vaadata .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kui ma netis ringi liigun ja tahan mõnd pdf faili näha ja avades teeb ta selle browseri aknas kohe lahti ( N : IE-s avatakse acrobat ja see fail mis ma vaadata tahan ) .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text="See laseks selle epsi pdf'ks , võtaks illukas näiteks lahti , teeks search-replacega kogu dokumendis vajalikud värviasendused ja olekski kogu moos ."),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Iraagi elu hästi tundev allikas selgitab : " Selleks et sinna minna , ei pea olema sõjaväelane .'),
#   Span('allikas', [{'lemma': 'allikas'}])),
#  (Text(text='Elektrooniline piletisüsteem lubab kogu aeg jälgida , kui palju inimesi rannas on .'),
#   Span('rannas', [{'lemma': 'rand'}])),
#  (Text(text='Tahan osta ka paar rulli : A3 laius ehk 297mm ja pikkus kuni 30m ( muidu läheb rull liiga suureks ) .'),
#   Span('laius', [{'lemma': 'laid'}])),
#  (Text(text='Muide ma kaa usun et lahe asi tuleb lõpuks .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='liiga lahe oli !'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='kui harju keskmisele mootorile nos installida ja kraan lahti keerata , algab mootoris korralik tshernobõl .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='seal on selline papp ees .. seda mina vähemalt eest ära ei saand .. ( ei viicind armatuuri maha kiskuda ) .. lõika kapoti alt sinna auk sisse , siis saad papi eest ära võta ( pärast paned teibiga augu kinni ) .. kalla sinna seda löga sisse mis radika ummistuse lahti teeb or smth .. peaks aitama .. väga imelik muide .. mul ikka julmalt palav seest .. praegu sõidan näiteks nii et katuseluuk ülespoole lahti , kui suicu teen siis juhi aken ka pool lahti , ja soojendus põhjas ..'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='ja monzta - ega ainult elukutseline bussijuht ei või autode koha pealt suud lahti teha .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='” Lootuse kaotanud Grubbs rabas kõiki nelja gaasiheeblit , et lennukit vasakule juhtida .'),
#   Span('rabas', [{'lemma': 'raba'}])),
#  (Text(text='Ning kui teed tööd kehvalt , lastakse sind lahti .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Õpetajad head ja aine kah lahe'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text="Vahemere lääneosa veed , mille piiriks on joon , mis algab Aafrika rannikult Alžeeria-Tuneesia piirilt ja kulgeb otse põhja kuni 38°00' põhjalaiuseni ; sealt otse läände kuni 8°00' idapikkuseni ; sealt otse põhja kuni 41°20' põhjalaiuseni ; sealt mööda loksodroomi läände kuni Prantsusmaa ja Hispaania vahelise maismaapiiri idapoolseima punktini mandri rannikul ; sealt piki Hispaania rannikut Punta Marroquíni ; sealt mööda 5°36' läänepikkust otse lõunasse Aafrika rannikuni ; sealt piki Aafrika rannikut ida suunas alguspunktini ."),
#   Span('mandri', [{'lemma': 'manner'}])),
#  (Text(text='E lisas on näidatud India ookeani lääneosa ( püügipiirkonna 51 ) piirid ja alarajoonid .'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='India ookeani lääneosa jagatakse järgmiselt :'),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='kui teema siin juba rattaga kihutamise peale läks siis aastaid 2 tagasi sai väänajõesuusse minnes mingist mäest ca 70 km/h kätte .'),
#   Span('mäest', [{'lemma': 'mägi'}])),
#  (Text(text='rand : Pärnu'), Span('rand', [{'lemma': 'rand'}])),
#  (Text(text='rand : Stroomi'), Span('rand', [{'lemma': 'rand'}])),
#  (Text(text='ja ämblikke ma ei karda .. kuid yx öö .. väike piip enne magamaminekut sai tehtud .. siis ärkasin mingi kell yles .. und lihtsalt ei olnd .. midagi unes ei näind kah .. olin siis lihtsalt kylili voodis .. vahtisin radiaatorit .. järsku tunnen .. meeletu kogu pikakoivalisi ämblikke ( teate neid kyll .. mis krdi jooxik ta oli - väike keha eriti pikad peened jalad ) kukb näkku .. ja jube noh .. neeid voolas säält laest mulle ikka paras kogus näkku .. laks olin voodist pysti .. jube värk .. hõõrud nägu .. ei midagi .. laes ei midagi .. isegi voodi tuulasin läbi .. ei midagi .. a meeletu kogus .. terve armee lausa jooxis mul yle näo .. tra .. seda enam und pärast ei tahtnud tulla .. nyyd mõtlen .. jõle lahe värk .. tahax veel siuxeid närvihalukaid kogeda !'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='See jutt , et profid teevad 20 sekundiga lukke lahti , ei oma mingit tähtsust .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Ja ühes Saksamaa väikelinnas oli keskvalitsus sunnitud kohaliku valitsuse nõudel vangla ja linna vahele rajama kõrghaljastusega mäe .'),
#   Span('mäe', [{'lemma': 'mägi'}])),
#  (Text(text='“ Mäletan Erikat väärika ja rühika naisena , ” meenutab Eva Lille raamatu “ Soome lahe kahel kaldal ” saatesõnas .'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='“ Nüüd aga tunnen , et vesi annab mulle jaksu ja lähen tihtipeale randa , ” räägib ta .'),
#   Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='Regionaalpoliitika nõukogus on olnud ka juttu , et ilmselt tuleks mõned read konkreetselt lahti kirjutada .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Ministeeriumidest on lahti lastud väga palju spetsialiste , oma ala tundjaid ja asemele on võetud kuulekad poliitsõdurid .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Uus plaan on nende jaoks tõhuseam : rahastada ametlikest allikatest terrorismi , et hävitada , paanikat külvata ja selliselt täielikult demoraliseerida tsiviilisikud Iisraelis .'),
#   Span('allikatest', [{'lemma': 'allikas'}])),
#  (Text(text='See paragrahv on kahe lõikega ning seletab meie arvates senisest lihtsamalt lahti teabekandja salastamistähtaja mõiste ja selle tähtaja arvestamise korra .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Nii et vastus on täna selline , et kui üldisest vajadusest ta jääb kahe ja poole kordselt või natuke rohkem maha , siis nende allikate puhul , mis siin on toodud , jääb ta maha umbes 300 miljonit krooni järgmise aasta arvestuses .'),
#   Span('allikate', [{'lemma': 'allikas'}])),
#  (Text(text='Kontrollisin - kõrgkoolide rektorid ütlevad selle kohta , et see on vale informatsioon , nemad nõuavad seda , et eelarved kirjutataks lahti , kuid seda ei tehta .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kahjuks on jäänud riigieelarve endiselt läbipaistmatuks ega näe arengus rahva laiu hulkasid , sellepärast me ei saa toetada 2001. aasta riigieelarve vastuvõtmist ja oleme väga murelikud selle pärast , et meie ettepanekuid pole arvestatud .'),
#   Span('laiu', [{'lemma': 'laid'}])),
#  (Text(text='Et ta soovimatut isetegevust ei teeks , oleks mõistlik siiski lahti ülendada='),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Selle vana võtsin kah lahti , hirmus s ... ne teine .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Võtame vaatluse alla Vabariigi Valitsuse algatatud ranna ja kalda kaitse seaduse muutmise seaduse eelnõu .'),
#   Span('ranna', [{'lemma': 'rand'}])),
#  (Text(text='Me ei olnud nõus aktsepteerima Isamaaliidu pakutud allikaid .'),
#   Span('allikaid', [{'lemma': 'allikas'}])),
#  (Text(text='colilmcrae - ilmselt pead sarja läbi sõitma et lisa optsioonid lahti tuleksid ...'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Täna on teisel lugemisel narkootiliste ainete seadus , mis põhimõtteliselt kirjutab selgemini lahti ÜRO konventsioonide ( 1961 , 1971 ) esitatud nõuded ja mõtestab mõnda külge põhiseaduse §-st 20 , mis käsitleb narkomaani vabaduse piiramist .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='ei , lahe foorum .'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='Seepeale läks lahti üldine arutelu teemal , kuidas kellegi kodus vanemad lapsi või lapsed vanemaid sõimavad .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Ees ootas Gobi kõrb .'), Span('kõrb', [{'lemma': 'kõrb'}])),
#  (Text(text='Kuid kooskõlas rahvusvaheliste kogemustega ja eeskujudega - oli ju selge , et tuli millestki eeskuju võtta - käsitleb ta põhiliselt ioniseeriva kiirgusega , seega suurema ohu allikaga seotud ohutuse küsimusi , delegeerides mitteioniseeriva kiirguse ja selle ohutuse reguleerimise valitsuse määrusele või määrustele .'),
#   Span('allikaga', [{'lemma': 'allikas'}])),
#  (Text(text='“ Muidu ei saanud , kui tuli küün lahti võtta ja jupphaaval vanasse kohta tagasi vedada . ”'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kaasik ütleb , et turbaväli tegutses toona raba keskosas 40 hektaril .'),
#   Span('raba', [{'lemma': 'raba'}])),
#  (Text(text='Esmaspäeval esitas Villu Reiljani juhitav Rahvaliit valitsusliidu 3R kaaslastele Res Publicale ja Reformierakonnale terava avalduse , millega ütles sisuliselt lahti koalitsioonilepingust .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Enim otsitud on talu veekogu kaldal .'),
#   Span('kaldal', [{'lemma': 'kallas'}])),
#  (Text(text='Mõned ametnikud lausa häbenevad Eesti kodaniku tavapassi , millega reisides on eestlastele pea kogu maailm lahti ( selle eest tuleb härra Ilvese tööle tunnustust avaldada ) .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Seaduse lisas on öeldud , et kuna Eesti Vabariigi ning Läti Vabariigi vahelistel läbirääkimistel ei ole territoriaalmere piir Irbe väinas ja Liivi lahes veel fikseeritud , siis võib Eesti Vabariigi territoriaalmere piir läbirääkimiste tulemusena teatud punktides muutuda .'),
#   Span('väinas', [{'lemma': 'väin'}])),
#  (Text(text='Läti pool peab ilmselt selles soodsaks piirijoone kulgemist Ikla-Heinaste piirkonnas , kus see arvestab Riia varasemaid ettepanekuid ning Eesti pool peab soodsaks 12 meremiili laiust territoriaalmerd Ruhnu ümber .'),
#   Span('laiust', [{'lemma': 'laid'}])),
#  (Text(text='Praegu on neil vastavalt 1994. aasta seadusele Liivi lahel kehtestatud ühine sisemeri .'),
#   Span('lahel', [{'lemma': 'laht'}])),
#  (Text(text='Kohalikele omavalitsustele kohustuse panemisel peavad täpselt olema sätestatud nii finantseerimise allikad kui ka kohalike omavalitsuste eelarvesse sihtotstarbeliste summade eraldamise kord .'),
#   Span('allikad', [{'lemma': 'allikas'}])),
#  (Text(text="Me teame , et juutidel on nii Euroopas kui ka Põhja-Ameerikas , isegi Vaikse ookeani ääres kõikides tähtsamates linnades n-ö prestiižsel kohal  holocaust  'i muuseumid ."),
#   Span('ookeani', [{'lemma': 'ookean'}])),
#  (Text(text='Ka mina tahan lahti saada sellest eraldamisest , millest seadustes räägitakse .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Kui nad seda ei ole , ka siis ei ole midagi lahti , sellepärast et üksikprojektide jaoks on võimalik alati raha saada Kultuurkapitalist või fondidest .'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Thawk: lahe mõlö'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='ade: no siis on kyll lahe kui te discole l2hete , peax kah minema.'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='renny: suuu läks väga lahti'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='maddog: lahe ju'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='tiina: kas kedagi harjumaal koselt on vää'),
#   Span('koselt', [{'lemma': 'kosk'}])),
#  (Text(text='kissgirl: vapsee lahe'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='seksy: on lahe vä'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='dj_crule: lahe'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='chokoladk2tlin: goldenhair .. selline lahe'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='tsau: mina ei lahe'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='enivei: boy_15 lahe karaoke .....'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='devilgirl: aaaa oki see lahe place'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='karlson: no lahe siis , ma jõuan selle ära oodata'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='mosse: ah soo kudas läx'), Span('soo', [{'lemma': 'soo'}])),
#  (Text(text='norma: join #s6brad seal on vega lahe tulge plizzzzzzzz seal on teiega lahe !!!!!!!!!!!!!!'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='marissa: ikka ei saa veel tomi lahti , miks ?'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='maria: lahti ple midagi , kõik kinni'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='raba: tegid roopi'), Span('raba', [{'lemma': 'raba'}])),
#  (Text(text='Tuuma_Enn: Kui tahad , et sinu arvamust jagaksid naabrid , hoia uks lahti.'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='Favoritas: kuule siin on ju selline lahe munadeta seltskond koos'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='kuska: oh ... lahe ... ma avastasin , et mul on amortidega tool ... nyyd ma saan hypata'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='maris14: nii lahe on'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='marco: mul kukkus suu lahti'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='windo|rapist: ja oleks lahe'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='mk: joid soid ja ...'), Span('soid', [{'lemma': 'soo'}])),
#  (Text(text='indrek: saabgi sittast lahti'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='anita: aga siin pole randa'), Span('randa', [{'lemma': 'rand'}])),
#  (Text(text='raba: ohh sa poiss'), Span('raba', [{'lemma': 'raba'}])),
#  (Text(text='PIPI: kosele ?'), Span('kosele', [{'lemma': 'kosk'}])),
#  (Text(text='andu: nõmme ?'), Span('nõmme', [{'lemma': 'nõmm'}])),
#  (Text(text='Teele: No limit Solder .... lahe nimi sull ...'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='kalla: lahe un soe ja saab reisida ja mererannas päevitaada'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text="'s: lahe"), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='manner14: ärgake üles'), Span('manner', [{'lemma': 'manner'}])),
#  (Text(text='QbaAff: randu läx ära'), Span('randu', [{'lemma': 'rand'}])),
#  (Text(text='hannes14: lahe'), Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='cookie_weica_segi: a waips ajab ema mu kohe arsti juurde ommiql ( mingi ullem jura mu lsuus lahti ) aj bljaaa'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='M6nus-Asi: kohe laäheb lahti Saku Hele 5.2'),
#   Span('lahti', [{'lemma': 'laht'}])),
#  (Text(text='raba: ic'), Span('raba', [{'lemma': 'raba'}])),
#  (Text(text='raba: voi miss'), Span('raba', [{'lemma': 'raba'}])),
#  (Text(text='Silent_Trigger: Kuco : mis soost yle 18 aastased punapead ?'),
#   Span('soost', [{'lemma': 'soo'}])),
#  (Text(text='kadi: tulge suveks kõik põltsu siin on lahe ........'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='+[negro: jumala lahe on kui klassi6de n2o t2is s6imab ja ei tea p6hjust'),
#   Span('lahe', [{'lemma': 'laht'}])),
#  (Text(text='raba: oled kindel'), Span('raba', [{'lemma': 'raba'}]))]

# %% [markdown]
# ### Saving samples

# %%
import pickle

with open("1000_ulejaanud.pickle",'wb') as f:
    pickle.dump(samples,f)

# %%
from copy import copy

for text, sample_span in samples:
    for span in copy(text.v172_geo_terms.spans):
        if span != sample_span:
            text.v172_geo_terms.remove_span(span)

# %% [markdown]
# ### Getting sentences to labelstudio format

# %%
from estnltk.converters.label_studio.label_studio import LabelStudioExporter

# %%
exporter = LabelStudioExporter("koond_1000_ulejaanud.json",'v172_geo_terms',checkbox=True)

# %%
print(exporter.labeling_interface)
# Out:
#         <View>
#             <Labels name="label" toName="text">
# 	<Label value="v172_geo_terms" background="#F888F5"/>
#
#             </Labels>
#         <Text name="text" value="$text"/>
#             <Header value="Are the annotations correct?"/>
#                 <Choices name="review" toName="text">
#                     <Choice value="yes"/>
#                     <Choice value="no"/>
#                 </Choices>
#             </View>

# %%
only_texts = [sample[0] for sample in samples]

# %%
exporter.convert(only_texts,append=False)

# %% [markdown]
# ### Working with files from labelstudio

# %%
import json

with open('project-13-at-2023-01-17-03-17-09a04ed6.json','r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
recall_set = []

for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        recall_set.append(txt['data']['text'])

# %%
recall_set
# Out:
# ['Kutsume kõiki huvilisi 17. mail kell 11 Hurmi järve äärde külavisiooni talgutele !',
#  '14. dets. 1936. a. Peipsi järvelt 7 kalurit...milline relvastus meie piirivalvuritel , kas on kordonites kuulipildujaid , kuidas on ülemuste nimed ja aukraadid .',
#  'Ta teenis Aegna saarel ning mängis sõjaväe orkestris .',
#  '“ Ja just siia Lagedile , Pirita jõe ja Leivajõe vahelisele saarele . ”',
#  'Opa , Ilsnä , Ipiku , Mäemõisa , Karkla , Kirbla , Koiva , Koivaliina , Kuivaste , Kuramaa , Kööna , Alamõisa , Vana-Liivimaa , Lemsalu , Loodi , Lutsi , Luke , Väike-Salatsi , Nausküla , Pedeli jõgi , Pedetsi jõgi , Reikküla järv , Räisaku , Ruhja jõgi , Salatsi , Salatsi jõgi , Uue-Salatsi , Säde jõgi , Sältnä , Talli , Tiikre , Tõrsa jõgi , Vaidva jõgi , Läti Valga , Vana-Laitsna e Laitsna , Vastse-Laitsna , Vana-Salatsi , Võnnu , Läti Liivimaa',
#  'Veel nimetas 20% vastanutest viimase aasta kurvastava asjaoluna Viljandi järve ja ranna kehva seisukorda .',
#  'Kuid paat , millele nad trügisid , pommitati puruks , ja nii leidis vanaema viimase puhkepaiga Balti mere põhjas .',
#  '1990. aastal Pärnu jõe suudme lähedalt leitud keskaegse laeva säilmete rohkem kui viis aastat kestnud konserveerimine on lõpule jõudnud ja leid pannakse vaatamiseks välja Pärnu muuseumis .',
#  'Filmitud on Sosva , Ljapini ja Konda jõe ääres .',
#  'Võru Kalevi spordijuhi Mati Ojandu sõnul on jooksul aastatega kujunenud oma raudvara , kes on Tamula järve jooksul kohal igal kevadel .',
#  'Uudisteagentuur AP nimetas Fort Dixit kaasaegseks Ellise saareks , meenutades omaaegset miljonite immigrantide saabumiskohta New Yorgi sadamas .',
#  'Narva jõel , kahel pool Eesti-Vene piiri elavad eakad põlisvenelased saavad ühelt kaldalt teisele häält pingutades surmateateid hõikuda , kuid mitte teineteisele kätt ulatada .',
#  'Eesti Vabariigis saadeti riigikukutajad Kihnu saarele , sest sealsed kõrvad olid kihutuskõnedele kurdid .',
#  'raport dramaatilisest kalastusretkest Valge mere äärde',
#  'Ja muidugi tuleb mainida ka Bali saart .',
#  'Harrastuskalamehed koguvad allkirju pöördumisele , milles paluvad linnavalitsusel Viljandi järvel võrgupüügi keelata .',
#  'Koos oma väikese tütre Wilmaga (  Ebba Hultqvist  ) asub Johan uut elu sisse seadma Stockholmi arhipelaagis paikneval Saltö saarel , et võtta seal üle oma äia klientuur .',
#  'Marssal Jegorovi 1936. aastal antud korralduse kohaselt tuli Balti mere laevastikul olla valmis Soome , Eesti ja Läti laevastike hävitamiseks .',
#  'Viimase aja arengud Lõuna-Hiina meres on vaid tõestanud probleemi tundlikkust ning olnud järjekordseks tunnistuseks Hiina agressiivsest välispoliitikast , pole aga pakkunud kriisile mingit lahendust .',
#  'Siit ka alguses vihjatud paralleelid admiral Cheng Hoga , kelle “ riigivisiidid ” India ookeanile viisid lõpuks koguni Punasele merele ning Ida-Aafrika rannikul asuvale Sansibarile .',
#  'Taifuun Okinawa saare lähedal segas ligi 30 000 reisijat , Jaapanis tühistati üle kahesaja siselennu .',
#  'Mõte on selles , et pakkuda alternatiiv Võru Tamula järve kontsertidele .',
#  'Elva jõe ja järvede ning Kavilda jõe seisundit on jälginud ja uurinud Zooloogia ja Botaanika Instituudi töötajad .',
#  'Seišelli saared on tõeline looduseime tänu sealse graniidisaarte grupi ainulaadsusele .',
#  'Koo mõtles Kommodoori saartest .',
#  'Võidab EM-ralli Assoori saartel .',
#  'Leib ju teadis , et Eidelkind senior pidi saama peatselt seitsmekümne seitsmeseks — iga , mil Kõigevägevam pühakirja järgi meid juba enda juurde ootavat — , kuid vanahärra Joshua särasilmist kiirgus veel küllaga erilist lummavat vaimujõudu ; kui tarvis , võiks ta juba homme — nagu tema nimekaim , Moosese järelkäija — oma valitud rahva läbi Jordani jõe viia , pillutada laiali viie vaenulise kuninga väed ja Jeeriku linna maatasa teha.',
#  'Paraku jookseb halastamatus Külvetil liiva : mahedasse jutuvestja tooni , pikkadesse aruteludesse ning “ kunstilisse ” lõpplahendusse , mis tavaliselt saabub mingi kulissidetaguse detaili läbi ( punane buss : “ Kuhu kuulud , Kristjan ? ” ; tolmunud frakk : “ Hommikust kirjakandja tulekuni ” ; urineeriv hiinlane : “ Sellist inimest ei ole ” ; loteriipilet : “ Märgutuli eksinud lindudele ” ; Deelose saar : “ Epidauruse vastus ” ; sombreero : “ Müüriladuja ” ; santsukott : “ Gulliveri käekõrval ” ; saatmata jäänud postkaart : “ Merehaigus ” ) .',
#  'Võib öelda , et uus ajastu maalähedaste objektide otsinguis algas 1995. aasta detsembris , kui läks käiku NASA kordineeritav kaamera NEAT ( Near-Earth Asteroid Tracking system ) , mis töötab USA õhujõudude teleskoobi taga Havai saartel Halcakala kustunud vulkaani tipul .',
#  'Kuid mind küll ei huvita , kas kirjanduslik Kohatu saar kõigis üksikasjades ikka kattub oma protomaastiku , Ruhnu saarega , kas ajalooliselt asus teatud hetkel peale Erik Norrmanni saarel juhuslikult kusagil veel keegi või oli ta üksinda jne.',
#  'Imekauni Daugava jõe kaldal tundub , et sotsialistlik suurtootmine lõppes alles täna .',
#  'Kui sakslased Teises maailmasõjas Taani vallutasid , hõivasid inglased Fääri saared .',
#  'Püsivama asulakohana tuntakse Eestis 1960-ndate lõpul avastatud Pulli asulat Pärnu jõe alamjooksul Sindi kohal .']

# %%
len(recall_set)
# Out:
# 353

# %%
import json

with open('project-14-at-2023-01-18-00-44-d22f56f0.json','r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
recall_set_2 = []

for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        recall_set_2.append(txt['data']['text'])

# %%
len(recall_set_2)
# Out:
# 13

# %%
import json

with open('project-15-at-2023-01-18-03-25-2438b42b.json','r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
recall_set_3 = []

for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        recall_set_3.append(txt['data']['text'])

# %%
len(recall_set_3)
# Out:
# 177

# %%
recall_set = []

for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        recall_set.append(txt['annotations'][0]['prediction']['result'][0]['value']['idx'])

# %%
true_sents = []
for i in range(len(only_texts)):
    if i in recall_set:
        true_sents.append(only_texts[i])

# %%
true_sents
# Out:
# [Text(text='Reisipakette on lisatud Hispaania mandriossa , Prantsusmaale ja Inglismaale , kuid ligi 5% võrra kahandatud Kanaari saartele .'),
#  Text(text='Kaks korda nädalas lendav kahemootoriline lennuk AN-28 on praegu ainus Ruhnu saarega regulaarset ühendust pidav transpordivahend .'),
#  Text(text='Nelja lõunapoolse Kuriili saare kuuluvuse küsimuse lahendamiseks jääb seega aega vaid kaks aastat .'),
#  Text(text='Vilsandi saar ei ole mitte ainult lindude , vaid ka kirjanike arvult ühe elaniku kohta kõige rikkam paik Eestimaal .'),
#  Text(text='Fääri saartel käinutel on raske testida sündmusi kronoloogilises järjekorras , sest Eesti delegatsiooni kuulunud isikud tegelesid selle nädala jooksul erinevate asjadega : poliitikud ja ajakirjanikud kohtusid poliitikute ja ajakirjanikega , muusikud ja kunstnikud kohtusid nii ametivendade kui laiema publikuga , nukuteatri trupp (  Helle Laas  ,  Riho Tammert  ,  Are Uder  ,  Leenamari Pirn  ) kohtus väikeste fäärlastega , andes neile kokku 8 menukat “ Pöial-Liisi ” etendust .'),
#  Text(text='Reis Kariibi mere saartele oleks vist kosutavam .'),
#  Text(text='Jätkuvalt sõidetakse Lõuna-Hispaaniasse , Kanaari saartele , Taisse , Dubaisse , Põhja-Aafrikasse ja Vahemere saartele .'),
#  Text(text='Egeuse meri , Küklaadide lõunaosa ; Ateenasse on 127 ja Kreeta saarele 70 meremiili .'),
#  Text(text='Peale selle ei välista ühendus Kanaari saartelt pärinevate kalasaaduste tariifikvootide arengut , mis on seotud Kanaari saarte kohaliku kalalaevastiku tõdetud arenguga .'),
#  Text(text="“ Norra Antarktise alad ( Bouvet' saar , Peeter I saar ja Kuninganna Maudi maa ) ”"),
#  Text(text='« Vetikakogumeid on märgata kogu Tallinna lahe ulatuses Aegna ja Naissaare vahelisel merealal ning Aegna saare ja Viimsi poolsaare rannikumeres , » kinnitab mereinstituudi osakonnajuhataja Georg Martin .'),
#  Text(text='Eesti meri sobib massaažiks väga hästi , kohati isegi paremini kui Kanaari saarte või Costa del Soli vesi , kus laine võib masseritava veest lihtsalt välja visata , räägib Lõhmus .'),
#  Text(text='Eriti hull on olukord Voxnani , Ljusnani , Ljungani ja Indalsälveni jõgede ääres .'),
#  Text(text='Sõudmise viiekordne olümpiavõitja britt Steven Redgrave ( keskel ) juhtis Sydneys kulla toonud neljapaati kilomeetri jagu mööda Thames jõge , kuni jõudis Henley Jõe- ja Sõudemuuseumini .'),
#  Text(text='Osa Berni vanalinnast on vee all ja ilma elektrita , kuna Aare jõgi tõusis üle kallaste .'),
#  Text(text='Läbisaamine Põhja-Kabulis ( Kabuli jõgi jaotab linna kaheks ) elavate dari keelt kõnelevate pärslastega on halb ning omavahelist läbikäimist eriti ei olegi .'),
#  Text(text='Vähemalt nii arvavad need Pedja jõe kallaste asukad , kelle heinamaad väikese hüdroelektrijaama paisu ehitamise tagajärjel üle ujutati .'),
#  Text(text='Kinnisvaraarendusfirma TSM tellimusel koostatud eskiisi järgi jaotatakse Pirita jõe saared paarikümneks krundiks , kuhu kerkivad ühepereelamud .'),
#  Text(text='Et siin peavad olema mängus Eestimaa transiitasend ning varsti kolmesaja-aastane Piiter Neeva jõe suudmes , peaks olema igale vaatlejale enam kui selge .'),
#  Text(text='14 . aprill 1999 – ähvardasid Põlva maakonnas Võhandu jõe ääres relvaga Põlvamaa metsainspektorit'),
#  Text(text='1989 september ,  " Eesti Ekspress " : " Tiiu Silvesel on Altai krai täitevkomitee luba viie Siberi jõe puhastamiseks ujuvpuidust .'),
#  Text(text='Pärnumaal Paikuse vallas Reiu jõe vana silla juures 7 . –11 .'),
#  Text(text='Ungern-Sternbergid peavad oma esiisaks ja suguvõsa rajajaks Attilat ( surnud aastal 453 ) , hunnide hõimupealikut , kes vallutas ja laastas hiigelterritooriumi Volga jõest ja Kaukaasiast kuni Reini jõeni ja Taanini .'),
#  Text(text='Ülejäänu tuleb juhuotstest , lasteaialeiba teenivalt elukaaslaselt Marjult ning õunapuude taga voolavast Ahja jõest .'),
#  Text(text='Tema hukkumispaigana nimetab müüt Eridanose jõge .'),
#  Text(text='Lisaks sellele olevat üks vene allveelaev fikseerinud avariipäeval Barentsi meres veel ühe plahvatuse .'),
#  Text(text='Filipiinide valitsuse teatel nõuab Abu Sayyaf pantvangide vahetusena omale autonoomsust ja võõrastele kalastuskeeldu Sulu merel .'),
#  Text(text='Sellel suvel teeb " Legare " operatsioone Balti meres ja Vahemeres , kus ta osaleb programmis " Partnerlus rahu nimel " ning NATO õppustel Baltops 97 .'),
#  Text(text='ICES II a statistiline alapiirkond ( üldtuntud kui Norra meri )'),
#  Text(text='võttes arvesse nõukogu 19. juuli 1993. aasta määrust ( EMÜ ) nr 2019/93 väiksemate Egeuse mere saarte heaks teatavate põllumajandussaaduste suhtes kohaldatavate erimeetmete kohta ,  1  eriti selle artikli 7 lõiget 5 ,'),
#  Text(text='Tehismärgala kasutamise eesmärk on vähendada kahjulike bakterite hulka Ülemiste järve jõudvas toorvees ning lokaliseerida võimalik avariiline reostus .'),
#  Text(text='Holdre piirivalvekordoni kaks piirivalvurit märkasid eile , 4. septembril , kella nelja paiku riigipiiri läheduses asuva Alatsi järve ääres kahte kalastajat ning otsustasid neid kontrollida .'),
#  Text(text='Peipsi järvel Vasknarva lähedal Narva jõe suudmes vajusid neljapäeval läbi jää kaks mootorsaani koos kolme kaluriga , kes suutsid siiski oma jõududega kaldale sumbata .'),
#  Text(text='Seega on mõistetav tema mure ka Tamula järve kalade tervise pärast .'),
#  Text(text='Otepää lähedal Nüpli järve ääres asub Gustav Wulff-Õie majamuuseum .'),
#  Text(text='Viimasel ajal on uuritud ja kasutatud Ermistu järve muda .'),
#  Text(text='Clooney elab suurema osa aastast selles väikeasulas Como järve ääres ning filmis seal tänavu suvel oma luksusvilla ümbruses , osa järve suleti , külakese tänavad olid näitleja austajatest üle ujutatud .'),
#  Text(text='Tõrvas ... vanamõisa järv ... võimas hüppetorn 10 meetrit ... soojem vesi eestis')]

# %%
from estnltk.taggers import NerTagger
ner = NerTagger()
for snt in true_sents:
    snt.tag_layer()
    ner.tag(snt)

# %%
exporter = LabelStudioExporter("koond_100_true.json",'ner',checkbox=True)

# %%
exporter.convert(true_sents,append=False)

# %%
print(exporter.labeling_interface)
# Out:
#         <View>
#             <Labels name="label" toName="text">
# 	<Label value="ner" background="#5A37B7"/>
#
#             </Labels>
#         <Text name="text" value="$text"/>
#             <Header value="Are the annotations correct?"/>
#                 <Choices name="review" toName="text">
#                     <Choice value="yes"/>
#                     <Choice value="no"/>
#                 </Choices>
#             </View>

# %%
import json

with open('project-12-at-2023-01-11-04-09-b44513d6.json','r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
correct = 0
for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        correct += 1

# %%
correct/len(data)
# Out:
# 0.7105263157894737
