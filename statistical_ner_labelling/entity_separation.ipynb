# %% [markdown]
# ## Entity separation

# %% [markdown]
# This notebook takes the CSV file from the previous step and separates the data into three
# CSV-s: one for singletons (entities with just one word), one for the first words
# (all but the last word of multiword entities) and one for the last words (last
# word of multiword entities)

# %%
import pandas as pd
ner_counts = pd.read_csv('ner_counts.csv')

# %%
ner_counts
# Out:
#       Unnamed: 0                            entity label  count
# 0              0                  ('Ühendriigid',)   LOC      1
# 1              1                     ('Leedusse',)   LOC      1
# 2              2   ('Leedu', 'välisministeeriumi')   ORG      1
# 3              3                  ('Interfaxile',)   ORG      1
# 4              4               ('Bill', 'Clinton')   PER      2
# ...          ...                               ...   ...    ...
# 4126        4126      ('Külli', 'Hansen', 'Sebra')   PER      1
# 4127        4127                        ('Fancy',)   LOC      1
# 4128        4128             ('Fun', '&', 'Fancy')   ORG      4
# 4129        4129  ('Hinnad', 'Sebra', 'galeriist')   ORG      1
# 4130        4130            ('Krista', 'Kivisalu')   PER      1
#
# [4131 rows x 4 columns]

# %% [markdown]
# Separate the entites to three

# %%
singletons_map = {}
last_word_map = {}
first_words_map = {}

import ast 

for row in ner_counts.itertuples():
    entity = ast.literal_eval(row.entity)
    if len(entity) == 1:
        curr_map = singletons_map.get(entity,{})
        curr_count = curr_map.get(row.label,0) 
        curr_map[row.label] = row.count + curr_count
        singletons_map[entity] = curr_map
    else:
        last_word = entity[-1]
        curr_map = last_word_map.get(last_word,{})
        curr_count = curr_map.get(row.label,0) 
        curr_map[row.label] = curr_count + row.count
        last_word_map[last_word] = curr_map
        
        first_words = entity[:-1]
        curr_map = first_words_map.get(first_words,{})
        curr_count = curr_map.get(row.label,0) 
        curr_map[row.label] = row.count + curr_count
        first_words_map[first_words] = curr_map

# %%
singletons_map
# Out:
# {('Ühendriigid',): {'LOC': 1},
#  ('Leedusse',): {'LOC': 1},
#  ('Interfaxile',): {'ORG': 1},
#  ('Leedu',): {'LOC': 49},
#  ('Leedus',): {'LOC': 19},
#  ('USA',): {'LOC': 53},
#  ('Lääne-Euroopa',): {'LOC': 1},
#  ('Jaapanil',): {'LOC': 1},
#  ('Kanadal',): {'LOC': 1},
#  ('Austraalial',): {'LOC': 1},
#  ('Uus-Meremaal',): {'LOC': 1},
#  ('Ungaril',): {'LOC': 1},
#  ('Poolal',): {'LOC': 1},
#  ('Tšehhil',): {'LOC': 1},
#  ('OPEC',): {'ORG': 2},
#  ('Londonis',): {'LOC': 4},
#  ('Riyadh',): {'PER': 1},
#  ('Viinis',): {'LOC': 1},
#  ('Ühispanga',): {'ORG': 9},
#  ('Norma',): {'ORG': 8},
#  ('Tallinna',): {'LOC': 67},
#  ('Mõis',): {'PER': 6},
#  ('BNS-ile',): {'ORG': 14},
#  ('Mõisa',): {'PER': 6},
#  ('Voog',): {'PER': 2},
#  ('Eesti',): {'LOC': 189},
#  ('Soome',): {'LOC': 38},
#  ('Kauppalehti',): {'ORG': 1},
#  ('Soomet',): {'LOC': 2},
#  ('Venemaa',): {'LOC': 42},
#  ('Aiwa',): {'ORG': 1},
#  ('Electrolux',): {'LOC': 1},
#  ('Peterburgi',): {'LOC': 1},
#  ('Moskvasse',): {'LOC': 4},
#  ('EL',): {'ORG': 9},
#  ('Vene',): {'LOC': 39},
#  ('Soomes',): {'LOC': 14},
#  ('Euroopa',): {'LOC': 30},
#  ('Venemaale',): {'LOC': 4},
#  ('Siberi',): {'LOC': 1},
#  ('Kaug-Idast',): {'LOC': 1},
#  ('Lätis',): {'LOC': 17},
#  ('ETAle',): {'ORG': 9},
#  ('LHV',): {'ORG': 1},
#  ('EMT',): {'ORG': 7},
#  ('Lätti',): {'LOC': 2},
#  ('Leetu',): {'LOC': 2},
#  ('Radiolinja',): {'ORG': 6, 'LOC': 1},
#  ('Eestis',): {'LOC': 98},
#  ('Ross',): {'PER': 2},
#  ('Baltimaades',): {'LOC': 1},
#  ('SRÜ',): {'ORG': 3},
#  ('Euroopas',): {'LOC': 17},
#  ('Austria',): {'LOC': 5},
#  ('Schelling',): {'ORG': 1},
#  ('Põhjarannikule',): {'PER': 1},
#  ('Skandinaavia',): {'LOC': 5},
#  ('AS',): {'ORG': 2},
#  ('Repo',): {'PER': 2},
#  ('EVK',): {'ORG': 1},
#  ('Suurväli',): {'PER': 5},
#  ('IOSCO',): {'PER': 1},
#  ('Balti',): {'LOC': 7},
#  ('Skandinaaviaga',): {'LOC': 1},
#  ('Rootis',): {'LOC': 1},
#  ('Lõuna-Eesti',): {'LOC': 2},
#  ('Kolbakov',): {'PER': 5},
#  ('Meosele',): {'PER': 1},
#  ('Kolbakovi',): {'PER': 2},
#  ('Krassulenkole',): {'PER': 1},
#  ('Krassulenko',): {'PER': 2},
#  ('Mõttust',): {'PER': 1},
#  ('ASi',): {'ORG': 1},
#  ('Kolbakovilt',): {'PER': 1},
#  ('Kolbakovil',): {'PER': 1},
#  ('Jõgevamaal',): {'LOC': 1},
#  ('Läti',): {'LOC': 22},
#  ('LASCO',): {'ORG': 2, 'LOC': 1, 'PER': 1},
#  ('BNS-le',): {'ORG': 2},
#  ('Grinblats',): {'PER': 3},
#  ('Tavidi',): {'ORG': 2},
#  ('Hiina',): {'LOC': 7},
#  ('Egiptuse',): {'LOC': 6},
#  ('LAV-i',): {'ORG': 1},
#  ('Mehhiko',): {'LOC': 3},
#  ('Tavid',): {'PER': 1},
#  ('Kürpose',): {'LOC': 1},
#  ('Kreeka',): {'LOC': 1},
#  ('Tai',): {'LOC': 2},
#  ('SKP',): {'ORG': 4},
#  ('SKPs',): {'LOC': 1},
#  ('Eurospordi',): {'ORG': 6},
#  ('Ida-Euroopa',): {'LOC': 2},
#  ('Berdal',): {'PER': 4},
#  ('Starmani',): {'ORG': 1},
#  ('Treude',): {'PER': 3},
#  ('Singer',): {'PER': 1},
#  ('Eurosport',): {'ORG': 1},
#  ('Berdali',): {'PER': 1},
#  ('Singeri',): {'PER': 2},
#  ('Saksamaa',): {'LOC': 12},
#  ('Frensi',): {'PER': 1, 'ORG': 1},
#  ('Frens',): {'PER': 1},
#  ('LISCO',): {'LOC': 1, 'ORG': 1, 'PER': 1},
#  ('Taani',): {'LOC': 6},
#  ('Paulauskas',): {'PER': 1},
#  ('Paulauskase',): {'PER': 1},
#  ('Kallaste',): {'PER': 1},
#  ('Tallinn-Tartu',): {'LOC': 4},
#  ('Taisto',): {'PER': 3},
#  ('Tallinnast',): {'LOC': 9},
#  ('Tartu',): {'LOC': 31},
#  ('Sebe',): {'ORG': 4},
#  ('Pärnu',): {'LOC': 20},
#  ('Kuressaarde',): {'LOC': 1},
#  ('LAL',): {'ORG': 2},
#  ('LAL-i',): {'ORG': 1},
#  ('LNNK',): {'ORG': 1},
#  ('Eestisse',): {'LOC': 27},
#  ('Talibor',): {'ORG': 1},
#  ('Talibid',): {'ORG': 1},
#  ('Hansapank',): {'ORG': 8},
#  ('Ühispank',): {'ORG': 2},
#  ('Valgevene',): {'LOC': 7},
#  ('Kristopaitis',): {'LOC': 1},
#  ('Belgia',): {'LOC': 3},
#  ('Belgias',): {'LOC': 1},
#  ('tervishoiuministeeriumi',): {'ORG': 1},
#  ('Reuters',): {'ORG': 4},
#  ('Prantsusmaa',): {'LOC': 7},
#  ('Põhja-Taanis',): {'LOC': 1},
#  ('Jüütimaal',): {'LOC': 1},
#  ('Hollandis',): {'LOC': 7},
#  ('Repše',): {'PER': 8},
#  ('SKP-st',): {'ORG': 1},
#  ('EL-i',): {'ORG': 3},
#  ('KPMG',): {'ORG': 7},
#  ('Tallinna-Helsingi',): {'ORG': 1, 'LOC': 2},
#  ('Hunt',): {'PER': 3},
#  ('Tallinn-Helsingi',): {'LOC': 1},
#  ('Ahvenamaal',): {'LOC': 1},
#  ('Lietuvos',): {'ORG': 3},
#  ('Williams',): {'PER': 1},
#  ('Lionginase',): {'PER': 1},
#  ('Bumgarner',): {'PER': 1},
#  ('Sampo',): {'LOC': 2, 'PER': 1},
#  ('Seesam',): {'ORG': 1},
#  ('Salva',): {'ORG': 1},
#  ('Hansapanga',): {'ORG': 9},
#  ('maksuamet',): {'ORG': 2},
#  ('Järve',): {'PER': 3},
#  ('Ruusalu',): {'PER': 1},
#  ('Rimess',): {'ORG': 1},
#  ('Maksuamet',): {'ORG': 2},
#  ('TV1',): {'ORG': 3},
#  ('ELi',): {'ORG': 12},
#  ('Põhjala',): {'LOC': 3},
#  ('Rootsist',): {'LOC': 2},
#  ('Rootsi',): {'LOC': 48},
#  ('Stockholmi',): {'LOC': 3},
#  ('Põhjamaade',): {'LOC': 2},
#  ('Põhjamaades',): {'LOC': 2},
#  ('Norra',): {'LOC': 9},
#  ('Rootsis',): {'LOC': 9},
#  ('Norras',): {'LOC': 4},
#  ('Telia',): {'ORG': 5},
#  ('Netcomiga',): {'ORG': 1},
#  ('Teliale',): {'ORG': 1},
#  ('Teliaga',): {'ORG': 1},
#  ('Netcomi',): {'ORG': 2},
#  ('Põhjalas',): {'ORG': 1},
#  ('Telias',): {'ORG': 1},
#  ('Rosengren',): {'PER': 1},
#  ('Rootsit',): {'LOC': 1},
#  ('Taanis',): {'LOC': 1},
#  ('TeleDanmarki',): {'ORG': 2},
#  ('SBC',): {'ORG': 1},
#  ('Teliat',): {'ORG': 1},
#  ('TeleDanmark',): {'ORG': 2},
#  ('Taanit',): {'LOC': 1},
#  ('Põhjamaad',): {'LOC': 1},
#  ('Graversen',): {'PER': 1},
#  ('SBSi',): {'ORG': 1},
#  ('Jaaksoo',): {'PER': 1},
#  ('Helsingi',): {'LOC': 12},
#  ('Adidase',): {'ORG': 1, 'LOC': 1},
#  ('Aavik',): {'PER': 9},
#  ('Eestist',): {'LOC': 7},
#  ('Euroopast',): {'LOC': 1},
#  ('Pärnus',): {'LOC': 3},
#  ('Hollandisse',): {'LOC': 1},
#  ('Saksamaal',): {'LOC': 10},
#  ('Aaviku',): {'PER': 1},
#  ('Aavikut',): {'PER': 1},
#  ('Haapsalu',): {'LOC': 2},
#  ('Kuressaare',): {'LOC': 2},
#  ('Tallinn',): {'LOC': 15},
#  ('Tartust',): {'LOC': 2},
#  ('Haapsallu',): {'LOC': 1},
#  ('Haapsalus',): {'LOC': 2},
#  ('Läänemaal',): {'LOC': 3},
#  ('Paju',): {'PER': 5},
#  ('Läänemaa',): {'LOC': 2},
#  ('Jairus',): {'PER': 1},
#  ('Prantsuse',): {'LOC': 4},
#  ('Dalkia',): {'LOC': 1},
#  ('Valga',): {'LOC': 1, 'PER': 1},
#  ('Yahoo',): {'PER': 2},
#  ('JAAPAN',): {'LOC': 1},
#  ('Softbank',): {'ORG': 1},
#  ('Aozora',): {'ORG': 1},
#  ('Honma',): {'PER': 1},
#  ('Jaapani',): {'LOC': 11},
#  ('Robbie',): {'PER': 1},
#  ('Feldman',): {'PER': 1},
#  ('Tokios',): {'LOC': 1},
#  ('Jaapan',): {'LOC': 5},
#  ('RRK',): {'ORG': 2},
#  ('Nikkei',): {'PER': 1},
#  ('Softbanki',): {'ORG': 1},
#  ('Sogo',): {'PER': 2},
#  ('Jesper',): {'PER': 1},
#  ('Koll',): {'PER': 2},
#  ('Honshu',): {'LOC': 1},
#  ('Riiga',): {'LOC': 4},
#  ('Hansabanka',): {'ORG': 2},
#  ('Neivelt',): {'PER': 7},
#  ('Riias',): {'LOC': 4},
#  ('Vilniusesse',): {'LOC': 1},
#  ('Eestit',): {'LOC': 5},
#  ('Tallinnas',): {'LOC': 33},
#  ('Baltikumi',): {'LOC': 2},
#  ('Helsingis',): {'LOC': 5},
#  ('Stockholmis',): {'LOC': 1},
#  ('Kopenhaagenis',): {'LOC': 1},
#  ('Merita',): {'PER': 1, 'LOC': 1},
#  ('Nordbanken',): {'PER': 1},
#  ('Kristiana',): {'PER': 1},
#  ('Nordpanga',): {'ORG': 1},
#  ('Vilniusest',): {'LOC': 1},
#  ('Järvani',): {'LOC': 1},
#  ('Vaarik',): {'PER': 2},
#  ('Lõhmus',): {'PER': 4},
#  ('Järvan',): {'PER': 1},
#  ('Kukk',): {'LOC': 1, 'PER': 1},
#  ('Lõhmuse',): {'PER': 2},
#  ('Uudam',): {'PER': 1},
#  ('Liviko',): {'ORG': 10},
#  ('Kunila',): {'PER': 12},
#  ('Jüri',): {'PER': 30},
#  ('NG',): {'ORG': 1},
#  ('Normas',): {'ORG': 1},
#  ('Togliattis',): {'LOC': 1},
#  ('Käo',): {'PER': 1},
#  ('Avtovazist',): {'ORG': 1},
#  ('Visa',): {'PER': 1},
#  ('Normal',): {'ORG': 1},
#  ('Selverite',): {'ORG': 1},
#  ('Livikosse',): {'ORG': 1},
#  ('Onistari',): {'PER': 1},
#  ('Onistar',): {'PER': 1},
#  ('Balbiino',): {'ORG': 1},
#  ('Kitman',): {'ORG': 1},
#  ('Türi',): {'LOC': 4},
#  ('Microsoft',): {'PER': 2, 'ORG': 2},
#  ('Microsofti',): {'ORG': 4},
#  ('Microsoftiga',): {'ORG': 1},
#  ('Suurbritannias',): {'LOC': 7},
#  ('Straw',): {'PER': 1},
#  ('Sky',): {'ORG': 1},
#  ('Brown',): {'PER': 1},
#  ('SEB',): {'ORG': 1},
#  ('Moskvas',): {'LOC': 9},
#  ('Media-Most',): {'ORG': 1},
#  ('Media-Mosti',): {'LOC': 2},
#  ('Gussinski',): {'PER': 7},
#  ('Gazprom-Media',): {'LOC': 2},
#  ('Gussinskit',): {'PER': 1},
#  ('Gazpromilt',): {'LOC': 1},
#  ('Hispaanias',): {'LOC': 2},
#  ('Soto',): {'PER': 1},
#  ('Reali',): {'PER': 1},
#  ('Hispaania',): {'LOC': 5},
#  ('Iisraeli',): {'LOC': 18},
#  ('NTV',): {'ORG': 14},
#  ('Gazpromi',): {'PER': 1},
#  ('NTV-s',): {'ORG': 1},
#  ('Media',): {'LOC': 2},
#  ('Turner',): {'PER': 5},
#  ('Gazprom',): {'PER': 1, 'ORG': 1},
#  ('Venemaalt',): {'LOC': 8},
#  ('Venta',): {'LOC': 4},
#  ('Keskpank',): {'ORG': 1},
#  ('Vabaduse',): {'ORG': 4},
#  ('Viljandimaalt',): {'LOC': 1},
#  ('Toome',): {'LOC': 1},
#  ('Viljandis',): {'LOC': 3},
#  ('Raekojas',): {'PER': 1},
#  ('Suurbritannia',): {'LOC': 4},
#  ('Itaalia',): {'LOC': 14},
#  ('Briti',): {'LOC': 9},
#  ('Maaleht',): {'ORG': 3},
#  ('Pächter',): {'PER': 2},
#  ('Võru-',): {'LOC': 1},
#  ('Põlvamaa',): {'LOC': 1},
#  ('Kiiu',): {'LOC': 1},
#  ('USA-st',): {'LOC': 2},
#  ('Kanadast',): {'LOC': 3},
#  ('Uus-Meremaalt',): {'LOC': 1},
#  ('Riia',): {'LOC': 6},
#  ('Stabu',): {'ORG': 1},
#  ('Reformierakond',): {'ORG': 13},
#  ('Reformierakonna',): {'ORG': 6},
#  ('ETV',): {'ORG': 3},
#  ('Sideministeeriumi',): {'ORG': 1},
#  ('Maksuameti',): {'ORG': 1},
#  ('Äripäev',): {'ORG': 2},
#  ('Visnapuu',): {'PER': 1},
#  ('Maksimarket',): {'PER': 1},
#  ('Selver',): {'ORG': 1},
#  ('Hansakeskus',): {'ORG': 1},
#  ('Tartus',): {'LOC': 9},
#  ('Sauk',): {'PER': 2},
#  ('Selveri',): {'LOC': 1},
#  ('Estikole',): {'ORG': 1},
#  ('Tallinna-Tartu-Luhamaa',): {'LOC': 2},
#  ('Maailmapanga',): {'ORG': 3},
#  ('Postimees',): {'ORG': 5},
#  ('Kose',): {'LOC': 2},
#  ('Vaida',): {'LOC': 1},
#  ('Aruvalla',): {'LOC': 2},
#  ('Maailmapank',): {'ORG': 1},
#  ('Vaida-Aruvalla',): {'LOC': 2},
#  ('Maanteeameti',): {'ORG': 1},
#  ('Mäoni',): {'LOC': 2},
#  ('Koselt',): {'LOC': 2},
#  ('Mäo',): {'LOC': 1},
#  ('Sõrmus',): {'PER': 1},
#  ('Eestil',): {'LOC': 7},
#  ('Taistot',): {'PER': 1},
#  ('maksuameti',): {'ORG': 1},
#  ('Tänav',): {'PER': 2},
#  ('maksuametile',): {'ORG': 1},
#  ('Taistoga',): {'PER': 1},
#  ('Tallinna-Tartu',): {'LOC': 3},
#  ('Tallinna-Narva',): {'LOC': 2},
#  ('Tallinna-Narva-Jõesuu',): {'LOC': 1},
#  ('Väike-Õismäe',): {'PER': 1, 'LOC': 1},
#  ('Kadaka',): {'PER': 1, 'ORG': 3},
#  ('SL',): {'ORG': 2},
#  ('Reigo',): {'PER': 1},
#  ('Vivendi',): {'LOC': 1},
#  ('Keskerakonna',): {'ORG': 10},
#  ('Väli',): {'PER': 8},
#  ('Ühispangaga',): {'ORG': 1},
#  ('Välil',): {'PER': 1},
#  ('Väliga',): {'PER': 1},
#  ('Finlux',): {'PER': 1},
#  ('Harjumaal',): {'LOC': 3},
#  ('Saku',): {'LOC': 1},
#  ('Keskerakonnast',): {'ORG': 1},
#  ('Bns',): {'ORG': 16},
#  ('Ameerika',): {'LOC': 14},
#  ('Reap',): {'PER': 1},
#  ('Honda',): {'PER': 1, 'LOC': 1},
#  ('Jõgi',): {'PER': 1},
#  ('Aamer',): {'PER': 1},
#  ('Frankfurti',): {'LOC': 1},
#  ('Hamburgi',): {'LOC': 2},
#  ('Kiievisse',): {'LOC': 1},
#  ('Kopenhaagenisse',): {'LOC': 1},
#  ('Londonisse',): {'LOC': 1},
#  ('Vilniusse',): {'LOC': 1},
#  ('Epl',): {'PER': 15},
#  ('Sideamet',): {'ORG': 1},
#  ('Unineti',): {'ORG': 1},
#  ('Naviplastil',): {'LOC': 1},
#  ('Muuga',): {'ORG': 2, 'LOC': 1},
#  ('Ruma',): {'PER': 1, 'LOC': 1},
#  ('Vaivaras',): {'LOC': 1},
#  ('Reporter',): {'PER': 1},
#  ('Ameerikas',): {'LOC': 4},
#  ('Kanadas',): {'LOC': 3},
#  ('Rakvere',): {'LOC': 20, 'ORG': 1},
#  ('Lääne-Viru',): {'LOC': 1},
#  ('Kivi',): {'PER': 8},
#  ('Palmse',): {'LOC': 11},
#  ('Palmsest',): {'LOC': 2},
#  ('Pomerants',): {'PER': 1},
#  ('Pomerantsi',): {'PER': 1},
#  ('Palmsesse',): {'LOC': 1},
#  ('Kaitseliit',): {'ORG': 1},
#  ('Estonia',): {'ORG': 6},
#  ('Palmses',): {'LOC': 1},
#  ('Joala',): {'PER': 10},
#  ('Valgre',): {'LOC': 1},
#  ("Roxette'i",): {'PER': 1, 'LOC': 1},
#  ('INGLISE',): {'LOC': 1},
#  ('Viilup',): {'PER': 1},
#  ('Ühendriikides',): {'LOC': 2},
#  ('Ühendriikide',): {'LOC': 1},
#  ('Tshehhoslovakkiast',): {'LOC': 1},
#  ('Andrej',): {'PER': 1},
#  ('Pittsburghis',): {'LOC': 2},
#  ('Andrew',): {'PER': 1},
#  ('Carnegie',): {'PER': 2},
#  ('Andy',): {'PER': 23},
#  ('USAs',): {'LOC': 11},
#  ('Warhol',): {'PER': 5},
#  ('Hacketti',): {'PER': 1},
#  ('Andyt',): {'PER': 1},
#  ('TV',): {'ORG': 2},
#  ('Warholi',): {'PER': 7},
#  ('Rothko',): {'ORG': 1},
#  ('Newmani',): {'ORG': 1},
#  ('Pollocki',): {'PER': 1},
#  ('Jackson',): {'PER': 5},
#  ('Mao',): {'PER': 1},
#  ('Päevikud',): {'PER': 2},
#  ('Michelangelo',): {'PER': 2},
#  ('Firenzest',): {'LOC': 1},
#  ('Rooma',): {'LOC': 2},
#  ('Peetri',): {'PER': 1},
#  ('Põhhjas',): {'PER': 1, 'LOC': 1},
#  ('Scooter',): {'PER': 1},
#  ('Moskvitshi',): {'ORG': 1},
#  ('Zhpritsi',): {'PER': 1},
#  ('Gorkiga',): {'PER': 1},
#  ('Eestimaa',): {'LOC': 3},
#  ('Baltoscandal',): {'LOC': 1, 'PER': 1},
#  ('LINNATEATER',): {'PER': 1},
#  ('Linnateater',): {'PER': 1},
#  ('kultuuriministeerium',): {'ORG': 1},
#  ('FESTIVALI',): {'PER': 1},
#  ('Leedust',): {'LOC': 3},
#  ('Lätist',): {'LOC': 2},
#  ('Poolast',): {'LOC': 1},
#  ('Saksamaalt',): {'LOC': 3},
#  ('Ungarist',): {'LOC': 1},
#  ('Austriast',): {'LOC': 1},
#  ('Dostojevski',): {'PER': 2},
#  ('K',): {'ORG': 1},
#  ('ETTE',): {'PER': 1},
#  ('Mõsina',): {'PER': 2},
#  ('Bitolasse',): {'LOC': 1},
#  ('Trinitas',): {'ORG': 1},
#  ('Bitola',): {'LOC': 1},
#  ('Hollandi',): {'LOC': 7, 'ORG': 1},
#  ('Martensi',): {'PER': 1},
#  ('Langeveld',): {'PER': 1},
#  ('Kross',): {'ORG': 1},
#  ('Kuuba',): {'LOC': 1},
#  ('Havannas',): {'LOC': 1},
#  ('Lennoni',): {'PER': 1, 'ORG': 1},
#  ('CIA',): {'ORG': 1},
#  ('Kremli',): {'ORG': 3},
#  ('Jefimoviga',): {'PER': 1},
#  ('Areenis',): {'PER': 1},
#  ('Mustamäe',): {'ORG': 1},
#  ('NU',): {'ORG': 1},
#  ('Bristolis',): {'LOC': 1},
#  ('Inglismaa',): {'LOC': 5},
#  ("Duchamp'i",): {'PER': 1},
#  ('Soosalu',): {'LOC': 1},
#  ('Curiosities',): {'PER': 1},
#  ('Viljandi',): {'LOC': 5},
#  ('Kondase',): {'PER': 1},
#  ('Christie',): {'PER': 1},
#  ('Washingtoni',): {'PER': 6, 'ORG': 1},
#  ('Washingtonist',): {'PER': 1},
#  ('Dublinis',): {'LOC': 1},
#  ('Ramage',): {'PER': 1},
#  ('Kunstikriitik',): {'ORG': 1},
#  ('Saksa',): {'LOC': 11},
#  ('Robini',): {'PER': 1},
#  ('Evi',): {'PER': 1},
#  ('Magda',): {'PER': 1},
#  ('Fassbinderi',): {'PER': 1},
#  ("Reichskunst'is",): {'LOC': 1},
#  ('Schmitti',): {'PER': 1},
#  ('Väinmaa',): {'ORG': 1},
#  ('Beethoven',): {'ORG': 1},
#  ('Tulevi',): {'PER': 2},
#  ('SCHNITTKE',): {'PER': 1},
#  ('SELGED',): {'PER': 1},
#  ('Tulevit',): {'PER': 1},
#  ('Schnittket',): {'PER': 1},
#  ('Beethoveni',): {'ORG': 1},
#  ('Schnittke',): {'PER': 1},
#  ('Baltimaade',): {'LOC': 3},
#  ('Kremer',): {'PER': 1},
#  ('Prokofjevi',): {'LOC': 1},
#  ('Mahleri',): {'PER': 1},
#  ('Müncheni',): {'LOC': 1},
#  ('NHL',): {'ORG': 1},
#  ('Colorado',): {'LOC': 5, 'PER': 2},
#  ('Columbuse',): {'PER': 2},
#  ('Avalanchel',): {'PER': 1},
#  ('NHL-i',): {'ORG': 1},
#  ('Mogilnõilt',): {'PER': 1},
#  ('Mogilnõi',): {'PER': 3},
#  ('Turco',): {'PER': 2},
#  ('Starsil',): {'LOC': 1},
#  ('Capitlasi',): {'PER': 2},
#  ('Washingtonile',): {'LOC': 1},
#  ('Minnesota',): {'LOC': 2},
#  ('Tortorellale',): {'PER': 1},
#  ('Lightningi',): {'PER': 1},
#  ('Montrealis',): {'LOC': 1},
#  ('Canadiensi',): {'LOC': 1},
#  ('Montreal',): {'LOC': 1},
#  ('TORONTO',): {'ORG': 1},
#  ('Modin',): {'PER': 1},
#  ('Holzinger',): {'PER': 1},
#  ('Toronto',): {'LOC': 2},
#  ('Joseph',): {'PER': 1},
#  ('Cloutier',): {'PER': 1},
#  ('MONTREAL',): {'ORG': 1},
#  ('Samsonov',): {'PER': 1},
#  ('Boston',): {'LOC': 3},
#  ('PHOENIX',): {'ORG': 1},
#  ('Holik',): {'PER': 2},
#  ('Brõlin',): {'PER': 2},
#  ('Mogilny',): {'ORG': 1},
#  ('Phoenix',): {'PER': 1},
#  ('DALLAS',): {'ORG': 1},
#  ('Nieuwendyk',): {'PER': 1},
#  ('Ferraro',): {'PER': 1},
#  ('Audette',): {'PER': 1},
#  ('Forsberg',): {'PER': 1},
#  ('Deadmarsh',): {'PER': 1},
#  ('Drury',): {'PER': 1},
#  ('Sakic',): {'PER': 1},
#  ('Columbus',): {'PER': 1},
#  ('Denis',): {'PER': 1},
#  ('Roy',): {'PER': 1},
#  ('WASHINGTON',): {'ORG': 1},
#  ('Pellerin',): {'PER': 1},
#  ('Fernandez',): {'PER': 1},
#  ('Washington',): {'PER': 1},
#  ('Billington',): {'ORG': 1},
#  ('EDMONTON',): {'ORG': 1},
#  ('Arhipov',): {'PER': 1},
#  ('Valicevic',): {'PER': 1},
#  ('Edmonton',): {'LOC': 1},
#  ('Salo',): {'LOC': 1},
#  ('Nashville',): {'PER': 1},
#  ('Dunham',): {'PER': 1},
#  ('VANCOUVER',): {'ORG': 1},
#  ('Arvedson',): {'PER': 1},
#  ('McEachern',): {'ORG': 1},
#  ('Alfredsson',): {'PER': 2},
#  ('Yashin',): {'ORG': 1},
#  ('Rachunek',): {'PER': 1},
#  ('Ottawa',): {'PER': 1},
#  ('ANAHEIM',): {'LOC': 1},
#  ('LOUIS',): {'ORG': 1},
#  ('Salvador',): {'PER': 1},
#  ('Tverdovski',): {'PER': 1},
#  ('Nash',): {'PER': 2},
#  ('Anaheim',): {'LOC': 1},
#  ('Johnson',): {'PER': 1},
#  ('Karistusminutid',): {'ORG': 1},
#  ('Jason',): {'PER': 1},
#  ('Ray',): {'PER': 1},
#  ('Tshetsheenia',): {'LOC': 3},
#  ('Dagestani',): {'LOC': 2},
#  ('Shvets',): {'PER': 1},
#  ('Tohvri',): {'LOC': 1},
#  ('Pareiko',): {'PER': 3},
#  ('Tohver',): {'PER': 3},
#  ('Kazakov',): {'PER': 1},
#  ('Pohlak',): {'PER': 1},
#  ('Dagestanis',): {'LOC': 1},
#  ('Kazakovil',): {'PER': 1},
#  ('Lehiste',): {'PER': 1},
#  ('Põhja-Osseetiast',): {'LOC': 1},
#  ('Liverpooli',): {'ORG': 3},
#  ('Liverpool',): {'ORG': 2},
#  ('Inglismaal',): {'LOC': 6},
#  ('Litmanen',): {'PER': 1},
#  ('Rubins',): {'ORG': 1},
#  ('Morrison',): {'PER': 1},
#  ('Smicer',): {'PER': 1},
#  ('Mehhikoga',): {'LOC': 1},
#  ('Hollandiga',): {'LOC': 1},
#  ("Derby's",): {'ORG': 1},
#  ('Iirimaa',): {'LOC': 2},
#  ('Itaaliaga',): {'LOC': 1},
#  ('Kreekaga',): {'LOC': 1},
#  ('Saksamaaga',): {'LOC': 1},
#  ('NBA',): {'ORG': 2},
#  ('McKie',): {'PER': 2},
#  ('Miami',): {'LOC': 1},
#  ('Kingsil',): {'ORG': 1},
#  ('Clevelandi',): {'LOC': 1},
#  ('B',): {'ORG': 1},
#  ('Walker',): {'ORG': 1},
#  ('Potapenko',): {'PER': 1},
#  ('W',): {'ORG': 1},
#  ('Howard',): {'PER': 1},
#  ('Smith',): {'PER': 1},
#  ('S',): {'ORG': 2},
#  ('Payton',): {'ORG': 1},
#  ('Pattersson',): {'ORG': 1},
#  ('T',): {'ORG': 1},
#  ('Carter',): {'PER': 1},
#  ('Davis',): {'LOC': 1},
#  ('Willis',): {'ORG': 1},
#  ('M',): {'ORG': 1},
#  ('Ellis',): {'LOC': 1},
#  ('Finley',): {'LOC': 1},
#  ('Stoudamire',): {'PER': 1},
#  ('LA',): {'ORG': 1},
#  ('Olowokandi',): {'ORG': 1},
#  ('Webber',): {'PER': 1},
#  ('Stojakovic',): {'ORG': 1},
#  ('Pollard',): {'PER': 1},
#  ('C',): {'ORG': 7},
#  ('Miller',): {'PER': 1},
#  ('Soomest',): {'LOC': 3},
#  ('DTM-',): {'ORG': 1},
#  ('Jalgpalliliit',): {'ORG': 1},
#  ('IDA',): {'PER': 2},
#  ('PÕHI',): {'PER': 2},
#  ('Märjamaa',): {'LOC': 1},
#  ('FC',): {'ORG': 2, 'PER': 3},
#  ('Feeling',): {'PER': 1},
#  ('SK',): {'ORG': 1},
#  ('Lasnamäe',): {'LOC': 1},
#  ('Viimsi',): {'PER': 1},
#  ('Spartak',): {'PER': 1},
#  ('NJK',): {'ORG': 1},
#  ('Käbi',): {'PER': 1},
#  ('Georgia',): {'PER': 1},
#  ('JK',): {'ORG': 1},
#  ('Kõrvemaa',): {'PER': 1},
#  ('EJL-i',): {'ORG': 1},
#  ('Ruhpoldingis',): {'LOC': 1},
#  ('Tšehhi',): {'LOC': 2},
#  ('Tšehhimaa',): {'LOC': 1},
#  ('AEK-i',): {'ORG': 1},
#  ('Kutluay',): {'ORG': 1},
#  ('Hatzis',): {'PER': 1},
#  ('Hammink',): {'ORG': 1},
#  ('Horvaatia',): {'LOC': 2},
#  ('Lee',): {'PER': 1},
#  ('Hispaaniat',): {'LOC': 1},
#  ('Slovakkia',): {'LOC': 2},
#  ('Šveits',): {'LOC': 3},
#  ('BNS',): {'ORG': 4},
#  ('Niinepuul',): {'PER': 1},
#  ('Niinepuult',): {'PER': 1},
#  ('Niinepuu',): {'PER': 13},
#  ('Niinepuule',): {'PER': 2},
#  ('Halensi',): {'LOC': 2},
#  ('AIVAR',): {'PER': 1},
#  ('VADI',): {'PER': 1},
#  ('Firmabowling',): {'PER': 1},
#  ('Berliinis',): {'LOC': 4},
#  ('SFKL',): {'ORG': 1},
#  ('SFKL-is',): {'ORG': 1},
#  ('Nokia',): {'LOC': 5},
#  ('Finnair',): {'PER': 1},
#  ('Fazer',): {'PER': 1},
#  ('IBM',): {'ORG': 1},
#  ('ICL',): {'ORG': 1},
#  ('Paulig',): {'PER': 1},
#  ('Siemens',): {'PER': 1},
#  ('Valmet',): {'ORG': 1},
#  ('Stockmann',): {'ORG': 1},
#  ('Anttila',): {'ORG': 1},
#  ('Helkama',): {'PER': 1},
#  ('Pohjola',): {'ORG': 1},
#  ('Yleisradio',): {'ORG': 1},
#  ('Onninen',): {'ORG': 1},
#  ('Raudalu',): {'PER': 1},
#  ('Vaidla',): {'PER': 1},
#  ('Anži',): {'LOC': 1},
#  ('Tohveriga',): {'PER': 1},
#  ('Mahhatškalasse',): {'LOC': 1},
#  ('Mahhatškala',): {'LOC': 1},
#  ('Napoli',): {'PER': 1, 'LOC': 1},
#  ('Maradona',): {'PER': 2},
#  ('Dundee',): {'LOC': 1},
#  ('Šotimaa',): {'LOC': 1},
#  ('Dundees',): {'LOC': 1},
#  ('Hingis',): {'PER': 1},
#  ('Ferrari',): {'ORG': 3},
#  ('Schumacherile',): {'PER': 1},
#  ('Istanbuli',): {'LOC': 1},
#  ('Telindus',): {'ORG': 1},
#  ('Telinduse',): {'ORG': 1},
#  ('B-grupis',): {'ORG': 1},
#  ('Kullamäe',): {'PER': 1, 'LOC': 3},
#  ('Oostendele',): {'ORG': 1},
#  ('Märtin',): {'PER': 11},
#  ('MMi',): {'ORG': 2},
#  ('Arai',): {'PER': 7},
#  ('Märtinit',): {'PER': 1},
#  ('Lemsalu',): {'PER': 7, 'LOC': 1},
#  ('Start',): {'ORG': 1},
#  ('Lõuna-Norra',): {'LOC': 1},
#  ('Stardil',): {'LOC': 1},
#  ('Karin',): {'PER': 6},
#  ('Liis',): {'PER': 2},
#  ('Urmas',): {'PER': 2},
#  ('Strømsgodset',): {'ORG': 1, 'PER': 1},
#  ('Lemsalust',): {'LOC': 1},
#  ('Kristiansandi',): {'LOC': 1},
#  ('Fædrelandsvenner',): {'ORG': 1},
#  ('Šge',): {'PER': 1},
#  ('IK',): {'ORG': 1},
#  ('Klubi',): {'PER': 1},
#  ('Drangsholvi',): {'PER': 1},
#  ('Drangsholv',): {'PER': 2},
#  ('Lemsalul',): {'LOC': 1},
#  ('Starti',): {'ORG': 1},
#  ('Kalevi',): {'PER': 3},
#  ('Nybiti',): {'PER': 2},
#  ('Varblase',): {'PER': 1},
#  ('Kalev',): {'PER': 3, 'ORG': 2},
#  ('Sokku',): {'PER': 1},
#  ('Teniste',): {'PER': 2},
#  ('Kerde',): {'PER': 1},
#  ('Valgevenes',): {'LOC': 4},
#  ('Salt',): {'LOC': 5},
#  ('Citys',): {'LOC': 4},
#  ('Katrin',): {'PER': 3},
#  ('Kristina',): {'PER': 12},
#  ('Neumannova',): {'PER': 3},
#  ('Skari',): {'PER': 3, 'LOC': 1},
#  ('Neumannovaga',): {'PER': 1},
#  ('Kristinat',): {'PER': 1},
#  ('Katrinit',): {'PER': 1},
#  ('Tšepalova',): {'PER': 3},
#  ('Tšehhitar',): {'LOC': 1},
#  ('Paruzzi',): {'PER': 1},
#  ('Scott',): {'PER': 1},
#  ('Tšepalovaga',): {'PER': 1},
#  ('Ameerikasse',): {'LOC': 2},
#  ('Šmigunide',): {'PER': 2},
#  ('Anatoli',): {'PER': 1},
#  ('USAsse',): {'LOC': 3},
#  ('Lake',): {'LOC': 2},
#  ('Katriniga',): {'PER': 1},
#  ('Valeiko',): {'PER': 5, 'LOC': 1},
#  ('Rumma',): {'PER': 2},
#  ('Nikolotov',): {'PER': 2},
#  ('Saag',): {'PER': 2},
#  ('Tenno',): {'PER': 1, 'ORG': 1},
#  ('Metstak',): {'PER': 3},
#  ('O',): {'ORG': 1},
#  ('Erkmaa',): {'PER': 1},
#  ('Melnik',): {'PER': 2},
#  ('Oostendesse',): {'LOC': 1},
#  ('Allingu',): {'PER': 2},
#  ('Villers',): {'ORG': 1},
#  ('Lokutsievski',): {'PER': 1},
#  ('Pugonen',): {'ORG': 1},
#  ('Moore',): {'PER': 2},
#  ('Kivinukk',): {'ORG': 1},
#  ('Šein',): {'ORG': 1},
#  ('Reinbok',): {'ORG': 1},
#  ('Tagamets',): {'LOC': 1},
#  ('Lips',): {'ORG': 1},
#  ('Hendrikson',): {'ORG': 1},
#  ('Suurorg',): {'ORG': 1},
#  ('Grigorjev',): {'ORG': 1, 'PER': 1},
#  ('Kuusmaa',): {'LOC': 1},
#  ('Eaker',): {'ORG': 1},
#  ('Ruut',): {'PER': 1},
#  ('Berrien',): {'ORG': 1},
#  ('Kangur',): {'LOC': 1},
#  ('Kaljula',): {'PER': 1},
#  ('Västeråsis',): {'LOC': 1},
#  ('Vinni',): {'PER': 1},
#  ('Sõber',): {'PER': 1},
#  ('TÜ-Delta',): {'ORG': 1},
#  ('Nybit',): {'ORG': 1, 'PER': 1},
#  ('Hotronic',): {'ORG': 1},
#  ('Ehitustööriist',): {'ORG': 1},
#  ('Ida-Virumaa',): {'LOC': 1},
#  ('WRX',): {'ORG': 1},
#  ('Subaru',): {'PER': 5},
#  ('Mariine',): {'PER': 1},
#  ('Märtinile',): {'PER': 1},
#  ('Märtinil',): {'PER': 2},
#  ('Burns',): {'PER': 1},
#  ('Märtini',): {'PER': 1},
#  ('Märtinilt',): {'PER': 1},
#  ('Sambiaga',): {'LOC': 1},
#  ('Hassan',): {'PER': 1},
#  ('FIDE',): {'ORG': 3},
#  ('Kasparovi',): {'PER': 1},
#  ('India',): {'ORG': 1},
#  ('Kramnikul',): {'PER': 1},
#  ('Sloveenia',): {'LOC': 2},
#  ('Istanbulis',): {'LOC': 1},
#  ('MK',): {'ORG': 2},
#  ('Tšehhimaalt',): {'LOC': 1},
#  ('Kanada',): {'PER': 1, 'LOC': 1},
#  ('Skarist',): {'PER': 1},
#  ('Neumannovat',): {'PER': 1},
#  ('Belmondo',): {'PER': 1},
#  ('Paruzzile',): {'PER': 1},
#  ('TV-le',): {'ORG': 1},
#  ('Kerese',): {'PER': 2, 'ORG': 1},
#  ('Sõnumilehes',): {'ORG': 1},
#  ('Olli',): {'PER': 1},
#  ('Oll',): {'PER': 2},
#  ('Polgar',): {'PER': 3},
#  ('Tammerti',): {'LOC': 1},
#  ('Polgari',): {'PER': 2},
#  ('Timmani',): {'PER': 1},
#  ('Tammertile',): {'PER': 1},
#  ('Tammert',): {'PER': 1},
#  ('Mazzacanet',): {'PER': 1},
#  ('Nool',): {'PER': 4},
#  ('Adidas',): {'ORG': 1},
#  ('Lõuna-Aafrikast',): {'LOC': 1},
#  ('Hispaaniasse',): {'LOC': 1},
#  ('Aaviksoo',): {'PER': 3},
#  ('Kuusk',): {'PER': 1},
#  ('Kuuse',): {'PER': 3},
#  ('ESS',): {'ORG': 2},
#  ('Kriiska',): {'LOC': 5},
#  ('Kriiskalt',): {'PER': 1},
#  ('Viru',): {'LOC': 7, 'PER': 6},
#  ('Isamaaliidu',): {'ORG': 5},
#  ('Arengupartei',): {'ORG': 3},
#  ('Iseseisvuspartei',): {'ORG': 3},
#  ('Keskerakond',): {'ORG': 4},
#  ('Isamaaliitu',): {'ORG': 7},
#  ('Jõgeva',): {'LOC': 3},
#  ('Arenguparteil',): {'ORG': 1},
#  ('Koonderakond',): {'ORG': 2},
#  ('Justiitsministeeriumi',): {'ORG': 2},
#  ('Barbo',): {'PER': 2},
#  ('Rahvaerakond',): {'ORG': 2},
#  ('Mõõdukad',): {'ORG': 6},
#  ('Isamaaliit',): {'ORG': 8},
#  ('Kilk',): {'LOC': 1},
#  ('Kranichi',): {'PER': 1},
#  ('Kranich',): {'PER': 3},
#  ('Pärnumaa',): {'LOC': 1},
#  ('Padjus',): {'PER': 1},
#  ('Lootsi',): {'ORG': 1},
#  ('Kalda',): {'PER': 7},
#  ('Toilasse',): {'LOC': 1},
#  ('Jõksi',): {'PER': 1},
#  ('Meri',): {'PER': 9},
#  ('Varkeli',): {'PER': 1},
#  ('Luik',): {'PER': 2},
#  ('Isamaaliiduga',): {'ORG': 1},
#  ('Isamaaliidust',): {'ORG': 2},
#  ('Kaitseliitu',): {'ORG': 2},
#  ('Kunnas',): {'PER': 2},
#  ('Kaitseliidu',): {'ORG': 4},
#  ('Michelson',): {'PER': 1},
#  ('Moora',): {'PER': 1},
#  ('Kunnase',): {'PER': 1},
#  ('Michelsoni',): {'PER': 1},
#  ('Feira',): {'ORG': 1},
#  ('Nizzas',): {'LOC': 1},
#  ('Nizza',): {'LOC': 3},
#  ('Göteborgi',): {'LOC': 2},
#  ('Lissabonis',): {'LOC': 1},
#  ('Rootsil',): {'LOC': 1},
#  ('Kliimaküsimus',): {'PER': 1},
#  ('Kesklinna',): {'LOC': 3},
#  ('Põhja-Tallinna',): {'LOC': 3},
#  ('Stroomi',): {'LOC': 1},
#  ('Järvamaa',): {'LOC': 1},
#  ('Muuseumis',): {'LOC': 1},
#  ('Peterburi',): {'LOC': 2},
#  ('Batmani',): {'PER': 1},
#  ('Paidesse',): {'LOC': 2},
#  ('Narvast',): {'LOC': 1},
#  ('Paidet',): {'LOC': 1},
#  ('Saaristi',): {'PER': 2},
#  ('Järvamaal',): {'LOC': 3},
#  ('Paides',): {'LOC': 1},
#  ('Hollywoodi',): {'LOC': 1},
#  ('Sõer',): {'PER': 2},
#  ('justiitsministeeriumi',): {'ORG': 1},
#  ('Keila',): {'LOC': 2},
#  ('Vasalemma',): {'LOC': 1},
#  ('Herodese',): {'PER': 1},
#  ('Riigikogu',): {'ORG': 16},
#  ('Kadrioru',): {'ORG': 2},
#  ('Lähis-Ida',): {'LOC': 2},
#  ('Põhja-Korea',): {'LOC': 1},
#  ('Venemaaga',): {'LOC': 3},
#  ('Perssoni',): {'PER': 1},
#  ('Prantsusmaalt',): {'LOC': 1},
#  ('Belgiale',): {'LOC': 1},
#  ('EBRD',): {'ORG': 4},
#  ('Raepressile',): {'ORG': 1},
#  ('Vilba',): {'PER': 2},
#  ('Tallinnalt',): {'LOC': 1},
#  ('Mõõdukate',): {'ORG': 2},
#  ('Pakosta',): {'PER': 10},
#  ('EPMÜ',): {'ORG': 10},
#  ('Koppeli',): {'PER': 1},
#  ('Koppel',): {'PER': 4},
#  ('Linde',): {'PER': 2},
#  ('Paikusel',): {'LOC': 1},
#  ('Merits',): {'PER': 1},
#  ('Creutzfeld-Jacobi',): {'LOC': 3},
#  ('Kreis',): {'PER': 1},
#  ('Tallinnale',): {'LOC': 2},
#  ('Soomega',): {'LOC': 2},
#  ('Lekko',): {'PER': 2},
#  ('Ukrainast',): {'LOC': 1},
#  ('Creutzfeldt-Jakobi',): {'LOC': 1},
#  ('Paavel',): {'PER': 1},
#  ('Lääne-Euroopat',): {'LOC': 1},
#  ('Loit',): {'PER': 2},
#  ('Hispaaniast',): {'LOC': 1},
#  ('Inglismaalt',): {'LOC': 1},
#  ('Iirimaalt',): {'LOC': 1},
#  ('Portugalist',): {'LOC': 1},
#  ('Sveitsist',): {'LOC': 1},
#  ('Hollandist',): {'LOC': 1},
#  ('Belgiast',): {'LOC': 1},
#  ('Taanist',): {'LOC': 3},
#  ('Loidi',): {'PER': 1},
#  ('Keldrima',): {'PER': 1},
#  ('Internetipanga',): {'ORG': 1},
#  ('U-Neti',): {'LOC': 1},
#  ('Välisministeeriumi',): {'ORG': 1},
#  ('Nõukogude',): {'LOC': 2},
#  ('Nõmme',): {'LOC': 1, 'ORG': 1},
#  ('Liumägi',): {'LOC': 1},
#  ('Põlva',): {'LOC': 1},
#  ('Nõmmele',): {'LOC': 1},
#  ('Jürgensoni',): {'PER': 1},
#  ('Reiljani',): {'PER': 2},
#  ('Jürgensonile',): {'PER': 1},
#  ('Kreitzberg',): {'PER': 2},
#  ('Reiljan',): {'PER': 1},
#  ('Riigikogule',): {'ORG': 1},
#  ('Edelaraudteel',): {'ORG': 2},
#  ('Riigikogus',): {'ORG': 4},
#  ('Edelaraudtee',): {'ORG': 20},
#  ('Jürgenson',): {'PER': 1},
#  ('Lätil',): {'LOC': 2},
#  ('LV',): {'ORG': 1},
#  ('Lukas',): {'PER': 2},
#  ('Haridusministeeriumi',): {'ORG': 1},
#  ('Lääne-Virumaal',): {'LOC': 2},
#  ('Tartumaal',): {'LOC': 1},
#  ('Edelaraudteega',): {'ORG': 3},
#  ('Postimehele',): {'ORG': 2},
#  ('Müllersonil',): {'PER': 1},
#  ('Pihlakasel',): {'PER': 1},
#  ('Tarand',): {'PER': 3},
#  ('Sootak',): {'PER': 1},
#  ('Rahvaliidu',): {'ORG': 1},
#  ('Raigo',): {'PER': 28},
#  ('Raigole',): {'LOC': 2, 'ORG': 1, 'PER': 1},
#  ('Raigol',): {'PER': 7},
#  ('Kristi',): {'PER': 3},
#  ('Puhtus',): {'LOC': 1},
#  ('Leena',): {'ORG': 2, 'PER': 1},
#  ('Inga',): {'PER': 1},
#  ('Eva',): {'PER': 1},
#  ('Tartusse',): {'LOC': 6},
#  ('Siina',): {'PER': 1},
#  ('Raigost',): {'PER': 1},
#  ('Eestiga',): {'LOC': 1},
#  ('Respublika',): {'ORG': 2, 'PER': 4},
#  ('NATO',): {'ORG': 24},
#  ('Baltimaa',): {'LOC': 1},
#  ('NATOga',): {'ORG': 1},
#  ('Eestile',): {'LOC': 5},
#  ('Leedut',): {'LOC': 2},
#  ('NATOsse',): {'ORG': 1},
#  ('Põhjamaaks',): {'LOC': 1},
#  ('Ida-Euroopasse',): {'LOC': 1},
#  ('Raadio',): {'ORG': 2},
#  ('Kulemaje',): {'PER': 1},
#  ('Läänes',): {'LOC': 2},
#  ('Vilnius',): {'LOC': 1},
#  ('Euroopasse',): {'LOC': 1},
#  ('reforme',): {'ORG': 1},
#  ('Tiesenhauseni',): {'PER': 4},
#  ('Toompea',): {'ORG': 1},
#  ('Tiesenhausenid',): {'PER': 1},
#  ('Ida-Virumaalt',): {'LOC': 3},
#  ('Toim',): {'PER': 1},
#  ('kapo',): {'ORG': 1},
#  ('Maie',): {'PER': 1},
#  ('Kapo',): {'ORG': 1},
#  ('Tiesenhausen',): {'PER': 2},
#  ('Kurvitsaga',): {'PER': 1},
#  ('Bergert',): {'PER': 6},
#  ('Ekspressi',): {'ORG': 2},
#  ('Kurvits',): {'PER': 1},
#  ...}

# %%
first_words_map
# Out:
# {('Leedu',): {'ORG': 6},
#  ('Bill',): {'PER': 7},
#  ('Saudi',): {'LOC': 3},
#  ('Aivo',): {'PER': 8},
#  ('Eesti',): {'ORG': 68, 'LOC': 10},
#  ('Jüri',): {'PER': 35},
#  ('Rein',): {'PER': 12},
#  ('Tallinna',): {'ORG': 55, 'LOC': 8},
#  ('Euroopa',): {'ORG': 24, 'LOC': 17},
#  ('Läti',): {'ORG': 5},
#  ('Ivar',): {'PER': 1},
#  ('ASi', 'Lõhmus', 'Haavel', '&'): {'ORG': 1},
#  ('Heiki',): {'PER': 9},
#  ('Trigon',): {'ORG': 1},
#  ('Mihkel',): {'PER': 5},
#  ('Q',): {'ORG': 10},
#  ('Ameerika',): {'LOC': 6, 'ORG': 1},
#  ('Jaana',): {'PER': 1},
#  ('Märten',): {'PER': 1},
#  ('Andres',): {'PER': 21},
#  ('ASis', 'Repo'): {'ORG': 1},
#  ('Repo',): {'ORG': 1, 'PER': 1},
#  ('Aivar',): {'PER': 8},
#  ('Balti',): {'LOC': 6, 'ORG': 1},
#  ('Karin',): {'PER': 7},
#  ('Kristjan-Erik',): {'PER': 3},
#  ('Eesti', 'Väärtpaberite'): {'ORG': 1},
#  ('Tartu',): {'ORG': 15, 'LOC': 2},
#  ('Vambola',): {'PER': 2},
#  ('Üllar',): {'PER': 3},
#  ('Kolbakov', 'Üllar'): {'PER': 1},
#  ('Lõuna-Eesti',): {'ORG': 3},
#  ('Eha',): {'PER': 2},
#  ('ASi',): {'ORG': 2},
#  ('AS',): {'ORG': 16},
#  ('ERA',): {'ORG': 3},
#  ('Indrek',): {'PER': 13},
#  ('Lõunatööstuse',): {'ORG': 2},
#  ('ASi', 'Werol'): {'ORG': 2},
#  ('Latvijas',): {'PER': 3},
#  ('Isamaale', 'ja', 'Vabadusele', '/'): {'ORG': 2},
#  ('Maris',): {'PER': 1},
#  ('Rahvaerakonna', 'Andris'): {'ORG': 1},
#  ('Kuno',): {'PER': 1},
#  ('Araabia',): {'ORG': 1},
#  ('Arnaud',): {'PER': 1},
#  ('Marko',): {'PER': 3},
#  ('Henri',): {'PER': 3},
#  ('Eurospordi',): {'ORG': 1},
#  ('Mladen',): {'PER': 2},
#  ('Eurosport',): {'ORG': 2},
#  ('Eestist',): {'LOC': 1},
#  ('Gallup',): {'PER': 1},
#  ('Saksamaa', 'Föderaalne'): {'ORG': 1},
#  ('ES',): {'ORG': 1},
#  ('Äriteenus',): {'ORG': 2},
#  ('Uue',): {'ORG': 2},
#  ('DFDS', 'Tor'): {'ORG': 1},
#  ('Vaclovas',): {'PER': 1},
#  ('Arturas',): {'PER': 1},
#  ('Vytautas',): {'PER': 1},
#  ('Piret',): {'PER': 6},
#  ('Ahti',): {'PER': 2},
#  ('Arvi',): {'PER': 5},
#  ('AS-i',): {'ORG': 5},
#  ('AS', 'Suure-Jaani'): {'ORG': 3},
#  ('Haapsallu',): {'LOC': 1},
#  ('Teetöötajate',): {'ORG': 1},
#  ('Ain',): {'PER': 4},
#  ('Toivi',): {'PER': 1},
#  ('Suure-Jaani',): {'PER': 2},
#  ('Lietuvos',): {'ORG': 2},
#  ('Gintaras',): {'PER': 1},
#  ('Kazimieras',): {'PER': 1},
#  ('Läti', 'riikliku', 'energeetikafirma'): {'ORG': 1},
#  ('Talis', 'Linkaits'): {'ORG': 1},
#  ('Zorzs', 'Tikmers', 'Läti'): {'ORG': 1},
#  ('Zigmunds', 'Krastins'): {'ORG': 1},
#  ('Juris',): {'ORG': 1},
#  ('Isamaale', 'ja'): {'ORG': 1},
#  ('Gundars',): {'PER': 1},
#  ('Aigars',): {'PER': 1},
#  ('Talis',): {'ORG': 1},
#  ('Riia',): {'ORG': 1},
#  ('Leonids',): {'PER': 1},
#  ('Poola', 'Kredyt', 'Bank'): {'ORG': 1},
#  ('Optiva',): {'ORG': 2},
#  ('Merita',): {'ORG': 2, 'PER': 1},
#  ('Svenska',): {'PER': 1},
#  ('Akmenes',): {'PER': 3},
#  ('Pranas',): {'PER': 1},
#  ('Einars',): {'PER': 2},
#  ('Hansatee',): {'ORG': 1},
#  ('AS-is',): {'ORG': 1},
#  ('Viking',): {'ORG': 2},
#  ('Mart',): {'PER': 8},
#  ('Mažeikiu',): {'ORG': 1, 'PER': 7},
#  ('Williams',): {'PER': 1, 'ORG': 1},
#  ('John',): {'PER': 11},
#  ('Aleksandras',): {'PER': 1},
#  ('Jonas',): {'PER': 1},
#  ('Valdas',): {'PER': 2},
#  ('Rolandas',): {'PER': 1},
#  ('Narva',): {'ORG': 1, 'LOC': 1},
#  ('Erki',): {'PER': 5},
#  ('Seesam', 'Rahvusvaheline', 'Kindlustuse'): {'ORG': 1},
#  ('Salva', 'Kindlustuse', "AS'i"): {'ORG': 1},
#  ('AS', 'Sampo', 'Eesti'): {'ORG': 1},
#  ('Inge',): {'PER': 1},
#  ('Audit',): {'PER': 1},
#  ('Kristjan',): {'PER': 8},
#  ('Rimess',): {'ORG': 2},
#  ('Lemmi',): {'PER': 1},
#  ('Aule',): {'PER': 1},
#  ('AS', 'Audit', 'EA'): {'ORG': 1},
#  ('Eesti', 'Sõltumatu', 'Televisiooni'): {'ORG': 1},
#  ('Tõnis',): {'PER': 7},
#  ('Björn',): {'PER': 2},
#  ('Erkki',): {'PER': 1},
#  ('Rootsi',): {'ORG': 2, 'LOC': 1},
#  ('Soome',): {'ORG': 2},
#  ('Telenori', 'ja'): {'ORG': 1},
#  ('Enskilda',): {'PER': 1},
#  ('Kenneth',): {'PER': 1},
#  ('Dagens',): {'ORG': 2},
#  ('TDC', 'Mobile'): {'ORG': 1},
#  ('TeleDanmark',): {'ORG': 1},
#  ('Deutsche',): {'ORG': 3},
#  ('NetCom',): {'ORG': 1},
#  ('HK',): {'ORG': 2},
#  ('Rakvere',): {'ORG': 3},
#  ('Pärnu',): {'ORG': 7, 'LOC': 1},
#  ('Aavik',): {'PER': 1},
#  ('Haapsalu',): {'LOC': 1, 'ORG': 4, 'PER': 1},
#  ('Leino',): {'PER': 1},
#  ('Lääne',): {'ORG': 1},
#  ('Läänemaa', 'Talupidajate'): {'ORG': 1},
#  ('DoubleClick',): {'PER': 1},
#  ('New',): {'LOC': 5, 'ORG': 9, 'PER': 2},
#  ('ValueClick',): {'PER': 1},
#  ('Mediaplex',): {'PER': 1},
#  ('Media',): {'ORG': 6, 'PER': 3},
#  ('Avenue', 'A'): {'ORG': 1},
#  ('America', 'Montgomery'): {'ORG': 1},
#  ('Siim',): {'PER': 5},
#  ('Rahvusvahelise', 'Sotsiaalteaduste', 'Kõrgkooli'): {'ORG': 1},
#  ('Maastrichti',): {'ORG': 1},
#  ('Tallinna', 'Koolidevahelises'): {'ORG': 1},
#  ('Saue',): {'ORG': 1, 'LOC': 1},
#  ('Garth', 'Alexander'): {'PER': 1},
#  ('Sunday',): {'ORG': 1},
#  ('Tadayo',): {'PER': 1},
#  ('Nippon', 'Credit'): {'ORG': 1},
#  ('Sinine',): {'PER': 1},
#  ('Honma',): {'PER': 1},
#  ('Yoshiro',): {'PER': 1},
#  ('Rahandusliku', 'Rekonstruktsiooni'): {'ORG': 1},
#  ('Hikari',): {'PER': 1},
#  ('Kyoei',): {'PER': 1},
#  ('Chiyoda', 'Mutual'): {'ORG': 1},
#  ('Merrill',): {'PER': 2},
#  ('Kiichi',): {'PER': 1},
#  ('Shikoku',): {'LOC': 1},
#  ('Michael',): {'PER': 5},
#  ('Hansapanga',): {'ORG': 7},
#  ('Tiit',): {'PER': 10},
#  ('PAAVO',): {'PER': 1},
#  ('Unidanmark',): {'ORG': 1},
#  ('Hansabanka', 'Läti'): {'ORG': 1},
#  ('Hansabankas',): {'LOC': 1},
#  ('Tiina',): {'PER': 6},
#  ('Aare',): {'PER': 6},
#  ('Daniel',): {'PER': 3},
#  ('Ülle',): {'PER': 5},
#  ('Kadri',): {'PER': 3},
#  ('Kalle',): {'PER': 6},
#  ('Veikko',): {'PER': 1},
#  ('Poliitikauuringute', 'Keskuses'): {'ORG': 1},
#  ('Rahvusvahelise', 'Valuutafondi', 'Eesti'): {'ORG': 1},
#  ('Margus',): {'PER': 6},
#  ('Paavo',): {'PER': 1},
#  ('Enn',): {'PER': 4},
#  ('Kapitalist',): {'PER': 1},
#  ('NG',): {'ORG': 5},
#  ('Norma',): {'ORG': 1},
#  ('Kännu',): {'PER': 1},
#  ('Kunila',): {'ORG': 2},
#  ('Selverite',): {'ORG': 1},
#  ('Mere', 'puiestee'): {'ORG': 1},
#  ('Rocca', 'al'): {'LOC': 1},
#  ('Türi',): {'LOC': 1},
#  ('Taani', 'mänguasjadetootja'): {'ORG': 1},
#  ('Eva',): {'PER': 1},
#  ('Suurbritannia',): {'ORG': 2},
#  ('Jack',): {'PER': 1},
#  ('Nokia',): {'LOC': 1},
#  ('Phil',): {'PER': 1},
#  ('Skandinaviska', 'Enskilda'): {'ORG': 1},
#  ('Andrei',): {'PER': 2},
#  ('Leonid',): {'PER': 10},
#  ('Vladimir',): {'PER': 10},
#  ('Hispaania',): {'ORG': 1},
#  ('Balthasar',): {'PER': 1},
#  ('Gussinski', 'Madridi'): {'ORG': 1},
#  ('Garzon',): {'PER': 1},
#  ('Gazprom',): {'LOC': 2, 'PER': 4},
#  ('Ted',): {'PER': 4},
#  ('Mihhail',): {'PER': 5},
#  ('Edzus',): {'PER': 1},
#  ('Suurbritannia', 'Regional', 'Property', 'Developments'): {'ORG': 1},
#  ('Saules',): {'ORG': 1},
#  ('Juri',): {'PER': 3},
#  ('VEF',): {'ORG': 1},
#  ('Gints',): {'PER': 1},
#  ('Kinnistud',): {'PER': 1},
#  ('AS', 'Sampo'): {'ORG': 1},
#  ('AS-i', 'Tallinna'): {'ORG': 5},
#  ('International', 'Water', 'United'): {'ORG': 1},
#  ('International', 'Water'): {'ORG': 3},
#  ('Tim',): {'PER': 1},
#  ('UU',): {'ORG': 1},
#  ('Gordon',): {'PER': 1},
#  ('International',): {'ORG': 1},
#  ('Patrick',): {'PER': 4},
#  ('Water',): {'PER': 1},
#  ('Sarah',): {'PER': 1},
#  ('Ameerika', 'Ühendriikide'): {'ORG': 1},
#  ('Dolores',): {'PER': 1},
#  ('Suprema',): {'PER': 1},
#  ('Rõuge',): {'ORG': 5},
#  ('Jaak',): {'PER': 4},
#  ('Tanel',): {'PER': 1},
#  ('Ene',): {'PER': 2},
#  ('Pro',): {'ORG': 5},
#  ('Tallinnas',): {'ORG': 4, 'LOC': 3},
#  ('RAS',): {'ORG': 1},
#  ('Sirje',): {'PER': 4},
#  ('Kesko',): {'ORG': 1},
#  ('Kesklinna',): {'ORG': 2},
#  ('ASi', 'Emajõe'): {'ORG': 1},
#  ('Priit',): {'PER': 13},
#  ('Emajõe',): {'ORG': 1},
#  ('ASi', 'Tallinna'): {'ORG': 1},
#  ('Tallinna', 'Järve'): {'ORG': 1},
#  ('OÜ',): {'ORG': 4},
#  ('Tallinnast',): {'LOC': 1},
#  ('Riho',): {'PER': 4},
#  ('Aap',): {'PER': 4},
#  ('AS', 'SL'): {'ORG': 1},
#  ('AS-i', 'SL'): {'ORG': 1},
#  ('Urmas',): {'PER': 7},
#  ('SL', 'Bussiliinid'): {'ORG': 2},
#  ('SL',): {'ORG': 14},
#  ('Soome', 'Savolinja'): {'ORG': 1},
#  ('Tuomo',): {'PER': 2},
#  ('Savonlinja',): {'PER': 2},
#  ('Connex',): {'PER': 2},
#  ('Edgar',): {'PER': 2},
#  ('Jakko',): {'PER': 9},
#  ('Tallinna', 'linnakohtu'): {'ORG': 1},
#  ('Intrum',): {'ORG': 4},
#  ('Risto',): {'PER': 1},
#  ('Mähel',): {'LOC': 1},
#  ('Marchel',): {'PER': 1},
#  ('Henrik',): {'PER': 3},
#  ('Katrin',): {'PER': 5},
#  ('Neste', 'Eesti'): {'ORG': 1},
#  ('Raul',): {'PER': 7},
#  ('Kaljo',): {'PER': 2},
#  ('Jevgeni',): {'PER': 3},
#  ('Viimsi',): {'ORG': 4, 'LOC': 1},
#  ('Estonia',): {'ORG': 1},
#  ('Muuga',): {'LOC': 1},
#  ('Ruma',): {'ORG': 1},
#  ('Saksamaa', 'Hypo'): {'ORG': 1},
#  ('Johnny',): {'PER': 1},
#  ('Clint',): {'PER': 1},
#  ('Signe',): {'PER': 2},
#  ('Pomerants',): {'PER': 1},
#  ('KIRVED',): {'PER': 1},
#  ('Ago',): {'PER': 2},
#  ('Romi',): {'PER': 1},
#  ('Eve',): {'PER': 4},
#  ('Jesus', 'Christ'): {'ORG': 1},
#  ('Bns', '/'): {'ORG': 1},
#  ('Martin', 'Luther'): {'ORG': 1},
#  ('Andy',): {'PER': 15},
#  ('Julia',): {'PER': 4},
#  ('Andrew',): {'PER': 3},
#  ('Ferus', 'Gallerys', 'Los'): {'ORG': 1},
#  ('Pat',): {'PER': 3},
#  ('De',): {'ORG': 1},
#  ('Warhol',): {'PER': 1},
#  ('Timo',): {'ORG': 1},
#  ('Warholi',): {'PER': 1},
#  ('José',): {'PER': 2},
#  ('Taani',): {'LOC': 1},
#  ('Hamburgi', 'Moodsa', 'Kunsti', 'Muuseumis'): {'ORG': 1},
#  ('Tallinnas', 'Rotermanni', 'Soolalaos', 'USA'): {'ORG': 1},
#  ('Marilyn',): {'PER': 1},
#  ('John', 'Peter'): {'PER': 1},
#  ('New', 'Yorgi'): {'ORG': 1},
#  ('Max',): {'PER': 3},
#  ('Igor',): {'PER': 6},
#  ('Peeter',): {'PER': 10},
#  ('Vadim',): {'PER': 3},
#  ('Triinu',): {'PER': 1},
#  ('Andero',): {'PER': 1},
#  ('Anne', 'Reemann'): {'PER': 1},
#  ('Margot',): {'PER': 1},
#  ('Kama',): {'PER': 1},
#  ('Daniil',): {'PER': 1},
#  ('Katerina', 'Ivanovna'): {'PER': 1},
#  ('Katerina',): {'PER': 3},
#  ('Oksana',): {'PER': 1},
#  ('Usk', 'Katerina'): {'PER': 1},
#  ('Makedoonias',): {'LOC': 1},
#  ('Avo',): {'PER': 1},
#  ('Benjamin',): {'PER': 2},
#  ('Ilmar',): {'PER': 2},
#  ('Kelli',): {'PER': 1},
#  ('NRC',): {'ORG': 1},
#  ('Jaan',): {'PER': 12},
#  ('Arthur',): {'PER': 1},
#  ('Fidel',): {'PER': 1},
#  ('Lennoni',): {'PER': 1},
#  ('Ricardo',): {'PER': 2},
#  ('Luure',): {'ORG': 1},
#  ('Jossif',): {'PER': 1},
#  ('Boriss',): {'PER': 2},
#  ('Tarmo',): {'PER': 7},
#  ('Hanno',): {'PER': 1},
#  ('Edgar', 'Johan'): {'PER': 1},
#  ('Nora',): {'PER': 1},
#  ('Triin',): {'PER': 1},
#  ('Eugen',): {'PER': 1},
#  ('Nikolai',): {'PER': 1},
#  ('Nordic', 'Art'): {'ORG': 1},
#  ("Duchamp'i",): {'PER': 1},
#  ('Heie',): {'PER': 2},
#  ('Roy',): {'PER': 1},
#  ('Inessa',): {'PER': 1},
#  ('Leonhard',): {'PER': 1},
#  ('Kadi',): {'PER': 1},
#  ('Ede',): {'PER': 2},
#  ('Urve',): {'PER': 1},
#  ('Paul',): {'PER': 6},
#  ('Viljandi',): {'LOC': 1, 'ORG': 2},
#  ('Tiiu',): {'PER': 5},
#  ('George',): {'PER': 10},
#  ('The',): {'ORG': 2, 'PER': 2},
#  ('Susan', 'Kleckner'): {'PER': 1},
#  ('Linnar',): {'PER': 3},
#  ('Will',): {'ORG': 1},
#  ('Lapper',): {'PER': 1},
#  ('Horst',): {'PER': 1},
#  ('Thomas',): {'PER': 1},
#  ('Eric-Emmanuel',): {'PER': 1},
#  ('Hannes',): {'PER': 2},
#  ('Tarvo',): {'PER': 1},
#  ('Ülle', 'Lichtfeldt'): {'PER': 1},
#  ('Karl',): {'PER': 2},
#  ('Ruta',): {'PER': 1},
#  ('Arvo',): {'PER': 1},
#  ('Agatha',): {'PER': 1},
#  ('TUNDED',): {'PER': 1},
#  ('Maria',): {'PER': 4},
#  ('Siiri',): {'PER': 1},
#  ('Anastassia',): {'PER': 1},
#  ('Alanis',): {'PER': 1},
#  ('Heili',): {'PER': 1},
#  ('Lauri',): {'ORG': 1, 'PER': 7},
#  ('Toivo',): {'PER': 6},
#  ('Alfred',): {'PER': 1},
#  ('Tulevi-plokk',): {'PER': 1},
#  ('Gidon',): {'PER': 2},
#  ('Kremerata',): {'ORG': 1},
#  ('Dinu',): {'ORG': 1},
#  ('Gia',): {'PER': 1},
#  ('Colorado',): {'ORG': 1},
#  ('Columbus', 'Blue'): {'PER': 1},
#  ('San', 'Jose'): {'ORG': 1},
#  ('Minnesota',): {'PER': 1, 'ORG': 1},
#  ('Marc',): {'PER': 1},
#  ('Adam',): {'PER': 2},
#  ('Joe',): {'PER': 4},
#  ('New', 'Jersey'): {'ORG': 1},
#  ('Phoenix',): {'ORG': 1},
#  ('Marty',): {'PER': 2},
#  ('Ed',): {'PER': 1},
#  ('Atlanta',): {'ORG': 1},
#  ('Ron',): {'PER': 3},
#  ('Jacques',): {'PER': 1},
#  ('Tampa',): {'ORG': 3},
#  ('Steve',): {'PER': 2},
#  ('Toronto', 'Maple'): {'ORG': 1},
#  ('Dan',): {'PER': 1},
#  ('Boston',): {'ORG': 2},
#  ('TAMPA',): {'ORG': 1},
#  ('Ryan',): {'PER': 1},
#  ('Vincent',): {'PER': 3},
#  ('Brian',): {'PER': 2},
#  ('Aleksandr',): {'PER': 4},
#  ('Fredrik',): {'PER': 1},
#  ('Yanic',): {'PER': 1},
#  ('Dave',): {'PER': 1},
#  ('BOSTON',): {'ORG': 1},
#  ('Sergei',): {'PER': 7},
#  ('Don',): {'PER': 1},
#  ('Mikko',): {'PER': 1},
#  ('Arron',): {'PER': 1},
#  ('Chad',): {'ORG': 1},
#  ('NEW',): {'ORG': 1},
#  ('Bobby',): {'PER': 1},
#  ('Randy',): {'PER': 3},
#  ('Mika',): {'PER': 1},
#  ('Ossi',): {'PER': 1},
#  ('Brad',): {'ORG': 2},
#  ('Patrik',): {'PER': 2},
#  ('Scott',): {'PER': 7},
#  ('Petr',): {'PER': 2, 'ORG': 1},
#  ('Jason',): {'PER': 2},
#  ('Brett',): {'PER': 1},
#  ('Darryl',): {'PER': 1},
#  ('Donald',): {'PER': 3},
#  ('Ray',): {'PER': 2},
#  ('Yannick',): {'PER': 1},
#  ('Brenden',): {'PER': 1},
#  ('Grant',): {'PER': 1},
#  ('Derian',): {'PER': 1},
#  ('COLORADO',): {'ORG': 1},
#  ('Peter',): {'PER': 2},
#  ('Geoff',): {'PER': 1},
#  ('Espen',): {'PER': 1},
#  ('Chris',): {'PER': 4, 'ORG': 1},
#  ('Martin',): {'PER': 4},
#  ('Alex',): {'PER': 1},
#  ('Greg',): {'PER': 1},
#  ('Bruce',): {'PER': 1},
#  ('Lyle',): {'PER': 1},
#  ('Aaron',): {'PER': 2},
#  ('Cam',): {'PER': 1},
#  ('Curtis',): {'PER': 1},
#  ('Stacy',): {'PER': 1},
#  ('Lubomir',): {'PER': 1},
#  ('NASHVILLE',): {'ORG': 1},
#  ('David',): {'PER': 3},
#  ('Tom',): {'PER': 3},
#  ('Anson',): {'PER': 1},
#  ('Doug',): {'PER': 1},
#  ('Denis',): {'PER': 1},
#  ('Mike',): {'PER': 3},
#  ('Georges',): {'PER': 1},
#  ('Rob',): {'PER': 1},
#  ('Karlis',): {'PER': 1},
#  ('Marian',): {'PER': 2},
#  ('OTTAWA',): {'ORG': 1},
#  ('Harold',): {'PER': 1},
#  ('Shawn',): {'PER': 1},
#  ('Wade',): {'PER': 1},
#  ('Magnus',): {'PER': 1},
#  ('Karel',): {'PER': 1},
#  ('Radek',): {'PER': 1},
#  ('Aleksei',): {'PER': 2},
#  ('Vancouver', ':'): {'ORG': 1},
#  ('ST',): {'ORG': 1},
#  ('Niklas',): {'PER': 1},
#  ('Oleg',): {'PER': 3},
#  ('Al',): {'PER': 2, 'ORG': 1},
#  ('Bryce',): {'PER': 1},
#  ('Pierre',): {'PER': 2},
#  ('Jochen',): {'PER': 1},
#  ('Craig',): {'PER': 1},
#  ('Tyson',): {'PER': 1},
#  ('Teemu',): {'PER': 1},
#  ('NY',): {'ORG': 2},
#  ('San',): {'ORG': 1, 'LOC': 1},
#  ('Klubi', 'Mänge'): {'ORG': 1},
#  ('Joe', 'Sakic'): {'PER': 1},
#  ('Donald', 'Audette'): {'PER': 1},
#  ('Jaromir', 'Jagr'): {'PER': 1},
#  ('Doug', 'Weight'): {'PER': 1},
#  ('Allison',): {'PER': 1},
#  ('Brian', 'Leetch'): {'PER': 1},
#  ('Sergei', 'Fjodorov'): {'PER': 1},
#  ('Aleksei', 'Kovaljov'): {'PER': 1},
#  ('Marian', 'Hossa'): {'PER': 1},
#  ('Peter', 'Bondra'): {'PER': 1},
#  ('Martin', 'Straka'): {'PER': 1},
#  ('Ferraro',): {'PER': 1},
#  ('Brett', 'Hull'): {'PER': 1},
#  ('Markus', 'Näslund'): {'PER': 1},
#  ('Steve', 'Sullivan'): {'PER': 1},
#  ('Radek', 'Bonk'): {'PER': 1},
#  ('Bill', 'Guerin'): {'PER': 1},
#  ('Mahhatshkala',): {'PER': 1, 'ORG': 1},
#  ('FC',): {'ORG': 7},
#  ('Toomas',): {'PER': 22},
#  ('Mark',): {'PER': 7},
#  ('Pavel',): {'PER': 2},
#  ('Crystal',): {'PER': 2},
#  ('Gerrald',): {'PER': 1},
#  ('Jari',): {'PER': 1},
#  ('Ipswich',): {'ORG': 1},
#  ('Birmingham',): {'LOC': 1},
#  ('Derby', 'Pride'): {'ORG': 1},
#  ('Tottenham',): {'PER': 1},
#  ('White', 'Hart'): {'PER': 2},
#  ('Sven-Göran',): {'PER': 1},
#  ('Birminghami', 'Villa'): {'ORG': 1},
#  ('Portland',): {'ORG': 1},
#  ('Rasheed',): {'PER': 1},
#  ('Portlandi', 'Damon'): {'PER': 1},
#  ('Sacramento', 'Kingsi', 'Chris'): {'ORG': 1},
#  ('Cleveland',): {'ORG': 1},
#  ('LA',): {'ORG': 1},
#  ('Van',): {'PER': 1},
#  ('Kristiine',): {'ORG': 1},
#  ('Tallinn', 'CUP'): {'ORG': 1},
#  ('LÕUNA',): {'PER': 2},
#  ('Kiviõli', 'FC', 'Shtrommi', 'Tarvastu', 'JK', 'Atli', 'Rapla'): {'ORG': 1},
#  ('Päästeamet',): {'ORG': 1},
#  ('Keila',): {'ORG': 3},
#  ('Põltsamaa', 'Kernu'): {'ORG': 1},
#  ('SK', 'Tapa'): {'ORG': 1},
#  ('Võru', 'Atli', 'Rapla'): {'ORG': 1},
#  ('SK', 'Trummi', 'Lootos', 'Põlva', 'FC'): {'ORG': 1},
#  ('Pärnu', 'FC'): {'LOC': 1},
#  ('RSK', 'Loksa', 'JK', 'Saue', 'SK', 'Kirm', 'FC', 'Mõigu'): {'ORG': 1},
#  ('JK', 'Voka', 'FC', 'Concordia', 'SK', 'Koeru', 'FC'): {'ORG': 1},
#  ('MS',): {'ORG': 1},
#  ('Kehra',): {'ORG': 1},
#  ('FC', 'Warrior', 'Valga', 'FC'): {'ORG': 1},
#  ('Kopli',): {'PER': 1},
#  ('Tartu', 'FC'): {'ORG': 1},
#  ('Eesti', 'Telefoni', 'SK'): {'ORG': 1},
#  ('SK',): {'ORG': 1},
#  ('SK', 'FC', 'Hansa'): {'ORG': 1},
#  ('JK', 'Roosna-Alliku', 'Emmaste'): {'ORG': 1},
#  ('JK',): {'ORG': 1},
#  ('K', 'Kristiine', 'JK', 'Tartu', 'JK', 'KPMG'): {'ORG': 1},
#  ('JK', 'Vana'): {'ORG': 1},
#  ('FC', 'Reaal', 'Raasiku', 'JK', 'FC'): {'ORG': 1},
#  ('Paolo',): {'PER': 1},
#  ('Rene',): {'PER': 4},
#  ('Egil',): {'PER': 2},
#  ('Frode',): {'PER': 2},
#  ('Dag',): {'PER': 2},
#  ('Ole', 'Einar'): {'PER': 2},
#  ('Marco',): {'PER': 1},
#  ('Alexander',): {'PER': 1},
#  ('Ricco',): {'PER': 1},
#  ('Julien',): {'PER': 1},
#  ('Raphael',): {'PER': 1},
#  ('Ivan',): {'PER': 2},
#  ('Roman',): {'PER': 4},
#  ('Zdenek',): {'PER': 1},
#  ('Wilfried',): {'PER': 1},
#  ('Ateena',): {'ORG': 1},
#  ('Zagrebi', 'Cibona'): {'ORG': 1},
#  ('Bologna',): {'ORG': 1},
#  ('Charleroi', "'"): {'ORG': 1},
#  ('Vitoria', 'TAU'): {'ORG': 1},
#  ('Peterburi',): {'ORG': 1},
#  ('Treviso',): {'ORG': 1},
#  ('Madridi',): {'ORG': 1},
#  ('Verona',): {'ORG': 1},
#  ('Saloniki',): {'ORG': 1},
#  ('Podgorica', 'KK'): {'ORG': 1},
#  ('Salt', 'Lake'): {'LOC': 1, 'ORG': 2},
#  ('Johann',): {'PER': 2},
#  ('Christian',): {'PER': 1},
#  ('Christian', 'Hoffmann'): {'PER': 1},
#  ('Cristian',): {'PER': 1},
#  ('Pietro', 'Piller'): {'PER': 1},
#  ('Fulvio',): {'PER': 1},
#  ('Justin',): {'PER': 1},
#  ('Centa',): {'PER': 1},
#  ('Mihhail', 'Botvinov'): {'PER': 1},
#  ('Gerhard', 'Urain'): {'PER': 1},
#  ('Fabio',): {'PER': 1},
#  ('Achim', 'Walcher'): {'PER': 1},
#  ('Markus', 'Hasler'): {'PER': 1},
#  ('Hiroyuki', 'Imai'): {'PER': 1},
#  ('Reto',): {'PER': 1},
#  ('Bundi',): {'PER': 1},
#  ('Emmanuel',): {'PER': 1},
#  ('Wilhelm',): {'PER': 1},
#  ('Jan', 'Jacob'): {'PER': 1},
#  ('Juan', 'Jesus'): {'PER': 1},
#  ('Alexander', 'Marent'): {'PER': 1},
#  ('Robert',): {'PER': 3},
#  ('Alexandre',): {'PER': 1},
#  ('Christopher',): {'PER': 4},
#  ('Lea',): {'PER': 6},
#  ('Eesti', 'Bowlingu'): {'ORG': 5},
#  ('Folger', 'Art'): {'ORG': 1},
#  ('Eero',): {'PER': 1},
#  ('Jajaa',): {'ORG': 1},
#  ('Mervi',): {'PER': 1},
#  ('Piia',): {'PER': 1},
#  ('Triip', 'Grupp'): {'ORG': 1},
#  ('Inga',): {'PER': 1},
#  ('Hansaprint',): {'ORG': 1},
#  ('Bowling', 'European'): {'ORG': 1},
#  ('Reija',): {'PER': 1},
#  ('Pasi',): {'PER': 1},
#  ('Jussi',): {'PER': 1},
#  ('Petri',): {'PER': 1},
#  ('Sami',): {'PER': 1},
#  ('Olli',): {'PER': 1},
#  ('Ari',): {'PER': 1},
#  ('Soome', 'Bowlingu'): {'ORG': 2, 'LOC': 1},
#  ('Baltic',): {'ORG': 2},
#  ('Suomen',): {'PER': 1},
#  ('Uponor',): {'ORG': 1},
#  ('Rank',): {'ORG': 1},
#  ('ISKU',): {'ORG': 1},
#  ('Kone',): {'ORG': 1},
#  ('Lemminkäinen',): {'ORG': 1},
#  ('Valio',): {'ORG': 1},
#  ('Raisio',): {'PER': 1},
#  ('Soome', 'Firmabowlingu'): {'ORG': 1},
#  ('Gunnar',): {'PER': 5},
#  ('Aleksander',): {'ORG': 1, 'PER': 2},
#  ('Valju',): {'PER': 1},
#  ('Ella',): {'PER': 1},
#  ('Harry',): {'PER': 4},
#  ('Meelis',): {'PER': 4},
#  ('Eesti', 'Rahva'): {'ORG': 1},
#  ('Anži',): {'PER': 1},
#  ('Anži', 'FC'): {'ORG': 1},
#  ('Anžile',): {'PER': 1},
#  ('Maardu',): {'ORG': 1},
#  ('Diego',): {'PER': 2},
#  ('Dundee',): {'ORG': 1},
#  ('Claudio',): {'PER': 1},
#  ('Martina',): {'PER': 1},
#  ('Kim',): {'PER': 1},
#  ('Melanie',): {'PER': 1},
#  ('Itaalia',): {'ORG': 1},
#  ('Gert',): {'PER': 2},
#  ('Oostende',): {'ORG': 2},
#  ('FIBA',): {'ORG': 1},
#  ('Damir',): {'PER': 1},
#  ('Predrag',): {'PER': 1},
#  ('Efes',): {'ORG': 1},
#  ('Lucien', 'Van'): {'PER': 1},
#  ('Rauno',): {'PER': 2},
#  ('Jon',): {'PER': 2},
#  ('Ralph',): {'PER': 1},
#  ('Virginijus',): {'ORG': 1},
#  ('Markko',): {'PER': 4},
#  ('Mariine',): {'ORG': 3},
#  ('Subaru',): {'PER': 7},
#  ('Monte',): {'ORG': 3, 'LOC': 1},
#  ('Richard',): {'PER': 5},
#  ('Toshihiro',): {'PER': 2},
#  ('Marek',): {'PER': 3},
#  ('Kristiansandi',): {'ORG': 1},
#  ('Tor',): {'ORG': 1},
#  ('Stig',): {'PER': 1},
#  ('Teitur',): {'PER': 1},
#  ('Roobale',): {'LOC': 1},
#  ('Kristen',): {'PER': 1},
#  ('Harald',): {'PER': 1},
#  ('Reinbok',): {'PER': 1},
#  ('Ando',): {'PER': 1},
#  ('Kristina',): {'PER': 7},
#  ('Bente',): {'PER': 2},
#  ('Beckie',): {'PER': 3},
#  ('Gabriella',): {'PER': 2},
#  ('Stefania',): {'PER': 2},
#  ('Peep',): {'PER': 9},
#  ('KK',): {'ORG': 3},
#  ('A.Le',): {'PER': 10},
#  ('Edmunds',): {'PER': 1},
#  ('Kaur',): {'PER': 1},
#  ('Kaido',): {'PER': 4},
#  ('Harri',): {'PER': 2},
#  ('Le',): {'PER': 5, 'ORG': 1},
#  ('Ida-Virumaa',): {'LOC': 1},
#  ('Margit',): {'PER': 1},
#  ('Ville',): {'PER': 1},
#  ('KK', 'Rakvere'): {'ORG': 1},
#  ('Nybit',): {'PER': 1},
#  ('A. Le',): {'PER': 9},
#  ('Vallo',): {'PER': 1},
#  ('Rummat', 'Chris'): {'PER': 1},
#  ('Raido',): {'PER': 1},
#  ('Märtin',): {'PER': 1},
#  ('Petter',): {'ORG': 1},
#  ('Reuters', '/'): {'ORG': 2},
#  ('Hossam',): {'PER': 1},
#  ('Lothar',): {'PER': 1},
#  ('Garri',): {'PER': 1},
#  ('Viswanathan',): {'PER': 1},
#  ('Jens',): {'PER': 1},
#  ('Samppa',): {'PER': 1},
#  ('Lake',): {'LOC': 1},
#  ('Kristina', 'Stefania'): {'PER': 1},
#  ('Gabriela',): {'PER': 1},
#  ('Lembit',): {'PER': 1},
#  ('Judit',): {'PER': 1},
#  ('Jan',): {'PER': 2},
#  ('Hendrik',): {'PER': 4},
#  ('Pai',): {'ORG': 1},
#  ('Gaston',): {'PER': 4},
#  ('Jean',): {'PER': 4},
#  ('Alain',): {'PER': 4},
#  ('Elite',): {'ORG': 1},
#  ('Reval', 'Hotels'): {'ORG': 1},
#  ('Reval',): {'PER': 1},
#  ('Raadio',): {'PER': 1, 'ORG': 1},
#  ('Wõro',): {'PER': 1},
#  ('Tauno',): {'PER': 1},
#  ('Aado',): {'PER': 2},
#  ('ASi', 'ESS'): {'ORG': 1},
#  ('Pankade', 'Kaardikeskuse'): {'ORG': 2},
#  ('Tallinnna',): {'ORG': 1},
#  ('Harju',): {'ORG': 3},
#  ('Magnum',): {'ORG': 1},
#  ('Kalev',): {'PER': 3},
#  ('Rahvaerakond',): {'ORG': 1},
#  ('Eestimaa',): {'ORG': 5},
#  ('Sotsiaaldemokraatlik',): {'ORG': 3},
#  ('Ühendatud',): {'ORG': 2},
#  ('Põllumeeste',): {'ORG': 2},
#  ('Vene', 'Balti'): {'LOC': 2},
#  ('Vene',): {'ORG': 4, 'LOC': 1},
#  ('Kristlik',): {'ORG': 2},
#  ('Einar',): {'PER': 4},
#  ('Eesti', 'Kohtunike'): {'ORG': 1},
#  ('Allar',): {'PER': 2},
#  ('Uno',): {'PER': 1},
#  ('Märt',): {'PER': 5},
#  ('Aase',): {'PER': 1},
#  ('Lennart',): {'PER': 14},
#  ('Leo',): {'PER': 5},
#  ('Eesti', 'Rahvusliku', 'Sõltumatuse'): {'ORG': 1},
#  ('Moora',): {'PER': 1},
#  ('Lissaboni',): {'ORG': 1},
#  ('Göteborgi',): {'ORG': 1},
#  ('Euroopa', 'Liidu'): {'ORG': 1},
#  ('Robert', 'de'): {'PER': 1},
#  ('Elvis',): {'ORG': 1},
#  ('Järvamaa',): {'ORG': 1},
#  ('Justiistministeeriumi',): {'ORG': 1},
#  ('Murru',): {'ORG': 1},
#  ('ETAle',): {'ORG': 5},
#  ('Kristiina',): {'PER': 2},
#  ('Norimasa',): {'ORG': 1},
#  ('Elisabet', 'Borsiin'): {'PER': 1},
#  ('Toomas', 'Hendrik'): {'PER': 9},
#  ('Göran',): {'PER': 2},
#  ('Alar',): {'PER': 2},
#  ('Philip',): {'PER': 1},
#  ('Rahvaerakonna',): {'ORG': 1},
#  ('Liisa',): {'PER': 6},
#  ('Eesti', 'Teadlaste'): {'ORG': 1},
#  ('Riigikogu',): {'ORG': 1},
#  ('Jürgen',): {'PER': 3},
#  ('Väino',): {'PER': 2},
#  ('Paikuse',): {'ORG': 1},
#  ('Ülo',): {'PER': 7},
#  ('Mustamäe',): {'ORG': 3},
#  ('Andrus',): {'PER': 2},
#  ('AS-idele', 'Hansa'): {'ORG': 1},
#  ('Hoiupanga',): {'ORG': 1},
#  ('Meri',): {'PER': 2},
#  ('Valga',): {'ORG': 1},
#  ('Elmut',): {'PER': 1},
#  ('Merit',): {'PER': 2},
#  ('Mati',): {'PER': 5},
#  ('Vahur',): {'PER': 3},
#  ('Ants',): {'PER': 3},
#  ('Küllike',): {'ORG': 1},
#  ('Nõmme',): {'ORG': 1},
#  ('Villu',): {'PER': 2},
#  ('AS', 'Eesti'): {'ORG': 1},
#  ('Liina',): {'PER': 1},
#  ('Pankade',): {'ORG': 1},
#  ('Jaanus',): {'PER': 3},
#  ('Igors',): {'PER': 1},
#  ('Artur',): {'PER': 1},
#  ('Agnes',): {'PER': 1},
#  ('Järva',): {'LOC': 1},
#  ('Riigikogu', 'Eestimaa'): {'ORG': 1},
#  ('Eerik-Juhan',): {'PER': 1},
#  ('Jaano',): {'PER': 1},
#  ('Eerik',): {'PER': 1},
#  ('Helve',): {'PER': 1},
#  ('Madis',): {'PER': 2},
#  ('LÜNGAD',): {'PER': 1},
#  ('Vanemõe',): {'ORG': 1},
#  ('Raviarst',): {'PER': 1},
#  ('Merle',): {'PER': 1},
#  ('Pekka',): {'PER': 2},
#  ('Skandinaavia',): {'LOC': 1},
#  ('Algirdas',): {'PER': 2},
#  ('Aet',): {'PER': 1},
#  ('Brunhild-Dorothea',): {'PER': 1},
#  ('Sirje', 'Rõõmu'): {'ORG': 1},
#  ('Oole',): {'PER': 2},
#  ('Merike',): {'PER': 1},
#  ('kapo', 'ja'): {'ORG': 1},
#  ('Alan',): {'PER': 4},
#  ('Anonüümsete',): {'ORG': 1},
#  ('Tervis',): {'ORG': 2},
#  ('Tartus',): {'LOC': 1},
#  ('Jämejala',): {'ORG': 1},
#  ('Artjom',): {'PER': 1},
#  ('Kashpirovski',): {'ORG': 1},
#  ('Aili',): {'PER': 2},
#  ('Kaja',): {'PER': 2},
#  ('Gea',): {'PER': 1},
#  ('Heido',): {'PER': 6},
#  ('Nüpli',): {'LOC': 1},
#  ('Palupera', 'Räbi'): {'ORG': 1},
#  ('Arvin',): {'PER': 2},
#  ('Otepää',): {'ORG': 1},
#  ('Otepääl',): {'ORG': 1},
#  ('Vello',): {'PER': 2},
#  ('Meema',): {'PER': 1},
#  ('Kääriku-Tehvandi',): {'ORG': 1},
#  ('Räbi',): {'ORG': 1},
#  ('Tartu', 'Ülikooli'): {'ORG': 1},
#  ('Veiko',): {'PER': 1},
#  ('Agne',): {'PER': 1},
#  ('JA',): {'PER': 2},
#  ('Atko',): {'PER': 3},
#  ('Valdeko',): {'PER': 1},
#  ('Ernst',): {'PER': 1},
#  ('Tbilisi',): {'ORG': 1},
#  ('Fred',): {'PER': 2},
#  ('Konstantin',): {'PER': 6},
#  ('McDonald', "'"): {'PER': 6, 'ORG': 1},
#  ('Alansi',): {'LOC': 2},
#  ('Helle',): {'PER': 3},
#  ('Mustamäe', 'McDonald', "'"): {'ORG': 1},
#  ('Wastewise',): {'PER': 1},
#  ('Ragn',): {'PER': 3},
#  ("McDonald's",): {'ORG': 1},
#  ('Dmitri',): {'PER': 1},
#  ('Taimar',): {'PER': 1},
#  ('Kanal',): {'ORG': 2},
#  ('"',): {'ORG': 2},
#  ('Alla',): {'PER': 1},
#  ('Mait',): {'PER': 3},
#  ('Kersti',): {'PER': 4},
#  ('Valeri',): {'PER': 3},
#  ('Krista',): {'PER': 2},
#  ('Tallinna-Pärnu', 'ja'): {'LOC': 1},
#  ('GB',): {'ORG': 4, 'PER': 1},
#  ('Rahvuslik-Demokraatlike', 'Jõudude'): {'ORG': 1},
#  ('Tatjana',): {'PER': 5},
#  ('Nelli',): {'PER': 2},
#  ('Evi',): {'PER': 2},
#  ('Sigrid',): {'PER': 2},
#  ('Osaühingu', 'Forniks'): {'ORG': 1},
#  ('Svetlana',): {'PER': 2},
#  ('Galina',): {'PER': 2},
#  ('Aktsiaselts',): {'PER': 1},
#  ('Erakliinik',): {'PER': 1},
#  ('Osaühing',): {'PER': 2},
#  ('TOP',): {'ORG': 1},
#  ('Inna',): {'PER': 7},
#  ('Vaivara',): {'LOC': 1, 'ORG': 1},
#  ('Utria',): {'LOC': 1},
#  ('Aki',): {'PER': 1},
#  ('Kaitseliidu',): {'ORG': 1},
#  ('Piirivalve', 'Narva-Jõesuu'): {'ORG': 1},
#  ('Viktor',): {'PER': 3},
#  ('Chris', "Moore'i"): {'PER': 1},
#  ('Hüüdnimi',): {'PER': 1},
#  ('BC',): {'ORG': 1},
#  ('Põllumajanduse',): {'ORG': 1},
#  ('Informatsiooni',): {'ORG': 1},
#  ('Heli',): {'PER': 2},
#  ('Aire',): {'PER': 1},
#  ('Aldo',): {'PER': 1},
#  ('Rocco',): {'PER': 1},
#  ('Moskva', 'Rahvusvaheliste', 'Suhete'): {'ORG': 1},
#  ('Konstantin', 'Provalov', 'Venemaa'): {'ORG': 1},
#  ('AS-iga',): {'ORG': 1},
#  ('Sarnito',): {'LOC': 1},
#  ('Saar',): {'ORG': 1, 'PER': 1},
#  ('Galsgow',): {'ORG': 1},
#  ('Kai',): {'PER': 2},
#  ('Kaupo',): {'PER': 1},
#  ('Epl',): {'ORG': 2},
#  ('Väike',): {'ORG': 1},
#  ('Sakari',): {'PER': 1},
#  ('Silver',): {'PER': 1},
#  ('Tuuli',): {'PER': 1},
#  ('Milvi',): {'PER': 2, 'ORG': 1},
#  ('EE', 'Teeninduse'): {'ORG': 1},
#  ('Riina',): {'PER': 1},
#  ('Ettevõtluse', 'Arendamise'): {'ORG': 1},
#  ('JAGAMINE',): {'PER': 1},
#  ('Mall',): {'PER': 1},
#  ('Eckerö',): {'ORG': 1},
#  ('Marika',): {'PER': 1},
#  ('Yrjö',): {'PER': 1},
#  ('ESS',): {'ORG': 1},
#  ('Oliver',): {'PER': 1},
#  ('Niinepuu',): {'PER': 1},
#  ('Kristel',): {'PER': 2},
#  ('Hain',): {'PER': 1},
#  ('Gregg',): {'PER': 1},
#  ('Jutta',): {'PER': 1},
#  ('Henning',): {'PER': 1},
#  ('Eesti', 'Kirikute'): {'ORG': 2},
#  ('Kärt',): {'PER': 1},
#  ('Aino',): {'PER': 2},
#  ('Raul-Roman',): {'PER': 1},
#  ('Tanja',): {'PER': 1},
#  ('Henn',): {'PER': 1},
#  ('Irina',): {'PER': 1},
#  ('Hilda',): {'PER': 1},
#  ('Otte',): {'PER': 1},
#  ('Anatoli',): {'PER': 1},
#  ('Koola',): {'LOC': 1},
#  ('Vaikse',): {'LOC': 1},
#  ('Jaapani',): {'LOC': 1},
#  ('Barentsi',): {'LOC': 1},
#  ('Kongo',): {'LOC': 1},
#  ('Edite',): {'PER': 1},
#  ('Palestiina',): {'ORG': 1},
#  ('Hikmat',): {'PER': 1},
#  ('Prantsuse',): {'ORG': 2, 'LOC': 1},
#  ('Demokraatlik',): {'ORG': 1},
#  ('Vytenis',): {'PER': 1},
#  ('RIA',): {'ORG': 1},
#  ('Demokraatlikku',): {'ORG': 1},
#  ('Abdul', 'Razzaq'): {'PER': 1},
#  ('Vaira',): {'PER': 1},
#  ('Vitali',): {'PER': 1},
#  ('Vojislav',): {'PER': 1},
#  ('Podgorica',): {'ORG': 1},
#  ('Osama', 'bin'): {'PER': 5},
#  ('Bin',): {'PER': 3},
#  ('Föderaalse',): {'ORG': 1},
#  ('USA',): {'LOC': 2, 'ORG': 3},
#  ('William', 'Cohen'): {'PER': 1},
#  ('Rahvuslikus',): {'ORG': 1},
#  ('Pentagoni',): {'ORG': 1},
#  ('Dennis',): {'PER': 1},
#  ('Nezavissimaja',): {'ORG': 2},
#  ('Cold', 'Spring'): {'PER': 1},
#  ('Johns', "Hopkins'i"): {'ORG': 1},
#  ('Lao',): {'PER': 2, 'ORG': 2},
#  ('Ciangmai',): {'LOC': 1},
#  ('Briti',): {'ORG': 1},
#  ('Pärsia',): {'LOC': 1},
#  ('John', 'Spellari'): {'PER': 1},
#  ('Tobias',): {'PER': 1},
#  ('Colombia',): {'ORG': 1},
#  ('Medellini', 'El', 'Tesoro'): {'ORG': 1},
#  ('Leoncio',): {'PER': 1},
#  ('Colombia', 'Revolutsioonilised'): {'ORG': 1},
#  ('Rahvusliku',): {'ORG': 1},
#  ('Biljana',): {'PER': 2},
#  ('Haagi',): {'ORG': 1},
#  ('Radovan',): {'PER': 1},
#  ('Serbia', 'Demokraatliku'): {'ORG': 1},
#  ('Momcilo',): {'PER': 1},
#  ('NSV',): {'LOC': 3},
#  ('Gerhard',): {'PER': 2},
#  ('Renate',): {'PER': 2},
#  ('Karl-Heinz',): {'PER': 1},
#  ('Mei',): {'PER': 3},
#  ('Tian',): {'PER': 3},
#  ('Lucy',): {'PER': 1},
#  ('Liu',): {'PER': 1},
#  ('Washington',): {'ORG': 2},
#  ('Likud',): {'ORG': 1},
#  ('Ariel',): {'PER': 3},
#  ('Ehud',): {'PER': 3},
#  ('Silvan',): {'PER': 1},
#  ('Ultraortodoksne',): {'PER': 1},
#  ('Jordani',): {'LOC': 1},
#  ('Amnon',): {'PER': 1},
#  ('NTV',): {'ORG': 1},
#  ('Little',): {'ORG': 1},
#  ('Associated', 'Press'): {'ORG': 1},
#  ('Wonderland',): {'PER': 2},
#  ('Grünstein', 'Product'): {'ORG': 1},
#  ('Kirsti',): {'PER': 5},
#  ('Oikeutta',): {'PER': 1, 'ORG': 1},
#  ('Hartwall',): {'PER': 1},
#  ('Chi',): {'PER': 1},
#  ('Ho', 'Chi'): {'PER': 10},
#  ('Hanoi',): {'ORG': 1},
#  ('In',): {'ORG': 1},
#  ('Ameerika', 'Sõjakuritegude'): {'ORG': 1},
#  ('War', 'Remnants'): {'ORG': 1},
#  ('Indohiina',): {'LOC': 1},
#  ('Vietnami', 'Demokraatliku'): {'ORG': 1},
#  ('Nho', 'Dinh'): {'PER': 1},
#  ...}

# %%
# making first words mapping keys strings to allow convenient dataframe creation
first_words_map = {str(k):v for k,v in first_words_map.items()}

# %%
last_word_map
# Out:
# {'välisministeeriumi': {'ORG': 3},
#  'Clinton': {'PER': 3},
#  'Araabia': {'LOC': 3},
#  'Kanguse': {'PER': 1},
#  'Telekomi': {'ORG': 5},
#  'Mõisa': {'PER': 3},
#  'Voogi': {'PER': 1},
#  'Vee': {'ORG': 2},
#  'Liidu': {'ORG': 15, 'LOC': 18},
#  'statistikaamet': {'ORG': 1},
#  'Soojuse': {'ORG': 4},
#  'Virkus': {'PER': 1},
#  'Viisemann': {'ORG': 1},
#  'Kivimaa': {'PER': 2},
#  'Kapitali': {'ORG': 3},
#  'Pärnoja': {'PER': 2},
#  "GSM'il": {'ORG': 1},
#  'GSMi': {'ORG': 7},
#  'Ühendriikidesse': {'LOC': 1},
#  'Adusoni': {'PER': 1},
#  'Panga': {'ORG': 11},
#  'Ross': {'PER': 1},
#  'Saarniit': {'PER': 2},
#  'Keskpank': {'ORG': 1},
#  'Vabrikud': {'ORG': 1},
#  'Vabrikute': {'ORG': 1},
#  'Karon': {'PER': 1},
#  'riikides': {'LOC': 4},
#  'Kruuda': {'PER': 1},
#  'Vabrikutes': {'PER': 1},
#  'Suurväli': {'PER': 2},
#  'börsi': {'ORG': 1},
#  'Keskdepositooriumiga': {'ORG': 1},
#  'maakohus': {'ORG': 1},
#  'Kolbakovile': {'PER': 1},
#  'Meoselt': {'PER': 1},
#  'Meose': {'PER': 1},
#  'Arengupangale': {'ORG': 1},
#  'Arengupanga': {'ORG': 2},
#  'Mõttusele': {'PER': 2},
#  'Kentexi': {'ORG': 1},
#  'Kentex': {'ORG': 1},
#  'Kolbakoviga': {'PER': 1},
#  'Ressarilt': {'PER': 1},
#  'Pangas': {'ORG': 1},
#  'ASil': {'ORG': 1},
#  'Tehased': {'ORG': 2},
#  'AS': {'ORG': 5},
#  'Kugnieciba': {'PER': 1},
#  'LNNK': {'ORG': 2},
#  'Grinblats': {'PER': 1},
#  'Škelega': {'ORG': 1},
#  'Tavid': {'ORG': 2},
#  'Rääk': {'PER': 1},
#  'Ühendemiraatide': {'ORG': 1},
#  'Konjunktuuriinstituudi': {'ORG': 1},
#  'Berdal': {'PER': 1},
#  'Uulits': {'PER': 1},
#  'Treude': {'PER': 3},
#  'Ida-Euroopa': {'ORG': 1},
#  'Singer': {'PER': 1},
#  'News': {'ORG': 1},
#  'Berdali': {'ORG': 1},
#  'Singeri': {'PER': 1},
#  'Leedu': {'LOC': 2},
#  'Media': {'PER': 4, 'LOC': 1},
#  'Statistikaamet': {'ORG': 1},
#  'Turu-uuringute': {'ORG': 1},
#  '2000': {'ORG': 2},
#  'Frens': {'ORG': 2},
#  'Riigivarafond': {'ORG': 2},
#  'Line': {'ORG': 4},
#  'Stankevicius': {'PER': 1},
#  'Paulauskas': {'PER': 1},
#  'Makauskas': {'PER': 1},
#  'Peensoo': {'PER': 4},
#  'linnavolikogus': {'ORG': 1},
#  'Kallaste': {'PER': 1},
#  'Tapver': {'PER': 5},
#  'Sebe': {'ORG': 1},
#  'Buss': {'ORG': 3, 'PER': 1},
#  'jm.': {'LOC': 1},
#  'Ametiühingu': {'ORG': 1},
#  'Tatter': {'PER': 1},
#  'Päevalehele': {'ORG': 3},
#  'Leht': {'PER': 2},
#  'Avialinijos': {'ORG': 1},
#  'Striaukas': {'PER': 1},
#  'Savinis': {'PER': 1},
#  'Latvenergo': {'ORG': 1},
#  'BNS-le': {'ORG': 1},
#  'Teest': {'ORG': 1},
#  'Rahvaerakonnast': {'ORG': 1},
#  'Vinkelis': {'ORG': 1},
#  'Vabadusele': {'ORG': 1},
#  'Partei': {'ORG': 2},
#  'Grinvalds': {'PER': 1},
#  'Kalvitise': {'PER': 1},
#  'Erastamisagentuuri': {'ORG': 1},
#  'Linkaits': {'ORG': 1},
#  'Tehnikaülikooli': {'ORG': 2},
#  'Ribickis': {'PER': 1},
#  'S': {'ORG': 1},
#  'Pank': {'ORG': 6},
#  'Handelsbanken': {'PER': 1},
#  'Cementas': {'PER': 1},
#  'Cementasi': {'PER': 1},
#  'Kristopaitis': {'PER': 1},
#  'Cementase': {'PER': 1},
#  'Repše': {'PER': 2},
#  'Hansatee': {'ORG': 2},
#  'KPMG': {'ORG': 1},
#  'Hunt': {'PER': 2},
#  'Liidult': {'ORG': 2},
#  'Laari': {'PER': 2},
#  'Nafta': {'ORG': 2, 'PER': 3},
#  'Internationali': {'PER': 1},
#  'Bumgarner': {'PER': 1},
#  'Naftale': {'PER': 2},
#  'Abisala': {'PER': 1},
#  'valitsus': {'ORG': 5},
#  'Lionginas': {'PER': 1},
#  'Naftal': {'PER': 2},
#  'Adamkuse': {'PER': 1},
#  'Pakšasega': {'PER': 1},
#  'Elektrijaamade': {'ORG': 1},
#  'Energia': {'ORG': 8},
#  'Peegel': {'PER': 1},
#  "AS'i": {'ORG': 1},
#  'liikluskindlustuse': {'ORG': 1},
#  'Varakindlustuse': {'ORG': 1},
#  'Rumessen': {'PER': 1},
#  'EA': {'PER': 1},
#  'Ruusalu': {'PER': 2},
#  'Järve': {'PER': 3},
#  'MRI': {'ORG': 2},
#  'Oro': {'PER': 1},
#  'Ruutsoo': {'PER': 1},
#  'Kindsigo': {'PER': 1},
#  'audiitor': {'ORG': 1},
#  'Arnover': {'PER': 1},
#  'Liit': {'ORG': 8, 'LOC': 3},
#  'Rosengren': {'PER': 2},
#  'Liidus': {'ORG': 2, 'LOC': 4},
#  'Komisjoni': {'ORG': 3},
#  'Liikaneniga': {'PER': 1},
#  'Netcom': {'ORG': 1},
#  'Sonera': {'ORG': 2},
#  'Securitiese': {'PER': 1},
#  'Graversen': {'PER': 1},
#  'Industri': {'ORG': 1},
#  'International': {'ORG': 1},
#  'Mobili': {'ORG': 1},
#  'Strand': {'PER': 1},
#  'GSM': {'ORG': 1},
#  'GSM-i': {'ORG': 1},
#  'Jaaksoo': {'PER': 1},
#  'Tele2': {'ORG': 1},
#  'Telefoni': {'ORG': 4},
#  'Ruokatalo': {'ORG': 2},
#  'Linnulihatooted': {'ORG': 1},
#  'Linnulihatoodete': {'ORG': 1},
#  'Lihakombinaat': {'ORG': 1},
#  'Aavik': {'PER': 2},
#  'Postimehele': {'ORG': 2},
#  'Edela': {'PER': 1},
#  'SEBE': {'ORG': 2},
#  'linna': {'LOC': 7},
#  'Soojus': {'ORG': 2, 'PER': 1},
#  'Eraküte': {'ORG': 1},
#  'Schnur': {'PER': 1},
#  'Elule': {'ORG': 1},
#  'Uksetehaselt': {'ORG': 1},
#  'Paju': {'PER': 4},
#  'Jairus': {'PER': 1},
#  "Inc'ile": {'PER': 1},
#  'Yorgis': {'LOC': 2, 'ORG': 2},
#  'Inc': {'PER': 2, 'ORG': 2},
#  'Kallas': {'PER': 3},
#  'Suurvälja': {'PER': 1},
#  'Lex': {'ORG': 1},
#  'ülikoolis': {'ORG': 3},
#  'õppekeskuses': {'ORG': 1},
#  'vallavalitsuses': {'ORG': 1},
#  'The': {'PER': 1},
#  'Times': {'ORG': 8},
#  'Honma': {'PER': 1},
#  'Banki': {'ORG': 2},
#  'Taevas': {'PER': 1},
#  'Osaka': {'PER': 1},
#  'Mori': {'PER': 1},
#  'Komitee': {'ORG': 1},
#  'Tsushini': {'PER': 1},
#  'Life': {'PER': 1, 'ORG': 1},
#  'Lynchist': {'PER': 1},
#  'Miyazawa': {'PER': 1},
#  'saari': {'LOC': 1},
#  'Porter': {'PER': 1},
#  'Neivelt': {'PER': 2},
#  'Gruppi': {'ORG': 1},
#  'Pekk': {'PER': 1},
#  'Grupi': {'ORG': 5},
#  'Hoiupanga': {'ORG': 1},
#  'Grupp': {'ORG': 2, 'PER': 2},
#  'KANGUR': {'PER': 1},
#  'Nordbankeni': {'PER': 1},
#  'Taanis': {'ORG': 1},
#  'pank': {'ORG': 1},
#  'Joosu': {'PER': 1},
#  'Järvaniga': {'PER': 1},
#  'Vaarik': {'PER': 1},
#  'Lõhmus': {'PER': 4},
#  'Ühendriikides': {'LOC': 1},
#  'Kuusk': {'PER': 2},
#  'Kukk': {'PER': 3},
#  'Vahar': {'PER': 1},
#  'linnavalitsuse': {'ORG': 3},
#  'Praxis': {'ORG': 1},
#  'büroos': {'ORG': 2},
#  'Uudam': {'PER': 1},
#  'Kangur': {'PER': 1},
#  'Kunila': {'PER': 3},
#  'Käo': {'PER': 3},
#  'Veskimäge': {'PER': 1},
#  'Investeeringud': {'ORG': 3},
#  'Grupist': {'ORG': 1},
#  'Gateski': {'PER': 1},
#  'Autolivile': {'ORG': 1},
#  'Kaubamajja': {'ORG': 1},
#  'Investeeringutes': {'ORG': 1},
#  'Liviko': {'ORG': 2},
#  'Kaubamaja': {'ORG': 3},
#  'ketti': {'ORG': 1},
#  '6e': {'ORG': 1},
#  'Mare': {'LOC': 1},
#  'Investeeringute': {'ORG': 1},
#  'Vanaselja': {'PER': 1},
#  'Järving': {'PER': 1},
#  'Siemens': {'ORG': 1},
#  'Lego': {'ORG': 1},
#  'Gates': {'PER': 2},
#  'Lykkegaard': {'PER': 1},
#  'Straw': {'PER': 1},
#  'UK': {'LOC': 1},
#  'Brown': {'PER': 2},
#  'Bankeni': {'ORG': 1},
#  'Tsimailo': {'PER': 1},
#  'Trošini': {'PER': 1},
#  'Gussinski': {'PER': 4},
#  'ülemkohtusse': {'ORG': 1},
#  'Garzoni': {'PER': 1},
#  'vanglasse': {'ORG': 1},
#  'Most': {'ORG': 3, 'PER': 2},
#  'Mosti': {'PER': 1, 'ORG': 1},
#  'Bankile': {'ORG': 1},
#  'Mediale': {'LOC': 1, 'PER': 1},
#  'Turner': {'PER': 2},
#  'Deljagin': {'PER': 1},
#  'Vejins': {'PER': 1},
#  'Ltd': {'ORG': 1},
#  'Banka': {'ORG': 2},
#  'Štšetinin': {'PER': 1},
#  'Zeltins': {'PER': 1},
#  'Linnavaraamet': {'ORG': 1},
#  'lahe': {'LOC': 3},
#  'Elamumajandusametile': {'ORG': 1},
#  'Logi': {'PER': 1},
#  'Kesklinna': {'LOC': 3},
#  'Loto': {'ORG': 1},
#  'Lotos': {'ORG': 1},
#  'linn': {'LOC': 3},
#  'Vesi': {'ORG': 5},
#  'Utilities': {'ORG': 1},
#  'Mõis': {'PER': 4},
#  'Tiiter': {'PER': 1},
#  'UU-d': {'ORG': 1},
#  'UU': {'ORG': 2, 'PER': 1},
#  'Lowe': {'PER': 1},
#  "International'i": {'ORG': 1},
#  'Waters': {'PER': 1},
#  "Water'i": {'ORG': 1},
#  'Jeantet': {'PER': 1},
#  'Squire': {'PER': 1},
#  'Suursaatkonna': {'ORG': 1},
#  'Securities': {'PER': 1},
#  'Piimaühistu': {'ORG': 2},
#  'Pächteri': {'PER': 1},
#  'Piimaühistule': {'ORG': 1},
#  'PÜ': {'ORG': 2},
#  'Steinberg': {'PER': 1},
#  'Maadvere': {'PER': 1},
#  'Ühendriikidest': {'LOC': 1},
#  'Ilmarise': {'ORG': 1},
#  'mnt': {'LOC': 1},
#  'Kapitalil': {'ORG': 1},
#  'Kapital': {'ORG': 1},
#  'Raadio': {'ORG': 1},
#  'Ookean': {'ORG': 1},
#  'Hooldushaigla': {'ORG': 1},
#  'Visnapuu': {'PER': 1},
#  'SuperNetto': {'ORG': 1},
#  'Kaubahall': {'ORG': 2},
#  'Ärikeskus': {'ORG': 1},
#  'Sauk': {'PER': 1},
#  'Estiko': {'ORG': 1},
#  'Ärikeskuse': {'ORG': 1},
#  'A-Selver': {'ORG': 1},
#  'Selveri': {'ORG': 1},
#  'GMP': {'ORG': 1},
#  'riik': {'LOC': 6},
#  'Vaidani': {'LOC': 1},
#  'Sõrmus': {'PER': 1},
#  'Tänav': {'PER': 3},
#  'Päevaleht': {'ORG': 5},
#  'maavalitsusest': {'ORG': 1},
#  'Bussile': {'PER': 1},
#  'Bussiliinid': {'ORG': 6},
#  'Reigo': {'PER': 2, 'ORG': 1},
#  'Honkanen': {'PER': 2},
#  'Finland': {'PER': 2},
#  'Väike-Õismäe': {'ORG': 1},
#  'Savisaare': {'PER': 1},
#  'Väli': {'PER': 4},
#  'halduskohtus': {'ORG': 1},
#  'Välilt': {'PER': 3},
#  'linnakohtu': {'ORG': 6},
#  'Justitia': {'ORG': 3},
#  'Justitiale': {'ORG': 1},
#  'politsei': {'ORG': 2},
#  'Sepp': {'PER': 3},
#  'linnakohus': {'ORG': 4},
#  'Välile': {'PER': 2},
#  'ringkonnakohus': {'ORG': 1},
#  'linnakohtus': {'ORG': 2},
#  'Randvere': {'LOC': 1},
#  'linnavolikogu': {'ORG': 1},
#  'Vichmannilt': {'PER': 1},
#  'Lasn': {'PER': 1},
#  'Reapi': {'PER': 1},
#  'Veho': {'ORG': 1},
#  'Jõgi': {'PER': 1},
#  'Aameri': {'PER': 1},
#  'Uninet': {'ORG': 1},
#  'Naviplast': {'ORG': 1},
#  'Kogan': {'PER': 1},
#  'Äripank': {'ORG': 1},
#  'Eilart': {'PER': 1},
#  'Vallavolikogu': {'ORG': 1},
#  'valda': {'LOC': 1},
#  'Vallavalitsus': {'ORG': 2},
#  'OÜ': {'ORG': 2},
#  'Maves': {'ORG': 1},
#  'Estonia': {'ORG': 2},
#  'Bain': {'PER': 1},
#  'Vereinsbank': {'ORG': 1},
#  'Tali': {'PER': 1},
#  'Depp': {'PER': 1},
#  'Eastwood': {'PER': 2},
#  'Travolta': {'PER': 1},
#  'Sikk': {'PER': 1},
#  'Kivi': {'PER': 2},
#  'Pomerants': {'PER': 1},
#  'Kivile': {'PER': 1},
#  'OOTAVAD': {'PER': 1},
#  'Gaškov': {'PER': 1},
#  'Erlach': {'PER': 1},
#  'Joala': {'PER': 2},
#  'Viilupi': {'PER': 3},
#  'Superstari': {'ORG': 1},
#  'epl': {'ORG': 2},
#  'Ühendriikide': {'LOC': 3},
#  'Kingi': {'ORG': 1},
#  'Meel': {'PER': 2},
#  'Warholi': {'PER': 8, 'ORG': 1},
#  'Warholale': {'PER': 1},
#  'Warhola': {'PER': 1},
#  'Yorki': {'ORG': 2, 'LOC': 1},
#  'Yorgi': {'ORG': 3},
#  'Angeleses': {'ORG': 1},
#  'Warhol': {'PER': 7},
#  'Hacketti': {'PER': 1},
#  'Kooningi': {'ORG': 1},
#  'Hackett': {'PER': 1},
#  'Pollocki': {'PER': 1},
#  'Valjakka': {'ORG': 1},
#  'Helsingi-näitus': {'PER': 1},
#  'Mugrabe': {'PER': 1},
#  'Louisiana': {'LOC': 1},
#  'Monroe': {'PER': 1},
#  'Hackettile': {'PER': 1},
#  'Nilsson': {'PER': 1},
#  'Factory-nimelisse': {'ORG': 1},
#  'Bitter': {'PER': 1},
#  'SHprits': {'PER': 1},
#  'Tammearu': {'PER': 1},
#  'Fomitshev': {'PER': 1},
#  'Roo': {'PER': 1},
#  'Kalda': {'PER': 2},
#  'Meriste': {'PER': 1},
#  'Ermel': {'PER': 1},
#  'jt.': {'PER': 2},
#  'Bitteri': {'PER': 1},
#  'Zhpritsi': {'PER': 1},
#  'Visnap': {'PER': 1},
#  'Linnateater': {'ORG': 2},
#  'Kultuurkapital': {'ORG': 1},
#  'Ginkase': {'PER': 1},
#  'Ginki': {'PER': 1},
#  'Marmeladova': {'PER': 1},
#  'Ivanovna': {'PER': 1},
#  'Mõsina': {'PER': 1},
#  'Ivanovnasse': {'PER': 1},
#  'Bitola': {'LOC': 1},
#  'Keerend': {'PER': 1},
#  'Wasserman': {'PER': 1},
#  'Kruusamäe': {'PER': 1},
#  'Allik': {'PER': 1},
#  'Kagovere': {'PER': 1},
#  'Eelma': {'PER': 1},
#  'Meele': {'PER': 1},
#  'Handelsblad': {'ORG': 1},
#  'Krossist': {'PER': 1},
#  'Langeveld': {'PER': 1},
#  'Lennonile': {'PER': 1},
#  'Villa': {'PER': 1},
#  'Castro': {'PER': 1},
#  "Imagine'ist": {'PER': 1},
#  'Alarcón': {'PER': 1},
#  'Keskagentuuris': {'ORG': 1},
#  'Stalini': {'PER': 1},
#  'Jefimov': {'PER': 1},
#  'Vahteri': {'PER': 1},
#  'Arhitektuurimuuseum': {'ORG': 1},
#  'Hallase': {'PER': 1},
#  'Kompuse': {'PER': 1},
#  'Kuusikule': {'PER': 1},
#  'Tammeti': {'PER': 1},
#  'Tammoja': {'PER': 1},
#  'Ojari': {'PER': 1},
#  'Sachariase': {'PER': 1},
#  'Kusmini': {'PER': 1},
#  'Review': {'ORG': 1},
#  'kohver': {'PER': 1},
#  'Treier': {'PER': 2},
#  'Exley': {'PER': 1},
#  'Kiiler': {'PER': 1},
#  'Josing': {'PER': 3},
#  'Lapin': {'PER': 1},
#  'Estland': {'PER': 1},
#  'Kurvel': {'PER': 1},
#  'Küttner': {'PER': 1},
#  'Kurreli': {'PER': 1},
#  'Alliku': {'PER': 1},
#  'Kondase': {'PER': 4},
#  'Männiste': {'PER': 1},
#  'Allikvee': {'PER': 1},
#  'Washingtoni': {'PER': 2},
#  'Washington': {'PER': 1},
#  'Ramage': {'PER': 1},
#  "Ramage'i": {'PER': 1},
#  'Christie': {'PER': 2},
#  'Priimägi': {'PER': 3, 'ORG': 1},
#  'Kunstihoones': {'ORG': 1},
#  "McBride'i": {'ORG': 1},
#  'Vespaga': {'PER': 1},
#  'Wackerbarthi': {'PER': 1},
#  'Ruschi': {'PER': 1},
#  'teater': {'ORG': 1},
#  'Schmitti': {'PER': 1},
#  'Prosa': {'PER': 1},
#  'Prikk': {'PER': 1},
#  'Sõmer': {'PER': 1},
#  'Kello': {'PER': 1},
#  'Celma': {'PER': 1},
#  'Vilu': {'PER': 1},
#  'Raud': {'PER': 1},
#  'Televisioonis': {'ORG': 1},
#  'PUUDUVAD': {'PER': 1},
#  'McKee': {'PER': 1},
#  'Sisaski': {'PER': 1},
#  'Berestovaja': {'PER': 1},
#  "Morissette'i": {'PER': 1},
#  'Vaus-tamm': {'PER': 1},
#  'Väinmaa': {'ORG': 1},
#  'Tulev': {'PER': 1},
#  'Schnittke': {'PER': 2},
#  'Kremer': {'PER': 1},
#  'Baltica': {'ORG': 1},
#  'Lipatti': {'ORG': 1},
#  'Kantšeli': {'PER': 1},
#  'Avalanche': {'ORG': 1},
#  'Jacket': {'PER': 1},
#  'Roy': {'PER': 1},
#  'Sharksi': {'ORG': 1},
#  'Nabokoviga': {'PER': 1},
#  'Wildi': {'PER': 1},
#  'Denis': {'PER': 1},
#  'Deadmarsh': {'PER': 2},
#  'Sakic': {'PER': 2},
#  'Devils': {'ORG': 1},
#  'Coyotes': {'ORG': 1},
#  'Turco': {'PER': 1},
#  'Belfouri': {'PER': 1},
#  'Trashersi': {'ORG': 1},
#  'Wild': {'ORG': 1},
#  'Wilson': {'PER': 1},
#  'Lemaire': {'PER': 1},
#  'Bay': {'ORG': 3},
#  'Ludziki': {'PER': 1},
#  'Tortorella': {'PER': 1},
#  'Leafsi': {'ORG': 1},
#  'Cloutier': {'PER': 1},
#  'Bruinsi': {'ORG': 1},
#  'BAY': {'ORG': 1},
#  'Johnson': {'PER': 2},
#  'Zjuzin': {'PER': 1},
#  'Lecavalier': {'PER': 1},
#  'Holzinger': {'PER': 1},
#  'Haritonov': {'PER': 1},
#  'Modin': {'PER': 1},
#  'Koroljov': {'PER': 1},
#  'Perreault': {'PER': 1},
#  'Manson': {'PER': 1},
#  '1': {'ORG': 2},
#  'Thornton': {'PER': 1},
#  'Rolston': {'PER': 1},
#  'Samsonov': {'PER': 1},
#  'Sweeney': {'PER': 1},
#  'Eloranta': {'PER': 1},
#  'Asham': {'PER': 1},
#  'Kilger': {'ORG': 1},
#  'JERSEY': {'ORG': 1},
#  'Holik': {'PER': 1},
#  'Brõlin': {'PER': 1},
#  'McKay': {'PER': 1},
#  'Alatalo': {'PER': 1},
#  'Väänänen': {'PER': 1},
#  'May': {'ORG': 1, 'PER': 1},
#  'Mogilnõi': {'PER': 1},
#  'Elias': {'PER': 1},
#  'Stevens': {'PER': 1},
#  'Gomez': {'PER': 1},
#  'Sykora': {'PER': 1},
#  'Arnott': {'PER': 1},
#  'Jersey': {'LOC': 2},
#  'Hull': {'PER': 1},
#  'Nieuwendyk': {'PER': 1},
#  'Sydor': {'PER': 1},
#  'Audette': {'PER': 1},
#  'Ferraro': {'PER': 1},
#  'Tremblay': {'PER': 1},
#  'Morrow': {'PER': 1},
#  'Marshall': {'PER': 1},
#  'Hatcher': {'PER': 1},
#  'Brunette': {'PER': 1},
#  '2': {'ORG': 3},
#  'Forsberg': {'PER': 1},
#  'Bourque': {'PER': 1},
#  'Sanderson': {'PER': 1},
#  'Knutsen': {'PER': 1},
#  'Drury': {'PER': 1},
#  'Skoula': {'PER': 1},
#  'Tanguay': {'PER': 1},
#  'deVries': {'PER': 1},
#  'Gardiner': {'PER': 1},
#  'Odelein': {'PER': 1},
#  'Nielsen': {'PER': 1},
#  'Gavey': {'PER': 1},
#  'Bombardir': {'ORG': 1},
#  'Pellerin': {'PER': 1},
#  'Stewart': {'PER': 1},
#  'Leschyshyn': {'PER': 1},
#  'Roest': {'PER': 1},
#  'Sekeras': {'PER': 1},
#  'McKenna': {'PER': 1},
#  'Walker': {'PER': 1},
#  'Legwand': {'PER': 1},
#  'Poti': {'PER': 1},
#  'Carter': {'PER': 1},
#  'Weight': {'PER': 1},
#  'Arhipov': {'PER': 1},
#  'Hartnell': {'PER': 1},
#  'Smith': {'PER': 1},
#  'Comrie': {'PER': 1},
#  'Laraque': {'PER': 1},
#  'Valicevic': {'PER': 1},
#  'Robitaille': {'PER': 1},
#  'Skrastins': {'PER': 1},
#  'Cisar': {'PER': 1},
#  'Kjellberg': {'PER': 1},
#  'Fitzgerald': {'PER': 1},
#  'Druken': {'PER': 1},
#  'Brashear': {'PER': 1},
#  'Lachance': {'PER': 1},
#  'McEachern': {'PER': 1},
#  'Alfredsson': {'PER': 1},
#  'Redden': {'PER': 1},
#  'Arvedson': {'PER': 1},
#  'Fisher': {'PER': 1},
#  'Rachunek': {'PER': 1},
#  'Hossa': {'PER': 1},
#  'Bonk': {'PER': 1},
#  'Jašin': {'PER': 1},
#  'Potvin': {'ORG': 1},
#  '.': {'ORG': 6},
#  'Havelid': {'PER': 1},
#  'Tenkrat': {'PER': 1},
#  'Tverdovski': {'PER': 1},
#  'MacInnis': {'PER': 1},
#  'Salvador': {'PER': 1},
#  'Turgeon': {'PER': 2},
#  'Hecht': {'PER': 1},
#  'Young': {'PER': 1},
#  'Conroy': {'PER': 1},
#  'Nash': {'PER': 1},
#  'Selänne': {'PER': 1},
#  'McInnis': {'PER': 1},
#  'Pronger': {'ORG': 1},
#  'Rangers': {'ORG': 1},
#  'Islanders': {'ORG': 1},
#  'Jose': {'ORG': 1},
#  'Värav': {'ORG': 1},
#  'Col': {'PER': 1},
#  'Atl': {'PER': 2},
#  'Pit': {'PER': 3},
#  'Edm': {'PER': 1},
#  'Bos': {'PER': 2},
#  'NYR': {'PER': 1},
#  'Det': {'PER': 1},
#  'Ott': {'PER': 3},
#  'Was': {'PER': 1},
#  'Dal': {'PER': 1},
#  'Van': {'PER': 1},
#  'Chi': {'PER': 1},
#  'AnZhi': {'PER': 1, 'ORG': 1},
#  'Flora': {'ORG': 4},
#  'Tohver': {'PER': 4},
#  'SHvets': {'PER': 1},
#  'Levadia': {'ORG': 1},
#  'Pareiko': {'PER': 2},
#  'SHvetsi': {'PER': 1},
#  'Pohlak': {'PER': 1},
#  'Kazakov': {'PER': 1},
#  'Lehiste': {'PER': 1},
#  'Palace': {'PER': 2},
#  'Owen': {'PER': 1},
#  'Houllier': {'PER': 1},
#  'Litmaneni': {'PER': 1},
#  'Smiceri': {'PER': 1},
#  'Town': {'ORG': 1},
#  "City'st": {'LOC': 1},
#  'Parkil': {'ORG': 2},
#  'Hotspuri': {'PER': 1},
#  "Lane'l": {'PER': 2},
#  'Erikssoni': {'PER': 1},
#  'Trailblazersile': {'ORG': 1},
#  'Wallace': {'PER': 1},
#  'McKie': {'PER': 1},
#  'Stoudamire': {'PER': 1},
#  'Celtics': {'ORG': 1},
#  'Webber': {'ORG': 1},
#  'Cavaliersi': {'ORG': 1},
#  'Gatling': {'PER': 1},
#  'Clippers-Denver': {'ORG': 1},
#  'Exel': {'PER': 1},
#  '24': {'ORG': 1},
#  'Sport': {'ORG': 3},
#  '2001': {'ORG': 1},
#  'LÄÄS': {'PER': 2},
#  'I': {'ORG': 1, 'PER': 1},
#  'Vilj': {'ORG': 1},
#  'JK': {'ORG': 3},
#  'Kadakas': {'ORG': 1},
#  'II': {'ORG': 1, 'PER': 2},
#  'Haapsalu': {'ORG': 1},
#  'Tabasalu': {'LOC': 1},
#  'Rae': {'ORG': 1},
#  'Kose': {'ORG': 1},
#  'Regina': {'ORG': 1},
#  'Loo': {'ORG': 1},
#  'Toompea': {'ORG': 1},
#  'Klooga': {'ORG': 1},
#  'FC': {'ORG': 1},
#  'Pakri': {'ORG': 1},
#  'United': {'ORG': 2},
#  'Kaitseliit': {'ORG': 1},
#  'Võru': {'ORG': 1},
#  'Villem': {'ORG': 1},
#  'Rõõba': {'ORG': 1},
#  'Longo': {'PER': 1},
#  'Cattarinussi': {'PER': 1},
#  'Gjelland': {'PER': 2},
#  'Andresen': {'PER': 2},
#  'Björndalen': {'PER': 4},
#  'Morgenstern': {'PER': 1},
#  'Sendel': {'PER': 1},
#  'Wolf': {'PER': 1},
#  'Gross': {'PER': 1},
#  'Aidarov': {'PER': 1},
#  'Sõman': {'PER': 1},
#  'Rõženkov': {'PER': 1},
#  'Šašurin': {'PER': 1},
#  'Defrasne': {'PER': 1},
#  'Robert': {'PER': 1},
#  'Poiree': {'PER': 1},
#  'Garabik': {'ORG': 1},
#  'Masarik': {'PER': 1},
#  'Dostal': {'PER': 1},
#  'Vitek': {'PER': 1},
#  'Favre': {'PER': 1},
#  'Pallhuber': {'PER': 1},
#  'Müürsepa': {'PER': 1},
#  'AEK': {'ORG': 1},
#  'VIP-i': {'ORG': 1},
#  'Kinder': {'ORG': 1},
#  'Spirou': {'ORG': 1},
#  'Ceramica': {'ORG': 1},
#  'Lions': {'ORG': 1},
#  'Benetton': {'ORG': 1, 'PER': 1},
#  'Real': {'ORG': 1},
#  'Müller': {'ORG': 1},
#  'PAOK': {'ORG': 1},
#  'Buducnost': {'ORG': 1},
#  "City's": {'LOC': 1},
#  'Mühlegg': {'PER': 2},
#  'Hoffmanni': {'PER': 1},
#  'Sommerfeldti': {'PER': 1},
#  'City': {'ORG': 2},
#  'Austria': {'PER': 5},
#  'Sommerfeldt': {'PER': 1},
#  'Spanuth': {'PER': 1},
#  'Zorzi': {'PER': 1},
#  'Cottrer': {'PER': 1},
#  'Valbusa': {'PER': 1},
#  'Wadsworth': {'PER': 1},
#  'Itaalia': {'PER': 1},
#  'Maj': {'PER': 1},
#  'Batory': {'PER': 1},
#  'Liechtenstein': {'PER': 1},
#  'Bajcicak': {'PER': 1},
#  'Jaapan': {'PER': 1},
#  'Burgermeister': {'PER': 1},
#  'Šveits': {'PER': 1},
#  'Vittoz': {'PER': 1},
#  'Jonnier': {'PER': 1},
#  'Aschwanden': {'PER': 1},
#  'Verdenius': {'PER': 1},
#  'Rölli': {'PER': 1},
#  'Gutierrez': {'PER': 1},
#  'Whitney': {'PER': 1},
#  'Rousselet': {'PER': 1},
#  'Kalevi': {'ORG': 1, 'PER': 1},
#  "Moore'i": {'PER': 3},
#  'Niinepuu': {'PER': 6},
#  'Küpriani': {'ORG': 1, 'PER': 1},
#  'Ülikoolid': {'ORG': 3},
#  'Moore': {'PER': 3},
#  'Papyrus': {'ORG': 1},
#  'AS-i': {'ORG': 4},
#  'Mölder': {'PER': 1},
#  'Kööp': {'PER': 1},
#  'Konsap': {'PER': 1},
#  'Murdmets': {'PER': 1},
#  'Lutt': {'PER': 1},
#  'Sait': {'PER': 1},
#  'Corporation': {'ORG': 1},
#  'Lunden': {'PER': 1},
#  'Uotila': {'PER': 1},
#  'Turtiainen': {'PER': 1},
#  'Mannonen': {'PER': 1},
#  'Heinilä': {'PER': 1},
#  'Hossi': {'PER': 1},
#  'Halme': {'PER': 1},
#  'Bowling': {'ORG': 1},
#  'Pankki': {'PER': 1},
#  'Oy': {'ORG': 6},
#  'Xerox': {'ORG': 1},
#  'Yhtymä': {'PER': 1},
#  'Vaidla': {'PER': 2},
#  'Kalamats': {'ORG': 1},
#  'Talv': {'PER': 1},
#  'Haldre': {'PER': 1},
#  'Veide': {'PER': 1},
#  'Juursoo': {'PER': 1},
#  'Spordimuuseumi': {'ORG': 1},
#  'Muusemi': {'ORG': 1},
#  'Mahhatškala': {'PER': 1},
#  'Tohveri': {'PER': 1},
#  'Švets': {'PER': 4},
#  'Florale': {'ORG': 1},
#  'Tohverist': {'PER': 2},
#  'Levadiast': {'ORG': 1},
#  'Florast': {'ORG': 1},
#  'Maradona': {'PER': 1},
#  'Caniggia': {'PER': 1},
#  'Hingist': {'PER': 1},
#  'Clijstersiga': {'PER': 1},
#  'Hingis': {'PER': 1},
#  'Alpides': {'ORG': 1},
#  'Schumacheri': {'PER': 1},
#  'Kullamäe': {'PER': 5},
#  'Telindus': {'ORG': 2},
#  'Suproliigas': {'ORG': 1},
#  'Mulaomerovic': {'PER': 1},
#  'Drobnjak': {'PER': 1},
#  'Pilseni': {'ORG': 1},
#  'Kerschaever': {'PER': 1},
#  'Pehka': {'PER': 1},
#  'Holden': {'PER': 1},
#  'Biggs': {'PER': 1},
#  'Praskevicius': {'ORG': 1},
#  'Press': {'PER': 1, 'ORG': 3},
#  'Vaher': {'PER': 2},
#  'Märtin': {'PER': 3},
#  'Auto': {'ORG': 5},
#  'Impreza': {'PER': 4},
#  'Carlosse': {'ORG': 2},
#  'Lapworth': {'PER': 2},
#  'Burnsi': {'PER': 2},
#  'Carlo': {'LOC': 1, 'ORG': 1},
#  'Arai': {'PER': 2},
#  'Lemsalu': {'PER': 2},
#  'Start': {'ORG': 1},
#  'Tulevikuga': {'ORG': 1},
#  'Thodeseni': {'ORG': 1},
#  'Lillegårdiga': {'PER': 1},
#  'Thordarsoni': {'PER': 1},
#  'Operile': {'PER': 1},
#  'külla': {'LOC': 2},
#  'Terehhov': {'PER': 1},
#  'Viikmäe': {'PER': 1},
#  'Drangsholvi': {'PER': 1},
#  'Reinbok': {'PER': 1},
#  'Sokku': {'PER': 1},
#  'Teniste': {'PER': 1},
#  'Varblasele': {'PER': 1},
#  'Kuusmaa': {'PER': 1},
#  'Tagametsa': {'PER': 1},
#  'Kerde': {'PER': 1},
#  'Noormetsaga': {'PER': 1},
#  'Grigorjev': {'PER': 1},
#  'Martinson': {'PER': 1},
#  'Šmigun': {'PER': 1},
#  'Neumannova': {'PER': 1},
#  'Neumannovale': {'PER': 1},
#  'Skari': {'PER': 2},
#  'Scottile': {'PER': 1},
#  'Paruzzile': {'PER': 1},
#  'Belmondo': {'PER': 1},
#  'Tšepalova': {'PER': 3},
#  'Vähi': {'PER': 2},
#  'Pahv': {'PER': 1},
#  'Rakvere': {'ORG': 2},
#  'Coqi': {'PER': 8},
#  'Valeiko': {'PER': 1},
#  'Heinaru': {'PER': 1},
#  'Saagi': {'PER': 1},
#  'Sõber': {'PER': 3},
#  'Rumma': {'PER': 3},
#  'Halliko': {'PER': 1},
#  'Nuka': {'PER': 1},
#  'Coq': {'PER': 14},
#  'Nikolotov': {'PER': 1},
#  'Metstak': {'PER': 2},
#  'Erkmaa': {'PER': 1},
#  'Pehkata': {'PER': 1},
#  'Ülikoolid-A': {'ORG': 4},
#  '16 0 16': {'LOC': 1},
#  'Rakverele': {'ORG': 1},
#  'Rüütel': {'PER': 1},
#  'Grigorjani': {'PER': 1},
#  'Arike': {'PER': 1},
#  'Vinnis': {'ORG': 1},
#  'Kalevit': {'PER': 1},
#  'Saag': {'PER': 1},
#  'Lokutsievski': {'PER': 1},
#  'Allingu': {'PER': 1},
#  'Coqil': {'PER': 1},
#  'Melnik': {'PER': 1},
#  'Erkmaad': {'PER': 1},
#  'Villersi': {'PER': 1},
#  'Jürine': {'PER': 3},
#  'Märtinile': {'PER': 2},
#  'Subarule': {'PER': 1},
#  'Solbergi': {'ORG': 1},
#  'Märtinilt': {'PER': 1},
#  'Hassan': {'PER': 1},
#  'Matthäusiga': {'PER': 1},
#  'Kasparov': {'PER': 1},
#  'Kramnikule': {'PER': 1},
#  'Anandil': {'PER': 1},
#  'Ehlvest': {'PER': 1},
#  'Beljavskiga': {'PER': 1},
#  'Rõtšagovi': {'PER': 1},
#  'Külaotsal': {'PER': 1},
#  'Salumäe': {'PER': 1},
#  'Lajunen': {'PER': 1},
#  'Shmigun': {'PER': 4},
#  'Citys': {'LOC': 2},
#  'Belmondost': {'PER': 1},
#  'Shmiguni': {'PER': 3},
#  'Scott': {'PER': 2},
#  'Paruzzi': {'PER': 1},
#  'Belmondot': {'PER': 1},
#  'Paruzzit': {'PER': 1},
#  'Kerese': {'PER': 1},
#  'Oll': {'PER': 1},
#  'Polgar': {'PER': 1},
#  'Timman': {'PER': 1},
#  'Tammert-seenior': {'PER': 1},
#  'Kiige': {'PER': 1},
#  'Vetemaa': {'PER': 1},
#  'Olde': {'PER': 1},
#  'Kalevile': {'ORG': 1},
#  'Mazzacane': {'PER': 3},
#  'Alesi': {'PER': 3},
#  'Prost': {'PER': 3},
#  'Lääne': {'PER': 1},
#  'Nool': {'PER': 2},
#  'Cup': {'ORG': 1},
#  'Hotels': {'PER': 1},
#  'Ühispank': {'ORG': 1},
#  'Sadam': {'ORG': 1},
#  'Mobiiltelefon': {'ORG': 1},
#  'Kuku': {'PER': 1},
#  'Televisioon': {'ORG': 2},
#  'Kommerts': {'PER': 1},
#  'Urm': {'PER': 1},
#  'Kangro': {'PER': 1},
#  'ülikooli': {'ORG': 4},
#  'Aaviksoo': {'PER': 1},
#  'Ülikooli': {'ORG': 3},
#  'Päevalehes': {'ORG': 1},
#  'Eesti': {'ORG': 3},
#  'Kriiska': {'PER': 4},
#  'majanduspolitsei': {'ORG': 2},
#  'Ehitus': {'ORG': 2},
#  'Medical': {'ORG': 1},
#  'Lillo': {'PER': 1},
#  'Mõõdukad': {'ORG': 2},
#  'Rahvaliit': {'ORG': 3},
#  'Tööpartei': {'ORG': 4},
#  'Rahvapartei': {'ORG': 4},
#  'Kogu': {'ORG': 2},
#  'Erakond': {'LOC': 2, 'ORG': 2},
#  'Ühtsuspartei': {'ORG': 2},
#  'Barbo': {'PER': 2},
#  'Kelder': {'PER': 2},
#  'Kranich': {'PER': 2},
#  'Kelderi': {'PER': 1},
#  'linnavalitsusele': {'ORG': 1},
#  'Padjuse': {'PER': 1},
#  'Loodus': {'PER': 2},
#  'Ühingu': {'ORG': 1},
#  'Jõks': {'PER': 1},
#  'Rask': {'PER': 3},
#  'Sammelselg': {'PER': 1},
#  'Meri': {'PER': 11},
#  'Varkel': {'PER': 1},
#  'Luik': {'PER': 2},
#  'Kunnase': {'PER': 2},
#  'Moora': {'PER': 4},
#  'Kunnas': {'PER': 2},
#  'Parteisse': {'ORG': 1},
#  'Michelson': {'PER': 1},
#  'Balti': {'PER': 1},
#  'Komisjonil': {'ORG': 1},
#  'Ülemkogu': {'ORG': 1},
#  'Lissaboni': {'LOC': 1},
#  'Ülemkogul': {'ORG': 1},
#  'Nõukogu': {'ORG': 4},
#  'Raag': {'PER': 1},
#  'Niro': {'PER': 1},
#  'Jacksoni': {'PER': 1},
#  'Presli': {'ORG': 1},
#  'Muusuemi': {'ORG': 1},
#  'Saaristi': {'PER': 1},
#  'vanglate': {'ORG': 1},
#  'Sõer': {'PER': 1},
#  'vanglast': {'ORG': 1},
#  'justiitsministeeriumi': {'ORG': 1},
#  'Herodes': {'PER': 1},
#  'Hasegawa': {'ORG': 1},
#  'Bonnier': {'PER': 1},
#  'Ilvesega': {'PER': 2},
#  'Perssoni': {'PER': 1},
#  'Streimanni': {'PER': 1},
#  'Vilba': {'PER': 4},
#  'Cornwelliga': {'PER': 1},
#  'linnavalitsus': {'ORG': 3},
#  'Pakosta': {'PER': 6},
#  'Põllumajandusülikool': {'ORG': 1},
#  'EPMÜ': {'ORG': 1},
#  'Koppel': {'PER': 1},
#  'Ülikool': {'ORG': 1},
#  'Lennukolledz': {'ORG': 1},
#  'Liitu': {'ORG': 2, 'LOC': 1},
#  'Keskerakonna': {'ORG': 1},
#  'Ligi': {'PER': 3},
#  'Linde': {'PER': 1},
#  ...}

# %% [markdown]
# creating three dataframes, filling missing values with 0

# %%
single_csv = pd.DataFrame.from_dict(singletons_map,orient='index')
single_csv = single_csv.fillna(0)
single_csv
# Out:
#                 LOC  ORG  PER
# Ühendriigid     1.0  0.0  0.0
# Leedusse        1.0  0.0  0.0
# Leedu          49.0  0.0  0.0
# Leedus         19.0  0.0  0.0
# USA            53.0  0.0  0.0
# ...             ...  ...  ...
# Elna            0.0  0.0  1.0
# Puiskestvikku   0.0  0.0  1.0
# Schwarzkopf     0.0  0.0  1.0
# Pott            0.0  0.0  1.0
# Mortoni         0.0  0.0  1.0
#
# [1952 rows x 3 columns]

# %%
last_df = pd.DataFrame.from_dict(last_word_map,orient='index')
last_df = last_df.fillna(0)
last_df
# Out:
#                      ORG  PER   LOC
# välisministeeriumi   3.0  0.0   0.0
# Telekomi             5.0  0.0   0.0
# Vee                  2.0  0.0   0.0
# Liidu               15.0  0.0  18.0
# statistikaamet       1.0  0.0   0.0
# ...                  ...  ...   ...
# meri                 0.0  0.0   4.0
# vabariigi            0.0  0.0   1.0
# Tammsaare            0.0  0.0   1.0
# Liberty              0.0  0.0   1.0
# põhja-osas           0.0  0.0   1.0
#
# [1840 rows x 3 columns]

# %%
first_df = pd.DataFrame.from_dict(first_words_map,orient='index')
first_df
# Out:
#                       ORG  PER   LOC
# ('Leedu',)            6.0  NaN   NaN
# ('Eesti',)           68.0  NaN  10.0
# ('Tallinna',)        55.0  NaN   8.0
# ('Euroopa',)         24.0  NaN  17.0
# ('Läti',)             5.0  NaN   NaN
# ...                   ...  ...   ...
# ('Aadria',)           NaN  NaN   2.0
# ('Jugoslaavia',)      NaN  NaN   1.0
# ('Utah', "'")         NaN  NaN   1.0
# ('EchoStar', ',')     NaN  NaN   1.0
# ('Lõuna-Ameerika',)   NaN  NaN   1.0
#
# [1312 rows x 3 columns]

# %% [markdown]
# Saving results to CSV files

# %%
last_df.to_csv('data/last_counts.csv')

# %%
single_csv.to_csv('data/single_counts.csv')

# %%
first_df.to_csv('data/first_counts.csv')
