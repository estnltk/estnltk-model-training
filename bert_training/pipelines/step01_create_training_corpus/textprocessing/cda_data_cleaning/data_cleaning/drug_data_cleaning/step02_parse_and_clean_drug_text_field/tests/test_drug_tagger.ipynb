# %%
import re
import os
import sys
import pytest
sys.path.append(os.path.abspath('../development'))
sys.path.append(os.path.abspath('../development/dev_taggers'))
from estnltk.taggers import TaggerTester
from drug_tagger import DrugTagger
from drug_grammar_token_tagger import DrugGrammarTokenTagger

# %%
def run_tester(type_nr:int):
    '''
    Runs tests in the folder corresponding to 'type_nr'. 
    Tests are based  on all 'input_type*.json' and 'target_type*.json' files.
    '''
    
    folder_name = 'type_' + str(type_nr) + '/'
    
    for file in os.listdir('./' + folder_name):
        # find input_*.json and target_*.json files
        if re.match('input_', file):
            target_file = file.replace('input', 'target')

            tester = TaggerTester(tagger=drug_tagger, input_file=folder_name + file, target_file= folder_name + target_file)
            tester.load()
            tester.run_tests()

def test_type_1():
    run_tester(1)
            
def test_type_2():
    run_tester(2)
            
def test_type_3():
    run_tester(3)
                        
def test_type_4():
    run_tester(4)

def test_type_5():
    run_tester(5)
        
def test_type_6():
    run_tester(6)

def test_type_7():
    run_tester(7)


drug_tagger = DrugTagger()
part_tagger = DrugFieldPartTagger()
test_type_1()
test_type_2()
test_type_3()
test_type_4()
test_type_5()
test_type_6()
test_type_7()
# Out:
# type 1 decorator
# type 4 decorator
# type 4 decorator
# type 1 decorator
# type 4 decorator
# type 1 decorator
# type1_1 PASSED
# type 1 decorator
# type 4 decorator
# type 4 decorator
# type 1 decorator
# type 4 decorator
# type 1 decorator
# type1_0 PASSED
# type 1 decorator
# type 4 decorator
# type1_2 PASSED
# type 2 decorator
# type 1 decorator
# type 1 decorator
# type1_3 PASSED
# type 2 decorator
# type 2 decorator
# type 2 decorator
# type 2 decorator
# type 2 decorator
# type2_0 PASSED
# type 6 decorator
# type 6 decorator
# type 6 decorator
# type 2 decorator
# type 3 decorator
# type 3 decorator
# type 3 decorator
# type7_1 PASSED
# type 6 decorator
# type 6 decorator
# type 2 decorator
# type 3 decorator
# type 3 decorator
# type 3 decorator
# type7_2 PASSED
# type 6 decorator
# type 6 decorator
# type 6 decorator
# type 2 decorator
# type 3 decorator
# type 3 decorator
# type 3 decorator
# type7_0 PASSED
# type 4 decorator
# type 4 decorator
# type 4 decorator
# type 4 decorator
# type4_0 PASSED
# type 5_1 decorator
# type 5_2 decorator
# type51_0 PASSED
# type 5_2 decorator
# type 5_2 decorator
# type52_3 PASSED
# type 5_1 decorator
# type 5_2 decorator
# type 5_1 decorator
# type 5_2 decorator
# type51_1 PASSED
# type 5_2 decorator
# type 5_2 decorator
# type52_2 PASSED
# type 5_2 decorator
# type52_1 PASSED
# type 5_1 decorator
# type 5_2 decorator
# type52_0 PASSED
# type 6 decorator
# type 6 decorator
# type6_1 PASSED
# type 6 decorator
# type 6 decorator
# type 6 decorator
# type 7 decorator
# type 6 decorator
# type 7 decorator
# type6_0 PASSED
# type 6 decorator
# type 6 decorator
# type6_2 PASSED
# type 6 decorator
# type 6 decorator
# type 6 decorator
# type 7 decorator
# type 6 decorator
# type 7 decorator
# type 7 decorator
# type 7 decorator
# type6_3 PASSED
# type 7 decorator
# type 7 decorator
# type 7 decorator
# type 7 decorator
# type7_1 PASSED
# type 7 decorator
# type 7 decorator
# type7_3 PASSED
# type 7 decorator
# type 7 decorator
# type7_2 PASSED
# type 7 decorator
# type 7 decorator
# type 7 decorator
# type 7 decorator
# type7_0 PASSED
