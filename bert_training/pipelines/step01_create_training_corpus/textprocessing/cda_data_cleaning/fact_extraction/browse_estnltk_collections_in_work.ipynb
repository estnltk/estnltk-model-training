# %% [markdown]
# # Browse EstNLTK collections in `egcut_epi.work`

# %%
from estnltk.storage import PostgresStorage

storage = PostgresStorage(pgpass_file='~/.pgpass',
                          dbname='egcut_epi',
                          schema='work',
                          role='egcut_epi_work_create')
# Out:
# INFO:storage.py:42: connecting to host: 'p12.stacc.ee', port: '5432', dbname: 'egcut_epi', user: 'ptammo'
# INFO:storage.py:58: schema: 'work', temporary: False, role: 'egcut_epi_work_create'

# %%
storage
# Out:
# <b>PostgresStorage</b><br/>
# host=p12.stacc.ee port=5432 dbname=egcut_epi user=ptammo schema=work<br/>temporary=False<br/>
# collection count: 23
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>rows</th>
#       <th>total_size</th>
#       <th>comment</th>
#     </tr>
#     <tr>
#       <th>collection</th>
#       <th>version</th>
#       <th>relations</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">dagetest2_procedure_subentries</th>
#       <th rowspan="2" valign="top">1.0</th>
#       <th></th>
#       <td>1319</td>
#       <td>1896 kB</td>
#       <td>created by dages on Mon Jun 24 12:58:30 2019</td>
#     </tr>
#     <tr>
#       <th>structure</th>
#       <td>1</td>
#       <td>32 kB</td>
#       <td>None</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# | collection                            | ???                                                                 |
# |:---                                   |:----                                                                |
# |`run_201904181825_events`              | [#1129](https://redmine.stacc.ee/redmine/issues/1129)               |
# |`run_201904181825_texts`               | [#1129](https://redmine.stacc.ee/redmine/issues/1129)               |
# |`run_201905181215_events`              | [run_201905181215.ipynb](event_extraction/development/run_201905181215.ipynb) |
# |`run_201905181215_texts`               | [run_201905181215.ipynb](event_extraction/development/run_201905181215.ipynb) |
# |`run_201905220848_events`              | latest run  [run_201905181215.ipynb](event_extraction/development/run_201905220848.ipynb) |
# |`run_201905220848_text`                | latest run  [run_201905181215.ipynb](event_extraction/development/run_201905220848.ipynb) |

# %%
# delete collections

for collection_name in []:
    storage.delete(collection_name, cascade=True)

# %%
storage.close()
