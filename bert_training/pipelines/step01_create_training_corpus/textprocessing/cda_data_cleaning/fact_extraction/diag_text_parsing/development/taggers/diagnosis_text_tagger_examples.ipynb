# %%
from estnltk import Text
from diagnosis_text_tagger import DiagnosisTextTagger

# %%
text1 = Text('Täpsustamata paikme korduv müokardiinfarkt\n(2.nonSTEMI, 09.10.15; C53> 23 DES, SPL4 >2 POBA, A342> 322 DES)\n\
NONSTEMI, anterioorne 29.11.2013\n\
Äge müokardiinfarkt, NSTEMI, lateraalne, 31.07.15\nPTKA OM1(4)>(2)\n\
Infarctus myocardii ac. (V; non-STEMI; 23.11.10)\n\
1997, PTKA+stent 20.03.08, non-stemi,18. 05.08\n\
Nstemi')

text2 = Text('Äge seinaläbine e transmuraalne müokardi eesseina infarkt STEMI 29.11.2013 PTKA A(26-)>(213)\n\
august 2011, PTKA+stent\n\
SKG +PTKA 06.07.08 ; 1 stent A 141->111\n\
Krooniline südame isheemiatõbi, aterosklerootiline südamehaigus ( CT koronarograafial ad 50 % ahenemisi).\n\
Aterosklerootiline kardiovaskulaarhaigus (nii kirjeldatud)\nPTKA+STENT 2011')

text3=Text('ajuinfarkt vasakul keskmise ajuarteri varustusalal: motoorne afaasia, parempoolne hemiparees (trombolüüs 04.08.12)\n\
Infarctus myocardii ac. (II; STEMI; p.anter.). Trombolüüs 25.04.10\n\
Ajuinfarkt vasakul vahelmise ajuarteri varustusalal ( trombolüüs+trombektoomia)')

text4=Text('Peaajuinfarkt (pea)ajuarterite täpsustamata sulguse vōi sten .\n\
Teisiti täpsustamata mitte seinaläbine äge müokardiinfarkt 2.LBBB 29.12.14; OM4>1.stent')

text5=Text('AKŠ 1991 ja 2001, PTKA+stent 1998\n\
M.I.C. Stenocardia III. 24.05.07 Aortokoronaarne šunteerimine\n\
Varasem müokardiinfark (2004. 2006. )aortokoronaarne sunt- 4 sunti.\n\
MIC.  AKš  (1999 )')

tagger = DiagnosisTextTagger()
tagger.tag(text2)
text2['diagnosis']
# Out:
# Layer(name='diagnosis', attributes=('grammar_symbol', 'regex_type', 'value', '_priority_'), spans=SL[AS(start=57, end=64, text:' STEMI '),
# AS(start=75, end=79, text:'PTKA'),
# AS(start=106, end=110, text:'PTKA'),
# AS(start=111, end=116, text:'stent'),
# AS(start=117, end=120, text:'SKG'),
# AS(start=122, end=126, text:'PTKA'),
# AS(start=140, end=145, text:'stent'),
# AS(start=226, end=241, text:'koronarograafia'),
# AS(start=322, end=326, text:'PTKA'),
# AS(start=327, end=332, text:'STENT')])
