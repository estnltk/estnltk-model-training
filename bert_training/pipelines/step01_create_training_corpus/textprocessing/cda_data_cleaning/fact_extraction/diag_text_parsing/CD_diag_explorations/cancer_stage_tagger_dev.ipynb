# %%
import psycopg2
#from connection_string_p12 import connection_string1
from collections import defaultdict
from datetime import datetime
import re
from collections import Counter
from estnltk import Text
import pickle
from tqdm import tqdm
import sys
import os

# %%
sys.path.append(re.sub('cda_data_cleaning/fact_extraction/diag_text_parsing/CD_diag_explorations', '', os.getcwd()))

# %%
#from cda_data_cleaning.fact_extraction.diag_text_parsing.development.taggers.diagnosis_text_tagger import DiagnosisTextTagger
from cda_data_cleaning.fact_extraction.diag_text_parsing.development.taggers.cancer_stage_tagger import CancerStageTagger
#from cda_data_cleaning.fact_extraction.measurement_extraction.taggers.robust_date_number_tagger.robust_date_number_tagger import RobustDateNumberTagger
# Out:
# INFO:base_parser.py:30: Loaded []

# %%
pwd
# Out:
# '/home/dage/Desktop/cda-data-cleaning/cda_data_cleaning/fact_extraction/diag_text_parsing/CD_diag_explorations'

# %%
real_extras = pickle.load(open("../all_diag_explorations2/real_extras2.pickle", "rb"))

# %%
cd_texts = Counter()
for thing, count in real_extras.items():
    if thing[1] == 'C00-D48': 
        cd_texts[thing] = count

# %%
cd_texts.most_common()
# Out:
# [(('Pk', 'C00-D48'), 110),
#  (('Kõigi paikmete hemangioom', 'C00-D48'), 81),
#  (('E pk', 'C00-D48'), 60),
#  (('Umbsool', 'C00-D48'), 46),
#  (('A pk', 'C00-D48'), 43),
#  (('Neer', 'C00-D48'), 36),
#  (('I pk', 'C00-D48'), 34),
#  (('Nahk', 'C00-D48'), 31),
#  (('Neerupealis', 'C00-D48'), 27),
#  (('E pahaloomuline kasvaja', 'C00-D48'), 26),
#  (('Pahaloomuline kasvaja', 'C00-D48'), 22),
#  (('Rinna pahaloomuline kasvaja', 'C00-D48'), 15),
#  (('IV st.', 'C00-D48'), 13),
#  (('Lümfoplasmotsütaarne lümfoom', 'C00-D48'), 12),
#  (('Kõri', 'C00-D48'), 11),
#  (('E kolangio- e sapisoonekartsinoom', 'C00-D48'), 11),
#  (('Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom ; c T2 N0 M1B IVBst\nTh 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom',
#    'C00-D48'),
#   10),
#  (('IgG I A st.', 'C00-D48'), 10),
#  (('Adenocarcinoma  prostatae GS 3+4=7', 'C00-D48'), 10),
#  (('Pärasool', 'C00-D48'), 10),
#  (('E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.20',
#    'C00-D48'),
#   10),
#  (('Täpsustamata sapiteed', 'C00-D48'), 9),
#  (('Emakas', 'C00-D48'), 9),
#  (('Kraniaalnärvid', 'C00-D48'), 8),
#  (('Käärsool', 'C00-D48'), 8),
#  (('. IV B st', 'C00-D48'), 8),
#  (('Pk ( 2006.a. gastrektoomia , koletsüstektoomia )', 'C00-D48'), 8),
#  (('Pk st IV', 'C00-D48'), 8),
#  (('Pk ( 2006 gastrektoomia , koletsüstektoomia )', 'C00-D48'), 8),
#  (('Vasakul', 'C00-D48'), 7),
#  (('Kaksteistsõrmik', 'C00-D48'), 7),
#  (('Kolangio- e spisoonekartsinoom 2c0c1 IV   2', 'C00-D48'), 7),
#  (('Adenokartsinoom', 'C00-D48'), 7),
#  (('Retsidiiv', 'C00-D48'), 7),
#  (('Difuusne B-suurrakk-lümfoom, IIEB', 'C00-D48'), 7),
#  (('Se pahaloomuline kasvaja; III vatsakese ja thalamuse piirkonna maligniseerunud epidermoidt',
#    'C00-D48'),
#   7),
#  (('Silma sidekest', 'C00-D48'), 7),
#  (('Opereeritud', 'C00-D48'), 7),
#  (('PK', 'C00-D48'), 6),
#  (('( leiomüosarkoom)', 'C00-D48'), 6),
#  (('Emakakeha', 'C00-D48'), 6),
#  (('<ANONYM id="1" type="per" morph="_Y_ sg el"/>', 'C00-D48'), 6),
#  (('Lamerakk-kartsinoom', 'C00-D48'), 6),
#  (('Seroosne adenokartsinoom', 'C00-D48'), 6),
#  (('I st <ANONYM id="1" type="per" morph="_S_ sg g"/> järgi,B st Binet järgi',
#    'C00-D48'),
#   6),
#  (('P T3A N0 M0 G2', 'C00-D48'), 6),
#  (('PT4B N 1MI M0 IIIAst', 'C00-D48'), 6),
#  (('Philadelphia positiivne, krooniline faas', 'C00-D48'), 6),
#  (('P T2C NX M0 G2', 'C00-D48'), 6),
#  (('Adenocarcinoma  prostatae GS 3+3=6', 'C00-D48'), 5),
#  (('Luu ja liigesekõhr', 'C00-D48'), 5),
#  (('IVBst', 'C00-D48'), 5),
#  (('A pk op.26.09.2011', 'C00-D48'), 5),
#  (('Kolangio- e spis', 'C00-D48'), 5),
#  (('Intradermaalne neevus', 'C00-D48'), 5),
#  (('Liitneevus', 'C00-D48'), 5),
#  (('Adenocarcinoma prostatae\nAdenocarcinoma prostatae', 'C00-D48'), 5),
#  (('P T2A N0 M0 G2', 'C00-D48'), 5),
#  (('Follikulaarne, pT2 N0M0\nFollikulaarne, pT2 N0M0', 'C00-D48'), 5),
#  (('P T3 N0 M0 G2 R', 'C00-D48'), 5),
#  (('Häbe', 'C00-D48'), 4),
#  (('Täpsustamata maks', 'C00-D48'), 4),
#  (('Parema rinna inv.duktaalkartsinoom; ÖR neg PR neg HER2 pos', 'C00-D48'),
#   4),
#  (('E pahaloomuline kasvaja\nadenokartsinoom', 'C00-D48'), 4),
#  (('Täpsustamata naissuguelund', 'C00-D48'), 4),
#  (('Carcinoma mammae dex', 'C00-D48'), 4),
#  (('Adenocarcinoma  prostatae Gleason 3+4=7', 'C00-D48'), 4),
#  (('E pk pk pT2N0M0G3  I st.  IIb--IIIkl. gr- 1999.a.', 'C00-D48'), 4),
#  (('Staadium arvel 01; c T2 N0 M0 <ANONYM id="1" type="per" morph="_S_ sg n"/>',
#    'C00-D48'),
#   4),
#  (('P T3 N0 M0 G2 R0', 'C00-D48'), 4),
#  (('Fibroadenoma mammae dex.\nFibroadenoma mammae dex.', 'C00-D48'), 4),
#  (('Maks', 'C00-D48'), 4),
#  (('Bilateraalsed fibroadenoomid', 'C00-D48'), 4),
#  (('Söögitoru', 'C00-D48'), 4),
#  (('Pahaloomuline kasvaja; IIst', 'C00-D48'), 4),
#  (('Staadium arvel 02', 'C00-D48'), 4),
#  (('IIst', 'C00-D48'), 4),
#  (('Kusiti', 'C00-D48'), 4),
#  (('Fibroadenoma mammae sin.\nFibroadenoma mammae sin.', 'C00-D48'), 4),
#  (('Philadelphia positiivne, krooniline faas\nPhiladelphia positiivne, krooniline faas',
#    'C00-D48'),
#   4),
#  (('P T4B N3 M0 R0 IIICst', 'C00-D48'), 4),
#  (('P T4B N0 M0 R0 IICst', 'C00-D48'), 4),
#  (('Kahtlus', 'C00-D48'), 4),
#  (('Pk 2013 op.', 'C00-D48'), 4),
#  (('Kl-lt sinineevus', 'C00-D48'), 4),
#  (('(IVB st)', 'C00-D48'), 3),
#  (('IV st', 'C00-D48'), 3),
#  (('Ussripik', 'C00-D48'), 3),
#  (('Lümfoid- ja vereloomekoe nin', 'C00-D48'), 3),
#  (('Kolangio- e spisoonekertsinoom  2b 1 0 <ANONYM id="1" type="per" morph="_S_ sg g"/>',
#    'C00-D48'),
#   3),
#  (('G3a; IIIAst\nG3a', 'C00-D48'), 3),
#  (('Intravaskulaarne variant', 'C00-D48'), 3),
#  (('Kusepõiekael', 'C00-D48'), 3),
#  (('Adenocarcinoma prostatae GS 3+3=6', 'C00-D48'), 3),
#  (('Adenocarcinoma prostatae GS 4+4=8', 'C00-D48'), 3),
#  (('PTaNoMo G1 TCC', 'C00-D48'), 3),
#  (('IV st. <ANONYM id="1" type="per" morph="_S_ sg g"/> järgi, C st. Binet järgi',
#    'C00-D48'),
#   3),
#  (('Maolävis', 'C00-D48'), 3),
#  (('Adenokartsinoom G3', 'C00-D48'), 3),
#  (('Sõrmusrakuline vähk', 'C00-D48'), 3),
#  (('C T2 N0 M0 G3', 'C00-D48'), 3),
#  (('Dysplasticus\ndysplasticus', 'C00-D48'), 3),
#  (('Staadium arvel 01', 'C00-D48'), 3),
#  (('Vasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg; p T1C N1MI M0 G1 R0 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nVasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg',
#    'C00-D48'),
#   3),
#  (('P T3A N0 M0 G3', 'C00-D48'), 3),
#  (('Alahuulel', 'C00-D48'), 3),
#  (('Mantelrakk lümfoom; IIIAst\nMantelrakk lümfoom', 'C00-D48'), 3),
#  (('_Kolangio- e spis', 'C00-D48'), 3),
#  (('P T2C N0 M0 G2', 'C00-D48'), 3),
#  (('Staadium arvel 03; p T3A N0 M0 G3', 'C00-D48'), 3),
#  (('I staadium <ANONYM id="2" type="per" morph="_S_ sg g"/> järgi\nI staadium <ANONYM id="3" type="per" morph="_S_ sg g"/> järgi',
#    'C00-D48'),
#   3),
#  (('Peensool', 'C00-D48'), 3),
#  (('Pk, 2C, p T4B N0 M0 G2 II C st', 'C00-D48'), 3),
#  (('Staadium arvel 02; p T2 N0 M0 G3', 'C00-D48'), 3),
#  (('P T2B N0 M0 G2', 'C00-D48'), 3),
#  (('Täpsustamata kesknärvisüsteem', 'C00-D48'), 3),
#  (('E pk; adenokartsinoom; Staadium arvel 02; p T1 N0 M0 G2 R0 <ANONYM id="0" type="per" morph="_S_ sg n"/>',
#    'C00-D48'),
#   3),
#  (('Emakakael', 'C00-D48'), 3),
#  (('Pk op.- resekts.  1999.-( gastrosk= N. 07.11. 2013 )', 'C00-D48'), 3),
#  (('Staadium arvel 02; c T3 N0 M0 IIst', 'C00-D48'), 3),
#  (('Munand', 'C00-D48'), 3),
#  (('Seljaaju', 'C00-D48'), 3),
#  (('P T2C N0 M0 G2 R1', 'C00-D48'), 3),
#  (('I pahaloomuline kasvaja', 'C00-D48'), 3),
#  (('Parema rinna kartsinoom ÖRpos, PRpos, HER2 neg; p T1B N0 M0 G1 R0 <ANONYM id="1" type="per" morph="_H_ sg n"/>\nParema rinna kartsinoom ÖRpos, PRpos, HER2 neg',
#    'C00-D48'),
#   3),
#  (('A melanotsüütneevused', 'C00-D48'), 3),
#  (('( jälgimisel)', 'C00-D48'), 3),
#  (('B rakuline, I staadium', 'C00-D48'), 3),
#  (('Vasak neer, nefrektoomia 1990', 'C00-D48'), 3),
#  (('Difuusse mitte-hodgkini tüüpi lümfoomi muud tüübid', 'C00-D48'), 3),
#  (('Vasaku rinna invasiivne duktaalkartsinoom ÖR pos PR pos HER2 neg',
#    'C00-D48'),
#   3),
#  (('IIICst', 'C00-D48'), 3),
#  (('Naha muud pahaloomulised kasvajad.', 'C00-D48'), 3),
#  (('. Silmalau, k.a silmanurga nahk', 'C00-D48'), 3),
#  (('Naevus sebaceus\nnaevus sebaceus', 'C00-D48'), 3),
#  (('Eosinofiilne sündroom\neosinofiilne sündroom', 'C00-D48'), 3),
#  (('Opereeritud 2009.a\nopereeritud 2009.a', 'C00-D48'), 3),
#  (('( op. 1999.a. )', 'C00-D48'), 3),
#  (('Adenokartsinoom: c T3 N1 M1a IV a st.', 'C00-D48'), 2),
#  (('- Ca. sigillocellulare ventriculi cum metastasibus.', 'C00-D48'), 2),
#  (('Lümfosarkoom', 'C00-D48'), 2),
#  (('Söögitoru rinnaosa', 'C00-D48'), 2),
#  (('Söögitoru teadmata loomusega kasvaja', 'C00-D48'), 2),
#  (('4 c 1 c X III st.', 'C00-D48'), 2),
#  (('Parem pool', 'C00-D48'), 2),
#  (('Pahaloomuline kasvaja\nsõrmusrakulise komponendiga adenokartsinoom',
#    'C00-D48'),
#   2),
#  (('Carcinoma mammae dex. Status post chemotherapiam.', 'C00-D48'), 2),
#  (('Maksa-kõhunäärmeampull [vateri]', 'C00-D48'), 2),
#  (('Sõrmusrakuline ca.c T3 c NX M1 IV st', 'C00-D48'), 2),
#  (('Parema rinna inv.duktaalkartsinoom; ÖR neg PR neg HER2 neg', 'C00-D48'),
#   2),
#  (('Sõrmusrakuline ca : c T3 cN1  M1 IVst.', 'C00-D48'), 2),
#  (('Cysta dermoides ovarii sinistri', 'C00-D48'), 2),
#  (('B1 thymoma; Masaoka III', 'C00-D48'), 2),
#  (('( Mantelrakuline lümfoom )', 'C00-D48'), 2),
#  (('Carcinoma papillare', 'C00-D48'), 2),
#  (('Cysta dermoides ovarii dextri', 'C00-D48'), 2),
#  (('Adenocarcinoma  prostatae', 'C00-D48'), 2),
#  (('Anaplastne astrotsütoom G3', 'C00-D48'), 2),
#  (('Müelodüsplastiline sündroom', 'C00-D48'), 2),
#  (('Täpsustamata rakutüüpi mitte-hodgkini tüüpi lümfoom', 'C00-D48'), 2),
#  (('Parema rinna kartsinoom; ÖR pos PR neg HER2 neg', 'C00-D48'), 2),
#  (('Peaaju ja ajukelmete metastaatiline pahaloomuline kasvaja (vasem hemisfäär)',
#    'C00-D48'),
#   2),
#  (('IVst', 'C00-D48'), 2),
#  (('Pahaloomuline kasvaja\nneuroendokriinne vähk', 'C00-D48'), 2),
#  (('FLT3 neg, NPM1 neg, 1.remissioon', 'C00-D48'), 2),
#  (('Parema rinna inv.duktaalkartsinoom; ÖR pos PR pos HER2 neg Ki67 15%',
#    'C00-D48'),
#   2),
#  (('Täpsustamata seedeelund', 'C00-D48'), 2),
#  (('Myoma uteri multiplex', 'C00-D48'), 2),
#  (('C T2M1 IV st', 'C00-D48'), 2),
#  (('Süda', 'C00-D48'), 2),
#  (('E pk op. 13.01. 2014', 'C00-D48'), 2),
#  (('Lentigo maligna melanoma', 'C00-D48'), 2),
#  (('P T2 N0 M0 G2 R2 IIst', 'C00-D48'), 2),
#  (('Juhuleiuna munasarjatsüsti operatsioonil elukohajärgses raviasutuses.',
#    'C00-D48'),
#   2),
#  (('Medulaarne, MEN2A\nmedulaarne, MEN2A', 'C00-D48'), 2),
#  (('Ülakõhul', 'C00-D48'), 2),
#  (('Dex operata; yc T0 N0 M0\ndex operata', 'C00-D48'), 2),
#  (('Paremal pontotserebellaarpiirkonnas.', 'C00-D48'), 2),
#  (('Cysta dermoides ovarii sin.', 'C00-D48'), 2),
#  (('Staadium arvel 2A', 'C00-D48'), 2),
#  (('Intraduktaalne papilloom paremal', 'C00-D48'), 2),
#  (('Ja subseroosne', 'C00-D48'), 2),
#  (('Emakaõõnt deformeeriv', 'C00-D48'), 2),
#  (('P T2A N0 M0 R0 <ANONYM id="2" type="per" morph="_Y_ sg el"/>', 'C00-D48'),
#   2),
#  (('A PK', 'C00-D48'), 2),
#  (('Intradermaalsed neevused', 'C00-D48'), 2),
#  (('C T3 NX M1C IVst', 'C00-D48'), 2),
#  (('IIIAst', 'C00-D48'), 2),
#  (('P T3A N2C M0 R0 IIIBst', 'C00-D48'), 2),
#  (('E pk pT2N1aM0 st III', 'C00-D48'), 2),
#  (('( fibroadenoom vasakul )', 'C00-D48'), 2),
#  (('Gleason 3+3=6', 'C00-D48'), 2),
#  (('Vasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg; c T1C N0 M0 <ANONYM id="1" type="per" morph="_H_ sg n"/>\nVasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg',
#    'C00-D48'),
#   2),
#  (('III staadium <ANONYM id="2" type="per" morph="_S_ sg g"/> järgi, B staadium Binet järgi\nIII staadium <ANONYM id="3" type="per" morph="_S_ sg g"/> järgi, B staadium Binet järgi',
#    'C00-D48'),
#   2),
#  (('A kartsinoom in situ; p TIS N0 M0 0isst', 'C00-D48'), 2),
#  (('C T1 N0 M0 <ANONYM id="1" type="per" morph="_S_ sg n"/>', 'C00-D48'), 2),
#  (('Melanoma malignum reg. cruris dextri; p T3A N0 M0 R0 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nMelanoma malignum reg. cruris dextri',
#    'C00-D48'),
#   2),
#  (('P T2B NX MX G1', 'C00-D48'), 2),
#  (('Fibroadenoma mammae dex.', 'C00-D48'), 2),
#  (('Pk- ca mammae dx. st.III c p T2 (3) pN3 M0 op. 12.11. 2013', 'C00-D48'),
#   2),
#  (('Adenocarcinoma prostatae; c T2C N0 M0 G1 IIBst\nAdenocarcinoma prostatae',
#    'C00-D48'),
#   2),
#  (('Pahaloomuline kasvaja; G3', 'C00-D48'), 2),
#  (('Vasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg; yc T0 N0 M1 IVst\nVasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg',
#    'C00-D48'),
#   2),
#  (('P T3A N0 M0 LVI <ANONYM id="1" type="per" morph="_Y_ sg el"/>', 'C00-D48'),
#   2),
#  (('Kukla piirkond', 'C00-D48'), 2),
#  (('Carcinoma multiloc. mammae dex.', 'C00-D48'), 2),
#  (('C T3 NX M0 G2', 'C00-D48'), 2),
#  (('Os . Papilloma palp.sup./ ,  näo', 'C00-D48'), 2),
#  (('Kasvutendentsiga.', 'C00-D48'), 2),
#  (('E pahaloomuline kasvaja; Staadium arvel 02', 'C00-D48'), 2),
#  (('P T1A <ANONYM id="1" type="per" morph="_Y_ sg el"/>', 'C00-D48'), 2),
#  (('I pahaloomuline kasvaja; Staadium arvel 01', 'C00-D48'), 2),
#  (('IIIst', 'C00-D48'), 2),
#  (('Naha T-rakklümfoom\nnaha T-rakklümfoom', 'C00-D48'), 2),
#  (('T-lümfoblastne lümfoom\nT-lümfoblastne lümfoom', 'C00-D48'), 2),
#  (('Parema rinna invasiivne duktaalkartsinoom ÖR pos, PR pos, HER2 neg',
#    'C00-D48'),
#   2),
#  (('Adenocarcinoma  prostatae Gleason 3+3=6', 'C00-D48'), 2),
#  (('Täpsustamata peaaju', 'C00-D48'), 2),
#  (('Vasaku rinna kartsinoom; ÖR neg, PR neg, HER2 neg; p T1C N0- M0 G3 <ANONYM id="1" type="per" morph="_S_ sg n"/>\nvasaku rinna kartsinoom; ÖR neg, PR neg, HER2 neg',
#    'C00-D48'),
#   2),
#  (('Gr. levis', 'C00-D48'), 2),
#  (('Staadium arvel 2A; c T3 N0 M0 <ANONYM id="1" type="per" morph="_Y_ sg el"/>',
#    'C00-D48'),
#   2),
#  (('Staadium arvel 01; p T1B N0 M0 G2', 'C00-D48'), 2),
#  (('P T1B N0 M0 R0 <ANONYM id="1" type="per" morph="_S_ sg n"/>', 'C00-D48'),
#   2),
#  (('Atüüpia', 'C00-D48'), 2),
#  (('IgA kapa, I A st.; Staadium arvel 01\nIgA kapa, I A st.', 'C00-D48'), 2),
#  (('I pahaloomuline kasvaja; Staadium arvel 03; c T2 N1 MX G2 IIIst',
#    'C00-D48'),
#   2),
#  (('I pk op. 2006', 'C00-D48'), 2),
#  (('(op. 19.04.2010)', 'C00-D48'), 2),
#  (('Melanoma malignum parietis abdominis', 'C00-D48'), 2),
#  (('Myoma multiplex', 'C00-D48'), 2),
#  (('PK 4bc1c1HEP IV   3', 'C00-D48'), 2),
#  (('Kirssangioomid', 'C00-D48'), 2),
#  (('IIIa', 'C00-D48'), 2),
#  (('Düsplastiline neevus?', 'C00-D48'), 2),
#  (('(difuusne) väikeste lõhestunud rakkudega lümfoom', 'C00-D48'), 2),
#  (('Maksa-kõhunäärmeampull [Vateri] pahaloomuline kasvaja; op.-tud 2004 nov.\nWhipple lõikus, adenokartsinoom G2, pT1N0M0G2R0 <ANONYM id="1" type="per" morph="_Y_ ?"/> st.',
#    'C00-D48'),
#   2),
#  (('Täpsustamata difuusne mitte-hodgkini tüüpi lümfoom', 'C00-D48'), 2),
#  (('Vasema rinna inv.lobulaarkartsoom; ÖR pos PR pos HER2 neg', 'C00-D48'), 2),
#  (('Op. 28.02.2000', 'C00-D48'), 2),
#  (('IgG  I a st.', 'C00-D48'), 2),
#  (('Opereeritud 2013', 'C00-D48'), 2),
#  (('Anamneesis', 'C00-D48'), 2),
#  (('Endometroidne adenokartsinoom opereeritud 2008', 'C00-D48'), 2),
#  (('E pahaloomuline kasvaja\nopereeritud', 'C00-D48'), 2),
#  (('Kaelal', 'C00-D48'), 2),
#  (('Alajäseme, k.a puusanahk. Dermatofibroom.', 'C00-D48'), 2),
#  (('Opereeritud  2012a.', 'C00-D48'), 2),
#  (('Varbal', 'C00-D48'), 2),
#  (('Alates 2001', 'C00-D48'), 2),
#  (('Parem rind, opereeritud 2012', 'C00-D48'), 2),
#  (('I PK', 'C00-D48'), 2),
#  (('Choroidea oc. sin.', 'C00-D48'), 2),
#  (('C61', 'C00-D48'), 2),
#  (('E pahaloomuline kasvaja; Staadium arvel 2A', 'C00-D48'), 2),
#  (('Angioma senile\nangioma senile', 'C00-D48'), 2),
#  (('(1990)\nCa! mammae', 'C00-D48'), 2),
#  (('( jaan. 2013)', 'C00-D48'), 2),
#  (('Tõbi MT- luudes', 'C00-D48'), 2),
#  (('Lõual', 'C00-D48'), 2),
#  (('ÖR/PR:POS; HER2 : neg; p T2(2) N0 M0 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nÖR/PR:POS; HER2 : neg',
#    'C00-D48'),
#   2),
#  (('Angioma senile', 'C00-D48'), 2),
#  (('<ANONYM id="0" type="per" morph="_Y_ sg el"/>', 'C00-D48'), 2),
#  (('-op', 'C00-D48'), 2),
#  (('PT2 Nx Mx, G2', 'C00-D48'), 1),
#  (('Pt2a cn0m0 r0, gleason 3+3=6', 'C00-D48'), 1),
#  (('(transformatsiooniga üle müelodüsplastilise sündroomi (RAEB2))',
#    'C00-D48'),
#   1),
#  (('Häälekõri', 'C00-D48'), 1),
#  (('Maksa-kõhunäärmeampull [Vateri]\nTu! papillae Vateri?', 'C00-D48'), 1),
#  (('Pea, näo ja kaela sidekude ja muu pehme', 'C00-D48'), 1),
#  (('PK (stenditud)', 'C00-D48'), 1),
#  (('Munasari (vasakpoolne)', 'C00-D48'), 1),
#  (('Mitte-hodgkini tüüpi lümfoomi muud täpsustatud tüübid', 'C00-D48'), 1),
#  (('.Bronchocarcinoma lobi inf. pulmonis dex. pT2 pNo MO st 1b ( operata 27.10.2009a ). Intoxicatio.',
#    'C00-D48'),
#   1),
#  (('PT2c N0 M0, Gleason 3+4=7', 'C00-D48'), 1),
#  (('ÄLL pre-B 1 CR (MRD neg)', 'C00-D48'), 1),
#  (('4ac1c1PER IV', 'C00-D48'), 1),
#  (('Aju metastaasidega', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja; p T4 N0, M0 III st.', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja (in susp.)', 'C00-D48'), 1),
#  (('- DERMOIDTSÜST PAREMAL', 'C00-D48'), 1),
#  (('Kusepõie osalt kattuvate pai', 'C00-D48'), 1),
#  (('Ülasagar, bronh või kops ( adenokartsinoom)', 'C00-D48'), 1),
#  (('Kõri-polüüp', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja; T3 N1 M0', 'C00-D48'), 1),
#  (('IVBst. ALK+', 'C00-D48'), 1),
#  (('----metastaasidega', 'C00-D48'), 1),
#  (('Krooniline lümfotsüütleukeemia(B_CLL/SLL)', 'C00-D48'), 1),
#  (('Carcinima ovarii pT cNOMO st. IIIC.', 'C00-D48'), 1),
#  (('Vasema munasarja tsüst', 'C00-D48'), 1),
#  (('Kõhunäärmepea?', 'C00-D48'), 1),
#  (('<ANONYM id="0" type="per" morph="_S_ sg g"/> pahaloomuline kasvaja',
#    'C00-D48'),
#   1),
#  (('Carcinoma anaplasticum ventriculi pT3N2M0 G3  st.IIb', 'C00-D48'), 1),
#  (('CA  flexurae coli hepatica', 'C00-D48'), 1),
#  (('- parema kopsu alasagar', 'C00-D48'), 1),
#  (('(RAEB-2)', 'C00-D48'), 1),
#  (('<ANONYM id="0" type="per" morph="_Y_ ?"/> lümfoom', 'C00-D48'), 1),
#  (('Vasaku abaluu piirkonnas; p T1B N2C M0 R0 IIIBst\nvasaku abaluu piirkonnas',
#    'C00-D48'),
#   1),
#  (('IgG III A st\nIgG III A st', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja-mts-d skeletis, kopsudes, maksas.', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja; mutsinoosadenokartsinoom; Staadium arvel 4B; c T4B N2 M1B IVBst\nmutsinoosadenokartsinoom',
#    'C00-D48'),
#   1),
#  (('(difuusne) suurrakklümfoom', 'C00-D48'), 1),
#  (('IVCst', 'C00-D48'), 1),
#  (('Opereeritud pT3N3aM0 opereeritud', 'C00-D48'), 1),
#  (('PK   3p3bp1PER, LYM, intestini tenui, coli', 'C00-D48'), 1),
#  (('Alajäseme, k.a puusa pahaloomuline melanoom pTx pN1b M0 - IIIA st',
#    'C00-D48'),
#   1),
#  (('Mutsinoosne tsüstadenoom', 'C00-D48'), 1),
#  (('Melanoomi metastaas paremal fronto-temporaalsel', 'C00-D48'), 1),
#  (('Ebaselge või teadmata loomusega kasvaja', 'C00-D48'), 1),
#  (('Ca mammae dex multilocularis', 'C00-D48'), 1),
#  (('Ja intramuraalne müoomisõlm', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja\npankreatobiliaarne adenokartsinoom', 'C00-D48'), 1),
#  (('M. Paget primaarne intrakutaanne mitteinvasiivne', 'C00-D48'), 1),
#  (('Cysta dermoides ovarii dex.', 'C00-D48'), 1),
#  (('Uroteliaalne Low Grade kartsinoom vasakul', 'C00-D48'), 1),
#  (('CT4B N2 M1B IVBst', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja\nTNM: yc T0 N0 M0 G1 IVst', 'C00-D48'), 1),
#  (('Carcinoma ovarii recidiva', 'C00-D48'), 1),
#  (('Vasakpoolne', 'C00-D48'), 1),
#  (('Carcinoma ovarii recediva', 'C00-D48'), 1),
#  (('Metastaatiline munasarja lamerakk-kartsinoom sigmasoole seroosa ning parameetriumi ja väheses osas ka müomeetriumi haaratusega',
#    'C00-D48'),
#   1),
#  (('Myeloma IgG /', 'C00-D48'), 1),
#  (('Sõrmusrakuline pk. ( peritoneaalne külv?)', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja\nsõrmusrakuline kartsinoom', 'C00-D48'), 1),
#  (('Kogu magu haarav sõrmusrakuline kartsinoom', 'C00-D48'), 1),
#  (('Muud naissuguelundid, vulva', 'C00-D48'), 1),
#  (('Granuloosarakulise kasvaja retsidiiv kõhu sirglihases', 'C00-D48'), 1),
#  (('Carcinoma lobularis mammae sin multilocularis', 'C00-D48'), 1),
#  (('Carcinoma endometrioides /ovarii dex/ , piirpahaloomuline p T1A c NX M0 G1 <ANONYM id="2" type="per" morph="_Y_ sg el"/>',
#    'C00-D48'),
#   1),
#  (('Gleason 4+5=9', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja\nadenokartsinoom G2-G3', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja c T3 c N1 M1 IV st.', 'C00-D48'), 1),
#  (('Kõhunäärmesaba, metastaasid luudes ja maksas', 'C00-D48'), 1),
#  (('Bilateraalne dermoidtsüst', 'C00-D48'), 1),
#  (('Parema rinna kartsinoom: ÖR pos PR pos HER2 neg', 'C00-D48'), 1),
#  (('Carcinoma papillaris mammae sin. ÖR pos PR neg HER2 neg Ki67 30%',
#    'C00-D48'),
#   1),
#  (('Adenokartsinoom; cT3cN1M0 IIIB enne neoadjuvantset kemoradiatsiooni',
#    'C00-D48'),
#   1),
#  (('Kopsude adenokartsinoom', 'C00-D48'), 1),
#  (('Kõhunäärmesaba; metastaasid luudes ja maksas', 'C00-D48'), 1),
#  (('Papillaarne, parem sagar', 'C00-D48'), 1),
#  (('Carcinoma mammae dex multilocularis', 'C00-D48'), 1),
#  (('(tubulaarne adenokatrtsinoom)', 'C00-D48'), 1),
#  (('(tubulaarne adenokartsinoom)', 'C00-D48'), 1),
#  (('Sõrmusrakulise komponendiga tubulaarne adenokartsinoom; opereeritud 29.10.2013',
#    'C00-D48'),
#   1),
#  (('II st <ANONYM id="1" type="per" morph="_S_ sg g"/> järgi', 'C00-D48'), 1),
#  (('Vasem rinnakartsinoom, ÖR pos pR pos HER2 neg', 'C00-D48'), 1),
#  (('Carcinoma parvocellulare', 'C00-D48'), 1),
#  (('III B st.', 'C00-D48'), 1),
#  (('Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom; kopsu-ja skeleti metastaasidega',
#    'C00-D48'),
#   1),
#  (('Emaka submukoosne leiomüoom, sündiv müoomisõlm', 'C00-D48'), 1),
#  (('Juustega peanaha ja kaelanaha pahaloomuline melanoom pT3b Nx M0, R0 - st IIB',
#    'C00-D48'),
#   1),
#  (('MGB G IV paremas otsmiku- ja oimusagaras', 'C00-D48'), 1),
#  (('Helerakk-kartsinom Fuhrman 4', 'C00-D48'), 1),
#  (('. st IIIC', 'C00-D48'), 1),
#  (('Parema neeru heledarakuline neerurakk-kartsinoom', 'C00-D48'), 1),
#  (('Paremal retroperitoneaalselt väikeses vaagnas, ulatub kubemekanalini',
#    'C00-D48'),
#   1),
#  (('IVB st.', 'C00-D48'), 1),
#  (('<ANONYM id="1" type="per" morph="_Y_ ?"/> lümfoom', 'C00-D48'), 1),
#  (('LCIS paremal; ÖR pos PR pos Ki67 10%', 'C00-D48'), 1),
#  (('Multiformne glioblastoom F-T paremal, WHO G4', 'C00-D48'), 1),
#  (('Rind', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja\nadenokartsinoom G2', 'C00-D48'), 1),
#  (('Kartsinoom, mts-d maksas, l/sõlmedes, kopsudes', 'C00-D48'), 1),
#  (('Polümenorrhea', 'C00-D48'), 1),
#  (('A healoomuline kasvaja\npolüüp', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja\nadenokartsinoom, G2-3', 'C00-D48'), 1),
#  (('Madal', 'C00-D48'), 1),
#  (('MALT-lümfoom', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja\nadenokartsinoom', 'C00-D48'), 1),
#  (('Carcinoma folliculare, op. 1996 ja 2003.a \ncarcinoma folliculare, op. 1996 ja 2003.a',
#    'C00-D48'),
#   1),
#  (('(liposarkoom)', 'C00-D48'), 1),
#  (('Adenokartsinoom Gleason 3+3=6', 'C00-D48'), 1),
#  (('Op. 1996\nop. 1996', 'C00-D48'), 1),
#  (('Carcinoma mammae dex multilocularis. Status post chemotherapiam.',
#    'C00-D48'),
#   1),
#  (('Carcinoma mammae sin multilocularis. Status post chemotherapiam. Täielik ravivastus',
#    'C00-D48'),
#   1),
#  (('Gleason 3+4', 'C00-D48'), 1),
#  (('Sekundaarne, tekkinud üle müelodüsplaasia', 'C00-D48'), 1),
#  (('Parema rinna G2/3 inv.duktaalkartsinoom; ÖR neg PR neg HER2 pos Ki67 30%',
#    'C00-D48'),
#   1),
#  (('Low grade', 'C00-D48'), 1),
#  (('Vasak tuumornefrektoomia 08/2015, heledarakuline neerurakk-kartsinoom, G2; \nopereeritud vasaku kopsu metastaasid 07.12.2015',
#    'C00-D48'),
#   1),
#  (('High grade liposarkoom', 'C00-D48'), 1),
#  (('Sõrmusrakk - kartsinoom G3', 'C00-D48'), 1),
#  (('Hepatotsellulaarne kartsinoom G1 (neuroendokriinse diferentseeringuga)',
#    'C00-D48'),
#   1),
#  (('(mts maksas ja kopsus)', 'C00-D48'), 1),
#  (('Maolävis;rc T3 rc NX M1 IVst', 'C00-D48'), 1),
#  (('Sõrmusrakuline kartsinoom', 'C00-D48'), 1),
#  (('Vasaku neeru heledarakuline neerurakk-kartsinoom', 'C00-D48'), 1),
#  (('Vasaku , peabronh', 'C00-D48'), 1),
#  (('B-rakuline krooniline lümfotsüütleukeemia; TNM: IVst', 'C00-D48'), 1),
#  (('Vasema rinna inv.lobulaarkartsinoom; ÖR pos PR pos HER2 neg Ki67 20%',
#    'C00-D48'),
#   1),
#  (('Hepatotsellulaarne kartsinoom G1 (neuroendokriinse diferentseeringuga),  cT3a N0 M0 IIIA st',
#    'C00-D48'),
#   1),
#  (('Parema rinna inv.duktaalkartsinoom; ÖR pos PR pos HER2 neg Ki67 20%',
#    'C00-D48'),
#   1),
#  (('Adenocarcinoma G3', 'C00-D48'), 1),
#  (('T1,Nx,M0', 'C00-D48'), 1),
#  (('Paremal', 'C00-D48'), 1),
#  (('. High grade liposarkoom', 'C00-D48'), 1),
#  (('CT3N0M0 gL 3+2=5', 'C00-D48'), 1),
#  (('Myomae uteri submucosum I - 0 st (1,5x2,5cm); II - 1 st (D 2,5-3cm).',
#    'C00-D48'),
#   1),
#  (('Adenokartsinoom cT2N0M0', 'C00-D48'), 1),
#  (('Vasaku kopsu ülasagara lamerakk-kartsinoom c_T3_c_N2_M0_G2_IIIA st',
#    'C00-D48'),
#   1),
#  (('Mantelrakklümfoom', 'C00-D48'), 1),
#  (('U pahaloomuline kasvaja. metastaasid ajus, kopsudes', 'C00-D48'), 1),
#  (('Adenocarcinoma lobi sup.bronchi vel pulmonis dex. c TX NX M1 G3 IV st.',
#    'C00-D48'),
#   1),
#  (('Opereeritud 21.06.2012', 'C00-D48'), 1),
#  (('Pt2a n0 r0, gleason 3+3=6', 'C00-D48'), 1),
#  (('Ca! T2N1M1 IV st.', 'C00-D48'), 1),
#  (('A pahaloomuline kasvaja.', 'C00-D48'), 1),
#  (('Ca IV st.', 'C00-D48'), 1),
#  (('(Adenocarcinoma Tx NX M1 IV st.', 'C00-D48'), 1),
#  (('(duktaalne adenokartsinoom; c T3 N1 M1 IV st (maksametastaasid))',
#    'C00-D48'),
#   1),
#  (('Abaluu ja ülajäseme pikad luud ?.', 'C00-D48'), 1),
#  (('A tuumor, metastaas maksas.', 'C00-D48'), 1),
#  (('<ANONYM id="0" type="per" morph="_Y_ ?"/> lümfoom, <ANONYM id="1" type="per" morph="_Y_ sg el"/>',
#    'C00-D48'),
#   1),
#  (('Paremal õlavarrel', 'C00-D48'), 1),
#  (('Pk  IV st', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja; adenokartsinoom; c T4 N1 M1 IVst\nadenokartsinoom',
#    'C00-D48'),
#   1),
#  (('Operata 2003', 'C00-D48'), 1),
#  (('Melanoma  malignum', 'C00-D48'), 1),
#  (('Liitneevus\nliitneevus', 'C00-D48'), 1),
#  (('Neevused seljal', 'C00-D48'), 1),
#  (('Dermoidtsüst paremal', 'C00-D48'), 1),
#  (('Vasaku neeru helerakk-kartsinoom; Staadium arvel 04; yc T0 N0 M1 IVst\nVasaku neeru helerakk-kartsinoom',
#    'C00-D48'),
#   1),
#  (('- 2000op-tud', 'C00-D48'), 1),
#  (('M1 variant\nM1 variant', 'C00-D48'), 1),
#  (('P T1 N0 M0 R0 <ANONYM id="1" type="per" morph="_S_ sg n"/>', 'C00-D48'),
#   1),
#  (('Carcinoma squamocellulare', 'C00-D48'), 1),
#  (('Adenocarcinoma  endometrioides endometrii', 'C00-D48'), 1),
#  (('Opereeritud 2012', 'C00-D48'), 1),
#  (('Vasema rinna inv.duktaalkartsinoom; ÖR pos PR pos HER2 neg Ki67 30%',
#    'C00-D48'),
#   1),
#  (('Düsplaasia', 'C00-D48'), 1),
#  (('Carcinoma papillare; T1 N0 M0\nCarcinoma papillare', 'C00-D48'), 1),
#  (('ÖR/PR:POS; HER2 : neg; p T1C N1A M0 G1 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nÖR/PR:POS; HER2 : neg',
#    'C00-D48'),
#   1),
#  (('2010 G7, adenokartsinoom G2', 'C00-D48'), 1),
#  (('P T2 N0 M0 G2', 'C00-D48'), 1),
#  (('Munasarjade seroos-papillarne tsüstadenokartsinoom', 'C00-D48'), 1),
#  (('(paremas kopsus )', 'C00-D48'), 1),
#  (('( vähenemistendentsiga)', 'C00-D48'), 1),
#  (('Carcinoma mammae sin; p T1C N1A M0 G2 L1 IIst\nCarcinoma mammae sin',
#    'C00-D48'),
#   1),
#  (('Vasema rinna inv.duktaalkartsinoom; ÖR pos PR pos HER2 neg', 'C00-D48'),
#   1),
#  (('Melanoma reg dorsi', 'C00-D48'), 1),
#  (('Op.16.12.2015', 'C00-D48'), 1),
#  (('Staadium arvel 03', 'C00-D48'), 1),
#  (('Kilpnäärme papillaarne kartsinoom', 'C00-D48'), 1),
#  (('(areakõhre piirkond paremal)', 'C00-D48'), 1),
#  (('(op. - 25.04.2014.a.)', 'C00-D48'), 1),
#  (('Fibroadenoom', 'C00-D48'), 1),
#  (('Carcinoma papillare; pT1N0M0', 'C00-D48'), 1),
#  (('Staadium arvel 1A', 'C00-D48'), 1),
#  (('Aksillaarsel', 'C00-D48'), 1),
#  (('Häbeme piirkond, verrucosae', 'C00-D48'), 1),
#  (('Parema rinna kartsinoom; ÖR pos, PR neg, HER2 neg', 'C00-D48'), 1),
#  (('Vulval', 'C00-D48'), 1),
#  (('(dgn histoloogiliselt täpsustamata)', 'C00-D48'), 1),
#  (('Vasemal kaenlaalusi', 'C00-D48'), 1),
#  (('Düsplastil. piirikomponendiga  liitneevus', 'C00-D48'), 1),
#  (('Staadium arvel 01; <ANONYM id="1" type="per" morph="_S_ sg n"/>',
#    'C00-D48'),
#   1),
#  (('Silmalau, k.a silmanurga nahk, tsüstid', 'C00-D48'), 1),
#  (('Parema rinna invasiivne duktaalkartsinoom ÖR pos, PR neg, HER2 neg; p T1C N0 M0 G2 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nParema rinna invasiivne duktaalkartsinoom ÖR pos, PR neg, HER2 neg',
#    'C00-D48'),
#   1),
#  (('Cysta ovariid dextri', 'C00-D48'), 1),
#  (('Kolju- ja näoluud', 'C00-D48'), 1),
#  (('Mt-ga op. 210 III B st. CT. 18.06.2013- pat-ta', 'C00-D48'), 1),
#  (('Vasaku rinna kartsinoom; ÖR pos PR pos HER2 pos', 'C00-D48'), 1),
#  (('Ca mammae sin multilocularis operata. Täielik terapeutiline efekt\nCa mammae sin multilocularis operata. Täielik terapeutiline efekt',
#    'C00-D48'),
#   1),
#  (('Fibroadenoma mammae sin.', 'C00-D48'), 1),
#  (('ÖR/PR:POS; HER2 : neg; p T2 PN0- M0 G2 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nÖR/PR:POS; HER2 : neg',
#    'C00-D48'),
#   1),
#  (('Vasak labakäsi', 'C00-D48'), 1),
#  (('Cystoma ovarii dex.', 'C00-D48'), 1),
#  (('Kapilaarsed veenilaiendid mõlamatel jalgadel', 'C00-D48'), 1),
#  (('Emaka intramuraalne leiomüoom. Gr levis', 'C00-D48'), 1),
#  (('-IgA-müeloom <ANONYM id="0" type="per" morph="_Y_ ?"/> st', 'C00-D48'), 1),
#  (('(cysta ov. sin.)', 'C00-D48'), 1),
#  (('(dermoidtsüt laparoskoopiline op. 26.11.2013)', 'C00-D48'), 1),
#  (('Keskkõrv', 'C00-D48'), 1),
#  (('Vasaku kopsu alasagara perifeerne tuumor. Suurenenud mts l/s mediastiinumis, mts maksas',
#    'C00-D48'),
#   1),
#  (('Burkitti lümfoomi retsidiiv peaajus', 'C00-D48'), 1),
#  (('(   metastaatilised kolled peaajus)', 'C00-D48'), 1),
#  (('Emaka verejooksud', 'C00-D48'), 1),
#  (('Tagasenal ja funduses', 'C00-D48'), 1),
#  (('Yc T4B yc N0 M1 IVst', 'C00-D48'), 1),
#  (('Melanoma malignum reg. femoris dex.', 'C00-D48'), 1),
#  (('Vasaku reie tagumisel küljel', 'C00-D48'), 1),
#  (('Lobectomia dex 1990+väliskiiritus 1991\nlobectomia dex 1990+väliskiiritus 1991',
#    'C00-D48'),
#   1),
#  (('Staadium arvel 02; c T2 N0 M0 IIst', 'C00-D48'), 1),
#  (('Papillaarne vähk, op-tud 2009; pT1bN0M0, <ANONYM id="1" type="per" morph="_H_ sg n"/>.',
#    'C00-D48'),
#   1),
#  (('Retsidiiv; IIBst\nretsidiiv', 'C00-D48'), 1),
#  (('Paremal pool lõual', 'C00-D48'), 1),
#  (('Vasakul küljel aksillaarjoonel', 'C00-D48'), 1),
#  (('Intramuraalne ja ubmukoosene', 'C00-D48'), 1),
#  (('Parema kõrva ees', 'C00-D48'), 1),
#  (('IV B staadium\nIV B staadium', 'C00-D48'), 1),
#  (('Hingetoru, bronh ja kops. Vasaku kopsu ülasagaras.', 'C00-D48'), 1),
#  (('Muud ja täpsustamata t-rakklümfoomid', 'C00-D48'), 1),
#  (('Parema rinna invasiivne duktaalkartsinoom ÖR pos, PR pos, HER2 neg; p T1C N0 M0 G2 R0 <ANONYM id="1" type="per" morph="_H_ sg n"/>\nParema rinna invasiivne duktaalkartsinoom ÖR pos, PR pos, HER2 neg',
#    'C00-D48'),
#   1),
#  (('Väliskael, ST 0, pTis cN0M0', 'C00-D48'), 1),
#  (('IgA lambda III B st. (Salmon ja Durie järgi); Staadium arvel 03\nIgA lambda III B st. (Salmon ja Durie järgi)',
#    'C00-D48'),
#   1),
#  (('Lümfoplasmatsütaarne lümfoom.', 'C00-D48'), 1),
#  (('D 6cm, alustab Esmya raviga', 'C00-D48'), 1),
#  (('Carcinoma papillare pT1N0M0', 'C00-D48'), 1),
#  (('Parema rinna inv.duktaalkartsinoom; ÖR pos PR pos HER2 neg Ki67 8%',
#    'C00-D48'),
#   1),
#  (('Ulatub emakaõõnde', 'C00-D48'), 1),
#  (('( cum metrorrhagia)', 'C00-D48'), 1),
#  (('Pk/C50.1 Ca mammae dex st Ivpul, oss ( PK) Paikmed:  PK, Pahaloomulise kasvaja levik: 2p1 1pul, oss (X)',
#    'C00-D48'),
#   1),
#  (('Tubulaarsed adenoomid, alanevast käärsoolest eemaldatud; rektumist võetud biopsia',
#    'C00-D48'),
#   1),
#  (('Parema rinna inv.duktaalkartsinoom', 'C00-D48'), 1),
#  (('Ulatub ka lihasesse, D4.5cm', 'C00-D48'), 1),
#  (('Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom',
#    'C00-D48'),
#   1),
#  (('/Lymphohaemangioma reg, membri inf. sinistri/', 'C00-D48'), 1),
#  (('Ülasagar, bronh või kops, kahtlus', 'C00-D48'), 1),
#  (('Peaaju kelmed. Meningioma reg parietalis sin', 'C00-D48'), 1),
#  (('Carcinoma mammae sin', 'C00-D48'), 1),
#  (('Staadium arvel 2B', 'C00-D48'), 1),
#  (('Kerenahk; T1 N0 M0', 'C00-D48'), 1),
#  (('Reed`i neevus', 'C00-D48'), 1),
#  (('Ca papillare gl thyroidea T2N1M0 St I . Thyreiodectomia subtot. 07.05.2009. Jääktüreoidektoomia 11.08.09. Lymphadenectomia selective colli dex III-IV 28.06.10. I-131 therapia 06.09-08.10 550mCi',
#    'C00-D48'),
#   1),
#  (('Opereeritud august 2009; Staadium arvel 04\nopereeritud august 2009',
#    'C00-D48'),
#   1),
#  (('T2nxM0 Gl6', 'C00-D48'), 1),
#  (('P T4(1) NX M0 G3 LX VX R1 IIIst', 'C00-D48'), 1),
#  (('Neeruvähi metastaas vasakus kopsus\nNeeruvähi metastaas vasakus kopsus',
#    'C00-D48'),
#   1),
#  (('(Euromelonoomi kampaania dgn. 2015)', 'C00-D48'), 1),
#  (('Carcinoma squamocellularis vaginae; yp T2 N0 M0 G2 IIst\nCarcinoma squamocellularis vaginae',
#    'C00-D48'),
#   1),
#  (('Angioma stellatum\nangioma stellatum', 'C00-D48'), 1),
#  (('Gleason 3+3; p T1A NX M0 G1\nGleason 3+3', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja; Staadium arvel 3B', 'C00-D48'), 1),
#  (('Parema rinna kartsinoom ÖRpos, PRpos, HER2 neg; p T1C N0 M0 G1 R0 <ANONYM id="1" type="per" morph="_H_ sg n"/>\nParema rinna kartsinoom ÖRpos, PRpos, HER2 neg',
#    'C00-D48'),
#   1),
#  (('IgA kapa', 'C00-D48'), 1),
#  (('Ebaselge tähendusega monoklonaalne gammopaatia', 'C00-D48'), 1),
#  (('Melanoma malignum reg. glutealis dex.; p T1A N0 M0 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nmelanoma malignum reg. glutealis dex.',
#    'C00-D48'),
#   1),
#  (('Lümfotsütaarne lümfoom; <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nlümfotsütaarne lümfoom',
#    'C00-D48'),
#   1),
#  (('Papillaarne', 'C00-D48'), 1),
#  (('Carcinoma mammae sin multilocularis. Status post chemotherapiam',
#    'C00-D48'),
#   1),
#  (('Bilateraalne papillaarne tsüstadenoom', 'C00-D48'), 1),
#  (('E pk colon transvers. resektsioon  02. 2012', 'C00-D48'), 1),
#  (('Halo- neevused', 'C00-D48'), 1),
#  (('0 st. <ANONYM id="2" type="per" morph="_S_ sg g"/> järgi, A st. Binet järgi\n0 st. <ANONYM id="3" type="per" morph="_S_ sg g"/> järgi, A st. Binet järgi',
#    'C00-D48'),
#   1),
#  (('Adenocarcinoma  prostatae GS 4+3=7', 'C00-D48'), 1),
#  (('Alajäseme, k.a puusa sidekude ja muu pehme kude/dermatofibroom',
#    'C00-D48'),
#   1),
#  (('Ulatub limaskestani', 'C00-D48'), 1),
#  (('Adenocarcinoma prostatae; p T2B N0 M0 G2 IIst\nAdenocarcinoma prostatae',
#    'C00-D48'),
#   1),
#  (('Vasema rinna kartsinoom; ÖR pos PR pos HER2 neg', 'C00-D48'), 1),
#  (('Paremal küünarvarre piirkonnas', 'C00-D48'), 1),
#  (('In suspectu\nin suspectu', 'C00-D48'), 1),
#  (('- vasema rinna fibroadenoom', 'C00-D48'), 1),
#  (('IIIa st.', 'C00-D48'), 1),
#  (('Carcinoma  colli uteri; p T1B1 N0 M0 G2 LVI IB1st\nCarcinoma  colli uteri',
#    'C00-D48'),
#   1),
#  (('Fibroadenoomid paremas rinnas', 'C00-D48'), 1),
#  (('Melanoma in situ reg. fem dex', 'C00-D48'), 1),
#  (('Parempoolne', 'C00-D48'), 1),
#  (('E PK', 'C00-D48'), 1),
#  (('Op. 23.05. 2012.', 'C00-D48'), 1),
#  (('. Kergahel-müeloomtõbi IIIA st', 'C00-D48'), 1),
#  (('U ebaselge või teadmata loomusega kasvaja; Vasaku kopsu ülasagara tuumor',
#    'C00-D48'),
#   1),
#  (('(vasak õlavars)', 'C00-D48'), 1),
#  (('Melanoma vaginae; p T4B NX M0 IICst\nMelanoma vaginae', 'C00-D48'), 1),
#  (('Kere melanotsüütneevused/<ANONYM id="0" type="per" morph="_H_ sg n"/> neevus',
#    'C00-D48'),
#   1),
#  (('Umbsool; p T3 p N2 M0 G3 IIIst', 'C00-D48'), 1),
#  (('Spitsoidseks melanotsütaarseks tuumoriks ebaselge maliignsuspotentsiaaliga; p TX N0 M0 0st\nspitsoidseks melanotsütaarseks tuumoriks ebaselge maliignsuspotentsiaaliga',
#    'C00-D48'),
#   1),
#  (('Hulgimüeloom.IgG I A st.', 'C00-D48'), 1),
#  (('Vasema rinna inv.lobulaarkartsinoom; ÖR pos PR pos HER2 neg', 'C00-D48'),
#   1),
#  (('Vasaku rinna invasiivne duktaalkartsinoom ÖR neg, PR neg, HER2 neg',
#    'C00-D48'),
#   1),
#  (('Fibroadenomata mammae sin.', 'C00-D48'), 1),
#  (('Sõlmed 4 cm', 'C00-D48'), 1),
#  (('(ninaõõne uudismoodustis paremal)', 'C00-D48'), 1),
#  (('Melanoma malignum reg. cruris dextri; p T1B N0 M0 <ANONYM id="1" type="per" morph="_H_ sg n"/>\nMelanoma malignum reg. cruris dextri',
#    'C00-D48'),
#   1),
#  (('B-rakuline; <ANONYM id="1" type="per" morph="_S_ sg n"/>\nB-rakuline',
#    'C00-D48'),
#   1),
#  (('2,5 cm', 'C00-D48'), 1),
#  (('Et intramuraalne', 'C00-D48'), 1),
#  (('Intramuraalne ja subseroosne sõlm', 'C00-D48'), 1),
#  (('Mittesekreteeriv vorm; Staadium arvel 03\nmittesekreteeriv vorm',
#    'C00-D48'),
#   1),
#  (('Adenocarcinoma prostatae; c T2C N0 M0 IIBst\nAdenocarcinoma prostatae',
#    'C00-D48'),
#   1),
#  (('Papillaarse kartsinoomi follikulaarne variant, pT3NxMx III st.',
#    'C00-D48'),
#   1),
#  (('Mikrokartsinoom, thyreoidectomia', 'C00-D48'), 1),
#  (('Atüüpiline (kaelal)', 'C00-D48'), 1),
#  (('Se ebaselge või teadmata loomusega kasvaja\nparema külgvatsakese tagasarve piirkonnas',
#    'C00-D48'),
#   1),
#  (('CT3bN0M0 Gl7', 'C00-D48'), 1),
#  (('/ neurilemmoma', 'C00-D48'), 1),
#  (('(vasaku kopsu lingula alaosa perifeerne tuumor)', 'C00-D48'), 1),
#  (('Paremal reiel ka Naevus Beckeri', 'C00-D48'), 1),
#  (('ÖR/PR:POS; HER2 : neg; p T2 N1 M0 G3 R0 IIBst\nÖR/PR:POS; HER2 : neg',
#    'C00-D48'),
#   1),
#  (('1.remissioon\n1.remissioon', 'C00-D48'), 1),
#  (('Müksoidne degeneratsioon, D 20cm', 'C00-D48'), 1),
#  (('Ninal', 'C00-D48'), 1),
#  (('Vähenemistendentsiga oliD  8 cm, nüüd 6 cm', 'C00-D48'), 1),
#  (('Vasakul kubeme pk', 'C00-D48'), 1),
#  (('Hoidub submukoosele', 'C00-D48'), 1),
#  (('Pk op.- resekts.  1999.-( gastrosk= N. 07.11. 2013 )  - hemorraagia   18.04.2015',
#    'C00-D48'),
#   1),
#  (('T1A N0 M0', 'C00-D48'), 1),
#  (('Kolangio- e spisoonekartsinoom 2c0c1 IV', 'C00-D48'), 1),
#  (('Kaelal 2 tk', 'C00-D48'), 1),
#  (('Adenocarcinoma  prostatae  GS 3+5', 'C00-D48'), 1),
#  (('Parema rinna invasiivne duktaalkartsinoom ÖRneg, PRneg, HER2 pos',
#    'C00-D48'),
#   1),
#  (('Staadium arvel 04', 'C00-D48'), 1),
#  (('Kahtlus; Staadium arvel 03\nkahtlus', 'C00-D48'), 1),
#  (('Parem põsk', 'C00-D48'), 1),
#  (('Parema neeru helerakk-kartsinoom', 'C00-D48'), 1),
#  (('Tumor endometrioides ovarii dex borderline', 'C00-D48'), 1),
#  (('Täpsustamata emakakael (recidiva?)', 'C00-D48'), 1),
#  (('Sinineevus\nsinineevus', 'C00-D48'), 1),
#  (('Adenocarcinoma  prostatae  GS 5+4=9; p T3B N1 M0 G3 IVst\nAdenocarcinoma  prostatae  GS 5+4=9',
#    'C00-D48'),
#   1),
#  (('Naba sees', 'C00-D48'), 1),
#  (('Naba kõrval', 'C00-D48'), 1),
#  (('Silma (päris)soonkest e koroidea Naevus OS', 'C00-D48'), 1),
#  (('Paremal aksillaarselt', 'C00-D48'), 1),
#  (('Mitmeid sõlmi, vastab ras suurusele 9 näd. Jälgimisel', 'C00-D48'), 1),
#  (('Eesseinal', 'C00-D48'), 1),
#  (('Remissioonis\nremissioonis', 'C00-D48'), 1),
#  (('Vasemal emaka eesseinal läbimõõduga 1,5cm', 'C00-D48'), 1),
#  (('Papillaarne T1N0M0, lobectomia 08.2007\npapillaarne T1N0M0, lobectomia 08.2007',
#    'C00-D48'),
#   1),
#  (('Vasaku rinna invasiivne duktaalkartsinoom ÖR pos, PR neg, HER2 neg',
#    'C00-D48'),
#   1),
#  (('(op <ANONYM id="0" type="per" morph="_H_ sg n"/> 12.05.2015)', 'C00-D48'),
#   1),
#  (('IgG III A st; Staadium arvel 02\nIgG III A st', 'C00-D48'), 1),
#  (('Vasaku rinna kartsinoom; yc T0 N0 M0\nVasaku rinna kartsinoom', 'C00-D48'),
#   1),
#  (('Hulgisõlmed', 'C00-D48'), 1),
#  (('ÖR: ++ ; PR- ; HER2 : 1+; yp T1C(2) N1A M0 G2 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nÖR: ++ ; PR- ; HER2 : 1+',
#    'C00-D48'),
#   1),
#  (('Seljal kahtlus MM', 'C00-D48'), 1),
#  (('Parema rinna kartsinoom; yc T0 N0 M0\nParema rinna kartsinoom', 'C00-D48'),
#   1),
#  (('C T2 N0 M0 R2 IIst', 'C00-D48'), 1),
#  (('ÖR/PR:POS; HER2 : neg; yp T2 N3A M0 G1 IIICst\nÖR/PR:POS; HER2 : neg',
#    'C00-D48'),
#   1),
#  (('Operata. Gleason 3+4=7. R+.', 'C00-D48'), 1),
#  (('.Myoma magna', 'C00-D48'), 1),
#  (('. Myoma magna', 'C00-D48'), 1),
#  (('Seljal, paremal', 'C00-D48'), 1),
#  (('Parema inna inv+insitu kartsinoom', 'C00-D48'), 1),
#  (('Vasaku silma alusi', 'C00-D48'), 1),
#  (('SA TÜK K. <ANONYM id="0" type="per" morph="_H_ sg n"/> 19.03.2012',
#    'C00-D48'),
#   1),
#  (('(op. 2009)', 'C00-D48'), 1),
#  (('Naba piirkonnas', 'C00-D48'), 1),
#  (('Rindkere ülaosa', 'C00-D48'), 1),
#  (('Põsel ja kaela ülaosas', 'C00-D48'), 1),
#  (('Vasakul tuharal fibrolipoom', 'C00-D48'), 1),
#  (('Cysta ovarii dex.', 'C00-D48'), 1),
#  (('Anaplastne suurrakklümfoom, IVB st.\nAnaplastne suurrakklümfoom, IVB st.',
#    'C00-D48'),
#   1),
#  (('Intraduktaalsed papilloomid', 'C00-D48'), 1),
#  (('Endomeetriumi stromaalne sarkoom', 'C00-D48'), 1),
#  (('C T2A NX MX <ANONYM id="1" type="per" morph="_S_ sg n"/>', 'C00-D48'), 1),
#  (('Neevus kaela ees ja vasemal kaela küljel', 'C00-D48'), 1),
#  (('Kere melanotsüütneevused/düsplastiline neevus vas. puusal', 'C00-D48'), 1),
#  (('Lõual, kaelal', 'C00-D48'), 1),
#  (('Uterus myomatosus', 'C00-D48'), 1),
#  (('Carcinoma papilliferum, varietas follicularis; T2 NX M0', 'C00-D48'), 1),
#  (('Düsplaasia tunnustega', 'C00-D48'), 1),
#  (('- adenoom.', 'C00-D48'), 1),
#  (('Ülajäseme lühikesed luud - paremal käel 3. s. keskmisel lülil', 'C00-D48'),
#   1),
#  (('<ANONYM id="1" type="per" morph="_H_ sg n"/> naevus´e foonil on üks tumedama pigmendiga naevus',
#    'C00-D48'),
#   1),
#  (('A healoomuline kasvaja\ntubulovilloosne adenoom', 'C00-D48'), 1),
#  (('Polüpoidne liitneevus', 'C00-D48'), 1),
#  (('T1 N0 M0', 'C00-D48'), 1),
#  (('Et submucosum', 'C00-D48'), 1),
#  (('P T2A N0 M0 G3 <ANONYM id="1" type="per" morph="_Y_ sg el"/>', 'C00-D48'),
#   1),
#  (('-remissioonis', 'C00-D48'), 1),
#  (('Pk sin', 'C00-D48'), 1),
#  (('Adenokartsinoom G2', 'C00-D48'), 1),
#  (('Adenocarcinoma papillare gl. thyreoideae cum mets colli bilat. st. I T3N1bM0. Op. Crile funct. bilat. et thyreoidectomia totalis 30.05.07. I-131 ablatio 150 mCi 02.07.07',
#    'C00-D48'),
#   1),
#  (('. TCC G2', 'C00-D48'), 1),
#  (('0 st.', 'C00-D48'), 1),
#  (('CT2c Nx M0, Gleason 3+3=6.', 'C00-D48'), 1),
#  (('Parem küünarvars', 'C00-D48'), 1),
#  (('Operata', 'C00-D48'), 1),
#  (('Ca papillare gl thyroidea T2N1M0 St I . Thyreiodectomia subtot. 07.05.2009. Jääktüreoidektoomia 11.08.09. Lymphadenectomia selective colli dex III-IV 28.06.10. I-131 therapia 06.09-08.10 550mCi.',
#    'C00-D48'),
#   1),
#  (('Pk- ca mammae dx. st.III c p T2 (3) pN3 MII op. 12.11. 2013', 'C00-D48'),
#   1),
#  (('Kavernoosne', 'C00-D48'), 1),
#  (('Parema rinna invasiivne duktaalkartsinoomG2/G3 ÖRpos, PRpos, HER2skoor1+',
#    'C00-D48'),
#   1),
#  (('Regionis buccae sin', 'C00-D48'), 1),
#  (('Medulaarne, MEN2A', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja; Staadium arvel 01; p T2 N0 M0 G3 R0 <ANONYM id="1" type="per" morph="_S_ sg n"/>',
#    'C00-D48'),
#   1),
#  (('Vasaku jalalaba mediaalsel pinnal', 'C00-D48'), 1),
#  (('( emaka verejooksudega)', 'C00-D48'), 1),
#  (('Bence-Jonesi ; Staadium arvel 03; IIIAst\nBence-Jonesi', 'C00-D48'), 1),
#  (('Adenocarcinoma  prostatae, GS 2+3=5', 'C00-D48'), 1),
#  (('Kahtlus papillaarsele vähile', 'C00-D48'), 1),
#  (('Epideermaalne sünnimärk seljal', 'C00-D48'), 1),
#  (('Vasema kopsu levinud väikerakk karstinoom  hulgimetastaasidega (vas kops, aju, p. neer, vas. neerupealis, nahaalune kude)',
#    'C00-D48'),
#   1),
#  (('Vasaku rinna kartsinoom, ÖR neg, PR neg, HER 2 pos; p T1C N2A M0 IIIAst\nVasaku rinna kartsinoom, ÖR neg, PR neg, HER 2 pos',
#    'C00-D48'),
#   1),
#  (('E täpsustamata polüüp', 'C00-D48'), 1),
#  (('(op.-tud)', 'C00-D48'), 1),
#  (('(parempoolne pulmonektoomia 2002)', 'C00-D48'), 1),
#  (('(opereeritud)', 'C00-D48'), 1),
#  (('Paremal ( opereeritud.)', 'C00-D48'), 1),
#  (('(lümfotsütaarne lümfoom)', 'C00-D48'), 1),
#  (('(difuusne) segatüüpi väike- ja suurrakklümfoom', 'C00-D48'), 1),
#  (('(papilla Vateri?pankreasepea?)', 'C00-D48'), 1),
#  (('( op. 2008)', 'C00-D48'), 1),
#  (('Op.2006.a.', 'C00-D48'), 1),
#  (('I11.0 (2007a. opereeritud sigmasoole <ANONYM id="0" type="per" morph="_Y_ ?"/> lümfoom)',
#    'C00-D48'),
#   1),
#  (('Papillaarne; maliigsed l/s üla - ja keskmediastiinumis, kaela, mts. kopsudes.',
#    'C00-D48'),
#   1),
#  (('(MTS lümfisölmedesse)', 'C00-D48'), 1),
#  (('(opereeritud 1999) kopsumetastaasidega', 'C00-D48'), 1),
#  (('Sanatum', 'C00-D48'), 1),
#  (('.Cysta dermoidea dex.', 'C00-D48'), 1),
#  (('(op TÜK 30.04.2012)', 'C00-D48'), 1),
#  (('- polüüp (2007) !', 'C00-D48'), 1),
#  (('(vasak)', 'C00-D48'), 1),
#  (('(ravitud, loetud tervistunuks)', 'C00-D48'), 1),
#  (('Kolangio- e spisoonekertsi', 'C00-D48'), 1),
#  (('(op.TÜK-s 30.04.2012.a.)', 'C00-D48'), 1),
#  (('Vasakul; opereeritud + kiiritus- ja keemiaravi', 'C00-D48'), 1),
#  (('Carcinoma sigillocellulare G4; cT4aNxM1 (paraort l/s) - IV staadium',
#    'C00-D48'),
#   1),
#  (('Opereeritud\nopereeritud', 'C00-D48'), 1),
#  (('Lig.teres uteri fibroleiomüoom paremal', 'C00-D48'), 1),
#  (('Dermoidtsüst\ndermoidtsüst', 'C00-D48'), 1),
#  (('Polüübid ristikäärsooles ja sigmasooles, tubulaarne adenoom', 'C00-D48'),
#   1),
#  (('Opereeritud ja saanud süsteemravi 2003-2004 aastal', 'C00-D48'), 1),
#  (('Cystadenoma serosum ovarii dextri', 'C00-D48'), 1),
#  (('Meningioom para- ja intrasellaarselt', 'C00-D48'), 1),
#  (('Müelodüsplastiline sündroom (alates 2009)', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja\nStaadium IVB', 'C00-D48'), 1),
#  (('Polüübid ristikäärsooles ja sigmasooles, tubulaarne adenoom, eemaldatud',
#    'C00-D48'),
#   1),
#  (('(op. 2002.a.)', 'C00-D48'), 1),
#  (('Morfoloogiliselt lamerakk-või suurrakk-kartsinoom', 'C00-D48'), 1),
#  (('Parema sagara mikrofollikulaarne adenoom (eemaldatud)', 'C00-D48'), 1),
#  (('Parema rinna mitmekoldeline kartsinoom opereeritud 2009.a.', 'C00-D48'),
#   1),
#  (('Parema munasarja  beniigne Brenneri kasvaja', 'C00-D48'), 1),
#  (('I a st.', 'C00-D48'), 1),
#  (('Kilpnäärme parema sagara mikrofollikulaarne adenoom', 'C00-D48'), 1),
#  (('2013.a, praegu remissioonis', 'C00-D48'), 1),
#  (('Opereeritud 2007', 'C00-D48'), 1),
#  (('Paremal, opereeritud', 'C00-D48'), 1),
#  (('Kartsinoidtuumor Ki67 1% p T2(mm) c NX M0 G1 <ANONYM id="3" type="per" morph="_Y_ sg el"/>',
#    'C00-D48'),
#   1),
#  (('IgG I a st.', 'C00-D48'), 1),
#  (('(-)', 'C00-D48'), 1),
#  (('Paremal; opereeritud 2010.a.', 'C00-D48'), 1),
#  (('(2011. a)', 'C00-D48'), 1),
#  (('(papillaarne vähk, op. 2000.a. )', 'C00-D48'), 1),
#  (('Vasemal. Op. 2008', 'C00-D48'), 1),
#  (('Anamneesis; opereeritud 2006', 'C00-D48'), 1),
#  (('Mao polüübid', 'C00-D48'), 1),
#  (('Vasaku', 'C00-D48'), 1),
#  (('Intraduktaalsed papilloomid vasemas rinnas', 'C00-D48'), 1),
#  (('Vasak neer', 'C00-D48'), 1),
#  (('Parema rinna kartsionoom opereeritud 2008; saanud ka kiiritusravi',
#    'C00-D48'),
#   1),
#  (('Vas. nefrektoomia 1990.a', 'C00-D48'), 1),
#  (('Väike subseroosne sõlm', 'C00-D48'), 1),
#  (('(kiiritusravi järgne seisund)', 'C00-D48'), 1),
#  (('Opereritud 2007', 'C00-D48'), 1),
#  (('Op 2008, retsidiivita', 'C00-D48'), 1),
#  (('Adenokarcinoma in situ, tubulovilloosne adenoom, endoskoopiliselt eemaldatud',
#    'C00-D48'),
#   1),
#  (('Ravitud, retsidiivideta', 'C00-D48'), 1),
#  (('Neeruvähi metastaas parema kopsu ülasagaras (opereeritud)\nNeeruvähi metastaas parema kopsu ülasagaras (opereeritud)',
#    'C00-D48'),
#   1),
#  (('Maokeha (opereeritud 03.2011)', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja\nadenokartsinoom G2, I staadium', 'C00-D48'), 1),
#  (('Cysta ovarii sinistri', 'C00-D48'), 1),
#  (('Ca mammae sin operata', 'C00-D48'), 1),
#  (('CT2NxM0IIst', 'C00-D48'), 1),
#  (('Neer, tumor renis sin', 'C00-D48'), 1),
#  (('Opereeritud 1986', 'C00-D48'), 1),
#  (('Radikaalselt opereeritud 2010', 'C00-D48'), 1),
#  (('P T3A N0 M0 G1 R0; opereeritud 2013 a.', 'C00-D48'), 1),
#  (('Ca! mammae', 'C00-D48'), 1),
#  (('(parema, ainsa neeru)', 'C00-D48'), 1),
#  (('Kahltus', 'C00-D48'), 1),
#  (('- radikaalne prostatektoomia 2010', 'C00-D48'), 1),
#  (('Täpsustamata käärsool (opereeritud)', 'C00-D48'), 1),
#  (('Hereditary nonpolyposis colorectal cancer (HNPCC) e. Lynchi sündroom',
#    'C00-D48'),
#   1),
#  (('- op, 2013 sitnigraafia normis', 'C00-D48'), 1),
#  (('Vasemal frontaalsel transitsionaalne meningioom, WHO GI', 'C00-D48'), 1),
#  (('E pahaloomuline kasvaja; adenokartsinoom G2\nTNM: c T0 c N1 M1 G2 IVBst 04',
#    'C00-D48'),
#   1),
#  (('Pahaloomuline kasvaja\noperata', 'C00-D48'), 1),
#  (('Adenokartsinoom; yp T2 yp N0 M0 G3 R0 I st, opereeritud 30.11.2015',
#    'C00-D48'),
#   1),
#  (('E pahaloomuline kasvaja opereeritud', 'C00-D48'), 1),
#  (('Ülasagar, bronh või kopsoper. 2008 a.', 'C00-D48'), 1),
#  (('Cystoma ovarii magna. Ulatub palp. nabani.', 'C00-D48'), 1),
#  (('Piirpahaloomuline  vasemas munasarjas', 'C00-D48'), 1),
#  (('Opereeritud 30.11.2015; adenokartsinoom G3', 'C00-D48'), 1),
#  (('I pahaloomuline kasvaja\nopereeritud 2014; varasemalt: Staadium arvel 3B; p T4A N1B M0 G2 IIIBst',
#    'C00-D48'),
#   1),
#  (('Emakalihaskest (müomeetrium) opereeritud 2007', 'C00-D48'), 1),
#  (('Adenokartsinoom IIIB st; opereeritud 23.3.2015', 'C00-D48'), 1),
#  (('Kopsu metastaaside kahtlus rö-thorax alusel', 'C00-D48'), 1),
#  (('Vasaku rinna kartsinoom, 2010 opereeritud', 'C00-D48'), 1),
#  (('Marginaaltsooni lümfoom', 'C00-D48'), 1),
#  (('Vasaku neeru tuumorektoomia 2008', 'C00-D48'), 1),
#  (('.Orchiectomia 2014a', 'C00-D48'), 1),
#  (('IVB staadium', 'C00-D48'), 1),
#  (('Ülenev käärsool, status post operata', 'C00-D48'), 1),
#  (('Kusejuha', 'C00-D48'), 1),
#  (('. Myoma uteri', 'C00-D48'), 1),
#  (('(2003).', 'C00-D48'), 1),
#  (('(opereeritud 2011)', 'C00-D48'), 1),
#  (('Pahaloomuline kasvaja.', 'C00-D48'), 1),
#  (('-opereeritud', 'C00-D48'), 1),
#  (('-op-2011', 'C00-D48'), 1),
#  (('Meningioom', 'C00-D48'), 1),
#  (('OP 08 2011A cum met', 'C00-D48'), 1),
#  (('U pk', 'C00-D48'), 1),
#  (('Epidermaalne neevus \nepidermaalne neevus', 'C00-D48'), 1),
#  (('Angioomid', 'C00-D48'), 1),
#  (('Düsplastiline liitneevus', 'C00-D48'), 1),
#  (('Seljal', 'C00-D48'), 1),
#  (('Silma sidekest par.silm', 'C00-D48'), 1),
#  (('(opereeritud 07.03.2013)', 'C00-D48'), 1),
#  (('Haemangioma hepatis', 'C00-D48'), 1),
#  (('Võimalik prostata vähi läbikasv soolde', 'C00-D48'), 1),
#  (('TNM: pT2CpN0M0G2R1 IIB st.', 'C00-D48'), 1),
#  (('I pk (op-tud 2004)', 'C00-D48'), 1),
#  (('Peanahal\npeanahal', 'C00-D48'), 1),
#  (('Paremal põlveõndlusel\nparemal põlveõndlusel', 'C00-D48'), 1),
#  (('Ülajäseme, k.a õla nahk (SCC,2014.; vas. õlav.)', 'C00-D48'), 1),
#  (('- lupjunud', 'C00-D48'), 1),
#  (('(difuusne) väikerakklümfoom', 'C00-D48'), 1),
#  (('E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.2013',
#    'C00-D48'),
#   1),
#  (('Pk op. 2008.', 'C00-D48'), 1),
#  (('Bronhi ja kopsu pahaloomuline kasvaja, . Diagnoositud 09.2014a .',
#    'C00-D48'),
#   1),
#  (('Täpsustamata bronh või kops. Diagnoositud 09.2014a .', 'C00-D48'), 1),
#  (('Intramuraalne 1,8 cm', 'C00-D48'), 1),
#  (('IIIA st.', 'C00-D48'), 1),
#  (('Silma (päris)soonkest e koroidea OS', 'C00-D48'), 1),
#  (('Peaaju osalt kattuvate paikmete pahaloomuline kasvaja/op. 2013/',
#    'C00-D48'),
#   1),
#  (('Meningioom; op.2007 ja 2008', 'C00-D48'), 1),
#  (('( kahtlus )', 'C00-D48'), 1),
#  (('(opereeritud 2007)', 'C00-D48'), 1),
#  (('Maokeha/ opereeritud/', 'C00-D48'), 1),
#  (('E pk, G2T3N0M0 II st-.', 'C00-D48'), 1),
#  (('AdenoCa G2-G3.', 'C00-D48'), 1),
#  (('Epigastriumi  piirkond', 'C00-D48'), 1),
#  (('Nii vasaku kui parema abaluu pk-s', 'C00-D48'), 1),
#  (('(op.2013.)', 'C00-D48'), 1),
#  (('1 suur sõlm', 'C00-D48'), 1),
#  (('(Op.25.02.2011.)', 'C00-D48'), 1),
#  (('Od  Naevus /, silma (päris)soonkest e koroidea', 'C00-D48'), 1),
#  (('- Ca mammae dex', 'C00-D48'), 1),
#  (('. Kusepõiekael', 'C00-D48'), 1),
#  (('(ninavahesein paremal)', 'C00-D48'), 1),
#  (('(mediastenumis mts)', 'C00-D48'), 1),
#  (('. Maksaväline sapijuha', 'C00-D48'), 1),
#  (('Sapiteede muude ja täpsustamata osade pahaloomuline kasvaja.', 'C00-D48'),
#   1),
#  (('( türeoidektoomia 2002; radioablatsioon)', 'C00-D48'), 1),
#  (('2001 a. opereeritud inv. duktaalkartsinoom', 'C00-D48'), 1),
#  (('Vasakul abaluu alumise serva all.', 'C00-D48'), 1),
#  (('2012 aastal loetud tervistunuks; Staadium arvel 00\n2012 aastal loetud tervistunuks',
#    'C00-D48'),
#   1),
#  (('(oper 04.10)', 'C00-D48'), 1),
#  (('(2015)', 'C00-D48'), 1),
#  (('Maokeha (2012.)', 'C00-D48'), 1),
#  (('Umbsool, sanata', 'C00-D48'), 1),
#  (('Dermatofibroom ülaseljal, vasakul', 'C00-D48'), 1),
#  (('Pk- mao - gastrectoomis 02. 2012', 'C00-D48'), 1),
#  (('Opereeritud 2.10.14.', 'C00-D48'), 1),
#  (('Pk op. 1995', 'C00-D48'), 1),
#  (('(2008)', 'C00-D48'), 1),
#  (('04.07.2014 MASTECTOMIA RADICALIS <ANONYM id="1" type="per" morph="_Y_ ?"/> MODO MADDEN SIN',
#    'C00-D48'),
#   1),
#  (('(2004)', 'C00-D48'), 1),
#  (('Bilateraalsed fibroadenoomid\nBilateraalsed fibroadenoomid', 'C00-D48'),
#   1),
#  (('Duktaalne adenoom paremas rinnas', 'C00-D48'), 1),
#  (('. Emakakeha osalt kattuvate paikmete pahaloomuline kasvaja', 'C00-D48'),
#   1),
#  (('Emakakeha pahaloomuline kasvaja.', 'C00-D48'), 1),
#  (('Sigmakäärsool (<ANONYM id="0" type="per" morph="_Y_ ?"/>. 2013.)',
#    'C00-D48'),
#   1),
#  (('Näo muude ja täpsustamata osade nahk. ksantelasm', 'C00-D48'), 1),
#  (('Kõhul atüüpiline? neevus', 'C00-D48'), 1),
#  (('(ravitud)', 'C00-D48'), 1),
#  (('-operata', 'C00-D48'), 1),
#  (('Op.2004a.', 'C00-D48'), 1),
#  (('12.12', 'C00-D48'), 1),
#  (('Tupe melanoom', 'C00-D48'), 1),
#  (('Paremal tuharal\nparemal tuharal', 'C00-D48'), 1),
#  (('? vasemas põlveõndlas', 'C00-D48'), 1),
#  (('OP. 1996', 'C00-D48'), 1),
#  (('Atüüpiaga', 'C00-D48'), 1),
#  (('Angioma stellatum', 'C00-D48'), 1),
#  (('(UHD leid)', 'C00-D48'), 1),
#  (('Emaka intramuraalne leiomüoom, gr levis', 'C00-D48'), 1),
#  (('Vasakul käel', 'C00-D48'), 1),
#  (('Parem õlavars', 'C00-D48'), 1),
#  (('Alaselg', 'C00-D48'), 1),
#  (('Pk p T4 p N1 M0 G2 IIIst', 'C00-D48'), 1),
#  (('Rinna pahaloomuline kasvaja.', 'C00-D48'), 1),
#  (('Kõigi paikmete hemangioom. Angioomid.', 'C00-D48'), 1),
#  (('Kerenahk. Nahanäsad.', 'C00-D48'), 1),
#  (('Alalõua piirkonnas', 'C00-D48'), 1),
#  (('1994 (ravitud)', 'C00-D48'), 1),
#  (('Mt-ga', 'C00-D48'), 1),
#  (('(-)K.Org07.01.2015', 'C00-D48'), 1),
#  (('Peaaju pahaloomuline kasvaja.', 'C00-D48'), 1),
#  (('. Otsmikusagar', 'C00-D48'), 1),
#  (('(sapipõie polüübid)', 'C00-D48'), 1),
#  (('Ülajäseme, k.a õlanahk, kaenla all', 'C00-D48'), 1),
#  (('Tsüst vasakul', 'C00-D48'), 1),
#  (('(remissioon)', 'C00-D48'), 1),
#  (('Silmalau, k.a silmanurga nahk; os\nos', 'C00-D48'), 1),
#  (('Vasakul nimme piirkonnas', 'C00-D48'), 1),
#  (('Vasaku jala tallal', 'C00-D48'), 1),
#  (('Täpsustamata meessuguelund', 'C00-D48'), 1),
#  (('Kahtlus radioloogiliselt', 'C00-D48'), 1),
#  (('(kahtlustatav)', 'C00-D48'), 1),
#  (('(op.Talts 12.05.2015)', 'C00-D48'), 1),
#  (('Lipoom', 'C00-D48'), 1),
#  (('Paremas kardiofreenilises nurgas', 'C00-D48'), 1),
#  (('Düsplastiline neevus', 'C00-D48'), 1),
#  (('Ülasagar, bronh või kops, operata', 'C00-D48'), 1),
#  (('Paremal kubemes', 'C00-D48'), 1),
#  (('Silmalau, k.a silmanurga nahk par.silm ülalau nahal', 'C00-D48'), 1),
#  (('Pk MTS? lülisambas Osteoporoos', 'C00-D48'), 1),
#  (('Op 2007', 'C00-D48'), 1),
#  (('Duraalne venoosne angioom paremal frontaalsel', 'C00-D48'), 1),
#  (('Perikardi lipoom', 'C00-D48'), 1),
#  (('Parema talla all\nparema talla all', 'C00-D48'), 1),
#  (('Emaka intramuraalne leiomüoom ( operata 10.04.2014 )', 'C00-D48'), 1),
#  (('. Umbsool', 'C00-D48'), 1),
#  (('Op. 2001a.', 'C00-D48'), 1),
#  (('-op 2011a', 'C00-D48'), 1),
#  (('(?)', 'C00-D48'), 1),
#  (('Fibroma ovarii dex. (OP 21.01.2010)', 'C00-D48'), 1),
#  (('Emakakaela pahaloomuline kasvaja,  ?', 'C00-D48'), 1),
#  (('Emakakaela osalt kattuvate paikmete pahaloomuline kasvaja ?', 'C00-D48'),
#   1),
#  (('Silma (päris)soonkest e koroidea; koroidea neevus OS\nkoroidea neevus OS',
#    'C00-D48'),
#   1),
#  (('Väike', 'C00-D48'), 1),
#  (('Od Papilloma /, pea, näo ja kaela sidekude ja muu pehme kude', 'C00-D48'),
#   1),
#  (('Paremal vöö prk. 10.5 cm. - eise ga', 'C00-D48'), 1),
#  (('OP 26.05.2015', 'C00-D48'), 1),
#  (('Emakalihaskest', 'C00-D48'), 1),
#  (('E pk- coli transversi -( eraldi seis. kasvaja  02.2012) MRT- 04.2015 =N',
#    'C00-D48'),
#   1),
#  (('Pk-( gastrectomia  Roux  et coli transversi  02.2012 )MRT 04.2015=N',
#    'C00-D48'),
#   1),
#  (('(pT1A_N0_M0_I ast)', 'C00-D48'), 1),
#  (('C T3 NX M0 G1', 'C00-D48'), 1),
#  (('Tuharal', 'C00-D48'), 1),
#  (('Emakakaela pahaloomuline kasvaja.', 'C00-D48'), 1),
#  (('. Emakakaela osalt kattuvate paikmete pahaloomuline kasvaja', 'C00-D48'),
#   1),
#  (('(nov. 2013); konsolideeriva ravi (MTX)', 'C00-D48'), 1),
#  (('- eemaldatud emakas ja munasarjad 20.03.2014', 'C00-D48'), 1)]

# %%
stages = []
st = []
for i in cd_texts:
    stage_old = re.search('(?P<stage>(I[IV]+)|(I[^A-ZÜÕÖÄŠŽa-züõöäš])) *(?P<letter>[abcABC])? *(?P<st>st)?', i[0])
    stage = re.search('(I[IV]+ *[ABCabc]) *(st)?', i[0])
    stage2 = re.search('(I[IV]+) *st', i[0])
    stage3 = re.search('([0-5] *[ABCabc]) *(st)?', i[0])
    stage4 = re.search('([0-5]) *st', i[0])
    stage5 = re.search('st\.? *([0-5] *[ABCabc]*)', i[0])
    stage6 = re.search('st\.? *(I[IV]+ *[ABCabc]*)', i[0])
    #print(stage)
    #print(i)
    if stage:
        stages.append((i[0], stage.group('stage'), stage.group('letter'), stage.group('st')))
    #if re.search('(^|\s|[-,])(?=[MDCLXVI])M*(C[MD]|D?C*)(X[CL]|L?X*)(I[XV]|V?I*)($|\s|[-,])', i[0]):
        #roman.append(i)
    #elif 'st' in i[0]:
    #    st.append(i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-45ec3d8b439c> in <module>
#      12     #print(i)
#      13     if stage:
# ---> 14         stages.append((i[0], stage.group('stage'), stage.group('letter'), stage.group('st')))
#      15     #if re.search('(^|\s|[-,])(?=[MDCLXVI])M*(C[MD]|D?C*)(X[CL]|L?X*)(I[XV]|V?I*)($|\s|[-,])', i[0]):
#      16         #roman.append(i)
#
# IndexError: no such group

# %%
rooma täht st?
rooma st
araabia täht st?
araabia st
st rooma täht?
st araabia täht?

# %%
# 0 staadium
# araabia numbritega staadiumid
# st või st. enne numbrit
# tähega staadiumid ilma st-ta
# I, millele eelnevad valed asjad (suured tähed/nr'd)
# vv
# tee regex_tagger
# jooksuta diagnoositekstide lisadel
# jooksuta vähidiagnoosiga tekstiväljadel

# %%
len(stages)
# Out:
# 139

# %%
for i in stages:
    if i[3] is None:
        print(i)
# Out:
# ('4ac1c1PER IV', 'IV', None, None)
# ('Carcinima ovarii pT cNOMO st. IIIC.', 'III', 'C', None)
# ('Carcinoma anaplasticum ventriculi pT3N2M0 G3  st.IIb', 'II', 'b', None)
# ('Kolangio- e spisoonekartsinoom 2c0c1 IV   2', 'IV', None, None)
# ('B1 thymoma; Masaoka III', 'III', None, None)
# ('Adenokartsinoom; cT3cN1M0 IIIB enne neoadjuvantset kemoradiatsiooni', 'III', 'B', None)
# ('Difuusne B-suurrakk-lümfoom, IIEB', 'II', None, None)
# ('Juustega peanaha ja kaelanaha pahaloomuline melanoom pT3b Nx M0, R0 - st IIB', 'II', 'B', None)
# ('MGB G IV paremas otsmiku- ja oimusagaras', 'IV', None, None)
# ('. st IIIC', 'III', 'C', None)
# ('Myomae uteri submucosum I - 0 st (1,5x2,5cm); II - 1 st (D 2,5-3cm).', 'I ', None, None)
# ('Se pahaloomuline kasvaja; III vatsakese ja thalamuse piirkonna maligniseerunud epidermoidt', 'III', None, None)
# ('I pk', 'I ', None, None)
# ('Vasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg; p T1C N1MI M0 G1 R0 <ANONYM id="1" type="per" morph="_Y_ sg el"/>\nVasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg', 'I ', None, None)
# ('PT4B N 1MI M0 IIIAst', 'I ', None, None)
# ('E pk pT2N1aM0 st III', 'III', None, None)
# ('E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.20', 'III', 'b', None)
# ('Pk st IV', 'IV', None, None)
# ('Pk- ca mammae dx. st.III c p T2 (3) pN3 M0 op. 12.11. 2013', 'III', 'c', None)
# ('Ca papillare gl thyroidea T2N1M0 St I . Thyreiodectomia subtot. 07.05.2009. Jääktüreoidektoomia 11.08.09. Lymphadenectomia selective colli dex III-IV 28.06.10. I-131 therapia 06.09-08.10 550mCi', 'I ', None, None)
# ('P T3A N0 M0 LVI <ANONYM id="1" type="per" morph="_Y_ sg el"/>', 'I ', None, None)
# ('I pahaloomuline kasvaja; Staadium arvel 01', 'I ', None, None)
# ('Carcinoma  colli uteri; p T1B1 N0 M0 G2 LVI IB1st\nCarcinoma  colli uteri', 'I ', None, None)
# ('I pahaloomuline kasvaja', 'I ', None, None)
# ('Kolangio- e spisoonekartsinoom 2c0c1 IV', 'IV', None, None)
# ('I pahaloomuline kasvaja; Staadium arvel 03; c T2 N1 MX G2 IIIst', 'I ', None, None)
# ('I pk op. 2006', 'I ', None, None)
# ('PK 4bc1c1HEP IV   3', 'IV', None, None)
# ('IIIa', 'III', 'a', None)
# ('Adenocarcinoma papillare gl. thyreoideae cum mets colli bilat. st. I T3N1bM0. Op. Crile funct. bilat. et thyreoidectomia totalis 30.05.07. I-131 ablatio 150 mCi 02.07.07', 'I ', None, None)
# ('Ca papillare gl thyroidea T2N1M0 St I . Thyreiodectomia subtot. 07.05.2009. Jääktüreoidektoomia 11.08.09. Lymphadenectomia selective colli dex III-IV 28.06.10. I-131 therapia 06.09-08.10 550mCi.', 'I ', None, None)
# ('Pk- ca mammae dx. st.III c p T2 (3) pN3 MII op. 12.11. 2013', 'III', 'c', None)
# ('I11.0 (2007a. opereeritud sigmasoole <ANONYM id="0" type="per" morph="_Y_ ?"/> lümfoom)', 'I1', None, None)
# ('E pahaloomuline kasvaja\nStaadium IVB', 'IV', 'B', None)
# ('I pahaloomuline kasvaja\nopereeritud 2014; varasemalt: Staadium arvel 3B; p T4A N1B M0 G2 IIIBst', 'I ', None, None)
# ('I pk (op-tud 2004)', 'I ', None, None)
# ('E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.2013', 'III', 'b', None)
# ('I PK', 'I ', None, None)

# %%
len(st)
# Out:
# 204

# %%
st
# Out:
# [('(transformatsiooniga üle müelodüsplastilise sündroomi (RAEB2))', 'C00-D48'),
#  ('PK (stenditud)', 'C00-D48'),
#  ('- Ca. sigillocellulare ventriculi cum metastasibus.', 'C00-D48'),
#  ('Mitte-hodgkini tüüpi lümfoomi muud täpsustatud tüübid', 'C00-D48'),
#  ('.Bronchocarcinoma lobi inf. pulmonis dex. pT2 pNo MO st 1b ( operata 27.10.2009a ). Intoxicatio.',
#   'C00-D48'),
#  ('Aju metastaasidega', 'C00-D48'),
#  ('(IVB st)', 'C00-D48'),
#  ('Täpsustamata maks', 'C00-D48'),
#  ('Kaksteistsõrmik', 'C00-D48'),
#  ('IVBst. ALK+', 'C00-D48'),
#  ('----metastaasidega', 'C00-D48'),
#  ('Carcinima ovarii pT cNOMO st. IIIC.', 'C00-D48'),
#  ('Täpsustamata sapiteed', 'C00-D48'),
#  ('Vasema munasarja tsüst', 'C00-D48'),
#  ('Carcinoma anaplasticum ventriculi pT3N2M0 G3  st.IIb', 'C00-D48'),
#  ('Vasaku abaluu piirkonnas; p T1B N2C M0 R0 IIIBst\nvasaku abaluu piirkonnas',
#   'C00-D48'),
#  ('G3a; IIIAst\nG3a', 'C00-D48'),
#  ('E pahaloomuline kasvaja; mutsinoosadenokartsinoom; Staadium arvel 4B; c T4B N2 M1B IVBst\nmutsinoosadenokartsinoom',
#   'C00-D48'),
#  ('Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom ; c T2 N0 M1B IVBst\nTh 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom',
#   'C00-D48'),
#  ('IVCst', 'C00-D48'),
#  ('PK   3p3bp1PER, LYM, intestini tenui, coli', 'C00-D48'),
#  ('Alajäseme, k.a puusa pahaloomuline melanoom pTx pN1b M0 - IIIA st',
#   'C00-D48'),
#  ('Mutsinoosne tsüstadenoom', 'C00-D48'),
#  ('Melanoomi metastaas paremal fronto-temporaalsel', 'C00-D48'),
#  ('Carcinoma mammae dex. Status post chemotherapiam.', 'C00-D48'),
#  ('Cysta dermoides ovarii dex.', 'C00-D48'),
#  ('CT4B N2 M1B IVBst', 'C00-D48'),
#  ('E pahaloomuline kasvaja\nTNM: yc T0 N0 M0 G1 IVst', 'C00-D48'),
#  ('Adenocarcinoma prostatae GS 3+3=6', 'C00-D48'),
#  ('Metastaatiline munasarja lamerakk-kartsinoom sigmasoole seroosa ning parameetriumi ja väheses osas ka müomeetriumi haaratusega',
#   'C00-D48'),
#  ('Adenocarcinoma  prostatae GS 3+3=6', 'C00-D48'),
#  ('Täpsustamata naissuguelund', 'C00-D48'),
#  ('Sõrmusrakuline ca : c T3 cN1  M1 IVst.', 'C00-D48'),
#  ('Cysta dermoides ovarii sinistri', 'C00-D48'),
#  ('Adenocarcinoma prostatae GS 4+4=8', 'C00-D48'),
#  ('Kõhunäärmesaba, metastaasid luudes ja maksas', 'C00-D48'),
#  ('Bilateraalne dermoidtsüst', 'C00-D48'),
#  ('Kõhunäärmesaba; metastaasid luudes ja maksas', 'C00-D48'),
#  ('Cysta dermoides ovarii dextri', 'C00-D48'),
#  ('Adenocarcinoma  prostatae', 'C00-D48'),
#  ('Adenocarcinoma  prostatae GS 3+4=7', 'C00-D48'),
#  ('Anaplastne astrotsütoom G3', 'C00-D48'),
#  ('Müelodüsplastiline sündroom', 'C00-D48'),
#  ('Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom; kopsu-ja skeleti metastaasidega',
#   'C00-D48'),
#  ('Juustega peanaha ja kaelanaha pahaloomuline melanoom pT3b Nx M0, R0 - st IIB',
#   'C00-D48'),
#  ('. st IIIC', 'C00-D48'),
#  ('Täpsustamata rakutüüpi mitte-hodgkini tüüpi lümfoom', 'C00-D48'),
#  ('IVB st.', 'C00-D48'),
#  ('Multiformne glioblastoom F-T paremal, WHO G4', 'C00-D48'),
#  ('Peaaju ja ajukelmete metastaatiline pahaloomuline kasvaja (vasem hemisfäär)',
#   'C00-D48'),
#  ('IVst', 'C00-D48'),
#  ('Carcinoma mammae dex multilocularis. Status post chemotherapiam.',
#   'C00-D48'),
#  ('Carcinoma mammae sin multilocularis. Status post chemotherapiam. Täielik ravivastus',
#   'C00-D48'),
#  ('Vasak tuumornefrektoomia 08/2015, heledarakuline neerurakk-kartsinoom, G2; \nopereeritud vasaku kopsu metastaasid 07.12.2015',
#   'C00-D48'),
#  ('Maolävis;rc T3 rc NX M1 IVst', 'C00-D48'),
#  ('Adenocarcinoma  prostatae Gleason 3+4=7', 'C00-D48'),
#  ('B-rakuline krooniline lümfotsüütleukeemia; TNM: IVst', 'C00-D48'),
#  ('Hepatotsellulaarne kartsinoom G1 (neuroendokriinse diferentseeringuga),  cT3a N0 M0 IIIA st',
#   'C00-D48'),
#  ('Täpsustamata seedeelund', 'C00-D48'),
#  ('Vasaku kopsu ülasagara lamerakk-kartsinoom c_T3_c_N2_M0_G2_IIIA st',
#   'C00-D48'),
#  ('U pahaloomuline kasvaja. metastaasid ajus, kopsudes', 'C00-D48'),
#  ('A tuumor, metastaas maksas.', 'C00-D48'),
#  ('Pahaloomuline kasvaja; adenokartsinoom; c T4 N1 M1 IVst\nadenokartsinoom',
#   'C00-D48'),
#  ('P T2 N0 M0 G2 R2 IIst', 'C00-D48'),
#  ('IVBst', 'C00-D48'),
#  ('Dysplasticus\ndysplasticus', 'C00-D48'),
#  ('Juhuleiuna munasarjatsüsti operatsioonil elukohajärgses raviasutuses.',
#   'C00-D48'),
#  ('Dermoidtsüst paremal', 'C00-D48'),
#  ('Vasaku neeru helerakk-kartsinoom; Staadium arvel 04; yc T0 N0 M1 IVst\nVasaku neeru helerakk-kartsinoom',
#   'C00-D48'),
#  ('Cysta dermoides ovarii sin.', 'C00-D48'),
#  ('Munasarjade seroos-papillarne tsüstadenokartsinoom', 'C00-D48'),
#  ('( vähenemistendentsiga)', 'C00-D48'),
#  ('Carcinoma mammae sin; p T1C N1A M0 G2 L1 IIst\nCarcinoma mammae sin',
#   'C00-D48'),
#  ('Mantelrakk lümfoom; IIIAst\nMantelrakk lümfoom', 'C00-D48'),
#  ('Pk ( 2006.a. gastrektoomia , koletsüstektoomia )', 'C00-D48'),
#  ('Pahaloomuline kasvaja; IIst', 'C00-D48'),
#  ('IIIAst', 'C00-D48'),
#  ('(dgn histoloogiliselt täpsustamata)', 'C00-D48'),
#  ('Düsplastil. piirikomponendiga  liitneevus', 'C00-D48'),
#  ('Silmalau, k.a silmanurga nahk, tsüstid', 'C00-D48'),
#  ('PT4B N 1MI M0 IIIAst', 'C00-D48'),
#  ('Cysta ovariid dextri', 'C00-D48'),
#  ('IIst', 'C00-D48'),
#  ('Cystoma ovarii dex.', 'C00-D48'),
#  ('P T3A N2C M0 R0 IIIBst', 'C00-D48'),
#  ('Silma sidekest', 'C00-D48'),
#  ('-IgA-müeloom <ANONYM id="0" type="per" morph="_Y_ ?"/> st', 'C00-D48'),
#  ('(cysta ov. sin.)', 'C00-D48'),
#  ('Vasaku kopsu alasagara perifeerne tuumor. Suurenenud mts l/s mediastiinumis, mts maksas',
#   'C00-D48'),
#  ('(   metastaatilised kolled peaajus)', 'C00-D48'),
#  ('E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.20',
#   'C00-D48'),
#  ('Adenocarcinoma prostatae\nAdenocarcinoma prostatae', 'C00-D48'),
#  ('Yc T4B yc N0 M1 IVst', 'C00-D48'),
#  ('A kartsinoom in situ; p TIS N0 M0 0isst', 'C00-D48'),
#  ('Staadium arvel 02; c T2 N0 M0 IIst', 'C00-D48'),
#  ('Retsidiiv; IIBst\nretsidiiv', 'C00-D48'),
#  ('Muud ja täpsustamata t-rakklümfoomid', 'C00-D48'),
#  ('Täpsustamata kesknärvisüsteem', 'C00-D48'),
#  ('Pk/C50.1 Ca mammae dex st Ivpul, oss ( PK) Paikmed:  PK, Pahaloomulise kasvaja levik: 2p1 1pul, oss (X)',
#   'C00-D48'),
#  ('Tubulaarsed adenoomid, alanevast käärsoolest eemaldatud; rektumist võetud biopsia',
#   'C00-D48'),
#  ('Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom',
#   'C00-D48'),
#  ('/Lymphohaemangioma reg, membri inf. sinistri/', 'C00-D48'),
#  ('Pk- ca mammae dx. st.III c p T2 (3) pN3 M0 op. 12.11. 2013', 'C00-D48'),
#  ('Pk ( 2006 gastrektoomia , koletsüstektoomia )', 'C00-D48'),
#  ('Adenocarcinoma prostatae; c T2C N0 M0 G1 IIBst\nAdenocarcinoma prostatae',
#   'C00-D48'),
#  ('Opereeritud august 2009; Staadium arvel 04\nopereeritud august 2009',
#   'C00-D48'),
#  ('Vasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg; yc T0 N0 M1 IVst\nVasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg',
#   'C00-D48'),
#  ('P T4B N3 M0 R0 IIICst', 'C00-D48'),
#  ('Neeruvähi metastaas vasakus kopsus\nNeeruvähi metastaas vasakus kopsus',
#   'C00-D48'),
#  ('Carcinoma squamocellularis vaginae; yp T2 N0 M0 G2 IIst\nCarcinoma squamocellularis vaginae',
#   'C00-D48'),
#  ('Angioma stellatum\nangioma stellatum', 'C00-D48'),
#  ('Carcinoma mammae sin multilocularis. Status post chemotherapiam',
#   'C00-D48'),
#  ('Pk op.- resekts.  1999.-( gastrosk= N. 07.11. 2013 )', 'C00-D48'),
#  ('Bilateraalne papillaarne tsüstadenoom', 'C00-D48'),
#  ('IIIst', 'C00-D48'),
#  ('0 st. <ANONYM id="2" type="per" morph="_S_ sg g"/> järgi, A st. Binet järgi\n0 st. <ANONYM id="3" type="per" morph="_S_ sg g"/> järgi, A st. Binet järgi',
#   'C00-D48'),
#  ('P T4B N0 M0 R0 IICst', 'C00-D48'),
#  ('Adenocarcinoma  prostatae GS 4+3=7', 'C00-D48'),
#  ('Ulatub limaskestani', 'C00-D48'),
#  ('Adenocarcinoma prostatae; p T2B N0 M0 G2 IIst\nAdenocarcinoma prostatae',
#   'C00-D48'),
#  ('Staadium arvel 02; c T3 N0 M0 IIst', 'C00-D48'),
#  ('T-lümfoblastne lümfoom\nT-lümfoblastne lümfoom', 'C00-D48'),
#  ('Adenocarcinoma  prostatae Gleason 3+3=6', 'C00-D48'),
#  ('IIIa st.', 'C00-D48'),
#  ('. Kergahel-müeloomtõbi IIIA st', 'C00-D48'),
#  ('Melanoma vaginae; p T4B NX M0 IICst\nMelanoma vaginae', 'C00-D48'),
#  ('Umbsool; p T3 p N2 M0 G3 IIIst', 'C00-D48'),
#  ('Spitsoidseks melanotsütaarseks tuumoriks ebaselge maliignsuspotentsiaaliga; p TX N0 M0 0st\nspitsoidseks melanotsütaarseks tuumoriks ebaselge maliignsuspotentsiaaliga',
#   'C00-D48'),
#  ('Täpsustamata peaaju', 'C00-D48'),
#  ('(ninaõõne uudismoodustis paremal)', 'C00-D48'),
#  ('Adenocarcinoma prostatae; c T2C N0 M0 IIBst\nAdenocarcinoma prostatae',
#   'C00-D48'),
#  ('ÖR/PR:POS; HER2 : neg; p T2 N1 M0 G3 R0 IIBst\nÖR/PR:POS; HER2 : neg',
#   'C00-D48'),
#  ('Vähenemistendentsiga oliD  8 cm, nüüd 6 cm', 'C00-D48'),
#  ('Pk op.- resekts.  1999.-( gastrosk= N. 07.11. 2013 )  - hemorraagia   18.04.2015',
#   'C00-D48'),
#  ('Adenocarcinoma  prostatae  GS 3+5', 'C00-D48'),
#  ('Täpsustamata emakakael (recidiva?)', 'C00-D48'),
#  ('Adenocarcinoma  prostatae  GS 5+4=9; p T3B N1 M0 G3 IVst\nAdenocarcinoma  prostatae  GS 5+4=9',
#   'C00-D48'),
#  ('Silma (päris)soonkest e koroidea Naevus OS', 'C00-D48'),
#  ('Mitmeid sõlmi, vastab ras suurusele 9 näd. Jälgimisel', 'C00-D48'),
#  ('ÖR/PR:POS; HER2 : neg; yp T2 N3A M0 G1 IIICst\nÖR/PR:POS; HER2 : neg',
#   'C00-D48'),
#  ('Cysta ovarii dex.', 'C00-D48'),
#  ('Anaplastne suurrakklümfoom, IVB st.\nAnaplastne suurrakklümfoom, IVB st.',
#   'C00-D48'),
#  ('Endomeetriumi stromaalne sarkoom', 'C00-D48'),
#  ('Kere melanotsüütneevused/düsplastiline neevus vas. puusal', 'C00-D48'),
#  ('Düsplaasia tunnustega', 'C00-D48'),
#  ('0 st.', 'C00-D48'),
#  ('Bence-Jonesi ; Staadium arvel 03; IIIAst\nBence-Jonesi', 'C00-D48'),
#  ('Adenocarcinoma  prostatae, GS 2+3=5', 'C00-D48'),
#  ('Düsplastiline neevus?', 'C00-D48'),
#  ('Vasema kopsu levinud väikerakk karstinoom  hulgimetastaasidega (vas kops, aju, p. neer, vas. neerupealis, nahaalune kude)',
#   'C00-D48'),
#  ('Vasaku rinna kartsinoom, ÖR neg, PR neg, HER 2 pos; p T1C N2A M0 IIIAst\nVasaku rinna kartsinoom, ÖR neg, PR neg, HER 2 pos',
#   'C00-D48'),
#  ('E täpsustamata polüüp', 'C00-D48'),
#  ('(difuusne) väikeste lõhestunud rakkudega lümfoom', 'C00-D48'),
#  ('Maksa-kõhunäärmeampull [Vateri] pahaloomuline kasvaja; op.-tud 2004 nov.\nWhipple lõikus, adenokartsinoom G2, pT1N0M0G2R0 <ANONYM id="1" type="per" morph="_Y_ ?"/> st.',
#   'C00-D48'),
#  ('Papillaarne; maliigsed l/s üla - ja keskmediastiinumis, kaela, mts. kopsudes.',
#   'C00-D48'),
#  ('(opereeritud 1999) kopsumetastaasidega', 'C00-D48'),
#  ('.Cysta dermoidea dex.', 'C00-D48'),
#  ('(ravitud, loetud tervistunuks)', 'C00-D48'),
#  ('Täpsustamata difuusne mitte-hodgkini tüüpi lümfoom', 'C00-D48'),
#  ('Dermoidtsüst\ndermoidtsüst', 'C00-D48'),
#  ('Polüübid ristikäärsooles ja sigmasooles, tubulaarne adenoom', 'C00-D48'),
#  ('Opereeritud ja saanud süsteemravi 2003-2004 aastal', 'C00-D48'),
#  ('Cystadenoma serosum ovarii dextri', 'C00-D48'),
#  ('Müelodüsplastiline sündroom (alates 2009)', 'C00-D48'),
#  ('Polüübid ristikäärsooles ja sigmasooles, tubulaarne adenoom, eemaldatud',
#   'C00-D48'),
#  ('Neeruvähi metastaas parema kopsu ülasagaras (opereeritud)\nNeeruvähi metastaas parema kopsu ülasagaras (opereeritud)',
#   'C00-D48'),
#  ('Cysta ovarii sinistri', 'C00-D48'),
#  ('CT2NxM0IIst', 'C00-D48'),
#  ('- radikaalne prostatektoomia 2010', 'C00-D48'),
#  ('Täpsustamata käärsool (opereeritud)', 'C00-D48'),
#  ('E pahaloomuline kasvaja; adenokartsinoom G2\nTNM: c T0 c N1 M1 G2 IVBst 04',
#   'C00-D48'),
#  ('Cystoma ovarii magna. Ulatub palp. nabani.', 'C00-D48'),
#  ('Emakalihaskest (müomeetrium) opereeritud 2007', 'C00-D48'),
#  ('Adenokartsinoom IIIB st; opereeritud 23.3.2015', 'C00-D48'),
#  ('Kopsu metastaaside kahtlus rö-thorax alusel', 'C00-D48'),
#  ('IVB staadium', 'C00-D48'),
#  ('Ülenev käärsool, status post operata', 'C00-D48'),
#  ('Düsplastiline liitneevus', 'C00-D48'),
#  ('Silma sidekest par.silm', 'C00-D48'),
#  ('Võimalik prostata vähi läbikasv soolde', 'C00-D48'),
#  ('IIICst', 'C00-D48'),
#  ('TNM: pT2CpN0M0G2R1 IIB st.', 'C00-D48'),
#  ('E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.2013',
#   'C00-D48'),
#  ('Täpsustamata bronh või kops. Diagnoositud 09.2014a .', 'C00-D48'),
#  ('IIIA st.', 'C00-D48'),
#  ('Silma (päris)soonkest e koroidea OS', 'C00-D48'),
#  ('Epigastriumi  piirkond', 'C00-D48'),
#  ('Od  Naevus /, silma (päris)soonkest e koroidea', 'C00-D48'),
#  ('(mediastenumis mts)', 'C00-D48'),
#  ('Sapiteede muude ja täpsustamata osade pahaloomuline kasvaja.', 'C00-D48'),
#  ('2012 aastal loetud tervistunuks; Staadium arvel 00\n2012 aastal loetud tervistunuks',
#   'C00-D48'),
#  ('Pk- mao - gastrectoomis 02. 2012', 'C00-D48'),
#  ('Näo muude ja täpsustamata osade nahk. ksantelasm', 'C00-D48'),
#  ('Angioma stellatum', 'C00-D48'),
#  ('Pk p T4 p N1 M0 G2 IIIst', 'C00-D48'),
#  ('Tsüst vasakul', 'C00-D48'),
#  ('Täpsustamata meessuguelund', 'C00-D48'),
#  ('(kahtlustatav)', 'C00-D48'),
#  ('Düsplastiline neevus', 'C00-D48'),
#  ('Pk MTS? lülisambas Osteoporoos', 'C00-D48'),
#  ('Silma (päris)soonkest e koroidea; koroidea neevus OS\nkoroidea neevus OS',
#   'C00-D48'),
#  ('Emakalihaskest', 'C00-D48'),
#  ('Pk-( gastrectomia  Roux  et coli transversi  02.2012 )MRT 04.2015=N',
#   'C00-D48'),
#  ('(pT1A_N0_M0_I ast)', 'C00-D48')]

# %%
tagger = CancerStageTagger()

# %%
tagged_texts = []
not_tagged_texts = []
for t in cd_texts:
    text = Text(t[0])
    tagger.tag(text)
    if len(text.stages) > 0:
        tagged_texts.append(text)
    else:
        not_tagged_texts.append(t)

# %%
len(tagged_texts)
# Out:
# 127

# %%
len(not_tagged_texts)
# Out:
# 787

# %%
tagged_texts[0].stages
# Out:
# Layer(name='stages', attributes=('grammar_symbol', 'regex_type', 'value', '_priority_'), spans=SL[Span('IV a st', [{'grammar_symbol': 'STAGE', 'regex_type': 'r1', 'value': 'IV a', '_priority_': 0}])])

# %%
for t in tagged_texts:
    print(t.text)
    print(t.stages.value)
# Out:
# Adenokartsinoom: c T3 N1 M1a IV a st.
# [['IV a']]
# .Bronchocarcinoma lobi inf. pulmonis dex. pT2 pNo MO st 1b ( operata 27.10.2009a ). Intoxicatio.
# [['1b']]
# Pahaloomuline kasvaja; p T4 N0, M0 III st.
# [['III']]
# (IVB st)
# [['IVB']]
# IV st
# [['IV']]
# IVBst. ALK+
# [['IVB']]
# Carcinima ovarii pT cNOMO st. IIIC.
# [['IIIC']]
# Carcinoma anaplasticum ventriculi pT3N2M0 G3  st.IIb
# [['IIb']]
# 4 c 1 c X III st.
# [['III']]
# Vasaku abaluu piirkonnas; p T1B N2C M0 R0 IIIBst
# vasaku abaluu piirkonnas
# [['IIIB']]
# IgG III A st
# IgG III A st
# [['III A'], ['III A']]
# G3a; IIIAst
# G3a
# [['IIIA']]
# E pahaloomuline kasvaja; mutsinoosadenokartsinoom; Staadium arvel 4B; c T4B N2 M1B IVBst
# mutsinoosadenokartsinoom
# [['IVB']]
# Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom ; c T2 N0 M1B IVBst
# Th 6-11 paravertebraalne perifeerne primitiivne neuroektodermaalne tuumor/ekstraossaalne Ewingi sarkoom
# [['IVB']]
# IVCst
# [['IVC']]
# Alajäseme, k.a puusa pahaloomuline melanoom pTx pN1b M0 - IIIA st
# [['IIIA']]
# CT4B N2 M1B IVBst
# [['IVB']]
# E pahaloomuline kasvaja
# TNM: yc T0 N0 M0 G1 IVst
# [['IV']]
# IgG I A st.
# [['I A']]
# I st <ANONYM id="1" type="per" morph="_S_ sg g"/> järgi,B st Binet järgi
# [['I']]
# Sõrmusrakuline ca.c T3 c NX M1 IV st
# [['IV']]
# Sõrmusrakuline ca : c T3 cN1  M1 IVst.
# [['IV']]
# Pahaloomuline kasvaja c T3 c N1 M1 IV st.
# [['IV']]
# Adenokartsinoom; cT3cN1M0 IIIB enne neoadjuvantset kemoradiatsiooni
# [['IIIB']]
# IV st. <ANONYM id="1" type="per" morph="_S_ sg g"/> järgi, C st. Binet järgi
# [['IV']]
# II st <ANONYM id="1" type="per" morph="_S_ sg g"/> järgi
# [['II']]
# III B st.
# [['III B']]
# Juustega peanaha ja kaelanaha pahaloomuline melanoom pT3b Nx M0, R0 - st IIB
# [['IIB']]
# . st IIIC
# [['IIIC']]
# . IV B st
# [['IV B']]
# IVB st.
# [['IVB']]
# IVst
# [['IV']]
# Maolävis;rc T3 rc NX M1 IVst
# [['IV']]
# B-rakuline krooniline lümfotsüütleukeemia; TNM: IVst
# [['IV']]
# Hepatotsellulaarne kartsinoom G1 (neuroendokriinse diferentseeringuga),  cT3a N0 M0 IIIA st
# [['IIIA']]
# Myomae uteri submucosum I - 0 st (1,5x2,5cm); II - 1 st (D 2,5-3cm).
# [['0'], ['1']]
# Vasaku kopsu ülasagara lamerakk-kartsinoom c_T3_c_N2_M0_G2_IIIA st
# [['IIIA']]
# Adenocarcinoma lobi sup.bronchi vel pulmonis dex. c TX NX M1 G3 IV st.
# [['IV']]
# Ca! T2N1M1 IV st.
# [['IV']]
# Ca IV st.
# [['IV']]
# C T2M1 IV st
# [['IV']]
# (Adenocarcinoma Tx NX M1 IV st.
# [['IV']]
# (duktaalne adenokartsinoom; c T3 N1 M1 IV st (maksametastaasid))
# [['IV']]
# E pk pk pT2N0M0G3  I st.  IIb--IIIkl. gr- 1999.a.
# [['IIb']]
# Pk  IV st
# [['IV']]
# IV st.
# [['IV']]
# Pahaloomuline kasvaja; adenokartsinoom; c T4 N1 M1 IVst
# adenokartsinoom
# [['IV']]
# P T2 N0 M0 G2 R2 IIst
# [['II']]
# IVBst
# [['IVB']]
# Vasaku neeru helerakk-kartsinoom; Staadium arvel 04; yc T0 N0 M1 IVst
# Vasaku neeru helerakk-kartsinoom
# [['IV']]
# Carcinoma mammae sin; p T1C N1A M0 G2 L1 IIst
# Carcinoma mammae sin
# [['II']]
# Mantelrakk lümfoom; IIIAst
# Mantelrakk lümfoom
# [['IIIA']]
# Pahaloomuline kasvaja; IIst
# [['II']]
# C T3 NX M1C IVst
# [['IV']]
# IIIAst
# [['IIIA']]
# I staadium <ANONYM id="2" type="per" morph="_S_ sg g"/> järgi
# I staadium <ANONYM id="3" type="per" morph="_S_ sg g"/> järgi
# [['I'], ['I']]
# PT4B N 1MI M0 IIIAst
# [['IIIA']]
# Mt-ga op. 210 III B st. CT. 18.06.2013- pat-ta
# [['III B']]
# IIst
# [['II']]
# P T3A N2C M0 R0 IIIBst
# [['IIIB']]
# E pk pT2N1aM0 st III
# [['III']]
# Pk, 2C, p T4B N0 M0 G2 II C st
# [['II C']]
# E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.20
# [['IIIb']]
# Yc T4B yc N0 M1 IVst
# [['IV']]
# III staadium <ANONYM id="2" type="per" morph="_S_ sg g"/> järgi, B staadium Binet järgi
# III staadium <ANONYM id="3" type="per" morph="_S_ sg g"/> järgi, B staadium Binet järgi
# [['III'], ['III']]
# Staadium arvel 02; c T2 N0 M0 IIst
# [['II']]
# Retsidiiv; IIBst
# retsidiiv
# [['IIB']]
# Pk st IV
# [['IV']]
# IV B staadium
# IV B staadium
# [['IV B'], ['IV B']]
# IgA lambda III B st. (Salmon ja Durie järgi); Staadium arvel 03
# IgA lambda III B st. (Salmon ja Durie järgi)
# [['III B'], ['III B']]
# Pk/C50.1 Ca mammae dex st Ivpul, oss ( PK) Paikmed:  PK, Pahaloomulise kasvaja levik: 2p1 1pul, oss (X)
# [['I']]
# Pk- ca mammae dx. st.III c p T2 (3) pN3 M0 op. 12.11. 2013
# [['III c']]
# Adenocarcinoma prostatae; c T2C N0 M0 G1 IIBst
# Adenocarcinoma prostatae
# [['IIB']]
# Opereeritud august 2009; Staadium arvel 04
# opereeritud august 2009
# [['2'], ['2']]
# Vasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg; yc T0 N0 M1 IVst
# Vasaku rinna kartsinoom ÖRpos, PRpos, HER2 neg
# [['IV']]
# P T4(1) NX M0 G3 LX VX R1 IIIst
# [['III']]
# P T4B N3 M0 R0 IIICst
# [['IIIC']]
# Carcinoma squamocellularis vaginae; yp T2 N0 M0 G2 IIst
# Carcinoma squamocellularis vaginae
# [['II']]
# IIIst
# [['III']]
# 0 st. <ANONYM id="2" type="per" morph="_S_ sg g"/> järgi, A st. Binet järgi
# 0 st. <ANONYM id="3" type="per" morph="_S_ sg g"/> järgi, A st. Binet järgi
# [['0'], ['0']]
# P T4B N0 M0 R0 IICst
# [['IIC']]
# Adenocarcinoma prostatae; p T2B N0 M0 G2 IIst
# Adenocarcinoma prostatae
# [['II']]
# Staadium arvel 02; c T3 N0 M0 IIst
# [['II']]
# IIIa st.
# [['IIIa']]
# Carcinoma  colli uteri; p T1B1 N0 M0 G2 LVI IB1st
# Carcinoma  colli uteri
# [['IB'], ['1']]
# . Kergahel-müeloomtõbi IIIA st
# [['IIIA']]
# Melanoma vaginae; p T4B NX M0 IICst
# Melanoma vaginae
# [['IIC']]
# Umbsool; p T3 p N2 M0 G3 IIIst
# [['III']]
# Spitsoidseks melanotsütaarseks tuumoriks ebaselge maliignsuspotentsiaaliga; p TX N0 M0 0st
# spitsoidseks melanotsütaarseks tuumoriks ebaselge maliignsuspotentsiaaliga
# [['0']]
# Hulgimüeloom.IgG I A st.
# [['I A']]
# Adenocarcinoma prostatae; c T2C N0 M0 IIBst
# Adenocarcinoma prostatae
# [['IIB']]
# Papillaarse kartsinoomi follikulaarne variant, pT3NxMx III st.
# [['III']]
# ÖR/PR:POS; HER2 : neg; p T2 N1 M0 G3 R0 IIBst
# ÖR/PR:POS; HER2 : neg
# [['IIB']]
# Adenocarcinoma  prostatae  GS 5+4=9; p T3B N1 M0 G3 IVst
# Adenocarcinoma  prostatae  GS 5+4=9
# [['IV']]
# IgA kapa, I A st.; Staadium arvel 01
# IgA kapa, I A st.
# [['I A'], ['I A']]
# I pahaloomuline kasvaja; Staadium arvel 03; c T2 N1 MX G2 IIIst
# [['III']]
# IgG III A st; Staadium arvel 02
# IgG III A st
# [['III A'], ['III A']]
# C T2 N0 M0 R2 IIst
# [['II']]
# ÖR/PR:POS; HER2 : neg; yp T2 N3A M0 G1 IIICst
# ÖR/PR:POS; HER2 : neg
# [['IIIC']]
# Anaplastne suurrakklümfoom, IVB st.
# Anaplastne suurrakklümfoom, IVB st.
# [['IVB'], ['IVB']]
# IIIa
# [['IIIa']]
# Adenocarcinoma papillare gl. thyreoideae cum mets colli bilat. st. I T3N1bM0. Op. Crile funct. bilat. et thyreoidectomia totalis 30.05.07. I-131 ablatio 150 mCi 02.07.07
# [['I']]
# 0 st.
# [['0']]
# Pk- ca mammae dx. st.III c p T2 (3) pN3 MII op. 12.11. 2013
# [['III c']]
# Bence-Jonesi ; Staadium arvel 03; IIIAst
# Bence-Jonesi
# [['IIIA']]
# Vasaku rinna kartsinoom, ÖR neg, PR neg, HER 2 pos; p T1C N2A M0 IIIAst
# Vasaku rinna kartsinoom, ÖR neg, PR neg, HER 2 pos
# [['IIIA']]
# B rakuline, I staadium
# [['I']]
# Carcinoma sigillocellulare G4; cT4aNxM1 (paraort l/s) - IV staadium
# [['IV']]
# E pahaloomuline kasvaja
# Staadium IVB
# [['IVB']]
# I a st.
# [['I a']]
# IgG  I a st.
# [['I a']]
# IgG I a st.
# [['I a']]
# E pahaloomuline kasvaja
# adenokartsinoom G2, I staadium
# [['I']]
# CT2NxM0IIst
# [['II']]
# E pahaloomuline kasvaja; adenokartsinoom G2
# TNM: c T0 c N1 M1 G2 IVBst 04
# [['IVB']]
# Adenokartsinoom; yp T2 yp N0 M0 G3 R0 I st, opereeritud 30.11.2015
# [['I']]
# I pahaloomuline kasvaja
# opereeritud 2014; varasemalt: Staadium arvel 3B; p T4A N1B M0 G2 IIIBst
# [['IIIB']]
# Adenokartsinoom IIIB st; opereeritud 23.3.2015
# [['IIIB']]
# IVB staadium
# [['IVB']]
# IIICst
# [['IIIC']]
# TNM: pT2CpN0M0G2R1 IIB st.
# [['IIB']]
# E pk -26.08.2013- adenocarcinoma tubulare coli sigmoideipT3N1cM0G2 st.IIIb-op. 04.09.2013
# [['IIIb']]
# IIIA st.
# [['IIIA']]
# E pk, G2T3N0M0 II st-.
# [['II']]
# 04.07.2014 MASTECTOMIA RADICALIS <ANONYM id="1" type="per" morph="_Y_ ?"/> MODO MADDEN SIN
# [['IA'], ['IC']]
# Pk p T4 p N1 M0 G2 IIIst
# [['III']]
# (pT1A_N0_M0_I ast)
# [['I a']]

# %%
tagger.tag(Text('Myomae uteri submucosum I - 0 st (1,5x2,5cm); II - 1 st (D 2,5-3cm).')).stages[0]
# Out:
# Span('I ', [{'grammar_symbol': 'STAGE_OLD', 'regex_type': 'stage_1', 'value': 'I', '_priority_': 1}])
