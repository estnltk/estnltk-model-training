# %%
from estnltk import Text
import csv
from datetime import datetime
from tqdm import tqdm
import psycopg2
import re

# %%
from cda_data_cleaning.common.db_operations import create_connection
from cda_data_cleaning.common import read_config

# %%
config_file = 'egcut_epi.ini'
config = read_config(config_file)

conn = create_connection(config)
cur = conn.cursor()

# %%
def clean_date(date_str):
    '''
    Turn datestring into datetime object
    '''
    if date_str:
        stripped_date = date_str.strip('\t\n,a ')
        stripped_date = stripped_date.replace(' ', '.')
        stripped_date = stripped_date.replace('..', '.')
    else:
        return
    if len(stripped_date) == 8:
        date = datetime.strptime(stripped_date, '%Y%m%d')
        return date
    elif len(stripped_date) == 9 and re.match('[0-9]\.', stripped_date):
        stripped_date_fixed = '0' + stripped_date
        date = datetime.strptime(stripped_date_fixed, '%d.%m.%Y')
        return date
    elif len(stripped_date) == 10:
        date = datetime.strptime(stripped_date, '%d.%m.%Y')
        return date
    else:
        return

# %%
clean_date(' ') == None
# Out:
# True

# %%
with open("parsed_drugs.csv", "r") as fin:
    reader = csv.reader(fin)
    #for row in tqdm(new_rows):
    for idx, row in enumerate(reader):
        if idx%1000000 == 0:
            print(idx)
        new_date = clean_date(row[3])
        if len(row[3]) > 2 and new_date == None:
            print(row[3])
            print(row)
# Out:
# 0
# 1000000
# kuupäev
# ['914531', '5053475', 'a', 'kuupäev', 'N06AX11', 'ESPRITAL 30', 'Mirtazapinum']
# 2000000
# 3000000
# 4000000
# 5000000
#  203483
#
# ['3667196', '44758971', 'a', ' 203483\n', 'N05AA02', '', 'Levomepromazinum']
# 6000000
#  207035,
# ['4324191', '58654955', 'a', ' 207035,', 'R01AD12', 'AVAMYS', 'Fluticasonum furoas']
#  141964,
# ['4365137', '58626874', 'a', ' 141964,', 'R06AX17', '', 'Ketotifenum']
# 7000000
# 8000000
# 9000000

# %%
t = '''
Väljastamise kuupäev: 08.03.2010, Retsepti number:  1000587736, Ravimi nimetus:  30TK, Originaalide arv: 2, ATC kood: N05BA08, Toimeaine: Bromazepamum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 0%, Annustamine: 1 ta 2 x pv Väljastamise kuupäev: 08.03.2010, Retsepti number:  1000587764, Ravimi nimetus:  25ml 1TK, Originaalide arv: 1, ATC kood: N05BA01, Toimeaine: Diazepamum, Ravimvorm: suukaudsed tilgad, lahus, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 15 tilka vaj.  Väljastamise kuupäev: 08.03.2010, Retsepti number:  1000587807, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 13.04.2010, Retsepti number:  1000952439, Ravimi nimetus: TRUXAL 100TK, Originaalide arv: 1, ATC kood: N05AF03, Toimeaine: Chlorprothixenum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 03.05.2010, Retsepti number:  1001086086, Ravimi nimetus:  30TK, Originaalide arv: 2, ATC kood: N05BA08, Toimeaine: Bromazepamum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 0%, Annustamine: 1 ta 2 x pv Väljastamise kuupäev: 03.05.2010, Retsepti number:  1001086119, Ravimi nimetus:  25ml 1TK, Originaalide arv: 1, ATC kood: N05BA01, Toimeaine: Diazepamum, Ravimvorm: suukaudsed tilgad, lahus, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 15 tilka vaj.  Väljastamise kuupäev: 03.05.2010, Retsepti number:  1001086178, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 31.05.2010, Retsepti number:  1001312074, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 31.05.2010, Retsepti number:  1001312080, Ravimi nimetus:  25ml 1TK, Originaalide arv: 1, ATC kood: N05BA01, Toimeaine: Diazepamum, Ravimvorm: suukaudsed tilgad, lahus, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 15 tilka vaj.  Väljastamise kuupäev: 28.06.2010, Retsepti number:  1001535891, Ravimi nimetus:  25ml 1TK, Originaalide arv: 1, ATC kood: N05BA01, Toimeaine: Diazepamum, Ravimvorm: suukaudsed tilgad, lahus, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 15 tilka vaj.  Väljastamise kuupäev: 28.06.2010, Retsepti number:  1001535910, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 28.06.2010, Retsepti number:  1001535924, Ravimi nimetus:  30TK, Originaalide arv: 2, ATC kood: N05BA08, Toimeaine: Bromazepamum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 0%, Annustamine: 1 ta 2 x pv Väljastamise kuupäev: 28.06.2010, Retsepti number:  1001535947, Ravimi nimetus: TRUXAL 100TK, Originaalide arv: 1, ATC kood: N05AF03, Toimeaine: Chlorprothixenum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 26.07.2010, Retsepti number:  1001758993, Ravimi nimetus:  30TK, Originaalide arv: 2, ATC kood: N05BA08, Toimeaine: Bromazepamum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 0%, Annustamine: 1 ta 2 x pv Väljastamise kuupäev: 26.07.2010, Retsepti number:  1001759016, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 26.07.2010, Retsepti number:  2001759016, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 26.07.2010, Retsepti number:  1001759031, Ravimi nimetus:  25ml 1TK, Originaalide arv: 1, ATC kood: N05BA01, Toimeaine: Diazepamum, Ravimvorm: suukaudsed tilgad, lahus, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 15 tilka vaj.  Väljastamise kuupäev: 13.09.2010, Retsepti number:  1002200739, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 13.09.2010, Retsepti number:  2002200739, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 13.09.2010, Retsepti number:  1002200778, Ravimi nimetus: TRUXAL 100TK, Originaalide arv: 1, ATC kood: N05AF03, Toimeaine: Chlorprothixenum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 08.11.2010, Retsepti number:  1002861106, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 08.11.2010, Retsepti number:  2002861106, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 08.11.2010, Retsepti number:  1002861138, Ravimi nimetus:  25ml 1TK, Originaalide arv: 1, ATC kood: N05BA01, Toimeaine: Diazepamum, Ravimvorm: suukaudsed tilgad, lahus, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 15 tilka vaj.  Väljastamise kuupäev: 08.11.2010, Retsepti number:  1002861221, Ravimi nimetus:  30TK, Originaalide arv: 2, ATC kood: N05BA08, Toimeaine: Bromazepamum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 0%, Annustamine: 1 ta 2 x pv Väljastamise kuupäev: 06.12.2010, Retsepti number:  1003222312, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 06.12.2010, Retsepti number:  2003222312, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 03.01.2011, Retsepti number:  1003565619, Ravimi nimetus: TRUXAL 100TK, Originaalide arv: 1, ATC kood: N05AF03, Toimeaine: Chlorprothixenum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 31.01.2011, Retsepti number:  1003940818, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 31.01.2011, Retsepti number:  2003940818, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 28.03.2011, Retsepti number:  1004706604, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 28.03.2011, Retsepti number:  2004706604, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 28.03.2011, Retsepti number:  1004706649, Ravimi nimetus:  30TK, Originaalide arv: 2, ATC kood: N05BA08, Toimeaine: Bromazepamum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 0%, Annustamine: 1 ta 2 x pv Väljastamise kuupäev:
Ravimi nimetus: TRUXAL 100TK, Originaalide arv: 1, ATC kood: N05AF03, Toimeaine: Chlorprothixenum, Ravimvorm: õhukese polümeerikattega tablett, So
# ...

# %%
r.grammar_tags
# Out:
# Layer(name='grammar_tags', attributes=('grammar_symbol', 'value'), spans=SL[Span('kuupäev', [{'grammar_symbol': 'DATE', 'value': 'DATE'}]),
# Span(' 08.03.2010,', [{'grammar_symbol': 'DATE', 'value': '08.03.2010,'}]),
# Span('Ravimi nimetus', [{'grammar_symbol': 'NAME', 'value': 'NAME'}]),
# Span('ATC kood', [{'grammar_symbol': 'CODE', 'value': 'CODE'}]),
# Span('N05BA08', [{'grammar_symbol': 'drug_code', 'value': 'drug_code'}, {'grammar_symbol': 'drug_code', 'value': 'N05BA08'}]),
# Span('Toimeaine', [{'grammar_symbol': 'INGR', 'value': 'INGR'}]),
# Span('Bromazepamum', [{'grammar_symbol': 'drug_name', 'value': 'drug_name'}]),
# Span('kuupäev', [{'grammar_symbol': 'DATE', 'value': 'DATE'}]),
# Span(' 08.03.2010,', [{'grammar_symbol': 'DATE', 'value': '08.03.2010,'}]),
# Span('Ravimi nimetus', [{'grammar_symbol': 'NAME', 'value': 'NAME'}]),
# Span('ATC kood', [{'grammar_symbol': 'CODE', 'value': 'CODE'}]),
# ...

# %%
drug_tagger.tag(r)
# Out:
# Text(text='\nVäljastamise kuupäev: 08.03.2010, Retsepti number:  1000587736, Ravimi nimetus:  30TK, Originaalide arv: 2, ATC kood: N05BA08, Toimeaine: Bromazepamum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 0%, Annustamine: 1 ta 2 x pv Väljastamise kuupäev: 08.03.2010, Retsepti number:  1000587764, Ravimi nimetus:  25ml 1TK, Originaalide arv: 1, ATC kood: N05BA01, Toimeaine: Diazepamum, Ravimvorm: suukaudsed tilgad, lahus, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 15 tilka vaj.  Väljastamise kuupäev: 08.03.2010, Retsepti number:  1000587807, Ravimi nimetus: ESPRITAL 30 30TK, Originaalide arv: 1, ATC kood: N06AX11, Toimeaine: Mirtazapinum, Ravimvorm: õhukese polümeerikattega tablett, Soodustus: 50%, Annustamine:  , Annustamine täpsemalt: 1 tab õhtul.  Väljastamise kuupäev: 13.04.2010, Retsepti number:  1000952439, Ravimi nimetus: TRUXAL 100TK, Originaalide arv: 1, ATC kood: N05AF03, Toimeaine: Chlorprothixenum, Ravimvorm: õhukese polümeerikattega tablett, So
# ...

# %%
r.parsed_drug
# Out:
# Layer(name='parsed_drug', attributes=('name', 'date', 'atc_code', 'drug_name', 'active_ingredient'), spans=SL[EnvelopingSpan([' 08.03.2010,', 'Ravimi nimetus', 'ATC kood', 'N05BA08', 'Toimeaine', 'Bromazepamum'], [{'name': 'DRUG', 'date': ' 08.03.2010,', 'atc_code': 'N05BA08', 'drug_name': '', 'active_ingredient': 'Bromazepamum'}]),
# EnvelopingSpan([' 08.03.2010,', 'Ravimi nimetus', 'ATC kood', 'N05BA01', 'Toimeaine', 'Diazepamum'], [{'name': 'DRUG', 'date': ' 08.03.2010,', 'atc_code': 'N05BA01', 'drug_name': '', 'active_ingredient': 'Diazepamum'}]),
# EnvelopingSpan([' 08.03.2010,', 'Ravimi nimetus', 'ESPRITAL 30', 'ATC kood', 'N06AX11', 'Toimeaine', 'Mirtazapinum'], [{'name': 'DRUG', 'date': ' 08.03.2010,', 'atc_code': 'N06AX11', 'drug_name': 'ESPRITAL 30', 'active_ingredient': 'Mirtazapinum'}]),
# ...

# %%
# "kuupäev" ei tohiks olla date väärtusena võimalik
