# %%
import csv
from collections import Counter, defaultdict

import csv
import os
from tqdm import tqdm
import pandas as pd

# %%
#from cda_data_cleaning.fact_extraction.measurement_extraction import MeasurementTagger
from taggers.measurement_tagger import MeasurementTagger
from taggers.measurement_token_tagger import MeasurementTokenTagger
from taggers.measurement_object_tagger.measurement_object_tagger import MeasurementObjectTagger
from estnltk import Text

# %%
token_tagger = MeasurementTokenTagger(output_layer = "measurement_tokens")
tagger = MeasurementTagger()

# %% [markdown]
# ### Precision 2020

# %%
pwd
# Out:
# '/home/dage/Desktop/cda-data-cleaning/cda_data_cleaning/fact_extraction/measurement_extraction/development'

# %%
tp_counts = Counter()
with open("../measurements_quality/labelled/precision_to_label.csv", "r") as fin:
    reader = csv.reader(fin)
    for row in reader:
        if row[0] != 'APGAR':
            if row[-1] != 'v':
                tp_counts[row[0]] += 1

# %%
tp_counts.most_common()
# Out:
# [('KUSIHAPE', 100),
#  ('LDL-KOLESTEROOL', 100),
#  ('LUUTIHEDUS', 100),
#  ('MCV', 100),
#  ('VÖÖÜMBERMÕÕT', 100),
#  ('ASAT', 100),
#  ('HDL-KOLESTEROOL', 100),
#  ('TRIGLÜTSERIIDID', 100),
#  ('ALAT', 99),
#  ('HEMOGLOBIIN', 99),
#  ('KOLESTEROOL', 99),
#  ('LEUKOTSÜÜDID', 98),
#  ('PSA', 98),
#  ('KREATINIIN', 98),
#  ('KAAL', 97),
#  ('GLÜKOHEMOGLOBIIN', 97),
#  ('KMI', 95),
#  ('GLÜKOOS', 94),
#  ('PIKKUS', 93),
#  ('BILIRUBIIN', 92),
#  ('PULSS', 91)]

# %%
precisions2020 = Counter()
for k, v in tp_counts.items():
    precisions2020[k] = v/100

# %%
precisions2020
# Out:
# Counter({'BILIRUBIIN': 0.92,
#          'PIKKUS': 0.93,
#          'KUSIHAPE': 1.0,
#          'ALAT': 0.99,
#          'GLÜKOOS': 0.94,
#          'HEMOGLOBIIN': 0.99,
#          'KAAL': 0.97,
#          'KMI': 0.95,
#          'LDL-KOLESTEROOL': 1.0,
#          'LEUKOTSÜÜDID': 0.98,
#          'LUUTIHEDUS': 1.0,
#          'MCV': 1.0,
#          'PULSS': 0.91,
#          'PSA': 0.98,
#          'VÖÖÜMBERMÕÕT': 1.0,
#          'KREATINIIN': 0.98,
#          'GLÜKOHEMOGLOBIIN': 0.97,
#          'KOLESTEROOL': 0.99,
#          'ASAT': 1.0,
#          'HDL-KOLESTEROOL': 1.0,
#          'TRIGLÜTSERIIDID': 1.0})

# %%
df = pd.DataFrame(pd.Series(precisions2020), columns = ['new_on_new_prec'])

# %% [markdown]
# ### Precision on 2014 data

# %%
path = '../measurements_quality/labelled_2014/'

# %%
files = os.listdir(path)
data = defaultdict(list)
for f in files:
    if f.endswith('csv'):
        fname = os.path.join(path, f)
        with open(fname, 'r', encoding = '1252') as fin:
            reader = csv.reader(fin)
            next(reader)
            for row in reader:
                if row[9] in precisions2020:
                    left = row[12].replace(row[13], '')
                    data[row[9]].append([left +' ' + row[13] + ' ' + row[14], row[15], row[16], row[30]])
                elif row[9] == 'BMI':    
                    left = row[12].replace(row[13], '')
                    data['KMI'].append([left +' ' + row[13] + ' ' + row[14], row[15], row[16], row[30]])

# %%
data.keys()
# Out:
# dict_keys(['KAAL', 'KREATINIIN', 'PIKKUS', 'TRIGLÜTSERIIDID', 'PULSS', 'PSA', 'KUSIHAPE', 'KOLESTEROOL', 'KMI', 'LDL-KOLESTEROOL', 'ALAT', 'HDL-KOLESTEROOL', 'HEMOGLOBIIN', 'GLÜKOHEMOGLOBIIN', 'ASAT', 'VÖÖÜMBERMÕÕT'])

# %%
len(precisions2020)
# Out:
# 21

# %%
from estnltk import Text

# %%
tagged_texts_old = {}
tagged_texts = {}
for obj, rows in tqdm(data.items()):
    tp = []
    fp = []
    fn = []
    tn = []
    tp_old = []
    fp_old = []

    for row in rows:
        t = Text(row[0])
        token_tagger.tag(t)
        tagger.tag(t)
        if len(t.measurements) > 0:
            if row[-1] == 'n':
                fp.append((t, row[-2]))
                fp_old.append((t, row[-2]))
            else:
                tp.append((t, row[-2]))
                tp_old.append((t, row[-2]))
        else:
            if row[-1] == 'n':
                tn.append((t, row[-2]))
                fp_old.append((t, row[-2]))
            else:
                fn.append((t, row[-2]))
                tp_old.append((t, row[-2]))
    tagged_texts[obj] = [tp, fp, fn, tn] 
    tagged_texts_old[obj] = [tp_old, fp_old]
# Out:
# 100%|██████████| 16/16 [01:47<00:00,  6.29s/it]

# %%
tagged_texts
# Out:
# {'KAAL': [[(Text(text=' Kaal 1245 g  ( 10-50P )'), '1245'),
#    (Text(text='Laps on sündinud ajalisena ,  sünnikaal ~ 3 kg  , pikkus 48 cm'),
#     '3'),
#    (Text(text='amine ) tulemus : pikkus : 53cm  kaal : 3.644kg  KMI : 13'),
#     '3.644'),
#    (Text(text='lt suurtest kogustest osaliselt  Kaal 3,7kg  Iste seedimata-teeb kuurina Gef'),
#     '3.7'),
#    (Text(text='08.03.2012 -  Kaal 3,8 kg ;sööb Aptamili 620 ml ööpäevas'),
#     '3.8'),
#    (Text(text='amine ) tulemus : pikkus : 55cm  kaal : 3.84kg  KMI : 12.7'),
#     '3.84'),
#    (Text(text=' Sünnikaal 3,992 kg  , pikkus 54 cm'), '3.992'),
#    (Text(text='1 laps - S/K/ kaal - 4,5 kg  ! ,'), '4.5'),
#    (Text(text='Eile  kaal 5,470 g '), '5.47'),
#    (Text(text='ine ) tulemus : pikkus : 62.5cm  kaal : 5.83kg  KMI : 14.9'),
#     '5.83'),
#    (Text(text='amine ) tulemus : pikkus : 64cm  kaal : 6.66kg  KMI : 16.3'),
#     '6.66'),
#    (Text(text='tulemus : pikkus : 70.5cm + 1cm  kaal : 7.86kg  + 230g - kuugaKMI : 15.8'),
#     '7.86'),
#    (Text(text='05.2012 - 10k18pv , 3 hammast ,  kaal 8,5kg '), '8.5'),
#    (Text(text='amine ) tulemus : pikkus : 73cm  kaal : 8.6kg  KMI : 16.1'),
#     '8.6'),
#    (Text(text='emus : pikkus : 69cm ( + 2 SD )  kaal : 8.99kg  ( + 3 SD ) KMI : 18.9'),
#     '8.99'),
#    (Text(text='* 11.06.2013 :  Kaal 10.2 kg  . Rinnapiima saab Hambaid -4'),
#     '10.2'),
#    (Text(text=' Kaal 10,38kg '), '10.38'),
#    (Text(text='Käima 10 k vanuses , siis  kaal 11 kg '), '11'),
#    (Text(text='eid : pikkus 80 cm ( + 1 SD ) ,  kaal 11,5 kg  ( 0 SD ) , peaümbermõõt 47 cm ('),
#     '11.5'),
#    (Text(text=' Kaal 12kg '), '12'),
#    (Text(text=' 12,5 mg õhtul ( 1/4 tabletti )  Kaalub 13 kg '), '13'),
#    (Text(text=' Kaal 13 kg  pikkus 84 sm'), '13'),
#    (Text(text='Pikkus 93 kg ,  kaal 13,7 kg '), '13.7'),
#    (Text(text='Pikkus 89,5 cm ,  kaal 13,800g  , pea ümbermõõt 46,5 cm , kõht '),
#     '13.8'),
#    (Text(text='Kasv 89 cm ( 10pt ) ,  kaal 14 kg  ( 25pt ) , KMI 17,7 , BSA m2'),
#     '14'),
#    (Text(text='vastuvõtus kehatemp 38,5 *  kaal 14 kg '), '14'),
#    (Text(text=' kaal 14,8kg  , pikkus 102,5cm , pea ümberm 4'), '14.8'),
#    (Text(text='nile , munavalgule ja villale ,  kaal 16 kg '), '16'),
#    (Text(text='mine ) tulemus : pikkus : 103cm  kaal : 17kg  KMI : 16'), '17'),
#    (Text(text='budes : Pikkus 117cm ( 3 ts ) ,  kaal 18kg  ( <3 ts ) , RR 117/79 mmHg'),
#     '18'),
#    (Text(text=' Kaal : 18,2kg  ; pikkus : 108,2cm'), '18.2'),
#    (Text(text=' kaal 18,2 kg '), '18.2'),
#    (Text(text='Obj :  kaal 18,4kg  , temp 39,1 * Laps istub , on h'), '18.4'),
#    (Text(text='Obj :  kaal 18,5 kg  , pikkus 112 cm'), '18.5'),
#    (Text(text='mine ) tulemus : pikkus : 113cm  kaal : 19kg  KMI : 14.9'),
#     '19'),
#    (Text(text='Kehatemperatuur 36,2C Lapse  kaal 19kg '), '19'),
#    (Text(text='kkus 112.5 cm ( 10-25 prots ) ,  kaal 19.1 kg  ( 25 . prots ) V S 4.9 mmol/l'),
#     '19.1'),
#    (Text(text=' kaal 19,4 kg  pikkus 114,5cm'), '19.4'),
#    (Text(text=' Vanus 7a 6k : pikkus : 124.3cm  kaal : 20.5kg  KMI : 13.3kg/m2 , BSA 0,87 m2 ,'),
#     '20.5'),
#    (Text(text=' Kaal 20,5kg '), '20.5'),
#    (Text(text='dav , kahvatu , pikkus 119 cm /  kaal 21,8 kg  , kopsudes vesikulaarne hingami'),
#     '21.8'),
#    (Text(text='I VORMISTAMINE , pikkus-121,0cm  kaal-22,4kg  , parem käsi RR 88/61 pulss 84 '),
#     '22.4'),
#    (Text(text=' Kaal 22,6kg '), '22.6'),
#    (Text(text='mine ) tulemus : pikkus : 111cm  kaal : 23kg  KMI : 18.7'),
#     '23'),
#    (Text(text=' Kaal : 24,6 kg  ( 90PT ) , pikkus : 128 cm ( ül'), '24.6'),
#    (Text(text=' Kaal 25 kg  ( ligi 50 protsentiili ) ;'), '25'),
#    (Text(text='tiivsus 30.01.2012 pikkus 131 ,  kaal 25kg '), '25'),
#    (Text(text=' Kaal 25.300  , pikkus 127 , RR 90/40 , visus'), '25.3'),
#    (Text(text='* 12.11.2013   :  Kaal 27 kg  , pikkus 120 cm'), '27'),
#    (Text(text=' Kaal : 28 kg  ( 25 -50 protsentiili )'), '28'),
#    (Text(text=' üldseisundis , Normosteenilise  Kaal 28g  kg , pikkus125 cm'),
#     '28'),
#    (Text(text='13.03.2012 -  Kaal 29,2 kg  ( < 90 pts ) , pikkus 136,5 cm '),
#     '29.2'),
#    (Text(text='Lapsel rohke rasvkude ,  kaal 31,6 kg  ( > 97 ts ) , pikkus 115,5 cm ('),
#     '31.6'),
#    (Text(text='mine ) tulemus : pikkus : 140cm  kaal : 33kg  KMI : 16.8'),
#     '33'),
#    (Text(text='pikkus 143,5 -> 149,8 cm ,  kehakaal 31,2 -> 34,0 kg  , KMI 15,0 -> 15,1 kg/m2 , käte'),
#     '34'),
#    (Text(text=' Kaal - 37,6 kg  ( + 2,3 kg )'), '37.6'),
#    (Text(text=' Kaal 42,7 kg  ( hea positiivne dünaamika ; ka'), '42.7'),
#    (Text(text='012 kehapikkus 164-> 167,8 cm ,  kehakaal 40,2-> 42,8 kg  , KMI14,9-> 15,2 , kopsumaht 3,'),
#     '42.8'),
#    (Text(text='pO2100 % Maks ei ole suurenenud  kaal 43,5 kg EKG : Siinusrütm fr 64 x min Ehh'),
#     '43.5'),
#    (Text(text='BMI 17,5 ( pikkus 159,5cm  kaal 44,6kg  ) Järeldus : Foonis välise hing'),
#     '44.6'),
#    (Text(text='Naine 159 pikk , raseduseelne  kaal 45 kg '), '45'),
#    (Text(text="81 x ' ;  kaal 45 kg "), '45'),
#    (Text(text=' Kaal 46 kg '), '46'),
#    (Text(text='Pikkus 164,7 cm ,  kaal 46 kg  , BSA 1,48 m2 .'), '46'),
#    (Text(text=' kaal 47kg  pikkus 155cm'), '47'),
#    (Text(text='pikkus : 165.5 cm ( 75ts ) ,  kaal : 48 kg  ( 50-75 ts ) , KMI : 17.5 ( 25-'),
#     '48'),
#    (Text(text='used : ei esita Objektiivselt :  Kaal 48 kg  Pikkus 159 cm Suitsetamine : ja'),
#     '48'),
#    (Text(text='Obj  kaal 48 kg  , pikkus 161 cm'), '48'),
#    (Text(text=' Kehakaal 50kg  ( + 1,5kg 1 aasta jooksul ) , p'), '50'),
#    (Text(text='ikkus : 166cm ( 25-50-prots ) ;  kaal : 51.5kg  ( 10-25 prots ) , KMI : 18.7'),
#     '51.5'),
#    (Text(text='x 1 , , Clexane 0,8 ml x 1 sc (  kehakaal 52 kg  ) , Vit B121000 g i/m 3 korda n'),
#     '52'),
#    (Text(text='Tachycardia Pikkus163 cm Kaal52 kg BMI19,57168128 Südamerütm SR fr6'),
#     '52'),
#    (Text(text='Obj :  kaal 52,5kg '), '52.5'),
#    (Text(text=' Kehakaal 52,8 kg '), '52.8'),
#    (Text(text='endus : Rütmihäired Kirjeldus :  kaal 53 kg  , pikkus 162 cm , kehapind 1,55'),
#     '53'),
#    (Text(text=' Kaal 53,2kg '), '53.2'),
#    (Text(text=' Kaal : 53,2 kg '), '53.2'),
#    (Text(text=' Kaal : 54,3kg  ( 1,0 )'), '54.3'),
#    (Text(text=' Kaal 54,400kg  Kasv 167,5cm'), '54.4'),
#    (Text(text=' Kaal - 55kg '), '55'),
#    (Text(text='Pikkus-157cm ,  kaal-56kg  , KMI--23,4RINDKERE JA KÕHUPIIR'),
#     '56'),
#    (Text(text='a oluliselt langenud , praegune  kehakaal 57 kg '), '57'),
#    (Text(text='20.03.2012 -  Kaal 57,5 kg  , saatekiri - J -131 plaanimise'),
#     '57.5'),
#    (Text(text=' Kaal : 57,9 kg '), '57.9'),
#    (Text(text='Patsient on 162 cm pikk ,  kaalub 59 kg  , KMI 22,5 – patsient on normaa'),
#     '59'),
#    (Text(text='Pikkus 165  Kaal 60  KMI 21'), '60'),
#    (Text(text='Pikkus täna 149.7 cm ja  kaal 60,1 kg '), '60.1'),
#    (Text(text=' Kaal 60,5 kg  pikkus 171 sm RR 115/50'), '60.5'),
#    (Text(text=' Kaal 60,5kg '), '60.5'),
#    (Text(text='Raseduse suurus 29+4 ,  kaalub 61kg  , F 29cm , KÜ 91cm'),
#     '61'),
#    (Text(text=' Kaal : 61 kg '), '61'),
#    (Text(text=' Kaalub 62,0 kg '), '62'),
#    (Text(text='grammi viimase poole nädalaga ,  kaal 62,7 kg  , KMI 19,79 .'),
#     '62.7'),
#    (Text(text=' Kaal 63 kg '), '63'),
#    (Text(text='mine ) tulemus : pikkus : 180cm  kaal : 63kg  KMI : 19.4'),
#     '63'),
#    (Text(text=' Kaal 63,7  - iive + 1,0kg'), '63.7'),
#    (Text(text='15 , 1 cm ja  kaal 63.7 kg '), '63.7'),
#    (Text(text=' Kaal 64  cm , pikkus 165 cm , KMI 24 .'), '64'),
#    (Text(text='i kasutaObj leid Pikkus 167cm ,  kaal 64kg  , RR 11070/mmHg paremal käel pu'),
#     '64'),
#    (Text(text=' Kaal 64kg  Kuumad hood ja higisööstud on e'), '64'),
#    (Text(text='Meespatsient , 54a ,  kaal 64,5 kg  , pikkus 172 cm , KMI-23 , elab'),
#     '64.5'),
#    (Text(text=' Kaal 64,8  iive + 0,3 kg'), '64.8'),
#    (Text(text='55-aastane , pikkus 158 cm ,  kaal 65 kg  , süda regul'), '65'),
#    (Text(text='Pikkus174 cm Kaal65 kg BMI21,46915048 Südamerütm SR fr6'),
#     '65'),
#    (Text(text='Pikkus 180 cm ,  kaal 65 kg  KMI 20,1'), '65'),
#    (Text(text='eiu kokkuvõte : Pikkus 169 cm ,  kaal 65 kg '), '65'),
#    (Text(text=' Kaal 65kg '), '65'),
#    (Text(text='Obj : pikkus 186 cm ,  kaal 65 kg  ( KMI 18 )'), '65'),
#    (Text(text=' Kehakaal 65,1 kg '), '65.1'),
#    (Text(text='sund rahuldav , pikkus 173 cm /  kaal 65,2 kg  ( + 3 kg aasta jooksul ) , KMI '),
#     '65.2'),
#    (Text(text=' kaal 65,4kg  ( + 2,7kg ) , turseid ei ole , '), '65.4'),
#    (Text(text='Pikkus 172cm , nüüd  kaal 66,0kg  , ei suitseta'), '66'),
#    (Text(text=' Kaal 66  : kg'), '66'),
#    (Text(text=' Kehakaal 66,4  , + 2,0kg'), '66.4'),
#    (Text(text='# Pikkus171 cm Kaal67 kg BMI22,91303307'), '67'),
#    (Text(text=' Pericarditis inf ? Pikkus173 cm Kaal67 kg BMI22,38631428 Südamerütm SR fr7'),
#     '67'),
#    (Text(text='Pikkus166 cm Kaal67 kg BMI24,31412397 Südamerütm SR fr6'),
#     '67'),
#    (Text(text=' Kaal : 67 kg '), '67'),
#    (Text(text='PATSIENDI PIKKUS 170 cm ,  KAAL 67 kg '), '67'),
#    (Text(text='# Pikkus160 cm Kaal67 kg BMI26,171875'), '67'),
#    (Text(text='Pikkus 158 cm ,  kaal 68 kg  , KMI 27 , VÜ 103 cm'), '68'),
#    (Text(text='Raseduse suurus 25+1 ,  kehakaal 68 kg  ( iive + 1 )'), '68'),
#    (Text(text='OBJ LEID : Pikkus 156cm ,  Kaal 68kg  Õlaliigestes liikuvus piiratud '),
#     '68'),
#    (Text(text='d pikkus , määratud KMI : 26,2 - kaal 68kg  ja pikkus 161 .'),
#     '68'),
#    (Text(text=' Kaal : 68 kg '), '68'),
#    (Text(text='Üldseisund - rahuldav ,  kaal 68 kg  , pikkus 155 cm , KMI 28,30 ( n'),
#     '68'),
#    (Text(text='aalus juurde võtnud oluliselt -  kaal 68,4 kg  . Obj liikuvus puusades , põlve'),
#     '68.4'),
#    (Text(text=' Kaal : 68,5 kg '), '68.5'),
#    (Text(text=' Kaal : 68,7 kg '), '68.7'),
#    (Text(text='Ema pikkus 175 cm ,  kaal 69 kg  , isa pikkus 198 cm , kaal 90 k'),
#     '69'),
#    (Text(text='RR140-80 ,  KAAL 69.0 '), '69'),
#    (Text(text=' Kaal : 70 kg '), '70'),
#    (Text(text='PATSIENDI PIKKUS 160 cm ,  KAAL 70 kg '), '70'),
#    (Text(text=' Kaal - 70,3 kg '), '70.3'),
#    (Text(text=' Kaal - 71kg '), '71'),
#    (Text(text=' Kaal 71,6 kg  , + 0,4 kg +/ - tursed'), '71.6'),
#    (Text(text=' Kaal : 72kg '), '72'),
#    (Text(text='20.02.2012 Pikkus - 167,5 cm ,  kaal - 72 kg '), '72'),
#    (Text(text='Vanus : 74 yrs  Kaal : 72 kg '), '72'),
#    (Text(text='t kontaktne , normosteeniline ,  kehakaal 72,2 kg  , pikkus 163 cm , naha peal ( E'),
#     '72.2'),
#    (Text(text=' kaal 72,4 kg  ; kasv 159,2 cm , PÜ 53,6 cm'), '72.4'),
#    (Text(text=' Kaal : 72,7kg '), '72.7'),
#    (Text(text='mine ) tulemus : pikkus : 174cm  kaal : 73kg  KMI : 24.1'),
#     '73'),
#    (Text(text='hitusega naine ; pikkus 163cm ,  kaal 73kg  , KMI 27,5 ; keel , nähtavad li'),
#     '73'),
#    (Text(text='Roaccutani ,  kehakaal 73 kg  , nõustatud täiendavalt reziimi'),
#     '73'),
#    (Text(text=' laigud ( erut ) Pikkus-168cm ,  kaal-73,2kg  , KMI-26,5RINDKERE JA KÕHUPIIRK'),
#     '73.2'),
#    (Text(text=' Kehakaal 73.500kg '), '73.5'),
#    (Text(text='Pikkus 168 cm  Kaal 74 kg  RR mmHg BSA 1,84'), '74'),
#    (Text(text="80x ' Pikkus 164 cm ,  Kaal 74 kg  , KMI 28 ."), '74'),
#    (Text(text='Pikkus 170cm ,  kaal 74kg  ( 1 kuu jooksul kaal langenud ~'),
#     '74'),
#    (Text(text=' kaal 75 kg  pikkus 180,5cm'), '75'),
#    (Text(text='õhutõbi ( kahtlus ) Pikkus183 cm Kaal75 kg BMI22,39541342 Südamerütm SR fr6'),
#     '75'),
#    (Text(text='KEHA KAAL 75 kg '), '75'),
#    (Text(text='Patsiendi pikkus 165cm ,  kehakaal 75kg '), '75'),
#    (Text(text=' Kehakaal 75,1 kg  ( + 0,4 kg )'), '75.1'),
#    (Text(text='Mõõdetud  kehakaal 75,5 kg  , KMI 23,8 , RP 18,8 % , VÜ 88 '),
#     '75.5'),
#    (Text(text=' kaal 76 kg '), '76'),
#    (Text(text=' Kaal : 77 kg '), '77'),
#    (Text(text='Ema pikkus 159 cm ,  kaal 77 kg  , isa pikkus 170 cm , kaal 80 k'),
#     '77'),
#    (Text(text='ne ) tulemus : pikkus : 182.5cm  kaal : 77.45kg  KMI : 23.3'),
#     '77.45'),
#    (Text(text='012 kehapikkus 175,5-176,5 cm ,  kehakaal 77,3-> 77,9 kg  , KMI 25,2-> 24,9 ; käte pigist'),
#     '77.9'),
#    (Text(text=' Kaal 78 kg  , pikkus 164cm'), '78'),
#    (Text(text='Kaal : 108,6 kg ( 97 pt  kaal 78 kg  )'), '78'),
#    (Text(text=' kaal 78 kg  RR 140/80'), '78'),
#    (Text(text=' ülekaaluline ( pikkus 161 cm ,  kehakaal 78,5 kg  , KMI=30,3 )'),
#     '78.5'),
#    (Text(text='17.08.2012 - Pt  kaal 78,9 kg  , pikkus 156 cm Palpatsioonil v'),
#     '78.9'),
#    (Text(text=' kaal 79 kg  v s 6,4 mmol l RR 150/90'), '79'),
#    (Text(text=' Kaal : 79 kg '), '79'),
#    (Text(text=' kehakaal : 80 kg '), '80'),
#    (Text(text=' on probleeme ( pikkus150 cm ja  kaal 80 kg  , mis annab kehamassiindeksiks '),
#     '80'),
#    (Text(text='Pikkus 155 ,  kaal 80  , KMI 33,5 .'), '80'),
#    (Text(text='Pikkus-167cm ,  kaal-80kg  , KMI-29RINDKERE JA KÕHUPIIRKON'),
#     '80'),
#    (Text(text='ud ANTROPOMEETRIAPikkus 186cm ,  kaal 80kg  , BMI 23,1 ; rasva 15,8 % , ras'),
#     '80'),
#    (Text(text='PATSIENDI PIKKUS 174 cm ,  KAAL 80 kg '), '80'),
#    (Text(text='07.08.12  Kaal 80,7kg  Isu tekkinud juustu järgi , mid'),
#     '80.7'),
#    (Text(text=' kaal 81 kg  RR 120/80'), '81'),
#    (Text(text=' Kehakaal 81,5kg  , + 0,5kg'), '81.5'),
#    (Text(text='Pt-i pikkus 160 cm ,  kaal 82 kg '), '82'),
#    (Text(text='RR 160/90  kaal 82 kg '), '82'),
#    (Text(text='tab pedagoogina Pikkus 177 cm ,  kaal 82 kg  , ei suitseta obj : RR 124/80 m'),
#     '82'),
#    (Text(text=' kaal 83 kg  RR 120/80'), '83'),
#    (Text(text='Pikkus 170cm ,  kaal 83kg '), '83'),
#    (Text(text='- Vanus 17a 9k : pikkus : 170cm  kaal : 83.7kg  KMI : 29kg/m2 , BSA 1,98 m2 , R'),
#     '83.7'),
#    (Text(text='Pikkus 182cm ,  kaal 84kg '), '84'),
#    (Text(text=' Kaal 84 kg '), '84'),
#    (Text(text=' kaal-84,3  , pikkus-179,5 cm'), '84.3'),
#    (Text(text='Pikkus165 cm Kaal85 kg BMI31,22130395 Südamerütm SR fr6'),
#     '85'),
#    (Text(text=' Kaal : 85 kg '), '85'),
#    (Text(text='13.05.2013 - -  KAAL 85  - - HBA1C 7,1'), '85'),
#    (Text(text=' Kaal 86 kg '), '86'),
#    (Text(text='# Pikkus164 cm Kaal86 kg BMI31,97501487'), '86'),
#    (Text(text='Kaal kasvab : praegu  kaal 86kg '), '86'),
#    (Text(text=' Kehakaal 87kg  , + 1,0kg'), '87'),
#    (Text(text=' Kehakaal 87,0kg  , + 1,0'), '87'),
#    (Text(text='# Pikkus 170 cm  Kaal 89 kg  BMI 30,79584775'), '89'),
#    (Text(text=' Kaal 89kg  , aastag tõus 6kg , kõht ettevõ'), '89'),
#    (Text(text=' Kaal : 89,8 kg '), '89.8'),
#    (Text(text='PATSIENDI PIKKUS 170 cm ,  KAAL 90 kg '), '90'),
#    (Text(text='RR 125/80 , kasv - 163cm ,  kaal - 90kg '), '90'),
#    (Text(text='Kaal 116 kg ! , Varem , kui  kaal olnud 90 kg  käinud mensesed regulaarselt'),
#     '90'),
#    (Text(text=' Kaal 90kg '), '90'),
#    (Text(text=' Kaal90,8 kg  , iive + 0,8 kg'), '90.8'),
#    (Text(text='kaalutõus  kaalub 93 kg  , pikkus 176 cm BMI 31 .'), '93'),
#    (Text(text=' kaal 94 kg  RR 120/80 v s 6,4 mmol l'), '94'),
#    (Text(text='Objektiivselt :  Kaal 95 kg  Pikkus 195 cm Suitsetamine : ei'),
#     '95'),
#    (Text(text=' Kaal 95 kg  , pikkus 160 cm'), '95'),
#    (Text(text='Pikkus 183cm ,  kehakaal 95 kg  RR 170/110 mmHg , fr 80x regul '),
#     '95'),
#    (Text(text=' Kaal 97 kg '), '97'),
#    (Text(text=' Kaal : 97 kg '), '97'),
#    (Text(text='15.11.2012 -  kaal 97,4kg  pikkus176,5cm BMI 31,27'), '97.4'),
#    (Text(text=' kaal 98 kg '), '98'),
#    (Text(text='Kirjeldus : Pikkus 185 cm ,  kehakaal 100 kg '), '100'),
#    (Text(text=' Kaal 100 kg  pikkus 166 KMI 33,29 .'), '100'),
#    (Text(text='imeid kasutanud ebaregulaarselt  Kehakaal 100kg  Töötab puidutööl'),
#     '100'),
#    (Text(text=' Kaal - 100 kg  , kasv - 166 sm . Ei suitseta'), '100'),
#    (Text(text='UHKUR 8.1 ( 2.5 T PEALE SÖÖKI )  kAAL 101 KG  , BMI 32.0 , RR 120-80'),
#     '101'),
#    (Text(text='Tagasi 10.06.2013 ( eesmärk  kaal 102kg '), '102'),
#    (Text(text='Hetkeline  kehakaal 104 kg  , pikkus 159 cm'), '104'),
#    (Text(text=' Kaal 104 kg  ( -4 kg 4 kuuga )'), '104'),
#    (Text(text='v s 14,4 mmol l RR 180/100  kaal 105 kg '), '105'),
#    (Text(text=' Kaal 105kg  , pikkus 178cm'), '105'),
#    (Text(text='algadel mõõdukad tursed põlvini  Kehakaal 105,5 kg '), '105.5'),
#    (Text(text='Püknilise kehaehitusega ,  kehakaal 106 kg '), '106'),
#    (Text(text=' Kaal 107kg  , RR 195/100 , fr'), '107'),
#    (Text(text='PATSIENDI PIKKUS 176 cm ,  KAAL 108 kg '), '108'),
#    (Text(text='v s 7 , 3 mmol l  kaal 108 kg  RR 125/80'), '108'),
#    (Text(text='kehakaalu tõttu Pikkus 161 cm ,  kaal 110 kg '), '110'),
#    (Text(text='us cardialis III FA Pikkus186 cm Kaal110 kg BMI31,7955833 Südamerütm FA fr51'),
#     '110'),
#    (Text(text='Käesolevalt  kehakaal 110 kg  , pikkus 172 cm'), '110'),
#    (Text(text=' Kaal 111kg  , Pikkus 173cm BMI 37'), '111'),
#    (Text(text='RR 130/70 , cor reg ,  kaal 112,8  ( viimati märtsis oli 108 ) , P'),
#     '112.8'),
#    (Text(text='veel otsustanud Pikkus 163 cm ,  kaal 114 kg  ( 2 a tagasi oli 102 kg ). RR=1'),
#     '114'),
#    (Text(text='Üldseisund - rahuldav ,  kaal 114 kg  , pikkus 184 cmNahk/limaskestad'),
#     '114'),
#    (Text(text='Obj : 178 cm ja  kaalub 115 kg '), '115'),
#    (Text(text='Max  kaal 116 kg '), '116'),
#    (Text(text='Pikkus 178 cm ,  kaal 116 kg  , KMI 35 .'), '116'),
#    (Text(text='Patsiendi pikkus 167 cm ja  kaal 117 kg '), '117'),
#    (Text(text=' kaal 118 cm , pikkus 159cm , olevat juurd'), '118'),
#    (Text(text='Pikkus 174 ,  kehakaal 120 kg '), '120'),
#    (Text(text=' Kaal 120 kg  Nahk kuivetu , ketandav'), '120'),
#    (Text(text=' kaal 120 kg  , pikkus 160 cm , KMI 48'), '120'),
#    (Text(text=' Kaal 120 kg  , pikkus 168 cm'), '120'),
#    (Text(text='Pt  kaalub 121 kg  , on kaalust maha võtnud 4 kg'), '121'),
#    (Text(text=' Kehakaal 122kg '), '122'),
#    (Text(text=' Kaal 122,7kg '), '122.7'),
#    (Text(text=' Kaal 127kg  , KMI=44 .'), '127'),
#    (Text(text='Pikkus 193 ,  kaal 129  , BMI 35 .'), '129'),
#    (Text(text='ses ja med valu kõnnib longates  kaal 130 kg  soovit küünartuge kasutada tule'),
#     '130'),
#    (Text(text=': Adipoosne 56-a meespatsient ,  kehakaal 130 kg  , pikkus 176 cm ; nähtavad lima'),
#     '130'),
#    (Text(text='On ülekaaluline ,  kehakaal 130kg '), '130'),
#    (Text(text='ulnud - kaal 128 kg ( jaanuaris  kaalus 134kg  )'), '134'),
#    (Text(text=' Kehakaal 140kg '), '140'),
#    (Text(text='Pikkus 186 cm ,  kaal 140 kg '), '140'),
#    (Text(text='Isa pikkus 190 cm ,  kaal 155 kg '), '155'),
#    (Text(text=' Sünnikaal-634g  Korrig vanus hetkel 39 + Kirjel'), '634'),
#    (Text(text=' Sk 1500gr  , Apgar 9/9 .'), '1500'),
#    (Text(text='isus elus enneaegne tütarlaps ,  kaaluga 1830 g  , Apgar 3-7-8 palli'),
#     '1830'),
#    (Text(text=' Sk 1884gr  , pea 31cm , pikkus 42cm'), '1884'),
#    (Text(text='; kell 05 : 53 sünnib II kaksik  kaaluga 1966g  , pikkus 43cm , Apgaritega 9/9 '),
#     '1966'),
#    (Text(text=' SK 2125g  ; SP 43cm ; PÜ 33cm ; RÜ 28cm p'), '2125'),
#    (Text(text=' KAKSIK : elus ajaline poeglaps  kaaluga 2406g /47 cm , Apgar 7/8 Avatud II loo'),
#     '2406'),
#    (Text(text='vs kollasuse tõttu , 02-04.09 ,  kaal 2530g  lahkudes , imevat rinda + piima'),
#     '2530'),
#    (Text(text='.05 kell sünnib elus poeglaps ,  kaal 2556g  , apgar 3/6/7 .'),
#     '2556'),
#    (Text(text='14.06.2012 sündis tütar  kaal 2702g  , pikkus 47cm ja apgar 8/9'),
#     '2702'),
#    (Text(text='15.10.2012 Mõõdud :  kaal 2720g  , ( 10 ts ) , pikkus 47cm , ( 1'),
#     '2720'),
#    (Text(text=' Sünnikaal 2726 g  ; pikkus 47cm ; pü 35 cm ; rü 2'), '2726'),
#    (Text(text=' kaksik elus ajaline poeglaps ,  kaaluga 2862g  , pikkus 49cm , Apgar 8/8 , pH '),
#     '2862'),
#    (Text(text='Sündinud 39 rasedusnädal  Kaal oli 2880g  , pikkus 49cm'),
#     '2880'),
#    (Text(text='tütarlaps , NV 1x ümber kaela ,  kaaluga 2916 g  , pikkusega 48 cm , Apgar 9-10 '),
#     '2916'),
#    (Text(text='I ,  sk 2920g  , A ? , rinnale kohe , koju IV '), '2920'),
#    (Text(text='22.07.2013 sündis poeg    kaal 2978g  , pikkus 48cm ja Apgar 9/9'),
#     '2978'),
#    (Text(text='Kaal : 9240 g  SM 3000 g '), '3000'),
#    (Text(text='SK 3180 g  kaal koju minnes 3010 g '), '3010'),
#    (Text(text='24.05.2013 sündis tütar  kaal 3020g  , pikkus 49cm ja Apgar 9/9'),
#     '3020'),
#    (Text(text='04.06.2012 sündis tütar  kaal 3022g  , pikkus 50cm ja apgar 7/8'),
#     '3022'),
#    (Text(text=' 11 : 09 elus ajaline tütarlaps  kaaluga 3034 g  , pikkus 51 cm , Apgarid 8 / 8 '),
#     '3034'),
#    (Text(text='19.09.2012 sündis tütar  kaal 3148g  , pikkus 51cm ja apgar 8/9'),
#     '3148'),
#    (Text(text='ul + Aptamil 1 süstlaga -tänane  kaal 3160 g '), '3160'),
#    (Text(text='03.02.201307 : 13 . sünnib poeg  kaaluga : 3164 g  , pikkus 51 cm apgariga : 8-9 .'),
#     '3164'),
#    (Text(text='kell 17 : 37 sündis tütarlaps ,  kaal 3190g  , Apgar 8-9-9 .'),
#     '3190'),
#    (Text(text='18.06.201302 : 30 . sünnib poeg  kaaluga : 3260g  , pikkus 47,5cm apgariga : 1 ` '),
#     '3260'),
#    (Text(text=' Sünnikaal 3290g '), '3290'),
#    (Text(text='line vaginaalne sünnitus , lapse  sk 3300g  , sp 50 cm , Apgar 8p'),
#     '3300'),
#    (Text(text='itusmajast lubati koju 4 . ep ,  kaaluga 3310 g  , vaakumotsikust turse oli lahe'),
#     '3310'),
#    (Text(text='Apgar 8/9/9  Sünnikaal 3390 g  , pikkus 53 cm , pea 33 cm Emal'),
#     '3390'),
#    (Text(text=' SK 3420 g  kaal koju minnes 3190 g'), '3420'),
#    (Text(text='13.09.2012 sündis poeg  kaal 3430g  , pikkus 50cm ja apgar 9/9'),
#     '3430'),
#    (Text(text=' Sünnikaal 3450g '), '3450'),
#    (Text(text='14 sünnib elus ajaline poeglaps  kaaluga 3450g  , pikkusega 50cm , Apgar 10-10 '),
#     '3450'),
#    (Text(text='.201205 : 06 . sünnitas : tütar  kaaluga : 3468g  pikkus 51cm apgariga : 9 - 9 .'),
#     '3468'),
#    (Text(text='07.07.201210 : 35 . sünnib poeg  kaaluga : 3488 g  , pikkus 52 cm apgariga : 8-8-8'),
#     '3488'),
#    (Text(text=' SK 3500g  kaal koju minnes 3200 g'), '3500'),
#    (Text(text='1.01.201305 : 57 . sünnib tütar  kaaluga : 3502gr  apgariga : 8-9 .'),
#     '3502'),
#    (Text(text='8.12.201211 : 31 . sünnib tütar  kaaluga : 3516 gr  , 51 cm apgariga : 9-10 .'),
#     '3516'),
#    (Text(text='8.07.201306 : 56 . sünnib tütar  kaaluga : 3518g  , pikkusega 50cm apgariga : 9-9'),
#     '3518'),
#    (Text(text=' SK 3520g  -kaal kojuminekul 3370g - täna '), '3520'),
#    (Text(text='Kaal : 3408 g  SM 3524 g '), '3524'),
#    (Text(text='0.07.201213 : 50 . sünnib tütar  kaaluga : 3524g /51cm apgariga : 8-9 .'),
#     '3524'),
#    (Text(text='9.10.201304 : 58 . sünnib tütar  kaaluga : 3528g  apgariga : 9-9 .'),
#     '3528'),
#    (Text(text=' SK 3530 g  kaal koju minnes 3330 g'), '3530'),
#    (Text(text=' Sünnikaal 3530 g  ; pikkus 51 cm ; pü 36 cm ; rü '), '3530'),
#    (Text(text=' kaal 3570 g  pikkus 52 cm Apgar 9 / 9 p'), '3570'),
#    (Text(text=' Kaal 3588g  ( -1,1 % sk-st ) , pikkus 50 cm'), '3588'),
#    (Text(text='20.08.2012 sündis tütar  kaal 3590g  , pikkus 52cm ja apgar 9/9'),
#     '3590'),
#    (Text(text=' Sünnikaal 3640 g  , pikkus 52 cm ; pü 36 cm ; rü '), '3640'),
#    (Text(text=' S/k 3650 gr  , pikkus 50 cm'), '3650'),
#    (Text(text='3.09.201303 : 27 . sünnib tütar  kaaluga : 3702  / 50 . apgariga : 9/9 .'),
#     '3702'),
#    (Text(text='29 sünnib ajaline elus poeglaps  kaaluga 3713g  , pikkus 53cm'),
#     '3713'),
#    (Text(text='askes asfükisas , Apgar 2/3/4 ,  kaaluga 3715 gr  , pH 6,9 , südametegevus < 100 '),
#     '3715'),
#    (Text(text='2.9 , P39.9 , Q63.8 , koju läks  kaaluga 3730 g  ( -6.7 % sünnikaalust )'),
#     '3730'),
#    (Text(text=' Sünnikaal 3740 g  , pikkus 51 cm ; pü 36 cm ; rü '), '3740'),
#    (Text(text=' Sünnikaal 3760 g  ; pikkus 53 cm ; pü 36 cm ; rü '), '3760'),
#    (Text(text=' SK 3760 g '), '3760'),
#    (Text(text='15.07 kell 09.23 sünnib poeg ,  kaal 3772g  , Apgar 9/9 .'),
#     '3772'),
#    (Text(text='st Apgari hinnetega 8/8 palli ,  sünnikaaluga 3790 g '),
#     '3790'),
#    (Text(text='al sünnib elus ajaline poeglaps  Kaal 3790 g  , pikkus 51 cm Järelveed roheka'),
#     '3790'),
#    (Text(text='SK 4075 g  kaal koju minnes 3830 g '), '3830'),
#    (Text(text=' Kaal 3850g '), '3850'),
#    (Text(text='Rp-toidul - ülihea kaaluiive :  sünnikaal 3852g  -> 6250g'),
#     '3852'),
#    (Text(text='Poeg  kaaluga 3858 g  , apgarid 9/10'), '3858'),
#    (Text(text='Sünnitus esile kutsutud 39 RN ,  SK 3872 gr  Apgar 9 ( ? )'),
#     '3872'),
#    (Text(text='3 sündis ajaline elus tütarlaps  kaaluga 3920g  , pikkus 51 cm'),
#     '3920'),
#    (Text(text='t ( 40 r näd ) , Apgariga 8/9 ,  sünnikaaluga 3950 gr '),
#     '3950'),
#    (Text(text=' SK 4000 g  , SP 51 cm , rinnapiima ei saan'), '4000'),
#    (Text(text='02.2012 kell 01 : 43 , poeglaps  kaal 4000  , pikkus 54cm , Apgar 9/9'),
#     '4000'),
#    (Text(text=' Kaal - 4050g '), '4050'),
#    (Text(text=' SK 4058 g  , pikkus 52 cm'), '4058'),
#    (Text(text='08.03.2012 Sündis poeglaps  kaaluga 4088g  , pikkusega 52cm'),
#     '4088'),
#    (Text(text='Sündis : õigeaegselt  Sünnikaal : 4140 g  Pikkus : 52 cm'),
#     '4140'),
#    (Text(text='Tagasi lastekodusse :  kaal 4170 gr  , pikkus 57 sm PÜ 37 sm'),
#     '4170'),
#    (Text(text=',5cm Organleid - patoloogiata ,  kaal 4194g /N/ OAE-parem kõrv/-/ vasak-N Ed'),
#     '4194'),
#    (Text(text='Tänane puhas  kaal 4256g '), '4256'),
#    (Text(text='6 ) vaginaalsel teel xxx-anonym  kaaluga 4262g '), '4262'),
#    (Text(text='16.12.201215 : 47 . sünnib poeg  kaaluga : 4286  . apgariga : 8-9 .'),
#     '4286'),
#    (Text(text=' Sk 4294g  , pikkus 52cm , P ? 37cm , R ? '), '4294'),
#    (Text(text='mber kaela Veeta periood 15 min  Kaal 4310 g  Pikkus 53 cm P ü 37 cm R ü 38 c'),
#     '4310'),
#    (Text(text='RP toidul -tänane  kaal 4330 g '), '4330'),
#    (Text(text=' SK 4330 g  kaal koju minnes 4060 g'), '4330'),
#    (Text(text='Elus , ajaline tütarlaps  kaaluga 4340 g  , pikkus 53 cm , Apgari hinne 9'),
#     '4340'),
#    (Text(text='etatud vaakumekstaraktsiooniga ,  sk 4340g  , A8/8 .'), '4340'),
#    (Text(text='psena vaginaalse sünnituse teel  sünnikaaluga 4370g  , pikkusega 53 cm , Apgaritega '),
#     '4370'),
#    (Text(text='6 sünnib elus ajaline tütarlaps  kaaluga 4380g  , pikkusega 55 cm'),
#     '4380'),
#    (Text(text=' Sünnikaal 4386 g  , pikkus 55 cm ; pü 36 cm ; rü '), '4386'),
#    (Text(text=' Kaal : 4450 g '), '4450'),
#    (Text(text='Obj :  Kaal 4900 gr  , pikkus 58cm , pea ü 38cm'), '4900'),
#    (Text(text=' Kaal 5170g  , pikkus 59cm , pea 40,4 cm , r'), '5170'),
#    (Text(text='Puhas  kaal 5214g '), '5214'),
#    (Text(text='* 31.05.2013   :  kaal 5500g  , pikkus61 cm , kib basseinis ,'),
#     '5500'),
#    (Text(text=' Kaal 6420 g /pikkus 63 cm'), '6420'),
#    (Text(text=' Kaal 6700 g  -100 mg/1,0 ml i/m jagatuna mõl'), '6700'),
#    (Text(text=' Kaal 7132 g  25 prots'), '7132'),
#    (Text(text='ehatemperatuur 36,9 kraadi ning  kaal 7760g '), '7760'),
#    (Text(text='Obj :  Kaal 8310 gr  , pikkus 67cm , pea ü 43cm'), '8310'),
#    (Text(text='akas , läbivaatuse ajal rahulik  kaal 8700g  pikkus 64cm pü 45cm Jume kahvat'),
#     '8700'),
#    (Text(text=' PT )/ PÜ 34 cm ( <3PT )-> 8k v  kaal 8880 g  ( <25PT )/ pikkus 69cm ( 10-25P'),
#     '8880'),
#    (Text(text=' Kaal 9250 gr  pikkus 75 sm'), '9250'),
#    (Text(text='* 05.07.2013   : Pikkus 73cm ,  kaal 9280g  , PÜ 46cm , RÜ 46cm'),
#     '9280'),
#    (Text(text='Obj  kaal 9730g  , pikkus 71,5cm peaümb'), '9730'),
#    (Text(text='* 12.11.2013   :  Kaal 10305 kg  , pikkus 71 cm , peaümbermõõt 4'),
#     '10305'),
#    (Text(text=' Sk 2,2 kg  , sp 45 cm'), '2.2'),
#    (Text(text='Kehatemperatuur 37,3C Lapse  kaal 3,5kg '), '3.5'),
#    (Text(text='amine ) tulemus : pikkus : 52cm  kaal : 3.84kg  KMI : 14.2'),
#     '3.84'),
#    (Text(text=' Sünnikaal : 4.2kg '), '4.2'),
#    (Text(text=' Kaal : 5 kg  , pikkus : 60cm'), '5'),
#    (Text(text=' kaal 5,03kg '), '5.03'),
#    (Text(text='ine ) tulemus : pikkus : 62.5cm  kaal : 5.98kg  KMI : 15.3 pea ümbermõõt : 38.5'),
#     '5.98'),
#    (Text(text='Lapse  kaal : 6 kg '), '6'),
#    (Text(text=' kaal 6,65kg '), '6.65'),
#    (Text(text=' Kaal 6,8kg  , 64cm , 43cm'), '6.8'),
#    (Text(text='Obj :  kaal 7,3kg '), '7.3'),
#    (Text(text='RR 140/80  kaal 7,5  mmol l'), '7.5'),
#    (Text(text=' kaal 8,81kg '), '8.81'),
#    (Text(text=' Kaalub 9,5 kg  , 10 hammast'), '9.5'),
#    (Text(text=' Kaal 10 kg '), '10'),
#    (Text(text=' Kehakaal 10,1 kg  ( <3 ts )'), '10.1'),
#    (Text(text='ga hakkama kaaluiive positiivne  kaal 10,2 kg '), '10.2'),
#    (Text(text=' kaal 10,3 kg '), '10.3'),
#    (Text(text=' Kaal 10,4 kg '), '10.4'),
#    (Text(text=' kaal 11 kg  pikkus 87,7cm'), '11'),
#    (Text(text='2a -lt kasv 86 cm ( 97pt ) ,  kaal 11,5 kg  pt ) , KMI 15,5 kg/m2 , BSA m2'),
#     '11.5'),
#    (Text(text='aniil on 1aasta5,5 kuu vanune ,  kaal 12kg  , 11 hammast Laps liigutustes h'),
#     '12'),
#    (Text(text='Patsient võtnud aastaga  kaalus 12 kg  alla kõhulahtisuse tõttu ja pea'),
#     '12'),
#    (Text(text='amine ) tulemus : pikkus : 93cm  kaal : 12.7kg  KMI : 14.7'),
#     '12.7'),
#    (Text(text='amine ) tulemus : pikkus : 92cm  kaal : 12.8kg  KMI : 15.1'),
#     '12.8'),
#    (Text(text='S e k k u m i n e  Kaal 13kg  , pikkus 75 cm'), '13'),
#    (Text(text=' Kaal 13 kg '), '13'),
#    (Text(text='kontsentratsioon 63,912.09.2011  Kaal-13 kg  pikkus 104cm pea 47cm'),
#     '13'),
#    (Text(text='Neeluring ii  Kaal 13,5kg  , Pikkus 90cm , H 16'), '13.5'),
#    (Text(text='amine ) tulemus : pikkus : 95cm  kaal : 14kg  KMI : 15.5'),
#     '14'),
#    (Text(text='RR 88/50 mm Hg kaal 14,9 kg EKG : Siinusrütm fr 121 x min , '),
#     '14.9'),
#    (Text(text='mine ) tulemus : pikkus : 101cm  kaal : 15kg  KMI : 14.7'),
#     '15'),
#    (Text(text='37,4 * ,  Kehakaal 15,5 kg '), '15.5'),
#    (Text(text=' kaal 16kg  pikkus 87,5 cm'), '16'),
#    (Text(text='Pikkus 95 cm ,  kaal 16 kg '), '16'),
#    (Text(text=' Kaal 17,5 kg  ( 25 pt ) , pikkus 98,2 cm ( al'), '17.5'),
#    (Text(text=' kaal 17,800 kg '), '17.8'),
#    (Text(text=' Kaal 18kg '), '18'),
#    (Text(text='Obj :  kaal 18 kg  , laps rahuldavas üldseisundis '), '18'),
#    (Text(text=' Kaal 18,5 kg  , pikkus 110 cm'), '18.5'),
#    (Text(text='leid : 4 aasta vanune tütarlaps  Kaal 18,5 kg  ( 75 protsentiili ) , pikkus 10'),
#     '18.5'),
#    (Text(text=' kaal 19,5 kg  pikkus 112,5 cm'), '19.5'),
#    (Text(text=' Kaal : 20,5kg  ( 50pt ) , pikkus : 115,5 cm ( '), '20.5'),
#    (Text(text='mine ) tulemus : pikkus : 119cm  kaal : 22kg  KMI : 15.5'),
#     '22'),
#    (Text(text=' Kaal - 22 kg  / pikkus 130 cm'), '22'),
#    (Text(text=' kaal - 22kg '), '22'),
#    (Text(text=' kaal 24,4kg  pikkus 134 cm'), '24.4'),
#    (Text(text=' kaal 25 kg '), '25'),
#    (Text(text=' Kaal 25 kg '), '25'),
#    (Text(text=' Kaal 25,7 kg  , pikkus 130 cm'), '25.7'),
#    (Text(text=' kaal 26kg '), '26'),
#    (Text(text='d silmaalused , pikkus 133 cm /  kaal 26,7  ( + 2,3 kg 0,5 aasta jooksul ) '),
#     '26.7'),
#    (Text(text='kus 118.5 cm ( alla 3 prots ) ,  kaal 27.2 kg  ( 3-10 . prots )'),
#     '27.2'),
#    (Text(text='Pikkus 119.7 cm ,  kaal 27.9kg '), '27.9'),
#    (Text(text='Obj  kaal 28kg  alahiilel lk taandunmas villike'), '28'),
#    (Text(text='mine ) tulemus : pikkus : 125cm  kaal : 30kg  KMI : 19.2'),
#     '30'),
#    (Text(text=' Kaal : 30,5 kg '), '30.5'),
#    (Text(text=' Kaal 34,5 kg  ( pr50-75 ) , pikkus 143 cm ( p'), '34.5'),
#    (Text(text='Saatekiri geneetikutele  kaal 36 kg '), '36'),
#    (Text(text=' Kaal 37 kg  ( 3-10 pt ) , pikkus 136 cm ( a'), '37'),
#    (Text(text=' Kaal-37 kg  ; Pikkus-153 cm ; KMI-15,8 ; Ha'), '37'),
#    (Text(text='108x ´ ,  Kaal 38,5 kg  , Pikkus 140,5 cm'), '38.5'),
#    (Text(text=' 3 tunni tagant , Objektiivselt  kaal 40 kg  , pikkus 156,5 cm , RR 115/72 m'),
#     '40'),
#    (Text(text=' ? pilane ( Kiigemetsa kool ) ;  kehakaal-40 kg  , pikkus-155,2 cm , KMI - 16 ; '),
#     '40'),
#    (Text(text='kkus 149,5 cm ( 50 ja 75 ts ) ,  kaal 42 kg  ( 75 ja 90 ts )'),
#     '42'),
#    (Text(text=' Kehakaal 43 kg '), '43'),
#    (Text(text='RR 92/60 mm Hg kaal 43 kg EKG : Siinusrütm fr 79 x min Ehh'),
#     '43'),
#    (Text(text=' 44,1kg madalaim pikkus 176,5 ;  kaal 44,1kg '), '44.1'),
#    (Text(text='oovida tõsta kehakaalu ( praegu  kaalub 45 kg  , mis oluliselt vähem eelnevast'),
#     '45'),
#    (Text(text=' kaal 45 kg  pikkus 151 cm'), '45'),
#    (Text(text='Toitumus hea  Kaal 46,8 kg  / pikkus 146,5 RR 116/62 , fr'),
#     '46.8'),
#    (Text(text=' Kaal : 47,9 kg '), '47.9'),
#    (Text(text='OBJ Neuroloogiliselt leiuta  Kehakaal 48,0 kg  , pikkus 167 cm , KMI 17 , RR d'),
#     '48'),
#    (Text(text='Ema sale , pikkus 158 cm ,  kaal 49 -52 kg'), '49'),
#    (Text(text='Pikkus - 164 cm ,  kaal - 50 kg '), '50'),
#    (Text(text='Pikkus154 cm Kaal50 kg BMI21,08281329 Südamerütm SR fr7'),
#     '50'),
#    (Text(text='kkus 150 cm ( 10-25 . prots ) ,  kaal 51.9 kg  ( 50-75 prots )'),
#     '51.9'),
#    (Text(text='kehaehitusega , pikkus 168 cm ,  kaal 52 kg  KMI 18,4 .'),
#     '52'),
#    (Text(text='tsükkel 26-27 päeva ,  kaal 52 kg '), '52'),
#    (Text(text=' Kaal 53,1kg '), '53.1'),
#    (Text(text='Obj :  kaal 53,6kg '), '53.6'),
#    (Text(text='mselt Roaccutani 30 mg päevas ,  kehakaal 54 kg '), '54'),
#    (Text(text='04.07.2012 -  Kaal 54 kg '), '54'),
#    (Text(text=' Kehakaal 54kg  , + 1,5kg'), '54'),
#    (Text(text='Pikkus-165cm ,  kaal-54kg  , KMI-20,5RINDKERE JA KÕHUPIIRK'),
#     '54'),
#    (Text(text=' Kaal 54,8 kg  Protsentiil ( 90-97 )'), '54.8'),
#    (Text(text=' kaal 55 kg  , tursevaba'), '55'),
#    (Text(text='Vanus : 62 yrs  Kaal : 55 kg '), '55'),
#    (Text(text=' Kaal : 55 kg '), '55'),
#    (Text(text='pikkus 163 cm ,  kehakaal 55 kg  ( KMI21 )'), '55'),
#    (Text(text='Enne sünnitust  kaalus 55kg '), '55'),
#    (Text(text='F 25 KÜ 88 RR 115/60  kaal 56,5  ( + 1,5 )'), '56.5'),
#    (Text(text=' Kaal 56,7 kg  pikkus 166 sm'), '56.7'),
#    (Text(text='raseduse suurus 20+5 ,  kaal 56,7  ( + 2,3kg ) , F 18 , KÜ 81 . , '),
#     '56.7'),
#    (Text(text='# Pikkus158 cm Kaal57 kg BMI22,83287935'), '57'),
#    (Text(text='ane Yasminelle originaal Tänane  kehakaal 57,5 kg '), '57.5'),
#    (Text(text='Tänane  kaal 58kg  ( iive + 2kg )'), '58'),
#    (Text(text='Rinnaresektaat  kaaluga 58 g  , mõõtudega 7x4,5x3 cm'), '58'),
#    (Text(text='Pikkus 164cm , praegune  kaal 58,4kg '), '58.4'),
#    (Text(text='Pikkus 157,8 cm ,  kaal 59 kg  , RR 127/80 mmHg'), '59'),
#    (Text(text='Obj : pt 175 cm pikk ja  kaalub 60 kg '), '60'),
#    (Text(text='# Pikkus 167 cm  Kaal 60 kg  BMI 21,51385851'), '60'),
#    (Text(text='Pikkus159 cm Kaal60 kg BMI23,7332384 Südamerütm SR fr80'),
#     '60'),
#    (Text(text='Pikkus 172cm  kaal : 61kg  KMI : 20.6 kg/m2 .'), '61'),
#    (Text(text=' Kaal 61 kg  pikkus 169 cm'), '61'),
#    (Text(text='viimase kolme nädalaga + 3 kg (  kehakaal 61 kg  )'), '61'),
#    (Text(text=' Kaal : 61,4kg '), '61.4'),
#    (Text(text=' Kehakaal 61,6kg  , iive + 1,6kg'), '61.6'),
#    (Text(text='oxini 50 mcg päevas ja Novofemi  Kaal 62 kg  Kaebusi ei ole Kilpnääre palpat'),
#     '62'),
#    (Text(text='langus ravi ajal 14 kg , praegu  kehakaal 62 kg  , seetõttu Pegintroni 80 mcg , '),
#     '62'),
#    (Text(text=' Kaal 62,0 kg  ( + 2,8 kg ) Füüsiline koormus '), '62'),
#    (Text(text='Pikkus-163cm ,  kaal-62kg ;KMI-24RINDKERE JA KÕHUPIIRKONDK'),
#     '62'),
#    (Text(text='Obj :  kaal 62,5kg '), '62.5'),
#    (Text(text=' kehakaal 63 kg '), '63'),
#    (Text(text='Vanus : 76 yrs  Kaal : 63 kg '), '63'),
#    (Text(text='v s 12,4 mmol l RR 135/80  kaal 63 kg '), '63'),
#    (Text(text='vi samas annuses 40 mg päevas ,  kehakaal 63 kg  , nõustatud reziimi osas'),
#     '63'),
#    (Text(text='# Pikkus168 cm Kaal64 kg BMI22,67573696'), '64'),
#    (Text(text=' Kehakaal 65kg  ( 8kuuga - 2kg )'), '65'),
#    (Text(text='Vanus : 61 yrs  Kaal : 65 kg '), '65'),
#    (Text(text='# Pikkus156 cm Kaal65 kg BMI26,70940171'), '65'),
#    (Text(text='Enne rasedust  kaal : 65kg '), '65'),
#    (Text(text=' Kaal 65kg  , pikkust täpselt ei tea ( u 17'), '65'),
#    (Text(text='OBJ pikkus 187 ,  kaal 65,5  riietega , KMI 18,5RR 130/80 , '),
#     '65.5'),
#    (Text(text='Pikkus-175cm ,  kaal-66kg  , KMI-22'), '66'),
#    (Text(text=' Kaal 67kg '), '67'),
#    (Text(text='Pikkus-169cm ,  kaal-67kg  , KMI-24RINDKERE JA KÕHUPIIRKON'),
#     '67'),
#    (Text(text='Pikkus 171 cm  Kaal 67 kg  BMI 22,91303307 Südamerütm SR f'),
#     '67'),
#    (Text(text='14.02.2012 - RR120/80mmHg  kaal 67,2kg  vs 5,0 mmol/l cor regul tahhüka'),
#     '67.2'),
#    (Text(text=' alusel , eeldatava maksimaalse  kaaluga 68 kg  , patsiendi kaal 86 kg )'),
#     '68'),
#    (Text(text='2009 olnud  kehakaal 68 kg  , järgmiseks aastaks 58 kg'), '68'),
#    (Text(text=' Kaal 68kg  pikkus 166cm KMI 24.5'), '68'),
#    (Text(text='Pikkus-169cm ,  kaal-68kg  , KMI-24,5RINDKERE JA KÕHUPIIRK'),
#     '68'),
#    (Text(text='seisund rahuldav , adekvaatne ,  kaal - 68 kg  , kasv - 161 cm , aktiivne , au'),
#     '68'),
#    (Text(text='Kaal pigem tõuseb -  kaal 68kg  , pikkus 155cm'), '68'),
#    (Text(text='Kasv 162 cm ,  kaal 68 kg '), '68'),
#    (Text(text='Pikkus-157cm ,  kaal-68kg  , KMI-28,2'), '68'),
#    (Text(text=' Kaal - 68,3kg '), '68.3'),
#    (Text(text='BMI 29 ( pikkus154cm  kaal 69kg  ) kaal Järeldus : Foonis välise'),
#     '69'),
#    (Text(text='Kaal 79kg ( tava kaal 69kg  )'), '69'),
#    (Text(text='r uuring ( patareid 2 . korda )  kaal 69 kg  , pikkus 154,2 cm'),
#     '69'),
#    (Text(text=' Kaal 69,5 kg '), '69.5'),
#    (Text(text='v , liikub ise , rr138/76 p76 ,  kaal-70  , pikkus-160 , südame toonid tu'),
#     '70'),
#    (Text(text='d tavalist värvi Pikkus-158cm ,  kaal-70 cm , KMI-29 RINDKERE JA KÕHUPIIR'),
#     '70'),
#    (Text(text='Ema pikkus 160 cm ,  kaal 70 g  , isa pikkus 176 cm , kaal 90 k'),
#     '70'),
#    (Text(text='11.05.2012 - Pikkus 154 cm ,  kaal 70 kg  , KMI 29,5'), '70'),
#    (Text(text='40mg päevas ,  kehakaal 70 kg  Helistab analüüsi vastuste pära'),
#     '70'),
#    (Text(text='-5 mgx1 , indapamiid 1.5 mgx1 .  kAAL 71.0 KG X1 , BMI 28.0'),
#     '71'),
#    (Text(text='F 20 KÜ 91 RR 100/60  kaal 71,0  ( + 0,5 )'), '71'),
#    (Text(text='objektiivselt : pikkus 164 cm ,  kehakaal 71 kg '), '71'),
#    (Text(text=' Kaal 71,8 kg  , pikkus 170 cm . Nahk kahvatu '), '71.8'),
#    (Text(text='vü-78cm kaal-72.3kg BMI -22.6FAT % -13.0%RR-152/79 m'), '72.3'),
#    (Text(text='PATSIENDI PIKKUS 172 cm ,  KAAL 73 kg '), '73'),
#    (Text(text=' Kaal 73,8kg  + 3,9kg'), '73.8'),
#    (Text(text=' kaal 74 kg '), '74'),
#    (Text(text=' Kehakaal 74  ( + 2 kg )'), '74'),
#    (Text(text='Pikkus-163cm ,  kaal-74kg  , KMI-28,8RINDKERE JA KÕHUPIIRK'),
#     '74'),
#    (Text(text=' Kaal : 74 kg '), '74'),
#    (Text(text=' Kaal 74kg  , pikkus 160 , KMI 28,91 .'), '74'),
#    (Text(text=' Kehakaal 74 , 5kg  ( + 0,9 kg )'), '74.5'),
#    (Text(text='Objektiivselt :  Kaal 75 kg  Pikkus 180 cm Suitsetamine : ja'),
#     '75'),
#    (Text(text=' kaal 75 kg  ( + 5 kg poole aastaga )'), '75'),
#    (Text(text='pertensivus card II Kirjeldus :  kaal 75 kg  , pikkus 170 cm , kehapind 1,86'),
#     '75'),
#    (Text(text='PATSIENDI PIKKUS 176 cm ,  KAAL 75 kg '), '75'),
#    (Text(text='Pikkus 187 cm  Kaal 75 kg  RR mmHg BSA 2,00'), '75'),
#    (Text(text=' kaal-76kg pikkus-165cmSuunatud dieetõele'), '76'),
#    (Text(text=' Kehakaal 76 kg '), '76'),
#    (Text(text='Kirjeldus : Pikkus 164 cm ;  kaal 76 kg '), '76'),
#    (Text(text='ormosteeniline , pikkus 182cm ,  kaal 77kg '), '77'),
#    (Text(text='# Pikkus168 cm Kaal77 kg BMI27,28174603'), '77'),
#    (Text(text='04.09.13  Kaal 77,1kg  On vältinud piimalaktoosi ja kõ'),
#     '77.1'),
#    (Text(text='# Pikkus165 cm Kaal78 kg BMI28,65013774'), '78'),
#    (Text(text='Vanus : 65 yrs  Kaal : 78 kg '), '78'),
#    (Text(text=' Kaal 78 kg  ( 3-4 kuuga tõusnud 5 kg )'), '78'),
#    (Text(text='# Pikkus 164 cm  Kaal 79 kg  BMI 29,37239738'), '79'),
#    (Text(text=' Kaal : 80 kg '), '80'),
#    (Text(text='Pikkus 166 cm  Kaal 80 kg  BSA 1,88'), '80'),
#    (Text(text=' kaal 80  ; pikkus 1.74 ; BMI 26 ; neelua'), '80'),
#    (Text(text='Pikkus-160,5cm ,  kaal-81kg  , KMI-32RINDKERE JA KÕHUPIIRKON'),
#     '81'),
#    (Text(text=' Kaal 81 kg  , pikkus 171 cmNahk lööbeta , p'), '81'),
#    (Text(text=' Kaal 81 kg '), '81'),
#    (Text(text='RR 125/80  kaal 81 kg '), '81'),
#    (Text(text=' Kaal : 81,7 kg '), '81.7'),
#    (Text(text='Rahuldavas üldseisundis meespt  kaal 82 kg  / pikkus 175 cm , nahk ja lk va'),
#     '82'),
#    (Text(text=' Kaal 82kg '), '82'),
#    (Text(text=' kaal 83 kg  probleemiks üldiselt see , et d'), '83'),
#    (Text(text=' Kaal : 83 kg '), '83'),
#    (Text(text=' kaal 83 kg '), '83'),
#    (Text(text='Pikkus 159cm ,  kaal 83,5kg '), '83.5'),
#    (Text(text='ellest sügisest Objektiivselt :  Kaal 84 kg  Pikkus 182 cm Suitsetamine : ja'),
#     '84'),
#    (Text(text=' Kaal 84,6 kg  , kaaluiive 0 .'), '84.6'),
#    (Text(text='Üldseisund - rahuldav ,  kaal 85 kg  , pikkus 176 cmNahk/limaskestad'),
#     '85'),
#    (Text(text='# Pikkus172 cm Kaal85 kg BMI28,73174689'), '85'),
#    (Text(text=' Kehakaal 85 kg '), '85'),
#    (Text(text=' Kaal 85 kg '), '85'),
#    (Text(text='Pikkus 165 cm  Kaal 85 kg  RR 120/80 mmHg'), '85'),
#    (Text(text=' Kaal : 87 kg '), '87'),
#    (Text(text=' Kaal : 87 kg '), '87'),
#    (Text(text='Pikkus-162cm ,  kaal-87kg  , KMI-34RINDKERE JA KÕHUPIIRKON'),
#     '87'),
#    (Text(text=' Kaal 87 kg  ; pikkus 164 cm'), '87'),
#    (Text(text=' Kaal : 87 kg '), '87'),
#    (Text(text='Mõõdetud  kehakaal 87,5 kg  , KMI 27,6 , RP 24,6 % , VÜ 100'),
#     '87.5'),
#    (Text(text=' Kaal 88 kg  ( püsib )'), '88'),
#    (Text(text=' Kaal : 88,5 kg '), '88.5'),
#    (Text(text='Kasv 164 cm ,  kaal 89 kg  adipoosne'), '89'),
#    (Text(text=' Kaal 89,0  - iive + 1,5kg'), '89'),
#    (Text(text='Vanus : 65 yrs  Kaal : 89 kg '), '89'),
#    (Text(text=' Kaal 90 kg '), '90'),
#    (Text(text=' Kaal 90,0 ( + 3,1 ) kg  , turseid ei ole , RR 125/70 mm'),
#     '90'),
#    (Text(text='kaal 0 kg , isa pikkus 180 cm ,  kaal 90 kg '), '90'),
#    (Text(text='Pikkus 180 cm  Kaal 90 kg  RR mmHg BSA'), '90'),
#    (Text(text=' Kaal : 91,4 kg '), '91.4'),
#    (Text(text=' kaal 92 kg  v s 6,3mmol l RR 140/80'), '92'),
#    (Text(text=' Kaal - 92 kg  , kasv - 161 sm BMI - 35,3 Ei s'), '92'),
#    (Text(text=' Kaal 92 kg  , pikkus 169 cm KMI 32'), '92'),
#    (Text(text='Pikkus 1.76 ;  kaal 94  ; BMI 34 ; Näidustatud : SPO2 ;'),
#     '94'),
#    (Text(text='Pikkus 180 cm ,  kaal 94 kg '), '94'),
#    (Text(text='aehituse analüüs Pikkus : 183 cm Kaal : 95,0 kg KMI - 28,4fat % - 27,2Vü - 107 c'),
#     '95'),
#    (Text(text='Temp 36,5C , Pikkus 158cm ,  kaal 95 kg '), '95'),
#    (Text(text='# Pikkus164 cm Kaal95 kg BMI35,32123736'), '95'),
#    (Text(text='# Pikkus182 cm Kaal95 kg BMI28,6801111'), '95'),
#    (Text(text=' kaal 95 kg  v s 9,5 mmol l RR 150/90'), '95'),
#    (Text(text=' kehakaal : 96 kg '), '96'),
#    (Text(text=' Kaal 96 kg  , praegu ka premenstruaalne per'), '96'),
#    (Text(text=' kaal 97kg '), '97'),
#    (Text(text='  juures-patoloogilise leiuta ,  Kaal 97 kg '), '97'),
#    (Text(text=' kaal - 98kg  , pikkus-168cm , Suunan densito'), '98'),
#    (Text(text=' Kaal 99 kg  , pikkus 174 cm , KMI=33 RR=141'), '99'),
#    (Text(text='Pikkus 191 cm ,  kaal 100 kg '), '100'),
#    (Text(text='mist ülekaalulise meeshaigega (  kaal 100 kg  , pikkus 175 cm , KMI 32 kg/m2 '),
#     '100'),
#    (Text(text='PATSIENDI PIKKUS 163 cm ,  KAAL 100 kg '), '100'),
#    (Text(text='tekkinud FA , diabeeti ei põe ,  kaal 100kg  , pikkus u 155cm , põlneliigese'),
#     '100'),
#    (Text(text=' kaal : 100kg  , pikkus : 163cm'), '100'),
#    (Text(text='Rasedus ,  kaal 102kg  , GTT 4,7-7,7-7,7mmol/l , Gesta'),
#     '102'),
#    (Text(text=' kaal-102 kg  , BMI-38 kg/m2 , AD 131/101 mmH'), '102'),
#    (Text(text='Pt-i pikkus 165.1 cm ,  kaal 102.5kg '), '102.5'),
#    (Text(text='Pikkus158 cm Kaal104 kg BMI41,65999039 Südamerütm SR fr5'),
#     '104'),
#    (Text(text=' Kaal 105kg '), '105'),
#    (Text(text='Obj : 164 cm pikk ja  kaalub 105 kg  vasak õlg madalamal tunduvalt'),
#     '105'),
#    (Text(text=' Kaal 105 kg '), '105'),
#    (Text(text='aal 87 kg , isa pikkus 175 cm ,  kaal 105 kg '), '105'),
#    (Text(text=' Kaal 105 kg  stabiilne'), '105'),
#    (Text(text='v s 6,4 mmol l RR 130/80  kaal 106 kg '), '106'),
#    (Text(text='Pikkus 171 cm ,  kaal 106 kg '), '106'),
#    (Text(text=' Kaal : 110 kg '), '110'),
#    (Text(text=' Kaal 110 kg  , pikkus 170 cm'), '110'),
#    (Text(text='RR 150/95mmHg  kaal 111,3kg '), '111.3'),
#    (Text(text='01.06.2012 -  kaal 113kg  pikkus 182cm BMI - 34,11'), '113'),
#    (Text(text=' Kehakaal 114kg '), '114'),
#    (Text(text='Käesolevalt  kaal 114kg  , pikkus 1,67 , KMI 41kg/m2 .'),
#     '114'),
#    (Text(text=' Kaal - 116kg '), '116'),
#    (Text(text='ngamise parandamiseks ei kasuta  Kehakaal : 120 kg  kasv : 168 cm ; BMI : 42.5KNKle'),
#     '120'),
#    (Text(text='Patsient adipoosne ,  kaal 120 kg '), '120'),
#    (Text(text='Praegu  kaal 122 kg '), '122'),
#    (Text(text='8,28,2 / 12,5 --SOL VICTOZA 1,2  Kaal 124 kg  17.09.2013 - Minimaalne kompens'),
#     '124'),
#    (Text(text='ekujuline adipoossus , kmi 42 ,  kehakaal olnud 130  püsivalt'),
#     '130'),
#    (Text(text='neerib rasestuda Pt adipoosne ,  kaal 135kg '), '135'),
#    (Text(text=' Kehakaal 137 kg  kuni 84 kg vähenenud'), '137'),
#    (Text(text='# Pikkus188 cm Kaal152 kg BMI43,00588502'), '152'),
#    (Text(text=' tegu ülekaalulise patsieniga ,  kaal 158 kg  , pikkus 188 cm'),
#     '158'),
#    (Text(text='25 nädalas  sünnikaal 690g '), '690'),
#    (Text(text='Veetaperiood  Sk 1328gr  , pea 26cm , pikkus 40cm'), '1328'),
#    (Text(text='Apgariga 8/8 , s  kaaluga 1824 gr '), '1824'),
#    (Text(text='Laps väikest kasvu ,  Sk 2145g '), '2145'),
#    (Text(text=' SK 2254g  , pikkus 43cm , pea 33cm , Ap 9'), '2254'),
#    (Text(text=' Kaal 2435g  , kaalus positiivne iive + 53 g'), '2435'),
#    (Text(text='Mõõdud :  kaal 2516g  , pikkus 46cm ja peaümbermõõt 3'),
#     '2516'),
#    (Text(text='dinud kaksiklapsena ajalisena ,  SK 2614 g  , Apgariga 9/9 .'),
#     '2614'),
#    (Text(text='Loote  kaal 2641 g '), '2641'),
#    (Text(text='Sünnib elus enneaegne tütarlaps  kaaluga 2648g  , pikkus 47 cm , pea ümbermõõt '),
#     '2648'),
#    (Text(text=' SK 2750g '), '2750'),
#    (Text(text='Sündinud ajaliselt ,  sünnikaal 2800 g  Esimesed sõnad 2a 6 kuu vanusen'),
#     '2800'),
#    (Text(text=' Sünnikaal 2830 g  ; pikkus 50cm ; pü 35 cm ; rü 3'), '2830'),
#    (Text(text=' Sünnikaal 2850 g  ; pikkus 47 cm ; pü 35 cm ; rü '), '2850'),
#    (Text(text=' Sünnikaal 2860 g  ; pikkus 49 cm ; pü 34 cm ; rü '), '2860'),
#    (Text(text=' Kaal 2870 g  , -6g , -3.3 %'), '2870'),
#    (Text(text=' SK 2870  , Apgar 9 ? Imemine tugev , omo'), '2870'),
#    (Text(text='2 ) vaginaalsel teel xxx-anonym  kaaluga 2924g '), '2924'),
#    (Text(text='SK 3290 g  kaal koju minnes 2990 g '), '2990'),
#    (Text(text=' Kaal 3002g '), '3002'),
#    (Text(text='2013 kell : 04 : 08 , tütarlaps  kaal 3020  , pikkus 50 cm , Apgar 8/9'),
#     '3020'),
#    (Text(text='kumekstraktsioon , apgar 7/8/8 ,  sk 3050  .'), '3050'),
#    (Text(text=' SK 3060g '), '3060'),
#    (Text(text='57 sündis elus ajaline poeglaps  kaaluga 3076g  , pikkusega 50cm , AP9-9 .'),
#     '3076'),
#    (Text(text='06.04.2012 Sündis tütarlaps  kaaluga 3086g  , pikkusega 48 cm'),
#     '3086'),
#    (Text(text='05.07.2012 sündis poeg  kaal 3088g  , pikkus 48cm ja apgar 8/8'),
#     '3088'),
#    (Text(text=' Sünnikaal 3110 g  , pikkus 50 cm , peaümbermõõt 3'), '3110'),
#    (Text(text='ündis I ajalisest sünnitusest ,  sünnikaal 3134 g  , pikkus 49 cm , Apgar 9/9 pall'),
#     '3134'),
#    (Text(text=' kaal : 3154  , pikkus : 50cm'), '3154'),
#    (Text(text=' SK 3160 g  kaal koju minnes 2960 g'), '3160'),
#    (Text(text='7p lapse  kaal 3170g  , 1p iive 10g'), '3170'),
#    (Text(text='Tänane paljas  kaal 3184g '), '3184'),
#    (Text(text='18.09.2013 sündis poeg  kaal 3196g  , pikkus 50cm ja Apgar 9/9'),
#     '3196'),
#    (Text(text='isena ( 39+5 ) vaginaalsel teel  kaaluga 3212 g '), '3212'),
#    (Text(text='eisendis elus ajaline tütarlaps  kaaluga 3240 g  , pikkus 49 cm , Ap 9-10 .'),
#     '3240'),
#    (Text(text=' SK 3250 g  kaal koju minnes 3120 g'), '3250'),
#    (Text(text='Kaaluiive hea ,  kaal 3280g '), '3280'),
#    (Text(text='SK 3380 g  kaal koju minnes 3280 '), '3280'),
#    (Text(text=' Kaal 3280g '), '3280'),
#    (Text(text='Sündinud ajalisena  kaaluga 3290g  , Apgar 9/9 palli'), '3290'),
#    (Text(text=' Sünnikaal 3320g  ; pikkus 49 cm ; pü 35 cm ; rü '), '3320'),
#    (Text(text='I sünnitusest ajalise lapsena ,  sünnikaal 3340 gramm i , pikkus 50 cm , peaümbermõõt '),
#     '3340'),
#    (Text(text=' Kaal 3360g  ( -3,6 % )'), '3360'),
#    (Text(text='oni teel elus ajaline tütarlaps  kaaluga 3384 g  , pikkus 51 cm , Apgarid 8/8 .'),
#     '3384'),
#    (Text(text='ane tita söötmisprobleemidega :  SK 3384 g  , esimesed 3 päeva aktiivne , t'),
#     '3384'),
#    (Text(text='Puhas kaal : 3400g '), '3400'),
#    (Text(text='Anamnees :  SK 3400 g '), '3400'),
#    (Text(text=' SK 3402 g '), '3402'),
#    (Text(text=' SK - 3440  , pikkus-49 , pü-35 , Apgar -8/'), '3440'),
# ...
#     '100'),
#    (Text(text=',2012 Südamekab ( prof ) KMI-35  VÜ-100  V/R -130/70 Kolesterool-7,16 Ve'),
#     '100'),
#    (Text(text='4,5 kg , KMI 30,9 , RP 26,9 % ,  VÜ 100 cm '), '100'),
#    (Text(text='KMI - 29.3 ( norm 18.5 - 25 ) ,  VÜM - 100 sm  ( Meeste norm kuni = 88 - 102 s'),
#     '100'),
#    (Text(text='4,0 kg , KMI 29,0 , RP 23,7 % ,  Vü 100 cm '), '100'),
#    (Text(text='hakaal 85 kg , pikkkus 164 cm ,  vööümbermõõt 100 cm  , KMI 31 , RR 130/100 , EKG-s r'),
#     '100'),
#    (Text(text=' RR 138/88 mmHgKMI 28,5Fat 23,6% Vü 100cm Nõustatud'), '100'),
#    (Text(text=' VÜ : 100,0 '), '100'),
#    (Text(text='K-96,400 , P-163,5 ,  VÜ - 100  , KMI-36,5 , Spo2 - 98/66 , RR-'),
#     '100'),
#    (Text(text=' VÜ 100 cm '), '100'),
#    (Text(text='proov-PSA+horm KMI 28,6FAT 24,0% Vü 100cm Nõustatud 6360 - KEHA RASVA - JA'),
#     '100'),
#    (Text(text=' vü 100,0 cm '), '100'),
#    (Text(text='6,6 kg , KMI 29,2 , RP 25,0 % ,  VÜ 100 cm '), '100'),
#    (Text(text='proov-PSA+test KMI 29,1Fat 26,8% Vü 100cm Nõustatud'), '100'),
#    (Text(text='d RR 156/97 mmHgPulss 117 x/min  Vööümbermõõt : 100 cm Tehtud kehaehituse aparaatanalüü'),
#     '100'),
#    (Text(text='2 Südamekab ( prof ) KMI - 31,5  VÜ-100  V/R -130/70 Kolesterool - 5,56 '),
#     '100'),
#    (Text(text='ndeks ) = 29 ( norm kuni 25 ) ,  vüm 101cm '), '101'),
#    (Text(text='l/l ; kaal-78kg , pikkus - ?? ,  vööümbermõõt - 101cm  ; v/s-5,8mmol/l ,'),
#     '101'),
#    (Text(text='  : kaal 68 kg , pikkus 156.5 ,  vööümbermõõt 101 cm  , tehtudEKG , pt nõustaud'),
#     '101'),
#    (Text(text=' Vööümbermõõt : 101cm '), '101'),
#    (Text(text='etud vereproov KMI 26,9Fat 22,1% Vü 101cm Nõustatud'), '101'),
#    (Text(text=' vööümbermõõt 101 cm  ( üle 90 . prots )'), '101'),
#    (Text(text=',2012 Südamekab ( prof ) KMI-34  VÜ-102  V/R-140/90 Kolesterool-6,56 Ver'),
#     '102'),
#    (Text(text=' vööümb -102  , pikkus 176,5 , kaal -94 KMI--'), '102'),
#    (Text(text='al 102 , pikkus 176 cm , KMI 32  vööümbermõõt 102 cm '), '102'),
#    (Text(text=' Vööümbermõõt : 102,0cm '), '102'),
#    (Text(text='3.0 kg , KMI 27,7 , RP 23,3 % ,  VÜ 102 cm '), '102'),
#    (Text(text='2 RR 142/91 mmHgKMI 28,6FAT 22,8 Vü 102cm Nõustatud'), '102'),
#    (Text(text=' rasva 33,4 % , rasva 32,0 kg ,  vü 102cm  STLI küsimustik : A6 , B11 , C1'),
#     '102'),
#    (Text(text='Obj KMI 28 ,  vü 102 cm '), '102'),
#    (Text(text='ülekaaluline meespatsient ,  vööümbermõõt 102cm '), '102'),
#    (Text(text='8,2 kg , KMI 29,0 , RP 24,8 % ,  VÜ 102 cm '), '102'),
#    (Text(text=' VÜ : 102 '), '102'),
#    (Text(text='cm , KMI = ~ 35 ( N : 19-25 ) ;  VÜ = 102cm '), '102'),
#    (Text(text=' 89 kg , KMI 29,1 , RP 25,2 % ,  VÜ 102 cm '), '102'),
#    (Text(text='9,0 kg , KMI 29,9 , RP 28,1 % ,  VÜ 102 cm '), '102'),
#    (Text(text=' VÜ : 102 '), '102'),
#    (Text(text='76 . kaal 98kg , pikkus 188cm ,  vööümbermõõt 102cm  , kopsus vesikul hingamiskahin '),
#     '102'),
#    (Text(text='Kõht :  VÜ 102 cm  , ettevõvuv , palpatoorne hellu'), '102'),
#    (Text(text='6,2 kg , KMI 30,0 , RP 30,1 % ,  VÜ 102,5 cm '), '102.5'),
#    (Text(text='mHg Kaal-105kg , pikkus-157cm ,  VÜ-103  , KMI 42,6 tegemist patsiendil '),
#     '103'),
#    (Text(text=' Vööümbermõõt 103 cm '), '103'),
#    (Text(text='4,4 kg , KMI 27,3 , RP 21,0 % ,  VÜ 103 cm '), '103'),
#    (Text(text='RR 126/79 mmHgKMI 32,2Fat 30,9% Vü 103cm Nõustatud -'), '103'),
#    (Text(text='.2012   : ! Õpib 9-ndas klassis  VÜ-103  , P-185 , K-106,3 , KMI-31 , TÜ'),
#     '103'),
#    (Text(text='5,2 kg , KMI 30,1 , RP 29,2 % ,  VÜ 103 cm '), '103'),
#    (Text(text='KMI 30,1 ; FAT 26,6 % ;  Vü 103cm  --> oluline kehakaalu korrigeer'),
#     '103'),
#    (Text(text='1,4 kg , KMI 31,6 , RP 29,8 % ,  VÜ 104 cm '), '104'),
#    (Text(text='012 Südamekab ( n prof ) KMI-32  VÜ-104  V/R -140/90 Kolesterool-5,99 Ve'),
#     '104'),
#    (Text(text='aal 97,5 kg , KMI , RP 27,7 % ,  VÜ 104 cm '), '104'),
#    (Text(text='Mõõdetud KMI 30,6 , RP 30,8 % ,  VÜ 104 cm '), '104'),
#    (Text(text=' Vööümbermõõt 104 cm '), '104'),
#    (Text(text='5p Vereproov KMI 28,1Fat 23,7% Vü 104cm Nõustatud'), '104'),
#    (Text(text='TDS säilitused KMI 28,7Fat 27,0% Vü 104 cm RR 157/91 mmHgNõustatud'),
#     '104'),
#    (Text(text='al 69 , pikkus 152 , KMI 29.8 ,  talje suurus 104  organleid ilma patoloogia määra'),
#     '104'),
#    (Text(text='KMI-29  VÜ-105  V/R -150/90 Kolesterool - 6,46 '), '105'),
#    (Text(text='103 ,  vööümber-105 '), '105'),
#    (Text(text=' RR 133/68 mmhgKMI 30,6Fat 24,6% Vü 105cm Nõustatud'), '105'),
#    (Text(text='ikkus : 163 cm ; Kaal : 86 kg ;  Vööümbermõõt : 105 cm  ; KMI : 33'),
#     '105'),
#    (Text(text='tra Teostatud kehaehitusanalüüs- vü-105cm kaal-99kgBMI29.9FAT%26.7%Nõustat'),
#     '105'),
#    (Text(text='2,9 kg , KMI 28,7 , RP 25,0 % ,  VÜ 105 cm '), '105'),
#    (Text(text=' Vü 105cm '), '105'),
#    (Text(text='s 178 cm , rasvaprotsent 27.7 ,  vööümbermõõt 105 cm '), '105'),
#    (Text(text='kaal 102 kg , pikkus 182 cm  vööümbermõõt 105 cm  , puusaümbermõõt 108 cm'),
#     '105'),
#    (Text(text=' VÜ 105  , PÜ 120 - suhe 0,87'), '105'),
#    (Text(text='8,0 kg , KMI 26,1 , RP 32,7 % ,  VÜ 106 cm '), '106'),
#    (Text(text=' Vööümbermõõt-106 sm  / Puusaluu ümbermõõt-100 sm---1'), '106'),
#    (Text(text='8,0 kg , KMI 26,1 , RP 32,7 % ,  VÜ 106 cm '), '106'),
#    (Text(text='012 Südamekab ( prof ) KMI - 40  VÜ-106  V/R-160/90 Kolesterool -5,27 Ve'),
#     '106'),
#    (Text(text='red+säilitused KMI 30,5Fat 26,7% Vü 106cm '), '106'),
#    (Text(text=' VÜ : 106cm '), '106'),
#    (Text(text=' Vööümbermõõt-106 sm  / Puusaluu ümbermõõt-122 sm---0'), '106'),
#    (Text(text='l 110kg pikkus 178 , KMI 34,7 ,  VÜ 106sm '), '106'),
#    (Text(text='-PSATeostatud kehaehitusanalüüs  vü-106.5cm kaal-89.7kgBMI-31.8FAT%-33.9 %'),
#     '106.5'),
#    (Text(text='012 Südamekab ( prof ) KMI - 33  VÜ-107  V/R -130/80 Kolesterool -6,8 Ve'),
#     '107'),
#    (Text(text='aal 82 kg , BMI - 32.85 kg/m2 ,  vööümbermõõt 107 cm '), '107'),
#    (Text(text='RR 132/88 mmHgKMI 32,3Fat 26,5% Vü 107cm Nõustatud'), '107'),
#    (Text(text=' Vööümbermõõt 107cm '), '107'),
#    (Text(text='9,6 kg , RP 33,3 % , KMI 31,4 ,  VÜ 107 cm '), '107'),
#    (Text(text='ndeks ) = 31 ( norm kuni 25 ) ,  vüm 107m '), '107'),
#    (Text(text='õetud vereproov-testost KMI 27,1 Vü 107 cm 3035 - Õe Iseseisev Vastuvõtt , '),
#     '107'),
#    (Text(text='0,8 kg , KMI 29,7 , RP 27,1 % ,  VÜ 108 cm '), '108'),
#    (Text(text='RR 178/101 mmHgKMI 28,3Fat 29,3% Vü 108cm Nõustatud'), '108'),
#    (Text(text='9,9 kg , KMI 30,2 , RP 27,0 % ,  VÜ 108 cm '), '108'),
#    (Text(text=' Vööümbermõõt-108 sm  / Puusaluu ümbermõõt-102 sm---1'), '108'),
#    (Text(text=' Vööümbermõõt-108 sm  / Puusaluu ümbermõõt - 92sm---1'), '108'),
#    (Text(text='2,9 kg , KMI 31,4 , RP 28,3 % ,  VÜ 108 cm '), '108'),
#    (Text(text='kaal 86 , pikkus 176 , KMI 27 ,  VÜ 108 '), '108'),
#    (Text(text='3,9 kg , KMI 29,6 , RP 32,9 % ,  VÜ 108 cm '), '108'),
#    (Text(text='üüsil : KMI 27,6 ; Fat 25,3 % ;  Vü 108cm '), '108'),
#    (Text(text='2,9 kg , KMI 31,4 , RP 28,3 % ,  VÜ 108 cm '), '108'),
#    (Text(text=' Vööümbermõõt 108cm '), '108'),
#    (Text(text='8,0 kg , RP 32,7 % , KMI 29,4 ,  VÜ 108 cm '), '108'),
#    (Text(text='sto Teostatud kehaehitusanalüüs  vü-108.5cm kaal-102.5kgBMI-32.4FAT%-28.8 %'),
#     '108.5'),
#    (Text(text=' VÜM : 109 cm '), '109'),
#    (Text(text='g kaal 119,8 kg pikkus 191,5 cm  VÜ 109 cm  BMI 32'), '109'),
#    (Text(text=' VÜM : 109 cm '), '109'),
#    (Text(text='8,2 kg , KMI 32,3 , RP 28,7 % ,  VÜ 109 cm '), '109'),
#    (Text(text='5,9 kg , KMI 33,1 , RP 27,5 % ,  VÜ 109 cm '), '109'),
#    (Text(text='; rasva 31,6 % , rasva 29,6kg ,  vü 109cm '), '109'),
#    (Text(text='5,4 kg , KMI 34,8 , RP 37,5 % ,  VÜ 109 cm '), '109'),
#    (Text(text=' , kaal 113 riietega , KMI 36 ,  vööümbermõõt 110cm '), '110'),
#    (Text(text='87,5 kg , KMI31,0 , RP 35,2 % ,  VÜ 110 cm '), '110'),
#    (Text(text=' Vü 110cm '), '110'),
#    (Text(text=' kehapikkus 176 cm , KMI 34,5 ,  vööümbermõõt 110 cm '), '110'),
#    (Text(text='3,8 kg , RP 27,7 % , KMI 32,8 ,  VÜ 110 cm '), '110'),
#    (Text(text='RR 169/105 mmHgKMI 29,0Fat 28,6% Vü 110cm Nõustatud'), '110'),
#    (Text(text='6,0 kg , RP 31,2 % , KMI 31,7 ,  VÜ 111 cm '), '111'),
#    (Text(text='1,9 kg , KMI 35,7 , RP 35,7 % ,  VÜ 111 cm '), '111'),
#    (Text(text='Augustis kehakaal 97kg ja  vööümbermõõt 111 cm  , september kehakaal 96kg , vöö'),
#     '111'),
#    (Text(text='5,3 kg , KMI 29,2 , RP 29,1 % ,  VÜ 111 cm '), '111'),
#    (Text(text=' rasva 27,8 % , rasva 27,0 kg ,  vü 111,0cm '), '111'),
#    (Text(text='Fundus 35cm ,  vööümbermõõt 111cm '), '111'),
#    (Text(text='2 , RP 33,4 % , Rmass 31,8 kg ,  VÜ 111 cm '), '111'),
#    (Text(text=' 2kg aastaga ) , Pikkus 159sm ,  VÜ 112sm '), '112'),
#    (Text(text=',2012 Südamekab ( prof ) KMI-37  VÜ-112  V/R -135//85 Kolesterool -5,58 '),
#     '112'),
#    (Text(text='ga + 9.8kg ) , pikkus - 164cm ;  vööümberm - 112cm '), '112'),
#    (Text(text=' rasva 36,8 % , rasva 36,7 kg ,  vü 112cm '), '112'),
#    (Text(text=',2012 Südamekab ( prof ) KMI-35  VÜ-112  V/R -100/70 Kolesterool -6,36 V'),
#     '112'),
#    (Text(text='4 , RP 28,1 % , Rmass 31,5 kg ,  VÜ 112 cm '), '112'),
#    (Text(text='4 , RP 28,1 % , Rmass 31,5 kg ,  VÜ 112 cm '), '112'),
#    (Text(text=' VÜ 112cm '), '112'),
#    (Text(text='aal0106 kg pikkus 182 sm BMI 32  vööümbermõõt 112  g'), '112'),
#    (Text(text='4,4 kg , KMI 28,5 , RP 29,4 % ,  VÜ 112 cm '), '112'),
#    (Text(text=' Vööümbermõõt-112 sm  / Puusaluu ümbermõõt-104 sm---1'), '112'),
#    (Text(text='m/Hg Kaal 103 kg , pikkus 165 ,  vööümbermõõt 113 cm '), '113'),
#    (Text(text='3,8 kg , KMI 32,9 , RP 34,3 % ,  Vü 113 cm '), '113'),
#    (Text(text='2 , keha rasvaprotsent 30.1 % ,  vü-113 '), '113'),
#    (Text(text='Kaal 101,6kg RP%38,3 , KMI 35,2  VÜ 113 cm '), '113'),
#    (Text(text='4p Vereproov KMI 31,3Fat 27,0% Vü 113 cm Nõustatud'), '113'),
#    (Text(text='7,5 kg , KMI 33,9 , RP 32,0 % ,  VÜ 113 cm '), '113'),
#    (Text(text='   : Pikkus 178,5cm kaal 97,5kg  vööümbermõõt 113cm  KMI 34 , RR 132/89mmHg'),
#     '113'),
#    (Text(text='100,4 kg , KMI 30,3 , RP 26 % ,  VÜ 113 cm '), '113'),
#    (Text(text=' , kaal 89,3 . , pikkus 165cm ,  vööümbermõõt 113  Kopsus vesikul hingamiskahin , '),
#     '113'),
#    (Text(text='9,5 kg , KMI 27,0 , RP 28,2 % ,  VÜ 114 cm '), '114'),
#    (Text(text=' Vööümbermõõt 115 cm '), '115'),
#    (Text(text=' VÜ 115 -> 114cm ,'), '115'),
#    (Text(text='9,4 kg , RP 30,8 % , KMI 34,5 ,  VÜ 115 cm '), '115'),
#    (Text(text=' 93 kg , KMI 31,5 , RP 29,3 % ,  VÜ 115 cm '), '115'),
#    (Text(text='9,9 kg , KMI 32,5 , RP 39,4 % ,  VÜ 115 cm '), '115'),
#    (Text(text=' Vööümbermõõt-115 sm  / Puusaluu ümbermõõt-100 sm---1'), '115'),
#    (Text(text=' Vööümbermõõt 115 cm '), '115'),
#    (Text(text='2,9 kg , KMI 32,5 , RP 32,6 % ,  VÜ 115 cm '), '115'),
#    (Text(text=' rasva 28,5 % , rasva 30,1 kg ,  vü 115,5cm '), '115.5'),
#    (Text(text='g/m2 ( cole järgi rasvumine ) ;  vööümbermõõt 116 cm  ( > 90 prots )'),
#     '116'),
#    (Text(text='g/m2 ( cole järgi rasvumine ) ,  vööümbermõõt 116 cm  ( > 90 prots )'),
#     '116'),
#    (Text(text='KMI 32,2 , FAT 29,8 % ,  Vü 116 cm '), '116'),
#    (Text(text='Kaal 119kg , pikkus 159cm ,  vööümbermõõt 116cm '), '116'),
#    (Text(text=' Vööümbermõõt 117 cm  , puusaümbermõõt 129 cm'), '117'),
#    (Text(text='eks ) = 33,5 ( norm kuni 25 ) ,  vüm 117cm '), '117'),
#    (Text(text='es kõrge kaaluga ( KMI = 33,3 ,  Vööümbermõõt 118 cm  ) ja proovida kolesterooli ravi'),
#     '118'),
#    (Text(text=' Vööümbermõõt-118 sm  / Puusaluu ümbermõõt-95 sm---1.'), '118'),
#    (Text(text=',2012 Südamekab ( prof ) KMI-55  VÜ-118  V/R -170/90 Kolesterool -4,5 Ve'),
#     '118'),
#    (Text(text=' VÜ-118 '), '118'),
#    (Text(text='8,0 kg , KMI 33,1 , RP 35,2 % ,  VÜ 118 cm '), '118'),
#    (Text(text=' Vööümbermõõt - 118 cm '), '118'),
#    (Text(text='Patsient on adipoosne ,  vööümbermõõt 119 cm  , tellitud siiski osteoporoosi '),
#     '119'),
#    (Text(text='7,1 kg , KMI 34,2 , RP 29,2 % ,  VÜ 119 cm '), '119'),
#    (Text(text='2,1 kg , KMI 34,5 , RP 39,1 % ,  VÜ 119 cm '), '119'),
#    (Text(text='; rasva 30,0 % , rasva 30,6kg ,  vü 119 cm '), '119'),
#    (Text(text='Adipoosne ,  vööümbermõõt 119 sm  , jalad turseteta , südametooni'),
#     '119'),
#    (Text(text='sed Teostatud kehaehitusanalüüs  vü - 119cm kaal-109.6kgBMI-36.2FAT%-34.3%RR'),
#     '119'),
#    (Text(text='1,3 kg , KMI 35,4 , RP 31,0 % ,  VÜ 119 cm '), '119'),
#    (Text(text=' vööümbermõõt 119 cm  ( üle 90 prots ) V S 5 . 1 mmol'), '119'),
#    (Text(text='etud vereproov KMI 36,3Fat 47,3% Vü 119cm Nõustatud'), '119'),
#    (Text(text=' RR 146/86 mmHgKMI 32,8Fat 30,1% Vü 119cm Nõustatud'), '119'),
#    (Text(text='1 kg , pikkus 163 cm , BMI 38 ,  vööümbermõõt 120 cm '), '120'),
#    (Text(text=' Vü 120 cm '), '120'),
#    (Text(text='5,5 kg , KMI 36,3 , RP 37,9 % ,  VÜ 120 cm '), '120'),
#    (Text(text='7 kg , pikkus 182 cm , KMI 38 ,  vööümbermõõt 120 cm '), '120'),
#    (Text(text='120kg-180sm  vööümb -120sm  KMI-37 ei suitseta Score 2 %'),
#     '120'),
#    (Text(text=' RR 141/81 mmHgKMI 34,4Fat 36,6% Vü 121 cm Nõustatud'), '121'),
#    (Text(text='0kg , Pikkus 165sm , KMI 47,8 ,  VÜ 121sm '), '121'),
#    (Text(text='e RR 170/107 mmHgPulss 87 x/min  Vööümbermõõt : 122 cm Tehtud kehaehituse aparaatanalüü'),
#     '122'),
#    (Text(text='kaal 115.7 pikkus 168 , KMI41.8  vööümbermõõt 124 cm '), '124'),
#    (Text(text=' KMI 44 - III astme rasvumine ,  vööümbermõõt 124cm '), '124'),
#    (Text(text='7,7 kg , KMI 37,1 , RP 31,4 % ,  VÜ 124 cm '), '124'),
#    (Text(text=' rasva 42,7 % , rasva 49,9 kg ,  vü 125cm '), '125'),
#    (Text(text='8,8 kg , KMI 35,5 , RP 35,4 % ,  VÜ 126 cm '), '126'),
#    (Text(text='9,5 kg , KMI 40,4 , RP 35,5 % ,  VÜ 127 cm '), '127'),
#    (Text(text='125kg , pikkus 167cm , BMI 45 ,  vööümbermõõt 127 cm '), '127'),
#    (Text(text='Kaal 102kg ,  vööümbermõõt 127cm '), '127'),
#    (Text(text='7,7 kg , KMI 34,0 , RP 35,5 % ,  VÜ 128 cm '), '128'),
#    (Text(text=' Vööümbermõõt 130cm '), '130'),
#    (Text(text='Tegelikult kaalub 128 kg ja  VÜ 130 cm '), '130'),
#    (Text(text=' VÜ 130 cm '), '130'),
#    (Text(text='RR 150/100 mmHgKMI 42,0Fat 40,3% Vü 130cm Nõustatud'), '130'),
#    (Text(text=' Vööümbermõõt 132 cm  EKG-s siinurütm , üksikud harva'), '132'),
#    (Text(text='HPM säilitused KMI 33,0Fat 32,9% Vü 132cm Nõustatud'), '132'),
#    (Text(text='5,2 kg , KMI 39,9 , RP 32,2 % ,  VÜ 132 cm '), '132'),
#    (Text(text='8 kg , pikkus 167 cm , KMI 42 ,  vööümbermõõt 132 cm '), '132'),
#    (Text(text=' Vööümbermõõt-135 sm  / Puusaluu ümbermõõt-100 sm---1'), '135'),
#    (Text(text='RR korras  vööümbermõõt 135 cm '), '135'),
#    (Text(text='s 172 , kaal127,5 --> 126,9 KMI  VÜ 135 '), '135'),
#    (Text(text=' vööümbermõõt 136 cm  ( üle 90 . prots )'), '136'),
#    (Text(text=' Vööümbermõõt 138cm '), '138'),
#    (Text(text='nalüüsi kodust KMI 45,0Fat 39,5% Vü 139cm Nõustatud 3035 - Õe Iseseisev Va'),
#     '139'),
#    (Text(text='iis ~ 150kg )) , pikkus 182cm ,  VÜ = 143,5cm  , KMI = ~ 45,5'),
#     '143.5'),
#    (Text(text=',2012 Südamekab ( prof ) KMI-46  VÜ-147  V/R -160/95 Veresuhkur -6,0 kol'),
#     '147'),
#    (Text(text='Kaal 143kg , pikkus 170cm ,  vööümbermõõt 150cm  , BMI 49 .'),
#     '150'),
#    (Text(text=' kg , pikkus 182 cm , BMI 160 ,  vööümbermõõt 167 cm '),
#     '167')],
#   [(Text(text='1  VÜ - 1  üh Lühitoimelist insulini'), '1'),
#    (Text(text=' KMI langenud 1.2 ühiku võrra ,  vööümbermõõt - 2 cm '), '2'),
#    (Text(text='natukene langenud ( -0,5 kg ) ,  vööümbermõõt - 2 cm '), '2'),
#    (Text(text=' KMI langenud 1,2 ühiku võrra ,  vööümbermõõt -3 cm '), '3'),
#    (Text(text='Tänaseks - 4kg ja  VÜM - 3 cm '), '3'),
#    (Text(text=' KMI langenud 0,3 ühiku võrra ,  vööümbermõõt - 5 cm  Toidupäevik ei ole täidetud'),
#     '5'),
#    (Text(text='! Ilmselt metaboolne sündroom (  VÜ 05.2011  - 106 cm )'),
#     '5.2011'),
#    (Text(text='sti ja positiivse dünaamikaga (  vööümbermõõt -6cm  )'), '6')],
#   [(Text(text='e koormus , kaalu langetamine (  vööümbermõõt 94cm  )'), '94'),
#    (Text(text=', Kaal 94 , pikkus 168 , suures  talje 113  , KMI 33 , nahk on puhas , orga'),
#     '113')],
#   []]}

# %%
metrics_prec = {}
new_metrics_rec = {}
#metrics_counts = 
for el, metrics in tagged_texts.items():
    metrics_prec[el] = {}
    prec = len(metrics[0])/(len(metrics[0]) + len(metrics[1]))
    rec = len(metrics[0])/(len(metrics[0]) + len(metrics[2]))
    metrics_prec[el]['new_on_old_prec'] = prec
    new_metrics_rec[el]= rec

for el, metrics in tagged_texts_old.items():
    prec = len(metrics[0])/(len(metrics[0]) + len(metrics[1]))
    metrics_prec[el]['old_on_old_prec']= prec

# %%
metrics_prec
# Out:
# {'KAAL': {'new_on_old_prec': 0.9774368231046932,
#   'old_on_old_prec': 0.9446666666666667},
#  'KREATINIIN': {'new_on_old_prec': 1.0, 'old_on_old_prec': 1.0},
#  'PIKKUS': {'new_on_old_prec': 0.9953488372093023, 'old_on_old_prec': 0.963},
#  'TRIGLÜTSERIIDID': {'new_on_old_prec': 1.0, 'old_on_old_prec': 1.0},
#  'PULSS': {'new_on_old_prec': 0.9844559585492227, 'old_on_old_prec': 0.94},
#  'PSA': {'new_on_old_prec': 0.9851116625310173, 'old_on_old_prec': 0.988},
#  'KUSIHAPE': {'new_on_old_prec': 0.9970674486803519, 'old_on_old_prec': 0.986},
#  'KOLESTEROOL': {'new_on_old_prec': 1.0, 'old_on_old_prec': 0.978},
#  'KMI': {'new_on_old_prec': 1.0, 'old_on_old_prec': 1.0},
#  'LDL-KOLESTEROOL': {'new_on_old_prec': 1.0, 'old_on_old_prec': 1.0},
#  'ALAT': {'new_on_old_prec': 1.0, 'old_on_old_prec': 1.0},
#  'HDL-KOLESTEROOL': {'new_on_old_prec': 1.0, 'old_on_old_prec': 1.0},
#  'HEMOGLOBIIN': {'new_on_old_prec': 0.9855818743563337,
#   'old_on_old_prec': 0.959},
#  'GLÜKOHEMOGLOBIIN': {'new_on_old_prec': 0.9947089947089947,
#   'old_on_old_prec': 0.996},
#  'ASAT': {'new_on_old_prec': 1.0, 'old_on_old_prec': 1.0},
#  'VÖÖÜMBERMÕÕT': {'new_on_old_prec': 0.9838383838383838,
#   'old_on_old_prec': 0.984}}

# %%
df2 = pd.DataFrame.from_dict(metrics_prec).T

# %%
df3 = pd.concat([df, df2], axis = 1).reindex(df.index)

# %%
df3
# Out:
#                   new_on_new_prec  new_on_old_prec  old_on_old_prec
# BILIRUBIIN                   0.92              NaN              NaN
# PIKKUS                       0.93         0.995349         0.963000
# KUSIHAPE                     1.00         0.997067         0.986000
# ALAT                         0.99         1.000000         1.000000
# GLÜKOOS                      0.94              NaN              NaN
# HEMOGLOBIIN                  0.99         0.985582         0.959000
# KAAL                         0.97         0.977437         0.944667
# KMI                          0.95         1.000000         1.000000
# LDL-KOLESTEROOL              1.00         1.000000         1.000000
# LEUKOTSÜÜDID                 0.98              NaN              NaN
# LUUTIHEDUS                   1.00              NaN              NaN
# MCV                          1.00              NaN              NaN
# PULSS                        0.91         0.984456         0.940000
# PSA                          0.98         0.985112         0.988000
# VÖÖÜMBERMÕÕT                 1.00         0.983838         0.984000
# KREATINIIN                   0.98         1.000000         1.000000
# GLÜKOHEMOGLOBIIN             0.97         0.994709         0.996000
# KOLESTEROOL                  0.99         1.000000         0.978000
# ASAT                         1.00         1.000000         1.000000
# HDL-KOLESTEROOL              1.00         1.000000         1.000000
# TRIGLÜTSERIIDID              1.00         1.000000         1.000000

# %% [markdown]
# ### Recall 2020

# %%
path = '../measurements_quality/labelled_recall'

# %%
os.listdir(path)
# Out:
# ['vöö.csv',
#  'hemoglobiin.csv',
#  'alat_.csv',
#  'glükoos.csv',
#  'kaal.csv',
#  'leuko.csv',
#  'psa.csv',
#  'bilirubiin.csv',
#  'kmi.csv',
#  'ldlkol.csv',
#  'pikkus.csv',
#  'pulss.csv']

# %%
fname_to_mo = {'vöö.csv': 'VÖÖÜMBERMÕÕT', 'hemoglobiin.csv': 'HEMOGLOBIIN', 'alat_.csv': 'ALAT', 'glükoos.csv': 'GLÜKOOS', 'leuko.csv': 'LEUKOTSÜÜDID', 'psa.csv': 'PSA', 'bilirubiin.csv': 'BILIRUBIIN', 'kmi.csv': 'KMI', 'ldlkol.csv': 'LDL-KOLESTEROOL', 'pikkus.csv': 'PIKKUS', 'pulss.csv': 'PULSS', 'kaal.csv': 'KAAL'}

# %%
false_neg_counts = {}
for fname in os.listdir(path):
    with open(os.path.join(path, fname), 'r') as fin:
        mo = fname_to_mo[fname]
        false_neg_counts[mo] = 0
        reader = csv.reader(fin)
        for row in reader:
            if row[3] == 'v' or row[3] == '?' or row[3] == 'n':
                false_neg_counts[mo] += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5d1b533351be> in <module>
#       1 false_neg_counts = {}
# ----> 2 for fname in os.listdir(path):
#       3     with open(os.path.join(path, fname), 'r') as fin:
#       4         mo = fname_to_mo[fname]
#       5         false_neg_counts[mo] = 0
#
# NameError: name 'os' is not defined

# %%
measurement_counts = {'PULSS': 118594,
             'HEMOGLOBIIN': 72684,
             'LEUKOTSÜÜDID': 69461,
             'MCV': 53533,
             'GLÜKOOS': 45378,
             'ALAT': 28023,
             'LDL-KOLESTEROOL': 11577,
             'PSA': 12515,
             'BILIRUBIIN': 11103,
             'KAAL': 33476,
             'PIKKUS': 26696,
             'KMI': 18262,
             'VÖÖÜMBERMÕÕT': 3941}

# %%
token_only_counts = {'PULSS': 104579,
             'BILIRUBIIN': 38015,
             'HEMOGLOBIIN': 20184,
             'VÖÖÜMBERMÕÕT': 1081,
             'LEUKOTSÜÜDID': 31749,
             'PIKKUS': 45882,
             'GLÜKOOS': 34823,
             'ALAT': 6044,
             'KAAL': 36812,
             'MCV': 4101,
             'LDL-KOLESTEROOL': 1079,
             'PSA': 9345,
             'KMI': 2562}

# %%
tp_counts
# Out:
# Counter({'BILIRUBIIN': 92,
#          'PIKKUS': 93,
#          'KUSIHAPE': 100,
#          'ALAT': 99,
#          'GLÜKOOS': 94,
#          'HEMOGLOBIIN': 99,
#          'KAAL': 97,
#          'KMI': 95,
#          'LDL-KOLESTEROOL': 100,
#          'LEUKOTSÜÜDID': 98,
#          'LUUTIHEDUS': 100,
#          'MCV': 100,
#          'PULSS': 91,
#          'PSA': 98,
#          'VÖÖÜMBERMÕÕT': 100,
#          'KREATINIIN': 98,
#          'GLÜKOHEMOGLOBIIN': 97,
#          'KOLESTEROOL': 99,
#          'ASAT': 100,
#          'HDL-KOLESTEROOL': 100,
#          'TRIGLÜTSERIIDID': 100})

# %%
false_neg_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d9df5346bd8> in <module>
# ----> 1 false_neg_counts
#
# NameError: name 'false_neg_counts' is not defined

# %%
measurement_to_token_ratio = {}
for k, v in measurement_counts.items():
    ratio = v/token_only_counts[k]
    measurement_to_token_ratio[k] = ratio

# %%
measurement_to_token_ratio
# Out:
# {'PULSS': 1.1340135208789528,
#  'HEMOGLOBIIN': 3.6010701545778834,
#  'LEUKOTSÜÜDID': 2.1878169391161926,
#  'MCV': 13.0536454523287,
#  'GLÜKOOS': 1.3031042701662694,
#  'ALAT': 4.636499007279947,
#  'LDL-KOLESTEROOL': 10.72937905468026,
#  'PSA': 1.3392188336008561,
#  'BILIRUBIIN': 0.2920689201630935,
#  'KAAL': 0.9093773769423015,
#  'PIKKUS': 0.5818403731310754,
#  'KMI': 7.128024980483997,
#  'VÖÖÜMBERMÕÕT': 3.6456984273820536}

# %%
recalls = {}
for k, v in false_neg_counts.items():
    fn = v
    tp = tp_counts[k]*measurement_to_token_ratio[k]
    recall = tp/(tp+fn)
    recalls[k] = recall

# %%
recalls
# Out:
# {'VÖÖÜMBERMÕÕT': 0.9358266547937073,
#  'HEMOGLOBIIN': 0.9295969193420116,
#  'ALAT': 0.9622652111343849,
#  'GLÜKOOS': 0.7227004515086121,
#  'KAAL': 0.6671951344798537,
#  'LEUKOTSÜÜDID': 0.9640297571082412,
#  'PSA': 0.8454041013268999,
#  'BILIRUBIIN': 0.6267815987570841,
#  'KMI': 0.8908128014064952,
#  'LDL-KOLESTEROOL': 0.9218171351130554,
#  'PIKKUS': 0.7401217354909218,
#  'PULSS': 0.7010772707754491}

# %%
recalls_2014 = {'PULSS': 0.77,
             #'BILIRUBIIN': 38015,
             'HEMOGLOBIIN': 0.96,
             'VÖÖÜMBERMÕÕT': 0.36,
             #'LEUKOTSÜÜDID': 31749,
             'PIKKUS': 0.81,
             'GLÜKOOS': 0.57,
             'ALAT': 0.96,
             'KAAL': 0.75,
             #'MCV': 4101,
             'LDL-KOLESTEROOL': 0.88,
                'HDL-KOLESTEROOL': 0.83,
             'PSA': 0.96,
               'KREATINIIN': 0.93,
               'GLÜKOHEMOGLOBIIN': 0.87,
               'KOLESTEROOL': 0.9,
               'KMI': 0.66,
               'ASAT': 0.97,
               'KUSIHAPE': 0.95,
               'TRIGLÜTSERIIDID': 0.82}

# %%
recalls_2014
# Out:
# {'PULSS': 0.77,
#  'HEMOGLOBIIN': 0.96,
#  'VÖÖÜMBERMÕÕT': 0.36,
#  'PIKKUS': 0.81,
#  'GLÜKOOS': 0.57,
#  'ALAT': 0.96,
#  'KAAL': 0.75,
#  'LDL-KOLESTEROOL': 0.88,
#  'HDL-KOLESTEROOL': 0.83,
#  'PSA': 0.96,
#  'KREATINIIN': 0.93,
#  'GLÜKOHEMOGLOBIIN': 0.87,
#  'KOLESTEROOL': 0.9,
#  'KMI': 0.66,
#  'ASAT': 0.97,
#  'KUSIHAPE': 0.95,
#  'TRIGLÜTSERIIDID': 0.82}

# %%
new_metrics_rec
# Out:
# {'KAAL': 0.7642907551164432,
#  'KREATINIIN': 0.696,
#  'PIKKUS': 0.8888888888888888,
#  'TRIGLÜTSERIIDID': 0.756,
#  'PULSS': 0.6063829787234043,
#  'PSA': 0.8036437246963563,
#  'KUSIHAPE': 0.6896551724137931,
#  'KOLESTEROOL': 0.8650306748466258,
#  'KMI': 0.912,
#  'LDL-KOLESTEROOL': 0.532,
#  'ALAT': 0.63,
#  'HDL-KOLESTEROOL': 0.53,
#  'HEMOGLOBIIN': 0.9979144942648592,
#  'GLÜKOHEMOGLOBIIN': 0.7550200803212851,
#  'ASAT': 0.652,
#  'VÖÖÜMBERMÕÕT': 0.9898373983739838}

# %%
df3['new_on_new_rec'] = pd.Series(recalls)

# %%
df3['old_on_old_rec'] = pd.Series(recalls_2014)

# %%
df3['new_on_old_rec'] = pd.Series(new_metrics_rec)

# %%
df3
# Out:
#                   new_on_new_prec  new_on_old_prec  old_on_old_prec  \
# BILIRUBIIN                   0.92              NaN              NaN
# PIKKUS                       0.93         0.995349         0.963000
# KUSIHAPE                     1.00         0.997067         0.986000
# ALAT                         0.99         1.000000         1.000000
# GLÜKOOS                      0.94              NaN              NaN
# HEMOGLOBIIN                  0.99         0.985582         0.959000
# KAAL                         0.97         0.977437         0.944667
# KMI                          0.95         1.000000         1.000000
# LDL-KOLESTEROOL              1.00         1.000000         1.000000
# LEUKOTSÜÜDID                 0.98              NaN              NaN
# LUUTIHEDUS                   1.00              NaN              NaN
# MCV                          1.00              NaN              NaN
# PULSS                        0.91         0.984456         0.940000
# PSA                          0.98         0.985112         0.988000
# VÖÖÜMBERMÕÕT                 1.00         0.983838         0.984000
# KREATINIIN                   0.98         1.000000         1.000000
# GLÜKOHEMOGLOBIIN             0.97         0.994709         0.996000
# KOLESTEROOL                  0.99         1.000000         0.978000
# ASAT                         1.00         1.000000         1.000000
# HDL-KOLESTEROOL              1.00         1.000000         1.000000
# TRIGLÜTSERIIDID              1.00         1.000000         1.000000
#
#                   new_on_new_rec  old_on_old_rec  new_on_old_rec
# BILIRUBIIN              0.626782             NaN             NaN
# PIKKUS                  0.740122            0.81        0.888889
# KUSIHAPE                     NaN            0.95        0.689655
# ALAT                    0.962265            0.96        0.630000
# GLÜKOOS                 0.722700            0.57             NaN
# HEMOGLOBIIN             0.929597            0.96        0.997914
# KAAL                    0.667195            0.75        0.764291
# KMI                     0.890813            0.66        0.912000
# LDL-KOLESTEROOL         0.921817            0.88        0.532000
# LEUKOTSÜÜDID            0.964030             NaN             NaN
# LUUTIHEDUS                   NaN             NaN             NaN
# MCV                          NaN             NaN             NaN
# PULSS                   0.701077            0.77        0.606383
# PSA                     0.845404            0.96        0.803644
# VÖÖÜMBERMÕÕT            0.935827            0.36        0.989837
# KREATINIIN                   NaN            0.93        0.696000
# GLÜKOHEMOGLOBIIN             NaN            0.87        0.755020
# KOLESTEROOL                  NaN            0.90        0.865031
# ASAT                         NaN            0.97        0.652000
# HDL-KOLESTEROOL              NaN            0.83        0.530000
# TRIGLÜTSERIIDID              NaN            0.82        0.756000

# %%
df3['f1_2020'] = 2*(df3['new_on_new_prec']*df3['new_on_new_rec'])/(df3['new_on_new_prec']+df3['new_on_new_rec'])

# %%
df3
# Out:
#                   new_on_new_prec  new_on_old_prec  old_on_old_prec  \
# BILIRUBIIN                   0.92              NaN              NaN
# PIKKUS                       0.93         0.995349         0.963000
# KUSIHAPE                     1.00         0.997067         0.986000
# ALAT                         0.99         1.000000         1.000000
# GLÜKOOS                      0.94              NaN              NaN
# HEMOGLOBIIN                  0.99         0.985582         0.959000
# KAAL                         0.97         0.977437         0.944667
# KMI                          0.95         1.000000         1.000000
# LDL-KOLESTEROOL              1.00         1.000000         1.000000
# LEUKOTSÜÜDID                 0.98              NaN              NaN
# LUUTIHEDUS                   1.00              NaN              NaN
# MCV                          1.00              NaN              NaN
# PULSS                        0.91         0.984456         0.940000
# PSA                          0.98         0.985112         0.988000
# VÖÖÜMBERMÕÕT                 1.00         0.983838         0.984000
# KREATINIIN                   0.98         1.000000         1.000000
# GLÜKOHEMOGLOBIIN             0.97         0.994709         0.996000
# KOLESTEROOL                  0.99         1.000000         0.978000
# ASAT                         1.00         1.000000         1.000000
# HDL-KOLESTEROOL              1.00         1.000000         1.000000
# TRIGLÜTSERIIDID              1.00         1.000000         1.000000
#
#                   new_on_new_rec  old_on_old_rec  new_on_old_rec   f1_2020
# BILIRUBIIN              0.626782             NaN             NaN  0.745599
# PIKKUS                  0.740122            0.81        0.888889  0.824267
# KUSIHAPE                     NaN            0.95        0.689655       NaN
# ALAT                    0.962265            0.96        0.630000  0.975936
# GLÜKOOS                 0.722700            0.57             NaN  0.817151
# HEMOGLOBIIN             0.929597            0.96        0.997914  0.958848
# KAAL                    0.667195            0.75        0.764291  0.790595
# KMI                     0.890813            0.66        0.912000  0.919455
# LDL-KOLESTEROOL         0.921817            0.88        0.532000  0.959318
# LEUKOTSÜÜDID            0.964030             NaN             NaN  0.971949
# LUUTIHEDUS                   NaN             NaN             NaN       NaN
# MCV                          NaN             NaN             NaN       NaN
# PULSS                   0.701077            0.77        0.606383  0.791992
# PSA                     0.845404            0.96        0.803644  0.907740
# VÖÖÜMBERMÕÕT            0.935827            0.36        0.989837  0.966850
# KREATINIIN                   NaN            0.93        0.696000       NaN
# GLÜKOHEMOGLOBIIN             NaN            0.87        0.755020       NaN
# KOLESTEROOL                  NaN            0.90        0.865031       NaN
# ASAT                         NaN            0.97        0.652000       NaN
# HDL-KOLESTEROOL              NaN            0.83        0.530000       NaN
# TRIGLÜTSERIIDID              NaN            0.82        0.756000       NaN

# %%
df3['f1_2014'] = 2*(df3['old_on_old_prec']*df3['old_on_old_rec'])/(df3['old_on_old_prec']+df3['old_on_old_rec'])

# %%
df3.sort_values(by=['f1_2020'], ascending = False)
# Out:
#                   new_on_new_prec  new_on_old_prec  old_on_old_prec  \
# ALAT                         0.99         1.000000         1.000000
# LEUKOTSÜÜDID                 0.98              NaN              NaN
# VÖÖÜMBERMÕÕT                 1.00         0.983838         0.984000
# LDL-KOLESTEROOL              1.00         1.000000         1.000000
# HEMOGLOBIIN                  0.99         0.985582         0.959000
# KMI                          0.95         1.000000         1.000000
# PSA                          0.98         0.985112         0.988000
# PIKKUS                       0.93         0.995349         0.963000
# GLÜKOOS                      0.94              NaN              NaN
# PULSS                        0.91         0.984456         0.940000
# KAAL                         0.97         0.977437         0.944667
# BILIRUBIIN                   0.92              NaN              NaN
# KUSIHAPE                     1.00         0.997067         0.986000
# LUUTIHEDUS                   1.00              NaN              NaN
# MCV                          1.00              NaN              NaN
# KREATINIIN                   0.98         1.000000         1.000000
# GLÜKOHEMOGLOBIIN             0.97         0.994709         0.996000
# KOLESTEROOL                  0.99         1.000000         0.978000
# ASAT                         1.00         1.000000         1.000000
# HDL-KOLESTEROOL              1.00         1.000000         1.000000
# TRIGLÜTSERIIDID              1.00         1.000000         1.000000
#
#                   new_on_new_rec  old_on_old_rec  new_on_old_rec   f1_2020  \
# ALAT                    0.962265            0.96        0.630000  0.975936
# LEUKOTSÜÜDID            0.964030             NaN             NaN  0.971949
# VÖÖÜMBERMÕÕT            0.935827            0.36        0.989837  0.966850
# LDL-KOLESTEROOL         0.921817            0.88        0.532000  0.959318
# HEMOGLOBIIN             0.929597            0.96        0.997914  0.958848
# KMI                     0.890813            0.66        0.912000  0.919455
# PSA                     0.845404            0.96        0.803644  0.907740
# PIKKUS                  0.740122            0.81        0.888889  0.824267
# GLÜKOOS                 0.722700            0.57             NaN  0.817151
# PULSS                   0.701077            0.77        0.606383  0.791992
# KAAL                    0.667195            0.75        0.764291  0.790595
# BILIRUBIIN              0.626782             NaN             NaN  0.745599
# KUSIHAPE                     NaN            0.95        0.689655       NaN
# LUUTIHEDUS                   NaN             NaN             NaN       NaN
# MCV                          NaN             NaN             NaN       NaN
# KREATINIIN                   NaN            0.93        0.696000       NaN
# GLÜKOHEMOGLOBIIN             NaN            0.87        0.755020       NaN
# KOLESTEROOL                  NaN            0.90        0.865031       NaN
# ASAT                         NaN            0.97        0.652000       NaN
# HDL-KOLESTEROOL              NaN            0.83        0.530000       NaN
# TRIGLÜTSERIIDID              NaN            0.82        0.756000       NaN
#
#                    f1_2014
# ALAT              0.979592
# LEUKOTSÜÜDID           NaN
# VÖÖÜMBERMÕÕT      0.527143
# LDL-KOLESTEROOL   0.936170
# HEMOGLOBIIN       0.959500
# KMI               0.795181
# PSA               0.973799
# PIKKUS            0.879898
# GLÜKOOS                NaN
# PULSS             0.846550
# KAAL              0.836153
# BILIRUBIIN             NaN
# KUSIHAPE          0.967665
# LUUTIHEDUS             NaN
# MCV                    NaN
# KREATINIIN        0.963731
# GLÜKOHEMOGLOBIIN  0.928746
# KOLESTEROOL       0.937380
# ASAT              0.984772
# HDL-KOLESTEROOL   0.907104
# TRIGLÜTSERIIDID   0.901099
